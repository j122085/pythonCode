# %%
# from
#  snownlp import
#  SnowNLP
# s = SnowNLP(u'一次满意的购物')
# s.words
# 1) s.words        词语
# 2) s.sentences   句子
# 3) s.sentiments 情感偏向,0-1之间的浮点数，越靠近1越积极
# 4) s.pinyin         转为拼音
# 5) s.han             转为简体
# 6) s.keywords(n) 提取关键字,n默认为5
# 7) s.summary(n)  提取摘要,n默认为5
# 8) s.tf                   计算term frequency词频
# 9) s.idf                 计算inverse document frequency逆向文件频率
# 10) s.sim(doc,index)          计算相似度

# %%
from snownlp import SnowNLP

# %%
s = SnowNLP('这个东西真心很赞')

# %%
s.words
# Out:
# ['这个', '东西', '真心', '很', '赞']

# %%
s.tags

# %%
s.sentiments
# Out:
# 0.9769551298267365

# %%
s.pinyin
# Out:
# ['zhe', 'ge', 'dong', 'xi', 'zhen', 'xin', 'hen', 'zan']

# %%
s = SnowNLP(u'「繁體字」「繁體中文」的叫法在臺灣亦很常見。')

# %%
s.han
# Out:
# '「繁体字」「繁体中文」的叫法在台湾亦很常见。'

# %%
text = u'''
自然语言处理是计算机科学领域与人工智能领域中的一个重要方向。
它研究能实现人与计算机之间用自然语言进行有效通信的各种理论和方法。
自然语言处理是一门融语言学、计算机科学、数学于一体的科学。
因此，这一领域的研究将涉及自然语言，即人们日常使用的语言，
所以它与语言学的研究有着密切的联系，但又有重要的区别。
自然语言处理并不是一般地研究自然语言，
而在于研制能有效地实现自然语言通信的计算机系统，
特别是其中的软件系统。因而它是计算机科学的一部分。
'''

# %%
s = SnowNLP(text)

# %%
s.keywords(3)
# Out:
# ['语言', '自然', '计算机']

# %%
s.summary(3)
# Out:
# ['因而它是计算机科学的一部分',
#  '自然语言处理是计算机科学领域与人工智能领域中的一个重要方向',
#  '自然语言处理是一门融语言学、计算机科学、数学于一体的科学']

# %%
s.sentences
# Out:
# ['自然语言处理是计算机科学领域与人工智能领域中的一个重要方向',
#  '它研究能实现人与计算机之间用自然语言进行有效通信的各种理论和方法',
#  '自然语言处理是一门融语言学、计算机科学、数学于一体的科学',
#  '因此',
#  '这一领域的研究将涉及自然语言',
#  '即人们日常使用的语言',
#  '所以它与语言学的研究有着密切的联系',
#  '但又有重要的区别',
#  '自然语言处理并不是一般地研究自然语言',
#  '而在于研制能有效地实现自然语言通信的计算机系统',
#  '特别是其中的软件系统',
#  '因而它是计算机科学的一部分']

# %%
s = SnowNLP([[u'这篇', u'文章', u'文章', u'文章'],
[u'那篇', u'论文'],
[u'这个']])

# %%
s.tf
# Out:
# [{'文章': 3, '这篇': 1}, {'论文': 1, '那篇': 1}, {'这个': 1}]

# %%
s.idf
# Out:
# {'文章': 2.5649493574615363,
#  '论文': 2.5649493574615363,
#  '这个': -2.001480000210124,
#  '这篇': 2.5649493574615363,
#  '那篇': 2.5649493574615363}

# %%
s.sim([u'文章'])
# Out:
# [-0.7567787018755419, -0.4836218923228314, 0]

# %%
import json
with open(r'D:\Data\JsonData\TainanFood\final_tainan.json') as f:
    rawdata=json.load(f)
# sampleText= rawdata[0]['comment'][0]['content']
sampleText=','.join([i['content'] for i in rawdata[2]['comment']])
# sampleTextlist=[i['content'] for i in rawdata[0]['comment']]

# %%
from snownlp import SnowNLP
s = SnowNLP(sampleText)

# %%
s.sentiments
# Out:
# 0.0

# %%
s.keywords(10)
# Out:
# ['不', '來', '吃', '這', '南', '還', '粥', '人', '台', '點']

# %%
s.summary(1)[0]
# Out:
# '真的是不夠不夠啦~~~女孩出沒地點,又一大早來台南覓食之前開車五點半來沒有開這次五點多開過來就真的開了太開心了終於可以吃到這間在台南很有名的阿堂鹹粥一早就好多人來光顧看來名店的生意真的是搶搶滾菜單好像有漲價了我是看店家的價目表有改過第一次來所以我也不是很清楚醬料我今日的早餐來了一早就是要吃好好豐盛早餐魚湯是台南早餐最佳選擇蝦仁飯飯量上個人覺得不多啦可能我要點個兩碗才吃得飽應該要再點個小菜才是魚肚湯一整片的大魚肚熱騰騰的魚湯很適合天冷的氣候吃終於吃到了這間台南大家愛的阿堂鹹粥來台南一定要來這間品嘗,總算可以吃得到阿堂鹹粥了,話說阿堂鹹粥不知在我筆記本裡躺了几年,一直没機會到台南吃,原因不外乎是阿堂名氣太大,總是人潮不斷,一定要排隊,再來是附近很難停車,老公最討厭找不到停車位了,所以通常都不了了知.這天可以吃得到,完全是老公佛心來著,再來是前往的時間,剛好是台南正逢登革熱嚴重的時間,所以...遊客有少了一點.台南三大鹹粥為阿堂鹹粥,阿憨鹹粥跟悅津鹹粥,我看來看去,總是特愛阿堂,某天經過,這人潮~~你說不吃行嗎??几乎不用等待是真的,找了空桌坐下來就點餐,餐點很快速送上來啊.在漁業工作的人,一定會吃魚頭,老公特地點來吃看看,没有腥味,而且滷的很入味,還蠻好吃的,不死鹹.油條是我點的,吃鹹粥怎能不點來加呢,加入油條,油條浸濕鹹粥的味道,很好吃啊,我超愛的.古早味香腸,寶貝愛吃,我倒覺得還好,肥肉有點多.鹹粥上桌,我超愛這種鹹粥的,有點像飯湯,我老公則說這是湯泡飯,有點忘了點的是綜合鹹粥還是虱目鹹粥,上桌就聞到鹹粥味,尤其是上頭的油蔥味.裡面不少虱目魚肉跟蚵,喝起來好順口,一口接著一口,很有飽足感,我喜歡,不過如果没記錯,價格有點小貴,不過如果再回到台南,應該是會回訪的小吃.阿堂鹹粥台南市西門路一段728號週一至週日5:00~~12:00(週二公休)路邊停車,收現金(以上純屬個人當天食後心得,並非代表所有人),阿堂鹹粥有名到應該無人不知無人不曉吧'

# %%
s.sentences
# Out:
# ['簡單、傳統的安平豆花',
#  '純白的豆花特別的挑逗我們的胃口',
#  '安平',
#  '兼具了台南傳統與現代的一個區域',
#  '而作為安平代表的傳統美食',
#  '一如我們所知的就是安平豆花與周氏蝦捲了',
#  '今天',
#  '帶點炎熱的天氣',
#  '是來點清涼降火冰品的好日子',
#  '當然是來喊個豆花消暑了',
#  '而吃安平豆花當然是要去最著名的同記安平豆花',
#  '同記安平豆花光是在安平就有兩個店面',
#  '相距只有一公里左右',
#  '今天我們來到的是總店',
#  '雖然是平日下午',
#  '但店內一副忙碌的景象',
#  '剛有客人離開',
#  '趕緊搶佔一桌',
#  '店內用的是原木的大張長桌以及長椅',
#  '很有古風呢',
#  '牆上擺的是這些年來到過安平豆花的名人',
#  '真的是不少',
#  '同記安平豆花在安平已經有四十多年的歷史了',
#  '取名「同」記是因為最早的創始人黃慶同名字中有個同字',
#  '從小推車一路叫賣開始',
#  '到現在成為台南十大傳統名產之一',
#  '其中艱辛不足與外人道(所以我們當然不知道了',
#  '跳過)',
#  '從1993年成立店面後',
#  '原本大家稱呼的安平豆花也正式的掛上了「同記」的前綴了',
#  '不過雖然安平區的豆花店逐漸變多',
#  '但是大家只要說到安平豆花',
#  '就知道是指同記安平豆花說',
#  '快快來點豆花了',
#  '種類並不是非常多',
#  '但是道道都是經典',
#  '我們選了最正宗、最傳統的紅豆豆花跟綠豆豆花各一碗',
#  '一切依古法精製',
#  '非基因改造有機黃豆製作',
#  '光看成色就令人心動',
#  '紅豆部分',
#  '則是由來自屏東萬丹的極品紅豆',
#  '經過數小時的熬煮後',
#  '以最佳的紅豆香氣呈現在我們眼前',
#  '好吃',
#  '加點一碗紅豆豆花',
#  '每顆紅豆都保持著完整的外觀',
#  '入口都很有口感說',
#  '每一口豆花的口感都是軟嫩細緻',
#  '入口傳統的黃豆香氣',
#  '手工製作跟用洋菜粉勾芡出來的口感就是不一樣',
#  '另外綠豆豆花則除了軟透心的綠豆外',
# ...

# %%
from snownlp import seg

# %%
from snownlp import seg
seg.train(r'D:\Anaconda3\Lib\site-packages\snownlp\seg\data.txt')
seg.save('seg.marshal')

# %%
from snownlp import tag
seg.train(r'D:\Anaconda3\Lib\site-packages\snownlp\tag\199801.txt')
tag.save('tag.marshal')

# %%
from snownlp import sentiment
sentiment.train(r'D:\Anaconda3\Lib\site-packages\snownlp\sentiment\neg.txt', r'D:\Anaconda3\Lib\site-packages\snownlp\sentiment\pos.txt')
sentiment.save('sentiment.marshal')
