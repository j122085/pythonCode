# %% [markdown]
# # try doc2vec

# %%
# model = Doc2Vec(contentcutlist, size=100, window=8, min_count=5, workers=4)
import pandas as pd
import numpy as np
import jieba
#改為中文繁體字典,預設是簡體，可到jieba的GitHub下載
jieba.set_dictionary(r'D:\WordLibrary\JiebaUse\jieba_dict.txt.big') 
from wordcloud import WordCloud
import random
import json

# %%
with open(r"D:\Data\JsonData\TainanFood\bigtable_1.0.json") as f:
    BigAnalyzeTable=json.load(f)

# %%
def StopWdFilter(user_input, stop_words):
    """Sanitize using intersection and list.remove()"""
    # Downsides:
    #   - Looping over list while removing from it?
    #     http://stackoverflow.com/questions/1207406/remove-items-from-a-list-while-iterating-in-python
    stop_words = set()
    with open('D:/WordLibrary/JiebaUse/stopwords.txt', 'r', encoding='utf-8') as sw:
        for line in sw:
            stop_words.add(line.strip('\n'))
    for sw in stop_words.intersection(user_input):
        while sw in user_input:
            user_input.remove(sw)

    return user_input

# %%
def CutWithFilter(CorpusList):
    result=[]
    for y in [jieba.cut(x) for x in CorpusList]:
        content = StopWdFilter([ _ for _ in y], stopwords)
        result.append(content)
    return result
#所以我選擇所過濾的是跟「文意」比較無關的符號
stopwords = ['〔','〕','／','（','）','「','」','『','』','\n','nan']
#像下面這種比較是傳統文字探勘在過濾字詞可能過濾的一些字詞
#stopwords = ['〔','〕','／','（','）','「','」','『','』','的','就是','這個','可以','一定'\
#             ,'一個','nan','沒有','我們','不是','不用','不是','自己','只要','大家','覺得','因為'\
#             ,'對於','起來','如果','每個','很多','一樣','時候','加上','使用','只是']

# %%
goodEatArticle=[{'name':dien["name"],'content':"".join(dien['contentcut'].split(" "))} for dien in BigAnalyzeTable if "非常好吃" in dien["tags"]]
goodServeArticle=[{'name':dien["name"],'content':"".join(dien['contentcut'].split(" "))} for dien in BigAnalyzeTable if "服務一級棒" in dien["tags"]]
goodEnviromentArticle=[{'name':dien["name"],'content':"".join(dien['contentcut'].split(" "))} for dien in BigAnalyzeTable if "環境超棒" in dien["tags"]]

# %%
goodEatArticle[0] #有name跟content的dict
# Out:
# {'content': '天氣冷吃個鍋內容比較一篇介紹無制式餐點本篇介紹花雕鍋有別於之前吃蹄膀雞肉這次吃比較少見蝦煲牛肉煲食下約主要提供套餐鍋物無制式套餐下午茶食下約想法廚房地址台南市安平區郡平路號電話營業時間粉絲專頁葷有素兒童座椅店家介紹食下約億載國小斜對面馬路邊相當好找一樓創意料理食下約二樓蔬食餐廳食蔬茶齋而三到六樓則是民宿會館整體走比較沉穩食材美味度經考驗路線茶具元素電梯覺得老少咸宜長輩住適合旁邊很大空地停車相當便利不用停車費招牌寫早午餐下午茶晚餐供應店內環境晚上氛圍比較沉穩和緩些店兩人座八人座約會親友聚餐適合店裡最大座位區這區型長型沙發方便放置包包雜物店內貼心備有兒童座椅這次比較特別靠近雙人座旁邊種植食用生菜裝飾店內具有保鮮作用覺得可愛食下約價格表菜單價位食下約菜單這次做一些小變動低消元用餐時間小時免費無制式菜單料理選主菜主食醬汁飲料主菜選項雞肉魚肉牛肉豬肉鴨肉海鮮主食選項有機麵條造型麵進口壽司米燉飯醬汁選項紅醬青醬咖哩醬墨西哥辣醬紅酒醬白酒醬食材品質好醬汁熬煮沒什麼雷選喜歡口味即可套餐價格元自選主菜主食醬汁飲品附甜點四種褒類價格元飲料甜點美式南瓜鍋義式番茄鍋日本梅鍋台式麻油鍋墨西哥勁辣鍋素食者吃蔬食鍋同樣元選主食澳洲牛板肉匈牙利松阪豬跑山雞雞腿肉整尾驢魚桌上水自助這次吃餐點經典花雕煲系列花雕蝦煲花雕煲系列附飲料甜點伴著花雕鍋上桌附上白飯補充古早味私房滷汁滷汁帶點花雕酒香氣有著清爽不膩口鹹味配飯吃相當涮嘴美味食下約雕花蝦煲嚴選大蝦入鍋大蝦六七隻左右鍋裡堆成一座小山蝦子蝦界老爺男生大拇指大小飽滿新鮮彈牙彷彿蝦剛從海裡捕撈煮熟送入口中一鍋一家子吃個一兩隻內心充滿平安喜樂鍋內蝦子熟之外菜煮滴控制想要熟度旁邊絲瓜南瓜娃娃菜杏鮑菇蝦子飽滿新鮮肉菜快速消滅花雕牛煲牛煲滿滿的肉堆疊一份錢一份貨啊菜單寫說優質牛肉不用吃品質好牛肉軟嫩一個爆應該牛腩軟嫩好入口爸牙齒不好中年人吃愉快旁邊一堆新鮮飽滿蔬菜整鍋相當營養清爽食材好反正預算夠錢會花值得蝦煲牛肉煲醬汁不太蝦煲稍鹹一些特別下飯牛肉煲湯適合當湯喝清爽帶有淡淡酒香好喝暖胃暖心狂喝特喝好喝這一鍋吃好喝清爽湯底新鮮蔬菜軟嫩美味具有份量牛肉附餐飲料熱伯爵茶飲料器皿設計感原本食下約飲料比較果汁類目前改為茶品餐點提升些許精緻度茶葉放在漂亮櫃子台上做展示冰歐式莓果茶喝順口淡淡果香糖冰調整附餐甜點最後甜點伯爵奶酪底下一些伯爵茶葉渣渣濃醇香細膩度也夠好好吃喔吃完一個還會想再吃兩個餐點小總結之前吃過蹄膀覺得不錯完全顛覆蹄膀印象原本以為吃油清爽不膩滷汁這次改良變得黏稠原本適合淋在飯新版特別牛煲喝補補清爽口味迷人蝦牛肉非常好吃食材等級軟嫩度適合嘴刁長輩說老少咸宜天氣冷冷的食下約吃吃美味花雕鍋囉食下約初訪中午篇食下約無制式菜單篇小食代讚接收台南各地好吃好玩訊息喔去年時間皮皮吃食下有約吃完覺得肉飲料厲害這次晚上家人店家做餐點調整雕花煲口味小菜提升些許精緻度食下約主要提供套餐鍋物無制式套餐下午茶食下約想法廚房地址台南市安平區郡平路號電話營業時間粉絲專頁葷有素兒童座椅店家介紹食下約億載國小斜對面馬路邊相當好找一樓創意料理食下約二樓蔬食餐廳食蔬茶齋而三到六樓則是民宿會館整體走比較沉穩食材美味度經考驗路線茶具元素電梯覺得老少咸宜長輩住適合旁邊很大空地停車相當便利不用停車費招牌寫早午餐下午茶晚餐供應店內環境晚上氛圍比較沉穩和緩些店兩人座八人座約會親友聚餐適合店裡最大座位區這區型長型沙發方便放置包包雜物店內貼心備有兒童座椅這次比較特別靠近雙人座旁邊種植食用生菜裝飾店內具有保鮮作用覺得可愛食下約價格表菜單價位食下約菜單這次做一些小變動低消元用餐時間小時免費無制式菜單料理選主菜主食醬汁飲料主菜選項雞肉魚肉牛肉豬肉鴨肉海鮮主食選項有機麵條造型麵進口壽司米燉飯醬汁選項紅醬青醬咖哩醬墨西哥辣醬紅酒醬白酒醬食材品質好醬汁熬煮沒什麼雷選喜歡口味即可套餐價格元自選主菜主食醬汁飲品附甜點四種褒類價格元飲料甜點美式南瓜鍋義式番茄鍋日本梅鍋台式麻油鍋墨西哥勁辣鍋素食者吃蔬食鍋同樣元選主食澳洲牛板肉匈牙利松阪豬跑山雞雞腿肉整尾驢魚這次吃餐點桌上水自助無制式菜單內容物附餐濃湯開胃前菜主餐飲料甜點濃湯口味好濃淡得宜喝順口熱度討人喜歡裡面一些菇類很大塊鮭魚旁邊薄荷葉栽種鱸魚蟹肉佐櫻桃蘿蔔旁邊食用裝飾花前菜部分吃蟹肉慕斯大塊鮮美的魚鮮炸全鱸魚整隻鱸魚骨後下去炸的連魚頭炸酥脆綠色菜店植栽種飽滿新鮮脆口魚肉很嫩嘴裡化開當天拍太久義大利麵醬汁收有點乾上面堅果口感好魚是炸熱熱吃最酥脆美味白蘭地櫻桃鴨這份想說太爽滿滿厚厚的櫻桃鴨舖飯哥選紅酒燉飯做搭配紅酒白蘭地酒味重不用醉來來來看看這肉側面公分厚飽滿多汁好咬沒什麼咬難分難捨筋吃超爽吃一塊吃第二塊食下約肉質真的很棒愛吃肉真的嗨翻這份蔬菜底下紅酒燉飯我哥說入味口味好兩份無制式料理吃完超飽足食量吃份試味道請店家打包爸好像高興回家還能再吃一次飲料熱義式桔果茶飲料器皿設計感原本食下約飲料比較果汁類目前改為茶品餐點提升些許精緻度茶葉放在漂亮櫃子台上做展示冰歐式莓果茶而冰飲料長喝順口淡淡果香糖冰調整糖附新茶喝也不錯會壞念之前滿滿水果水果茶說附餐甜點最後則是伯爵奶酪好好吃喔底下一些伯爵茶葉渣渣濃醇香細膩度夠吃完一個還會想再吃兩個餐點小總結無制式菜單內容如圖主餐自由選擇醬汁主食肉品附前菜濃湯飲料奶酪吃完飽足附餐湯品跟前菜吃蟹肉大塊鮭魚不算花俏口感美味度好每次吃肉眉開眼笑食下約肉真的好吃特別推鴨胸牛肉食下約無制式料理分享囉初訪分享文小食代讚接收台南各地好吃好玩訊息喔這是一間台南美食新秀聽說當地小有名氣現在線購物結點全台各地朋友口福包裝鹹甜食外包裝包裝適合送禮失禮適合伴手禮包裝做到營養標示部分仔細中英文品名一些食材資料甜點但愛吃人不在意方便料理包則使用真空包裝食材保鮮送來時冷藏狀況米兒食用先放置冷凍食用時先前一天退冰袋子提著好看內外想周到甜點德式布丁塔因保存期限天快快吃掉德式布丁塔算是甜點中米兒喜歡甜點蛋塔乳酪蛋糕結合體享受感覺幸福整體宅配過來完全無受損真的很棒塔類容易運送過程碎裂看到完整無缺米兒開心剖面看出布丁餡部分氣孔整體扎實實在布丁餡滑順塔皮微酥香整體味道表現不錯花雕雞部分肉湯是分開這點米兒覺得超棒分開加熱肉變老米兒先將熱到湯滾加雞肉煮滾雞肉完全柴喲花雕雞湯當淋汁吃還火鍋附的湯分量超大米兒將湯留下來放一些蔬菜涮牛肉整個超級搭超好吃花雕味很種很重很香很香吃完整個暖雞肉部分使用雞腿吃整個超嫩店家使用雞腿關係雞肉煮剛剛好熟宅配拿到加熱後嫩嫩的好吃食下約獨家私房菜花雕系列傳統花雕雞外創新花雕牛花雕大蝦全程真空低溫宅配原汁原味送達以上資訊官方公布主米兒資訊來源全由官網公布得知分享米兒食用後心得有人接受有人接受這是口味追蹤米兒口味大部分相同請繼續追蹤米兒美食情報呦食下約想法廚房台南市安平區安郡路號官方網站官方臉書訂貨小寫喜歡米兒分享請到米兒三分料理給米兒讚鼓勵優本為試吃體驗全皆由體驗請安心食用正餐下午茶食下約想法廚房幫簡單輕鬆完成說吃一直人每日最重要工作選擇外出打牙祭嚐嚐新奇美味食物之外想要在家輕鬆吃好料理不難年關倒留意一下適合伴手禮今天要來分享這家實體店面餐廳之外全台各地饕客在家享用美食現在推出道人氣料理宅配服務台南美食餐廳新秀食下約想法廚房終於推出購物車宅配府料理餐廳現做感覺唷瞧這粉嫩嫩的包裝盒是不是適合送禮話說食下約想法廚房最具超人氣名私房菜花雕系列宅配府花雕蹄膀煲內面附上雙面彩色說明卡瞧紅通通蹄膀好好吃感覺說明卡上完整提供兩款食用方式盒側面加貼完整商品資訊使用成份製造日期有效期限真空方式完整封包後送入急凍保鮮之後再冷凍專車全程低溫宅配府加熱方式可採微波隔水加熱方式後食用一下重點囉附上食下約想法廚房精心熬煮花雕高湯高湯單獨使用當做湯料理用高湯像是花雕火鍋很美味搭配豬蹄膀一起食用當做淋飯醬汁很想嚐嚐花雕火鍋家人愛用高湯拌飯快速作法額外再買個筍乾先熱水殺青去除酸味之後再倒入高湯送入微波爐加熱後備之後再將隔水加熱後豬蹄膀放入快速完成這道花雕蹄膀筍乾煲想這道年節時上桌一刻起一定會超受歡迎上桌聞濃郁花雕酒香氣視覺嗅覺味覺人驚呼年節時端出一道料理想必要花費功夫印度咖哩醬採用印度咖哩異國辛香料加入洋蔥馬鈴薯紅蘿蔔蔬菜熬煮當做獨特風味咖哩鍋底湯話說家裡久時日做咖哩今天咖哩醬來做道美味下飯咖哩雞準備材料洋蔥一顆馬玲薯一顆三色甜椒適量雞腿三支蔥末少許蒜末少許食下約想法廚房印度咖哩醬半罐先將雞腿骨後備再雞腿骨熬製高湯骨後雞腿肉煎雙面變色後放入馬玲薯炒微軟後起鍋備用將煎微焦雞腿肉盛起後切成適口大小後備使用原鍋先將洋蔥炒軟後再放入起鍋馬玲薯拌炒後再放入三色甜椒拌炒微軟之後倒入使用雞腿骨熬煮成高湯後熬煮約分鐘之後再加入半罐食下約想法廚房印度咖哩醬拌匀後即可起鍋盛盤之後再灑些蔥花就行了再煮個湯炒盤青菜今天晚餐是不是豐盛滷相當入味蹄膀再特製花雕滷汁人吃幾碗這我加筍乾超有味唷吃飽飯後準備甜點甜言蜜語系列德國布丁塔世界好茶系列英式伯爵茶世界好茶系列英式伯爵茶斯里蘭卡原裝進口錫蘭紅茶基底天然佛手柑提味非市面上常用香精香料伯爵茶愛好者最佳選擇擁有獨特清新口感輕啜一口嘴裡淡淡的佛手柑香氣不澀好入喉加點鮮奶滴點蜂蜜可調成伯爵奶茶超適合甜言蜜語系列德國布丁塔乳酪布丁細緻綿密濃郁乳酪綿密交織而成誘人滋味藍姆酒香葡萄檸檬皮淡淡香氣觸動味蕾酸甜一道充滿異國風味下午茶甜點這塔皮好吃稍稍嫌厚些倒太影響口感悠閒午後下午茶點輕鬆品嚐美味發掘上網逛逛食下約想法廚房地址台南市安平區郡平路號預約電話宅配網址訂貨小寫本文為僅針對此次商品使用心得分享使用也將因人而異以上訊息僅共網友參考適用於所有人內文若有引用產品官網圖文說明僅只做輔助參考之用並未宣稱具其療效以上訊息僅供網友參考本篇商品標的興趣請自行評估需求歡迎加入粉絲一起變美麗封 ...
#  'name': '食下有約 想法廚房'}

# %% [markdown]
# # 4. 把文件讀進來（以食記好吃、好服務、環境好為範例）把店加跟內文以空格串接，作為分析的一個單位的Corpus，然後斷詞

# %%
Eat_df=pd.DataFrame(goodEatArticle)
Serve_df=pd.DataFrame(goodServeArticle)
Enviroment_df=pd.DataFrame(goodEnviromentArticle)

Eat = Eat_df.name+ " " + Eat_df.content
Serve  = Serve_df.name+ " " + Serve_df.content
Enviroment     = Enviroment_df.name+ " " + Enviroment_df.content

# %%
Eat_df #有name跟content的pandas dataframe
# Out:
#                                                content  \
# 0    天氣冷吃個鍋內容比較一篇介紹無制式餐點本篇介紹花雕鍋有別於之前吃蹄膀雞肉這次吃比較少見蝦煲牛...
# 1    飛饗義法典藏料理旗艦總店週日上班日下班美食好好犒賞同事跑飛饗義法典藏料理吃好料放鬆一下飛饗義...
# 2    之前住日木本來騷烤家吃晚餐當天組部落客約約喬喬昨天終於阿熊吃騷烤家火車站後站成育樂街附近不算...
# 3    位於德安百貨小銅鍋提供多樣義式料理排餐招牌舒芙蕾飲品甜食環境寬敞清幽質感後方座位區還透過落地...
# 4    台南永康一間港式點心專門店不論什麼門口總是大排長龍好奇神奇魔力這次台南行第一站來到聯盈發天兒...
# 5    今日店家提供小菜五種分別泡菜海帶芽珊瑚草青椒百香果南瓜泡菜以外屬於比較清爽口味無限量加點喔韓...
# 6    大學路巷內異國餐廳林立成功大學對面最著名兩條巷子巷巷充滿著滿滿台南人美食聚餐記憶總感覺此地台...
# 7    坐落台南大學巷一間小餐館以慢活舒食訴求提供多種餐點這是考試前幾個月抓住草莓季尾巴跑吃店內溫暖...
# 8    店名府城騷烤家前鋒總店電話地址臺南市東區前鋒路號營業時間週二公休停車場無停放公用停車格刷卡否...
# 9    去年台南小旅行時曾經轉角餐廳用餐一篇放久寫文章忙轉角餐廳就位成功大學商圈附近大學路巷看到招牌...
# 10   圖文並茂網誌豬窩一個多月前訂碳佐今天終於吃真的太人愉悅今天點了三人套餐四個人吃皮豬肉捲羊小排...
# 11   這間朋友母親邀請我來吃湘口袋名單每次好想嘗嘗機會這次終於吃超級開心位新光三越樓上招牌超級明顯...
# 12   紅葡萄最近超愛吃港查哪裡專聽說高雄來一間評價兩極反正沒差吃過知道台南商務會館港茶品質挑選對德...
# 13   女孩兒總喜歡粉嫩嫩浪漫水晶燈蕾絲鑲邊裝飾餐廳瑪莉洋房屬於瑪莉餐飲團隊台南營業已年時光網上評論...
# 14   歡迎加入粉絲團追蹤新文原文出處咩灣裡羊肉總店台南美食挖完在灣裡興南街上有著一家開業六十多年老...
# 15   舟鶴家位於文賢路上靠近台南武聖夜市舟鶴家真好吃名字簡單好記主打親民樸實價格吃府城最好吃嫩骨飯...
# 16   本次用餐使用愛評網口碑券今天來到這家位於台南東區成功大學城附近井選日式定食話說這間轉角集團旗...
# 17   相對假日熱潮聚集平日來訪人潮不多倒幾分悠閒旅遊調調累想找一間特色質感餐廳歇歇腳放放空感受不同...
# 18   台南知名素食餐廳食蔬茶齋年推出全新菜色現在也將預約制取消囉營業時間隨時以來盡情享用精緻蔬果料...
# 19   沒錯無敵企鵝輕鬆點早午餐全天候能點早午餐重點這次二訪義式可麗餅蛋捲創始店鄰近勝利路附近學校可...
# 20   台南精緻自助烤肉料理系列極致燒肉美味配菜甜點飯桶家族顧名思義喜歡品嚐美食紀錄分享喜歡寵物相機...
# 21   今天小蚌蚌分享隱身健康路上容易錯過隱藏版運動餐廳葳苙二壘小小招牌容易隔壁診所招牌搶風頭仔細有...
# 22   台南延平郡王祠附近一家已經營多年餐廳音樂廚房餐廳隱身一片綠意中茂盛綠植湧出圍牆外白色拱門紅色...
# 23   愛評體驗團特別邀約體驗活動禮拜整個太拼一直處理業務導致身體有點小累想要按摩說月真的跑肩頸整個...
# 24   信燒烤串燒小炒電話地址台南市中西區公園路號營業時間下午點半夜點居酒屋型信燒烤走濃濃日式氛圍口...
# 25   充滿陽光魅力高值聚餐小店飯編最近老媽同學得知一家相當厲害小店陽光義式廚房最近接許多宅配案件好...
# 26   威葳義法餐廳已經台南經營十年之久位中西區海安路上威葳義法餐廳附近正是數家台南傳統小吃競爭熱鬧...
# 27   歡迎加入美食魚樂誌台南好多美食居酒屋第一次覺得新鮮這間鯨吞燒有很棒雞料理職人串烤非常好吃完整...
# 28   去年三月第一次吃山小屋聽店長說新品店長希望再試試揪朋友一起二訪假日中午人還蠻初訪文章點我店裡...
# 29   吃鍋季節覺得冬天裡吃著熱呼呼的鍋物最幸福今天分享府前路上一家麻辣鍋勾勾鍋鴛鴦火鍋棠爸棠媽太吃...
# ..                                                 ...
# 106  大腳覺得麻豆意想不到挖寶地挖這家義大利專門店現場袍起司超酷義麵愛義大利料理相當突出大腳超愛家...
# 107  青森Dryad時尚餐廳早午餐前陣子看到朋友轉貼青森粉絲頁推出全新早午餐元月底前買一送一訂週日...
# 108  台南夏慕尼新香榭鐵板燒公園南店今天二位帥哥用餐好想坐圓桌喔只可惜平日人數未達到二樓圓桌開放客...
# 109  搭吹海風趣吃早午餐每周台南市安平區慶平路號無外觀橘色彩繪樑柱格一個玻璃窗展現十足閒適鄉村風搶...
# 110  瓏豐海鮮庭園式景觀餐廳地址台南市安南區大眾路號電話營業時間官網瓏豐水產官方臉書瓏豐海鮮庭園式...
# 111  今天暫停囉請繼續往下插播新聞喜歡文章朋友歡迎加入訂閱痞客邦加入讚粉絲團囉娜塔一併推廣粉絲專頁...
# 112  說玉井第一個想到一定芒果周末天氣好家人來到芒果故鄉玉井玩中午來享鮮餐廳解決原以間小餐館沒想到...
# 113  鹽酥雞令人難以抗拒國民美食今天分享鹹酥雞不同於以往唷特殊地方趕緊過來位中華東路二路一起囉香爆...
# 114  文平路上近期新開異國餐廳中式餐館附近居民餐點選擇一帶生活方便熱鬧新開幕約四個月瑪西達韓式餐廳...
# 115  爽爽口吃皮薄酥脆起士香濃物料好吃過癮滿足比薩斜塔手作窯烤披薩電話地址台南市東區中華東路三段巷...
# 116  用餐前幾天碰上颱風遇上中秋節連假假日出遊跑東安路找找美食東安路上餐廳一陣子沒來發現許多家新面...
# 117  熱血特別選一天心愛欸下班浪漫燭光晚餐聊表心愛愛意想來品嚐看看朋友極力推薦店店家藏身透天大樓裡...
# 118  水鳥和洋創料台南開幕後朋友傳來問著說東安路上開一間好漂亮餐廳吃過臉上寫愛吃鬼點了愛吃痣真的寫...
# 119  睽違已久早午餐文是說上班以後真的再追這種早午餐類型以前總是喜歡找美美房子美美餐點現在比較正餐...
# 120  搭敲鍋吃鍋煮鍋金站鍋物料理週一週日無台南市北區北門路二段號無吃鍋吃鍋吃鍋台南人真愛吃火鍋天氣...
# 121  今天暫停請繼續往下插播新聞喜歡文章朋友歡迎加入訂閱痞客邦加入讚粉絲團囉電腦版已說讚設定成搶先...
# 122  地址台南市東區裕農三街號電話營業時間周一粉絲專頁店家簡介位於美食臺南市東區一家手作麵包專門店...
# 123  大學生倒數第二個班聚脫離吃吃點精緻王品集團桌上擺好芝麻磨好後再加豬排醬特製豬排醬汁入座時服務...
# 124  記得初訪貝里尼台北京站等車看到裡面賣就衝時間只點吃吃閃人這次台南夢時代貝里尼聚餐終於機會品嚐...
# 125  温野菜來自日本牛角集團日本涮涮鍋品牌日本店舖數量最多涮涮鍋專門店新鮮食材多種健康湯頭手工醬料...
# 126  記得桑妮高雄人這間應該所有高雄人知道店記得前已經知道多久以前海南涮羊肉高雄鳳山火紅耶依稀記得...
# 127  位於新營區南瀛綠心公園前龍鳳東大門間十分韓國風格裝潢韓式料理店進門前往裡頭一瞥看到穿著韓服服...
# 128  店家名稱洋城義大利餐廳台南永康店消費日期年月地址台南市永康區中華二路號電話營業時間官網永康料...
# 129  來自高雄連鎖品牌濰克早午餐開來台南一次兩間崇善店更是台南創始店這次崇善路創始店嚐嚐早午餐店內...
# 130  歡迎加入粉絲團追蹤新文原文出處一直以來淘氣猴粵式料理特別偏愛過去特別寫過粵式料理文章這次遊台...
# 131  道義大利麵燉飯提拉米蘇平價義式料理組合飯編喜歡吃美食喜歡幫食物拍遺照最近正好稱連假期間整理各...
# 132  日本料理情有獨鍾真的覺得上輩子日本人一個月少說吃三到四次不等以後真的一篇台南日本料理懶人包說...
# 133  台南目前共有三家春川炒雞只剩下永康中華店插旗達陣成功去年春川炒雞台展店陸陸續續半年兩家第三家...
# 134  之前吃過看店來客量很多人知道中華北路上一間用心餐廳自私收藏很想做店內位置並不特別真心覺得料理...
# 135  燈光美氣氛佳餐點美味南紡夢時代雅悅會館看飯編最近文章開頭知道最近出車禍親戚家白吃白喝休養手邊...
#
#                                  name
# 0                           食下有約 想法廚房
# 1                            飛饗創意西式料理
# 2                           騷烤家(前鋒總店)
# 3                      小銅鍋義式餐廳(德安誠品店)
# 4                            聯盈發點心專門店
# 5                    OMAYA春川炒雞(台南永華店)
# 6                          歐加里(台南大學店)
# 7                        KAFFE @ HOME
# 8                               府城騷烤家
# 9                                轉角餐廳
# 10                    碳佐麻里日式燒肉(台南府前店)
# 11                     1010湘(台南三越西門店)
# 12                        台南商務會館-港式飲茶
# 13                 瑪莉洋房 Marie's House
# 14                         咩 灣裡羊肉(總店)
# 15                        舟鶴家嫩骨飯(文賢店)
# 16                             井選日式定食
# 17                            Brick磚塊
# 18                          食蔬茶齋 蔬果料理
# 19                Relax.brunch 輕鬆點早午餐
# 20                    碳佐麻里日式燒肉(台南中華店)
# 21                  Willy's Grill葳苙二壘
# 22                           M&M 音樂廚房
# 23                           牡丹庭 漢風料理
# 24                                信燒烤
# 25                  Sunny Pasta陽光義式廚坊
# 26                        WiWe 威葳義法餐廳
# 27                  鯨吞燒 地雞料理專門店(赤崁分店)
# 28           山小屋 Yamagoya Taiwan(台南店)
# 29                           勾勾鍋 鴛鴦火鍋
# ..                                ...
# 106                     義麵愛PASTA LOVE
# 107                       青森Dryad時尚餐廳
# 108                  夏慕尼新香榭鐵板燒(台南公園店)
# 109               Curry+ Kitchen 誠欣廚房
# 110                       瓏豐海鮮庭園式景觀餐廳
# 111                       Takeat 輕享原食
# 112                             來享鮮餐廳
# 113                       ICHIRO，ㄧ起囉！
# 114                               瑪西達
# 115                    比薩斜塔pizzastyle
# 116                               綠麥田
# 117                格樓主題餐廳-Grimm House
# 118                      水鳥和洋創作料理-府城店
# 119         NO.17 Brunch table & More
# 120                             金站麻辣鍋
# 121                            井煲仔沙茶爐
# 122                          Mr. Deer
# 123                       品田牧場(台南勝利店)
# 124   BELLINI Pasta Pasta 貝里尼(台南夢時代店)
# 125  しゃぶしゃぶ温野菜日本涮涮鍋專門店Taiwan On-Yasai
# 126                        海南涮羊肉(永大店)
# 127                             龍鳳東大門
# 128                           洋城義大利餐廳
# 129                       濰克早午餐-台南崇善店
# 130                           御品饗粵式煲鍋
# 131                            秘密義大利麵
# 132                            京鶴日本料理
# 133                 OMAYA 春川炒雞(台南永康店)
# 134                           五五禾概念套餐
# 135                    雅悅會館(雅悅會館 台南館)
#
# [136 rows x 2 columns]

# %%
Eat #流水號  店名+內文的Corpus(文集)?
# Out:
# 0      食下有約 想法廚房 天氣冷吃個鍋內容比較一篇介紹無制式餐點本篇介紹花雕鍋有別於之前吃蹄膀雞肉...
# 1      飛饗創意西式料理 飛饗義法典藏料理旗艦總店週日上班日下班美食好好犒賞同事跑飛饗義法典藏料理吃...
# 2      騷烤家(前鋒總店) 之前住日木本來騷烤家吃晚餐當天組部落客約約喬喬昨天終於阿熊吃騷烤家火車站...
# 3      小銅鍋義式餐廳(德安誠品店) 位於德安百貨小銅鍋提供多樣義式料理排餐招牌舒芙蕾飲品甜食環境寬...
# 4      聯盈發點心專門店 台南永康一間港式點心專門店不論什麼門口總是大排長龍好奇神奇魔力這次台南行第...
# 5      OMAYA春川炒雞(台南永華店) 今日店家提供小菜五種分別泡菜海帶芽珊瑚草青椒百香果南瓜泡菜...
# 6      歐加里(台南大學店) 大學路巷內異國餐廳林立成功大學對面最著名兩條巷子巷巷充滿著滿滿台南人美...
# 7      KAFFE @ HOME 坐落台南大學巷一間小餐館以慢活舒食訴求提供多種餐點這是考試前幾個月...
# 8      府城騷烤家 店名府城騷烤家前鋒總店電話地址臺南市東區前鋒路號營業時間週二公休停車場無停放公用...
# 9      轉角餐廳 去年台南小旅行時曾經轉角餐廳用餐一篇放久寫文章忙轉角餐廳就位成功大學商圈附近大學路...
# 10     碳佐麻里日式燒肉(台南府前店) 圖文並茂網誌豬窩一個多月前訂碳佐今天終於吃真的太人愉悅今天點...
# 11     1010湘(台南三越西門店) 這間朋友母親邀請我來吃湘口袋名單每次好想嘗嘗機會這次終於吃超級...
# 12     台南商務會館-港式飲茶 紅葡萄最近超愛吃港查哪裡專聽說高雄來一間評價兩極反正沒差吃過知道台南...
# 13     瑪莉洋房 Marie's House 女孩兒總喜歡粉嫩嫩浪漫水晶燈蕾絲鑲邊裝飾餐廳瑪莉洋房屬...
# 14     咩 灣裡羊肉(總店) 歡迎加入粉絲團追蹤新文原文出處咩灣裡羊肉總店台南美食挖完在灣裡興南街上...
# 15     舟鶴家嫩骨飯(文賢店) 舟鶴家位於文賢路上靠近台南武聖夜市舟鶴家真好吃名字簡單好記主打親民樸...
# 16     井選日式定食 本次用餐使用愛評網口碑券今天來到這家位於台南東區成功大學城附近井選日式定食話說...
# 17     Brick磚塊 相對假日熱潮聚集平日來訪人潮不多倒幾分悠閒旅遊調調累想找一間特色質感餐廳歇歇...
# 18     食蔬茶齋 蔬果料理 台南知名素食餐廳食蔬茶齋年推出全新菜色現在也將預約制取消囉營業時間隨時以...
# 19     Relax.brunch 輕鬆點早午餐 沒錯無敵企鵝輕鬆點早午餐全天候能點早午餐重點這次二訪...
# 20     碳佐麻里日式燒肉(台南中華店) 台南精緻自助烤肉料理系列極致燒肉美味配菜甜點飯桶家族顧名思義...
# 21     Willy's Grill葳苙二壘 今天小蚌蚌分享隱身健康路上容易錯過隱藏版運動餐廳葳苙二壘...
# 22     M&M 音樂廚房 台南延平郡王祠附近一家已經營多年餐廳音樂廚房餐廳隱身一片綠意中茂盛綠植湧出...
# 23     牡丹庭 漢風料理 愛評體驗團特別邀約體驗活動禮拜整個太拼一直處理業務導致身體有點小累想要按摩...
# 24     信燒烤 信燒烤串燒小炒電話地址台南市中西區公園路號營業時間下午點半夜點居酒屋型信燒烤走濃濃日...
# 25     Sunny Pasta陽光義式廚坊 充滿陽光魅力高值聚餐小店飯編最近老媽同學得知一家相當厲害...
# 26     WiWe 威葳義法餐廳 威葳義法餐廳已經台南經營十年之久位中西區海安路上威葳義法餐廳附近正是...
# 27     鯨吞燒 地雞料理專門店(赤崁分店) 歡迎加入美食魚樂誌台南好多美食居酒屋第一次覺得新鮮這間鯨...
# 28     山小屋 Yamagoya Taiwan(台南店) 去年三月第一次吃山小屋聽店長說新品店長希望...
# 29     勾勾鍋 鴛鴦火鍋 吃鍋季節覺得冬天裡吃著熱呼呼的鍋物最幸福今天分享府前路上一家麻辣鍋勾勾鍋鴛...
#                              ...
# 106    義麵愛PASTA LOVE 大腳覺得麻豆意想不到挖寶地挖這家義大利專門店現場袍起司超酷義麵愛...
# 107    青森Dryad時尚餐廳 青森Dryad時尚餐廳早午餐前陣子看到朋友轉貼青森粉絲頁推出全新早午...
# 108    夏慕尼新香榭鐵板燒(台南公園店) 台南夏慕尼新香榭鐵板燒公園南店今天二位帥哥用餐好想坐圓桌喔...
# 109    Curry+ Kitchen 誠欣廚房 搭吹海風趣吃早午餐每周台南市安平區慶平路號無外觀橘色...
# 110    瓏豐海鮮庭園式景觀餐廳 瓏豐海鮮庭園式景觀餐廳地址台南市安南區大眾路號電話營業時間官網瓏豐水...
# 111    Takeat 輕享原食 今天暫停囉請繼續往下插播新聞喜歡文章朋友歡迎加入訂閱痞客邦加入讚粉絲...
# 112    來享鮮餐廳 說玉井第一個想到一定芒果周末天氣好家人來到芒果故鄉玉井玩中午來享鮮餐廳解決原以間...
# 113    ICHIRO，ㄧ起囉！ 鹽酥雞令人難以抗拒國民美食今天分享鹹酥雞不同於以往唷特殊地方趕緊過來...
# 114    瑪西達 文平路上近期新開異國餐廳中式餐館附近居民餐點選擇一帶生活方便熱鬧新開幕約四個月瑪西達...
# 115    比薩斜塔pizzastyle 爽爽口吃皮薄酥脆起士香濃物料好吃過癮滿足比薩斜塔手作窯烤披薩電...
# 116    綠麥田 用餐前幾天碰上颱風遇上中秋節連假假日出遊跑東安路找找美食東安路上餐廳一陣子沒來發現許...
# 117    格樓主題餐廳-Grimm House 熱血特別選一天心愛欸下班浪漫燭光晚餐聊表心愛愛意想來品...
# 118    水鳥和洋創作料理-府城店 水鳥和洋創料台南開幕後朋友傳來問著說東安路上開一間好漂亮餐廳吃過臉...
# 119    NO.17 Brunch table & More 睽違已久早午餐文是說上班以後真的再追這種...
# 120    金站麻辣鍋 搭敲鍋吃鍋煮鍋金站鍋物料理週一週日無台南市北區北門路二段號無吃鍋吃鍋吃鍋台南人真...
# 121    井煲仔沙茶爐 今天暫停請繼續往下插播新聞喜歡文章朋友歡迎加入訂閱痞客邦加入讚粉絲團囉電腦版已...
# 122    Mr. Deer 地址台南市東區裕農三街號電話營業時間周一粉絲專頁店家簡介位於美食臺南市東區...
# 123    品田牧場(台南勝利店) 大學生倒數第二個班聚脫離吃吃點精緻王品集團桌上擺好芝麻磨好後再加豬排...
# 124    BELLINI Pasta Pasta 貝里尼(台南夢時代店) 記得初訪貝里尼台北京站等車看...
# 125    しゃぶしゃぶ温野菜日本涮涮鍋專門店Taiwan On-Yasai 温野菜來自日本牛角集團日本...
# 126    海南涮羊肉(永大店) 記得桑妮高雄人這間應該所有高雄人知道店記得前已經知道多久以前海南涮羊肉...
# 127    龍鳳東大門 位於新營區南瀛綠心公園前龍鳳東大門間十分韓國風格裝潢韓式料理店進門前往裡頭一瞥看...
# 128    洋城義大利餐廳 店家名稱洋城義大利餐廳台南永康店消費日期年月地址台南市永康區中華二路號電話營...
# 129    濰克早午餐-台南崇善店 來自高雄連鎖品牌濰克早午餐開來台南一次兩間崇善店更是台南創始店這次崇...
# 130    御品饗粵式煲鍋 歡迎加入粉絲團追蹤新文原文出處一直以來淘氣猴粵式料理特別偏愛過去特別寫過粵式...
# 131    秘密義大利麵 道義大利麵燉飯提拉米蘇平價義式料理組合飯編喜歡吃美食喜歡幫食物拍遺照最近正好稱...
# 132    京鶴日本料理 日本料理情有獨鍾真的覺得上輩子日本人一個月少說吃三到四次不等以後真的一篇台南日...
# 133    OMAYA 春川炒雞(台南永康店) 台南目前共有三家春川炒雞只剩下永康中華店插旗達陣成功去年...
# 134    五五禾概念套餐 之前吃過看店來客量很多人知道中華北路上一間用心餐廳自私收藏很想做店內位置並不...
# 135    雅悅會館(雅悅會館 台南館) 燈光美氣氛佳餐點美味南紡夢時代雅悅會館看飯編最近文章開頭知道最...
# Length: 136, dtype: object

# %%
Eat_List = CutWithFilter(Eat)
Ser_List = CutWithFilter(Serve)
Env_List = CutWithFilter(Enviroment)
# Out:
# ['食下',
#  '約',
#  ' ',
#  '想法',
#  '廚房',
#  ' ',
#  '天氣',
#  '冷吃個',
#  '鍋',
#  '內容',
#  '比較',
#  '一篇',
#  '介紹',
#  '無',
#  '制式',
#  '餐點',
#  '本篇',
#  '介紹',
#  '花雕',
#  '鍋',
#  '有別於',
#  '之前',
#  '吃',
#  '蹄膀',
#  '雞肉',
#  '這次',
#  '吃',
#  '比較',
#  '少見',
#  '蝦煲',
#  '牛肉',
#  '煲',
#  '食下',
#  '約',
#  '主要',
#  '提供',
#  '套餐',
#  '鍋物',
#  '無',
#  '制式',
#  '套餐',
#  '下午',
#  '茶食',
#  '下約',
#  '想法',
#  '廚房',
#  '地址',
#  '台南市',
#  '安平',
#  '區郡',
#  '平路號',
#  '電話',
#  '營業時間',
#  '粉絲',
#  '專頁',
#  '葷',
#  '有素',
#  '兒童座椅',
#  '店家',
#  '介紹',
#  '食下',
#  '約',
#  '億載',
#  '國',
#  '小',
#  '斜對面',
#  '馬路邊',
#  '相當',
#  '好找',
#  '一樓',
#  '創意',
#  '料理',
#  '食下',
#  '約',
#  '二樓',
#  '蔬食',
#  '餐廳',
#  '食蔬',
#  '茶',
#  '齋',
#  '三到',
#  '六樓',
#  '則是',
#  '民宿',
#  '會館',
#  '整體',
#  '走',
#  '比較',
#  '沉穩',
#  '食材',
#  '美味',
#  '度經',
#  '考驗',
#  '路線',
#  '茶具',
#  '元素',
#  '電梯',
#  '覺得',
#  '老少咸宜',
#  '長輩',
#  '住',
#  '適合',
#  '旁邊',
#  '很大',
#  '空地',
#  '停車',
#  '相當',
#  '便利',
#  '不用',
#  '停車費',
#  '招牌',
#  '寫',
#  '早',
#  '午餐',
#  '下午茶',
#  '晚餐',
#  '供應',
#  '店內',
#  '環境',
#  '晚上',
#  '氛圍',
#  '比較',
#  '沉穩',
#  '和緩',
#  '些',
#  '店',
#  '兩人座',
#  '八人座',
#  '約會',
#  '親友',
#  '聚餐',
#  '適合',
#  '店裡',
#  '最大',
#  '座位',
#  '區這區',
#  '型',
#  '長型',
#  '沙發',
#  '方便',
#  '放置',
#  '包包',
#  '雜物',
#  '店內',
#  '貼心',
#  '備有',
#  '兒童座椅',
#  '這次',
#  '比較',
#  '特別',
#  '靠近',
#  '雙人',
#  '座',
#  '旁邊',
#  '種植',
#  '食用',
#  '生菜',
#  '裝飾',
#  '店內',
#  '具有',
#  '保鮮',
#  '作用',
#  '覺得',
#  '可愛',
#  '食下',
#  '約',
#  '價格表',
#  '菜單',
#  '價位',
#  '食下',
#  '約',
#  '菜單',
#  '這次',
#  '做',
#  '一些',
#  '小',
#  '變動',
#  '低',
#  '消元',
#  '用餐',
#  '時間',
#  '小時',
#  '免費',
#  '無',
#  '制式',
#  '菜單',
#  '料理',
#  '選',
#  '主菜',
#  '主食',
#  '醬汁',
#  '飲料',
#  '主菜',
#  '選項',
#  '雞肉',
#  '魚肉',
#  '牛肉',
#  '豬肉',
#  '鴨肉',
#  '海鮮',
#  '主食',
#  '選項',
#  '有機',
#  '麵',
#  '條',
#  '造型',
#  '麵',
#  '進口',
#  '壽司',
#  '米燉',
#  '飯',
#  '醬汁',
#  '選項',
#  '紅醬',
#  '青醬',
#  '咖哩',
#  '醬',
#  '墨西哥',
#  '辣醬',
#  '紅酒',
#  '醬',
#  '白酒',
#  '醬',
#  '食材',
#  '品質',
#  '好',
#  '醬汁',
#  '熬',
#  '煮',
#  '沒什麼',
#  '雷選',
#  '喜歡',
#  '口味',
#  '即可',
#  '套餐',
#  '價格',
#  '元',
#  '自選',
#  '主菜',
#  '主食',
#  '醬汁',
#  '飲品',
#  '附',
#  '甜點',
#  '四種',
#  '褒類',
#  '價格',
#  '元',
#  '飲料',
#  '甜點',
#  '美式',
#  '南瓜',
#  '鍋義式',
#  '番茄',
#  '鍋',
#  '日本',
#  '梅鍋',
#  '台式',
#  '麻',
#  '油鍋',
#  '墨西哥',
#  '勁辣鍋',
#  '素食者',
#  '吃',
#  '蔬食',
#  '鍋',
#  '同樣',
#  '元選',
#  '主食',
#  '澳洲',
#  '牛板',
#  '肉',
#  '匈牙利',
#  '松阪',
#  '豬跑',
#  '山雞',
#  '雞腿肉',
#  '整尾',
#  '驢魚',
#  '桌上',
#  '水',
#  '自助',
#  '這次',
#  '吃',
#  '餐點',
#  '經典',
#  '花雕',
#  '煲',
#  '系列',
#  '花雕',
#  '蝦煲',
#  '花雕',
#  '煲',
#  '系列',
#  '附',
#  '飲料',
#  '甜點',
#  '伴著',
#  '花雕',
#  '鍋',
#  '上桌',
#  '附上',
#  '白飯',
#  '補充',
#  '古早',
#  '味',
#  '私房',
#  '滷汁',
#  '滷汁',
#  '帶點',
#  '花雕酒',
#  '香氣',
#  '有著',
#  '清爽',
#  '不膩',
#  '口',
#  '鹹味',
#  '配飯',
#  '吃',
#  '相當',
#  '涮',
#  '嘴',
#  '美味',
#  '食下',
#  '約',
#  '雕花',
#  '蝦煲',
#  '嚴選',
#  '大蝦',
#  '入鍋',
#  '大蝦',
#  '六七隻',
#  '左右',
#  '鍋裡',
#  '堆成',
#  '一座',
#  '小山',
#  '蝦子',
#  '蝦界',
#  '老爺',
#  '男生',
#  '大拇指',
#  '大小',
#  '飽滿',
#  '新鮮',
#  '彈牙',
#  '彷彿',
#  '蝦剛',
#  '海裡',
#  '捕撈',
#  '煮熟',
#  '送入',
#  '口中',
#  '一鍋',
#  '一家子',
#  '吃個',
#  '一兩隻',
#  '內心',
#  '充滿',
#  '平安',
#  '喜樂',
#  '鍋內',
#  '蝦子',
#  '熟',
#  '之外',
#  '菜',
#  '煮',
#  '滴',
#  '控制',
#  '想要',
#  '熟度',
#  '旁邊',
#  '絲瓜',
#  '南瓜',
#  '娃娃',
#  '菜',
#  '杏鮑菇',
#  '蝦子',
#  '飽滿',
#  '新鮮肉',
#  '菜',
#  '快速',
#  '消滅',
#  '花雕',
#  '牛煲',
#  '牛煲',
#  '滿滿的',
#  '肉',
#  '堆疊',
#  '一份',
#  '錢',
#  '一份',
#  '貨啊',
#  '菜單',
#  '寫',
#  '說',
#  '優質',
#  '牛肉',
#  '不用',
#  '吃',
#  '品質',
#  '好',
#  '牛肉',
#  '軟嫩',
#  '一個',
#  '爆',
#  '應該',
#  '牛腩',
#  '軟嫩',
#  '好',
#  '入口',
#  '爸',
#  '牙齒',
#  '不好',
#  '中年人',
#  '吃',
#  '愉快',
#  '旁邊',
#  '一堆',
#  '新鮮',
#  '飽滿',
#  '蔬菜',
#  '整鍋',
#  '相當',
#  '營養',
#  '清爽',
#  '食材',
#  '好',
#  '反正',
#  '預算',
#  '夠錢會花',
#  '值得',
#  '蝦煲',
#  '牛肉',
#  '煲',
#  '醬汁',
#  '不太蝦',
#  '煲',
#  '稍',
#  '鹹',
#  '一些',
#  '特別',
#  '下飯',
#  '牛肉',
#  '煲湯',
#  '適合',
#  '當湯',
#  '喝',
#  '清爽',
#  '帶有',
#  '淡淡',
#  '酒香',
#  '好喝',
#  '暖',
#  '胃',
#  '暖',
#  '心狂',
#  '喝',
#  '特喝',
#  '好喝',
#  '這一鍋',
#  '吃',
#  '好喝',
#  '清爽',
#  '湯底',
#  '新鮮',
#  '蔬菜',
#  '軟嫩',
#  '美味',
#  '具有',
#  '份量',
#  '牛肉',
#  '附',
#  '餐飲',
#  '料熱',
#  '伯爵',
#  '茶飲料',
#  '器皿',
#  '設計',
#  '感',
#  '原本',
#  '食下',
#  '約',
#  '飲料',
#  '比較',
#  '果汁',
#  '類目',
#  '前',
#  '改為',
#  '茶品',
#  '餐點',
#  '提升',
#  '些許',
#  '精緻',
#  '度',
#  '茶葉',
#  '放在',
#  '漂亮',
#  '櫃子',
#  '台上',
#  '做',
#  '展示',
#  '冰',
#  '歐式',
#  '莓',
#  '果茶',
#  '喝',
#  '順口',
#  '淡淡',
#  '果香',
#  '糖冰',
#  '調整',
#  '附餐',
#  '甜點',
#  '最後',
#  '甜點',
#  '伯爵',
#  '奶酪',
#  '底下',
#  '一些',
#  '伯爵',
#  '茶葉',
#  '渣渣濃',
#  '醇香',
#  '細膩',
#  '度',
#  '也夠',
#  '好',
#  '好吃',
#  '喔',
#  '吃',
#  '完',
#  '一個',
#  '還會',
#  '想',
#  '再',
#  '吃',
#  '兩個',
#  '餐點',
#  '小',
#  '總結',
#  '之前',
#  '吃過',
#  '蹄膀',
#  '覺得',
#  '不錯',
#  '完全',
#  '顛覆',
#  '蹄膀',
#  '印象',
#  '原本',
#  '以為',
#  '吃',
#  '油',
#  '清爽',
#  '不膩',
#  '滷汁',
#  '這次',
#  '改良',
#  '變得',
#  '黏稠',
#  '原本',
#  '適合',
#  '淋在',
#  '飯',
#  '新版',
#  '特別',
#  '牛煲',
#  '喝',
#  '補補',
#  '清爽',
#  '口味',
#  '迷人',
#  '蝦',
#  '牛肉',
#  '好吃',
#  '食材',
#  '等級',
#  '軟嫩度',
#  '適合',
#  '嘴刁',
#  '長輩',
#  '說',
#  '老少咸宜',
#  '天氣',
#  '冷冷的',
#  '食下',
#  '約',
#  '吃',
#  '吃',
#  '美味',
#  '花雕',
#  '鍋',
#  '囉',
#  '食下',
#  '約',
#  '初訪',
#  '中午',
#  '篇',
#  '食下',
#  '約',
#  '無',
#  '制式',
#  '菜單',
#  '篇',
#  '小食',
#  '代',
#  '讚',
#  '接收',
#  '台南',
#  '各地',
#  '好吃',
#  '好玩',
#  '訊息',
#  '喔',
#  '去年',
#  '時間',
#  '皮皮',
#  '吃食',
#  '下有',
#  '約',
#  '吃',
#  '完',
#  '覺得',
#  '肉',
#  '飲料',
#  '厲害',
#  '這次',
#  '晚上',
#  '家人',
#  '店家',
#  '做',
#  '餐點',
#  '調整',
#  '雕花',
#  '煲',
#  '口味',
#  '小菜',
#  '提升',
#  '些許',
#  '精緻',
#  '度食',
#  '下',
#  '約',
#  '主要',
#  '提供',
#  '套餐',
#  '鍋物',
#  '無',
#  '制式',
#  '套餐',
#  '下午',
#  '茶食',
#  '下約',
#  '想法',
#  '廚房',
#  '地址',
#  '台南市',
#  '安平',
#  '區郡',
#  '平路號',
#  '電話',
#  '營業時間',
#  '粉絲',
#  '專頁',
#  '葷',
#  '有素',
#  '兒童座椅',
#  '店家',
#  '介紹',
#  '食下',
#  '約',
#  '億載',
#  '國',
#  '小',
#  '斜對面',
#  '馬路邊',
#  '相當',
#  '好找',
#  '一樓',
#  '創意',
#  '料理',
#  '食下',
#  '約',
#  '二樓',
#  '蔬食',
#  '餐廳',
#  '食蔬',
#  '茶',
#  '齋',
#  '三到',
#  '六樓',
#  '則是',
#  '民宿',
#  '會館',
#  '整體',
#  '走',
#  '比較',
#  '沉穩',
#  '食材',
#  '美味',
#  '度經',
#  '考驗',
#  '路線',
#  '茶具',
#  '元素',
#  '電梯',
#  '覺得',
#  '老少咸宜',
#  '長輩',
#  '住',
#  '適合',
#  '旁邊',
#  '很大',
#  '空地',
#  '停車',
#  '相當',
#  '便利',
#  '不用',
#  '停車費',
#  '招牌',
#  '寫',
#  '早',
#  '午餐',
#  '下午茶',
#  '晚餐',
#  '供應',
#  '店內',
#  '環境',
#  '晚上',
#  '氛圍',
#  '比較',
#  '沉穩',
#  '和緩',
#  '些',
#  '店',
#  '兩人座',
#  '八人座',
#  '約會',
#  '親友',
#  '聚餐',
#  '適合',
#  '店裡',
#  '最大',
#  '座位',
#  '區這區',
#  '型',
#  '長型',
#  '沙發',
#  '方便',
#  '放置',
#  '包包',
#  '雜物',
#  '店內',
#  '貼心',
#  '備有',
#  '兒童座椅',
#  '這次',
#  '比較',
#  '特別',
#  '靠近',
#  '雙人',
#  '座',
#  '旁邊',
#  '種植',
#  '食用',
#  '生菜',
#  '裝飾',
#  '店內',
#  '具有',
#  '保鮮',
#  '作用',
#  '覺得',
#  '可愛',
#  '食下',
#  '約',
#  '價格表',
#  '菜單',
#  '價位',
#  '食下',
#  '約',
#  '菜單',
#  '這次',
#  '做',
#  '一些',
#  '小',
#  '變動',
#  '低',
#  '消元',
#  '用餐',
#  '時間',
#  '小時',
#  '免費',
#  '無',
#  '制式',
#  '菜單',
#  '料理',
#  '選',
#  '主菜',
#  '主食',
#  '醬汁',
#  '飲料',
#  '主菜',
#  '選項',
#  '雞肉',
#  '魚肉',
#  '牛肉',
#  '豬肉',
#  '鴨肉',
#  '海鮮',
#  '主食',
#  '選項',
#  '有機',
#  '麵',
#  '條',
#  '造型',
#  '麵',
#  '進口',
#  '壽司',
#  '米燉',
#  '飯',
#  '醬汁',
#  '選項',
#  '紅醬',
#  '青醬',
#  '咖哩',
#  '醬',
#  '墨西哥',
#  '辣醬',
#  '紅酒',
#  '醬',
#  '白酒',
#  '醬',
#  '食材',
#  '品質',
#  '好',
#  '醬汁',
#  '熬',
#  '煮',
#  '沒什麼',
#  '雷選',
#  '喜歡',
#  '口味',
#  '即可',
#  '套餐',
#  '價格',
#  '元',
#  '自選',
#  '主菜',
#  '主食',
#  '醬汁',
#  '飲品',
#  '附',
#  '甜點',
#  '四種',
#  '褒類',
#  '價格',
#  '元',
#  '飲料',
#  '甜點',
#  '美式',
#  '南瓜',
#  '鍋義式',
#  '番茄',
#  '鍋',
#  '日本',
#  '梅鍋',
#  '台式',
#  '麻',
#  '油鍋',
#  '墨西哥',
#  '勁辣鍋',
#  '素食者',
#  '吃',
#  '蔬食',
#  '鍋',
#  '同樣',
#  '元選',
#  '主食',
#  '澳洲',
#  '牛板',
#  '肉',
#  '匈牙利',
#  '松阪',
#  '豬跑',
#  '山雞',
#  '雞腿肉',
#  '整尾',
#  '驢魚',
#  '這次',
#  '吃',
#  '餐點',
#  '桌上',
#  '水',
#  '自助',
#  '無',
#  '制式',
#  '菜單',
#  '內容',
#  '物附餐',
#  '濃湯',
#  '開胃',
#  '前菜主',
#  '餐飲',
#  '料',
#  '甜點',
#  '濃湯',
#  '口味',
#  '好',
#  '濃淡',
#  '得宜',
#  '喝',
#  '順口',
#  '熱度',
#  '討人喜歡',
#  '裡面',
#  '一些',
#  '菇類',
#  '很大',
#  '塊',
#  '鮭魚',
#  '旁邊',
#  '薄荷葉',
#  '栽種',
#  '鱸魚',
#  '蟹肉',
#  '佐',
#  '櫻桃',
#  '蘿蔔',
#  '旁邊',
#  '食用',
#  '裝飾',
#  '花前',
#  '菜',
#  '部分',
#  '吃',
#  '蟹肉',
#  '慕斯',
#  '大塊',
#  '鮮美',
#  '魚鮮',
#  '炸全',
#  '鱸魚',
#  '整隻',
#  '鱸魚',
#  '骨',
#  '後',
#  '下去',
#  '炸的連',
#  '魚頭',
#  '炸',
#  '酥脆',
#  '綠色',
#  '菜店',
#  '植',
#  '栽種',
#  '飽滿',
#  '新鮮',
#  '脆口',
#  '魚肉',
#  '很嫩',
#  '嘴裡',
#  '化開',
#  '當天',
#  '拍',
#  '太久',
#  '義大利',
#  '麵',
#  '醬汁',
#  '收',
#  '有點',
#  '乾',
#  '上面',
#  '堅果',
#  '口感',
#  '好魚',
#  '炸',
#  '熱熱',
#  '吃',
#  '最',
#  '酥脆',
#  '美味',
#  '白蘭地',
#  '櫻桃',
#  '鴨',
#  '這份',
#  '想',
#  '說',
#  '太爽',
#  '滿滿',
#  '厚厚的',
#  '櫻桃',
#  '鴨',
#  '舖',
#  '飯',
#  '哥選',
#  '紅酒',
#  '燉',
#  '飯',
#  '做',
#  ...]

# %%
Eat_List[0]  #斷詞list的list
# Out:
# [['食下',
#   '約',
#   ' ',
#   '想法',
#   '廚房',
#   ' ',
#   '天氣',
#   '冷吃個',
#   '鍋',
#   '內容',
#   '比較',
#   '一篇',
#   '介紹',
#   '無',
#   '制式',
#   '餐點',
#   '本篇',
#   '介紹',
#   '花雕',
#   '鍋',
#   '有別於',
#   '之前',
#   '吃',
#   '蹄膀',
#   '雞肉',
#   '這次',
#   '吃',
#   '比較',
#   '少見',
#   '蝦煲',
#   '牛肉',
#   '煲',
#   '食下',
#   '約',
#   '主要',
#   '提供',
#   '套餐',
#   '鍋物',
#   '無',
#   '制式',
#   '套餐',
#   '下午',
#   '茶食',
#   '下約',
#   '想法',
#   '廚房',
#   '地址',
#   '台南市',
#   '安平',
#   '區郡',
#   '平路號',
#   '電話',
#   '營業時間',
#   '粉絲',
#   '專頁',
#   '葷',
#   '有素',
#   '兒童座椅',
#   '店家',
#   '介紹',
#   '食下',
#   '約',
#   '億載',
#   '國',
#   '小',
#   '斜對面',
#   '馬路邊',
#   '相當',
#   '好找',
#   '一樓',
#   '創意',
#   '料理',
#   '食下',
#   '約',
#   '二樓',
#   '蔬食',
#   '餐廳',
#   '食蔬',
#   '茶',
#   '齋',
#   '三到',
#   '六樓',
#   '則是',
#   '民宿',
#   '會館',
#   '整體',
#   '走',
#   '比較',
#   '沉穩',
#   '食材',
#   '美味',
#   '度經',
#   '考驗',
#   '路線',
#   '茶具',
#   '元素',
#   '電梯',
#   '覺得',
#   '老少咸宜',
#   '長輩',
#   '住',
#   '適合',
#   '旁邊',
#   '很大',
#   '空地',
#   '停車',
#   '相當',
#   '便利',
#   '不用',
#   '停車費',
#   '招牌',
#   '寫',
#   '早',
#   '午餐',
#   '下午茶',
#   '晚餐',
#   '供應',
#   '店內',
#   '環境',
#   '晚上',
#   '氛圍',
#   '比較',
#   '沉穩',
#   '和緩',
#   '些',
#   '店',
#   '兩人座',
#   '八人座',
#   '約會',
#   '親友',
#   '聚餐',
#   '適合',
#   '店裡',
#   '最大',
#   '座位',
#   '區這區',
#   '型',
#   '長型',
#   '沙發',
#   '方便',
#   '放置',
#   '包包',
#   '雜物',
#   '店內',
#   '貼心',
#   '備有',
#   '兒童座椅',
#   '這次',
#   '比較',
#   '特別',
#   '靠近',
#   '雙人',
#   '座',
#   '旁邊',
#   '種植',
#   '食用',
#   '生菜',
#   '裝飾',
#   '店內',
#   '具有',
#   '保鮮',
#   '作用',
#   '覺得',
#   '可愛',
#   '食下',
#   '約',
#   '價格表',
#   '菜單',
#   '價位',
#   '食下',
#   '約',
#   '菜單',
#   '這次',
#   '做',
#   '一些',
#   '小',
#   '變動',
#   '低',
#   '消元',
#   '用餐',
#   '時間',
#   '小時',
#   '免費',
#   '無',
#   '制式',
#   '菜單',
#   '料理',
#   '選',
#   '主菜',
#   '主食',
#   '醬汁',
#   '飲料',
#   '主菜',
#   '選項',
#   '雞肉',
#   '魚肉',
#   '牛肉',
#   '豬肉',
#   '鴨肉',
#   '海鮮',
#   '主食',
#   '選項',
#   '有機',
#   '麵',
#   '條',
#   '造型',
#   '麵',
#   '進口',
#   '壽司',
#   '米燉',
#   '飯',
#   '醬汁',
#   '選項',
#   '紅醬',
#   '青醬',
#   '咖哩',
#   '醬',
#   '墨西哥',
#   '辣醬',
#   '紅酒',
#   '醬',
#   '白酒',
#   '醬',
#   '食材',
#   '品質',
#   '好',
#   '醬汁',
#   '熬',
#   '煮',
#   '沒什麼',
#   '雷選',
#   '喜歡',
#   '口味',
#   '即可',
#   '套餐',
#   '價格',
#   '元',
#   '自選',
#   '主菜',
#   '主食',
#   '醬汁',
#   '飲品',
#   '附',
#   '甜點',
#   '四種',
#   '褒類',
#   '價格',
#   '元',
#   '飲料',
#   '甜點',
#   '美式',
#   '南瓜',
#   '鍋義式',
#   '番茄',
#   '鍋',
#   '日本',
#   '梅鍋',
#   '台式',
#   '麻',
#   '油鍋',
#   '墨西哥',
#   '勁辣鍋',
#   '素食者',
#   '吃',
#   '蔬食',
#   '鍋',
#   '同樣',
#   '元選',
#   '主食',
#   '澳洲',
#   '牛板',
#   '肉',
#   '匈牙利',
#   '松阪',
#   '豬跑',
#   '山雞',
#   '雞腿肉',
#   '整尾',
#   '驢魚',
#   '桌上',
#   '水',
#   '自助',
#   '這次',
#   '吃',
#   '餐點',
#   '經典',
#   '花雕',
#   '煲',
#   '系列',
#   '花雕',
#   '蝦煲',
#   '花雕',
#   '煲',
#   '系列',
#   '附',
#   '飲料',
#   '甜點',
#   '伴著',
#   '花雕',
#   '鍋',
#   '上桌',
#   '附上',
#   '白飯',
#   '補充',
#   '古早',
#   '味',
#   '私房',
#   '滷汁',
#   '滷汁',
#   '帶點',
#   '花雕酒',
#   '香氣',
#   '有著',
#   '清爽',
#   '不膩',
#   '口',
#   '鹹味',
#   '配飯',
#   '吃',
#   '相當',
#   '涮',
#   '嘴',
#   '美味',
#   '食下',
#   '約',
#   '雕花',
#   '蝦煲',
#   '嚴選',
#   '大蝦',
#   '入鍋',
#   '大蝦',
#   '六七隻',
#   '左右',
#   '鍋裡',
#   '堆成',
#   '一座',
#   '小山',
#   '蝦子',
#   '蝦界',
#   '老爺',
#   '男生',
#   '大拇指',
#   '大小',
#   '飽滿',
#   '新鮮',
#   '彈牙',
#   '彷彿',
#   '蝦剛',
#   '海裡',
#   '捕撈',
#   '煮熟',
#   '送入',
#   '口中',
#   '一鍋',
#   '一家子',
#   '吃個',
#   '一兩隻',
#   '內心',
#   '充滿',
#   '平安',
#   '喜樂',
#   '鍋內',
#   '蝦子',
#   '熟',
#   '之外',
#   '菜',
#   '煮',
#   '滴',
#   '控制',
#   '想要',
#   '熟度',
#   '旁邊',
#   '絲瓜',
#   '南瓜',
#   '娃娃',
#   '菜',
#   '杏鮑菇',
#   '蝦子',
#   '飽滿',
#   '新鮮肉',
#   '菜',
#   '快速',
#   '消滅',
#   '花雕',
#   '牛煲',
#   '牛煲',
#   '滿滿的',
#   '肉',
#   '堆疊',
#   '一份',
#   '錢',
#   '一份',
#   '貨啊',
#   '菜單',
#   '寫',
#   '說',
#   '優質',
#   '牛肉',
#   '不用',
#   '吃',
#   '品質',
#   '好',
#   '牛肉',
#   '軟嫩',
#   '一個',
#   '爆',
#   '應該',
#   '牛腩',
#   '軟嫩',
#   '好',
#   '入口',
#   '爸',
#   '牙齒',
#   '不好',
#   '中年人',
#   '吃',
#   '愉快',
#   '旁邊',
#   '一堆',
#   '新鮮',
#   '飽滿',
#   '蔬菜',
#   '整鍋',
#   '相當',
#   '營養',
#   '清爽',
#   '食材',
#   '好',
#   '反正',
#   '預算',
#   '夠錢會花',
#   '值得',
#   '蝦煲',
#   '牛肉',
#   '煲',
#   '醬汁',
#   '不太蝦',
#   '煲',
#   '稍',
#   '鹹',
#   '一些',
#   '特別',
#   '下飯',
#   '牛肉',
#   '煲湯',
#   '適合',
#   '當湯',
#   '喝',
#   '清爽',
#   '帶有',
#   '淡淡',
#   '酒香',
#   '好喝',
#   '暖',
#   '胃',
#   '暖',
#   '心狂',
#   '喝',
#   '特喝',
#   '好喝',
#   '這一鍋',
#   '吃',
#   '好喝',
#   '清爽',
#   '湯底',
#   '新鮮',
#   '蔬菜',
#   '軟嫩',
#   '美味',
#   '具有',
#   '份量',
#   '牛肉',
#   '附',
#   '餐飲',
#   '料熱',
#   '伯爵',
#   '茶飲料',
#   '器皿',
#   '設計',
#   '感',
#   '原本',
#   '食下',
#   '約',
#   '飲料',
#   '比較',
#   '果汁',
#   '類目',
#   '前',
#   '改為',
#   '茶品',
#   '餐點',
#   '提升',
#   '些許',
#   '精緻',
#   '度',
#   '茶葉',
#   '放在',
#   '漂亮',
#   '櫃子',
#   '台上',
#   '做',
#   '展示',
#   '冰',
#   '歐式',
#   '莓',
#   '果茶',
#   '喝',
#   '順口',
#   '淡淡',
#   '果香',
#   '糖冰',
#   '調整',
#   '附餐',
#   '甜點',
#   '最後',
#   '甜點',
#   '伯爵',
#   '奶酪',
#   '底下',
#   '一些',
#   '伯爵',
#   '茶葉',
#   '渣渣濃',
#   '醇香',
#   '細膩',
#   '度',
#   '也夠',
#   '好',
#   '好吃',
#   '喔',
#   '吃',
#   '完',
#   '一個',
#   '還會',
#   '想',
#   '再',
#   '吃',
#   '兩個',
#   '餐點',
#   '小',
#   '總結',
#   '之前',
#   '吃過',
#   '蹄膀',
#   '覺得',
#   '不錯',
#   '完全',
#   '顛覆',
#   '蹄膀',
#   '印象',
#   '原本',
#   '以為',
#   '吃',
#   '油',
#   '清爽',
#   '不膩',
#   '滷汁',
#   '這次',
#   '改良',
#   '變得',
#   '黏稠',
#   '原本',
#   '適合',
#   '淋在',
#   '飯',
#   '新版',
#   '特別',
#   '牛煲',
#   '喝',
#   '補補',
#   '清爽',
#   '口味',
#   '迷人',
#   '蝦',
#   '牛肉',
#   '好吃',
#   '食材',
#   '等級',
#   '軟嫩度',
#   '適合',
#   '嘴刁',
#   '長輩',
#   '說',
#   '老少咸宜',
#   '天氣',
#   '冷冷的',
#   '食下',
#   '約',
#   '吃',
#   '吃',
#   '美味',
#   '花雕',
#   '鍋',
#   '囉',
#   '食下',
#   '約',
#   '初訪',
#   '中午',
#   '篇',
#   '食下',
#   '約',
#   '無',
#   '制式',
#   '菜單',
#   '篇',
#   '小食',
#   '代',
#   '讚',
#   '接收',
#   '台南',
#   '各地',
#   '好吃',
#   '好玩',
#   '訊息',
#   '喔',
#   '去年',
#   '時間',
#   '皮皮',
#   '吃食',
#   '下有',
#   '約',
#   '吃',
#   '完',
#   '覺得',
#   '肉',
#   '飲料',
#   '厲害',
#   '這次',
#   '晚上',
#   '家人',
#   '店家',
#   '做',
#   '餐點',
#   '調整',
#   '雕花',
#   '煲',
#   '口味',
#   '小菜',
#   '提升',
#   '些許',
#   '精緻',
#   '度食',
#   '下',
#   '約',
#   '主要',
#   '提供',
#   '套餐',
#   '鍋物',
#   '無',
#   '制式',
#   '套餐',
#   '下午',
#   '茶食',
#   '下約',
#   '想法',
#   '廚房',
#   '地址',
#   '台南市',
#   '安平',
#   '區郡',
#   '平路號',
#   '電話',
#   '營業時間',
#   '粉絲',
#   '專頁',
#   '葷',
#   '有素',
#   '兒童座椅',
#   '店家',
#   '介紹',
#   '食下',
#   '約',
#   '億載',
#   '國',
#   '小',
#   '斜對面',
#   '馬路邊',
#   '相當',
#   '好找',
#   '一樓',
#   '創意',
#   '料理',
#   '食下',
#   '約',
#   '二樓',
#   '蔬食',
#   '餐廳',
#   '食蔬',
#   '茶',
#   '齋',
#   '三到',
#   '六樓',
#   '則是',
#   '民宿',
#   '會館',
#   '整體',
#   '走',
#   '比較',
#   '沉穩',
#   '食材',
#   '美味',
#   '度經',
#   '考驗',
#   '路線',
#   '茶具',
#   '元素',
#   '電梯',
#   '覺得',
#   '老少咸宜',
#   '長輩',
#   '住',
#   '適合',
#   '旁邊',
#   '很大',
#   '空地',
#   '停車',
#   '相當',
#   '便利',
#   '不用',
#   '停車費',
#   '招牌',
#   '寫',
#   '早',
#   '午餐',
#   '下午茶',
#   '晚餐',
#   '供應',
#   '店內',
#   '環境',
#   '晚上',
#   '氛圍',
#   '比較',
#   '沉穩',
#   '和緩',
#   '些',
#   '店',
#   '兩人座',
#   '八人座',
#   '約會',
#   '親友',
#   '聚餐',
#   '適合',
#   '店裡',
#   '最大',
#   '座位',
#   '區這區',
#   '型',
#   '長型',
#   '沙發',
#   '方便',
#   '放置',
#   '包包',
#   '雜物',
#   '店內',
#   '貼心',
#   '備有',
#   '兒童座椅',
#   '這次',
#   '比較',
#   '特別',
#   '靠近',
#   '雙人',
#   '座',
#   '旁邊',
#   '種植',
#   '食用',
#   '生菜',
#   '裝飾',
#   '店內',
#   '具有',
#   '保鮮',
#   '作用',
#   '覺得',
#   '可愛',
#   '食下',
#   '約',
#   '價格表',
#   '菜單',
#   '價位',
#   '食下',
#   '約',
#   '菜單',
#   '這次',
#   '做',
#   '一些',
#   '小',
#   '變動',
#   '低',
#   '消元',
#   '用餐',
#   '時間',
#   '小時',
#   '免費',
#   '無',
#   '制式',
#   '菜單',
#   '料理',
#   '選',
#   '主菜',
#   '主食',
#   '醬汁',
#   '飲料',
#   '主菜',
#   '選項',
#   '雞肉',
#   '魚肉',
#   '牛肉',
#   '豬肉',
#   '鴨肉',
#   '海鮮',
#   '主食',
#   '選項',
#   '有機',
#   '麵',
#   '條',
#   '造型',
#   '麵',
#   '進口',
#   '壽司',
#   '米燉',
#   '飯',
#   '醬汁',
#   '選項',
#   '紅醬',
#   '青醬',
#   '咖哩',
#   '醬',
#   '墨西哥',
#   '辣醬',
#   '紅酒',
#   '醬',
#   '白酒',
#   '醬',
#   '食材',
#   '品質',
#   '好',
#   '醬汁',
#   '熬',
#   '煮',
#   '沒什麼',
#   '雷選',
#   '喜歡',
#   '口味',
#   '即可',
#   '套餐',
#   '價格',
#   '元',
#   '自選',
#   '主菜',
#   '主食',
#   '醬汁',
#   '飲品',
#   '附',
#   '甜點',
#   '四種',
#   '褒類',
#   '價格',
#   '元',
#   '飲料',
#   '甜點',
#   '美式',
#   '南瓜',
#   '鍋義式',
#   '番茄',
#   '鍋',
#   '日本',
#   '梅鍋',
#   '台式',
#   '麻',
#   '油鍋',
#   '墨西哥',
#   '勁辣鍋',
#   '素食者',
#   '吃',
#   '蔬食',
#   '鍋',
#   '同樣',
#   '元選',
#   '主食',
#   '澳洲',
#   '牛板',
#   '肉',
#   '匈牙利',
#   '松阪',
#   '豬跑',
#   '山雞',
#   '雞腿肉',
#   '整尾',
#   '驢魚',
#   '這次',
#   '吃',
#   '餐點',
#   '桌上',
#   '水',
#   '自助',
#   '無',
#   '制式',
#   '菜單',
#   '內容',
#   '物附餐',
#   '濃湯',
#   '開胃',
#   '前菜主',
#   '餐飲',
#   '料',
#   '甜點',
#   '濃湯',
#   '口味',
#   '好',
#   '濃淡',
#   '得宜',
#   '喝',
#   '順口',
#   '熱度',
#   '討人喜歡',
#   '裡面',
#   '一些',
#   '菇類',
#   '很大',
#   '塊',
#   '鮭魚',
#   '旁邊',
#   '薄荷葉',
#   '栽種',
#   '鱸魚',
#   '蟹肉',
#   '佐',
#   '櫻桃',
#   '蘿蔔',
#   '旁邊',
#   '食用',
#   '裝飾',
#   '花前',
#   '菜',
#   '部分',
#   '吃',
#   '蟹肉',
#   '慕斯',
#   '大塊',
#   '鮮美',
#   '魚鮮',
#   '炸全',
#   '鱸魚',
#   '整隻',
#   '鱸魚',
#   '骨',
#   '後',
#   '下去',
#   '炸的連',
#   '魚頭',
#   '炸',
#   '酥脆',
#   '綠色',
#   '菜店',
#   '植',
#   '栽種',
#   '飽滿',
#   '新鮮',
#   '脆口',
#   '魚肉',
#   '很嫩',
#   '嘴裡',
#   '化開',
#   '當天',
#   '拍',
#   '太久',
#   '義大利',
#   '麵',
#   '醬汁',
#   '收',
#   '有點',
#   '乾',
#   '上面',
#   '堅果',
#   '口感',
#   '好魚',
#   '炸',
#   '熱熱',
#   '吃',
#   '最',
#   '酥脆',
#   '美味',
#   '白蘭地',
#   '櫻桃',
#   '鴨',
#   '這份',
#   '想',
#   '說',
#   '太爽',
#   '滿滿',
#   '厚厚的',
#   '櫻桃',
#   '鴨',
#   '舖',
#   '飯',
#   '哥選',
#   '紅酒',
#   '燉',
#   '飯',
#   '做',
#   ...],
#  ['飛',
#   '饗',
#   '創意',
#   '西式',
#   '料理',
#   ' ',
#   '飛',
#   '饗',
#   '義',
#   '法典',
#   '藏',
#   '料理',
#   '旗艦',
#   '總店',
#   '週日',
#   '上班',
#   '日',
#   '下班',
#   '美食',
#   '好好',
#   '犒賞',
#   '同事',
#   '跑',
#   '飛',
#   '饗',
#   '義',
#   '法典',
#   '藏',
#   '料理',
#   '吃',
#   '好料',
#   '放鬆',
#   '一下',
#   '飛',
#   '饗',
#   '義',
#   '法典',
#   '藏',
#   '料理',
#   '位於',
#   '長榮',
#   '女中',
#   '正對面',
#   '一旁',
#   '鳳凰',
#   '手作',
#   '炸雞',
#   '屋濃園',
#   '滿漢',
#   '餐廳',
#   '不錯',
#   '喔',
#   '飛',
#   '饗',
#   '義',
#   '法典',
#   '藏',
#   '料理',
#   '印象',
#   '中',
#   '之前',
#   '大東',
#   '夜市',
#   '對面',
#   '公園',
#   '長榮',
#   '路側',
#   '現在',
#   '則遷',
#   '店來',
#   '長榮',
#   '女中',
#   '新',
#   '經營',
#   '團隊',
#   '菜色',
#   '變動',
#   '提供',
#   '義法',
#   '料理',
#   '美味',
#   '度',
#   '提升',
#   '不變',
#   '雅緻',
#   '舒適',
#   '用餐',
#   '環境',
#   '飛',
#   '饗',
#   '義',
#   '法典',
#   '藏',
#   '料理',
#   '停車',
#   '方便',
#   '非',
#   '學生',
#   '上學',
#   '時段',
#   '對面',
#   '長榮',
#   '女中',
#   '提供',
#   '停車場',
#   '停放',
#   '愛車',
#   '飛',
#   '饗',
#   '義',
#   '法典',
#   '藏',
#   '料理店',
#   '外',
#   '裝飾',
#   '鄉',
#   '村風',
#   '適合',
#   '拍照',
#   '走進',
#   '大門',
#   '右手邊',
#   '顯',
#   '目的',
#   '亮',
#   '紫色',
#   '沙發',
#   '一旁',
#   '隻',
#   '大熊',
#   '娃娃',
#   '陪',
#   '坐',
#   '好多',
#   '人',
#   '拍照',
#   '打卡',
#   '飛',
#   '饗',
#   '飛翔',
#   '飛想',
#   '上方',
#   '飛',
#   '饗',
#   '專屬',
#   '質感',
#   '餐廳',
#   '隨處可見',
#   '左手邊',
#   '一大',
#   '面',
#   '飲品',
#   '調製',
#   '區兼',
#   '結帳',
#   '櫃檯',
#   '櫃檯',
#   '後',
#   '裝飾',
#   '好',
#   '幾幅',
#   '異國',
#   '風景畫',
#   '歐式',
#   '風情',
#   '當天',
#   '前往',
#   '週日',
#   '晚餐',
#   '時間',
#   '一樓',
#   '已',
#   '滿席',
#   '引導',
#   '二樓',
#   '座位',
#   '區循著',
#   '旋轉',
#   '樓梯',
#   '欣賞',
#   '一顆顆',
#   '白黃',
#   '相間',
#   '巨大',
#   '燈飾',
#   '緩緩',
#   '走上',
#   '樓',
#   '樓上',
#   '氣氛',
#   '更佳',
#   '飛',
#   '饗',
#   '義',
#   '法典',
#   '藏',
#   '料理',
#   '二樓',
#   '之景',
#   '昏黃',
#   '燈光',
#   '宮廷',
#   '風',
#   '裝潢',
#   '浪漫',
#   '靠牆',
#   '側為',
#   '整排',
#   '紫色',
#   '沙發椅',
#   '上面',
#   '鑲嵌',
#   '漂亮',
#   '白色',
#   '鑽石',
#   '搭配',
#   '亮',
#   '紫色',
#   '絨布',
#   '面',
#   '感覺',
#   '華麗',
#   '雅緻',
#   '沙發',
#   '坐',
#   '好',
#   '舒適',
#   '整個',
#   '人像',
#   '吸裡面',
#   '捨不得',
#   '起身',
#   '感覺',
#   '放鬆',
#   '好',
#   '適合',
#   '這群剛',
#   '下班',
#   '上班族',
#   '樓上',
#   '接近',
#   '客滿',
#   '好險',
#   '下班',
#   '樓上樓下',
#   '茶水',
#   '自助',
#   '區',
#   '需要',
#   '自行',
#   '取用',
#   '服務',
#   '人員',
#   '告知',
#   '需求',
#   '餐廳',
#   '必備',
#   '兒童座椅',
#   '圖樣',
#   '可愛',
#   '帶貝',
#   '比來',
#   '爸',
#   '媽咪',
#   '放心',
#   '晚餐',
#   '時刻',
#   '用餐',
#   '店家',
#   '會為',
#   '桌上',
#   '點上',
#   '一盞',
#   '蠟燭',
#   '真的',
#   '名副其實',
#   '燭光',
#   '晚餐',
#   '趕緊',
#   '看看',
#   '菜單',
#   '義式',
#   '料理',
#   '部分',
#   '有燉',
#   '飯',
#   '義大利',
#   '麵',
#   '排餐',
#   '加價',
#   '升級',
#   '套餐',
#   '服務',
#   '升級',
#   '套餐',
#   '選項',
#   '餐',
#   '典藏',
#   '土壤',
#   '花園',
#   '沙拉',
#   '飲品',
#   '美式',
#   '咖啡',
#   '原味',
#   '鐵',
#   '皇家',
#   '伯爵',
#   '紅茶',
#   '飲品',
#   '折抵',
#   '餐',
#   '典藏',
#   '土壤',
#   '花園',
#   '沙拉',
#   '主廚',
#   '每日',
#   '精選',
#   '濃湯',
#   '甜點',
#   '飲品',
#   '甜點',
#   '可可',
#   '榛果',
#   '脆餅',
#   '鮮',
#   '奶酪',
#   '招牌',
#   '義式',
#   '提拉',
#   '米蘇',
#   '嚴選生',
#   '巧克力',
#   '塔',
#   '當日',
#   '限定',
#   '甜品',
#   '飲品',
#   '美式',
#   '咖啡',
#   '原味',
#   '鐵',
#   '皇家',
#   '伯爵',
#   '紅茶',
#   '飲品',
#   '折抵',
#   '比較',
#   '特別',
#   '飛',
#   '饗',
#   '義',
#   '法典',
#   '藏',
#   '料理',
#   '採',
#   '自助式',
#   '服務費',
#   '服務費',
#   '顧客',
#   '自由',
#   '給予',
#   '真正',
#   '分給',
#   '外場',
#   '服務',
#   '人員',
#   '視',
#   '服務滿意',
#   '程度',
#   '給予',
#   '服務費',
#   '外場',
#   '服務',
#   '人員',
#   '一個',
#   '實質',
#   '鼓勵',
#   '沒多久',
#   '餐點',
#   '一一',
#   '送上',
#   '應該',
#   '限時',
#   '用餐',
#   '前面',
#   '餐點',
#   '滿快',
#   '棒棒',
#   '典藏',
#   '土壤',
#   '花園',
#   '沙拉',
#   '沙拉',
#   '一送',
#   '生菜',
#   '放在',
#   '圓柱狀',
#   '透明',
#   '容器',
#   '手扶',
#   '容器',
#   '手持',
#   '叉子',
#   '輕壓',
#   '冰涼',
#   '生菜',
#   '推下來',
#   '囉',
#   '瞧瞧',
#   '是不是',
#   '挺',
#   '美的',
#   '生菜',
#   '特別',
#   '事先',
#   '冰鎮',
#   '冰涼',
#   '口感',
#   '適合',
#   '現在',
#   '盛夏',
#   '時光',
#   '再',
#   '搭配',
#   '店家',
#   '給的',
#   '醬汁',
#   '盤特調',
#   '千島',
#   '醬',
#   '紅酒',
#   '醋',
#   '佐',
#   '藍莓',
#   '醬',
#   '新鮮',
#   '芒果',
#   '塊',
#   '全部',
#   '淋上',
#   '沾',
#   '品嚐',
#   '不錯',
#   '誒',
#   '巨鼠',
#   '尤其',
#   '喜愛',
#   '紅酒',
#   '醋',
#   '佐',
#   '藍莓',
#   '醬',
#   '酸甜',
#   '滋味',
#   '很棒',
#   '喔',
#   '試試',
#   '主廚',
#   '每日',
#   '精選',
#   '濃湯',
#   '馬鈴薯',
#   '濃湯',
#   '要點',
#   '選',
#   '套餐',
#   '單點',
#   '濃湯',
#   '喝',
#   '熱呼呼',
#   '醇口',
#   '感覺',
#   '馬鈴薯',
#   '丁',
#   '燉煮',
#   '成',
#   '軟綿',
#   '化入',
#   '濃湯',
#   '裡了',
#   '喝',
#   '感覺',
#   '真的',
#   '真材實料',
#   '麵',
#   '包丁',
#   '培根',
#   '碎',
#   '煮',
#   '軟甜',
#   '洋蔥',
#   '搭配',
#   '手磨',
#   '黑胡椒',
#   '粒超',
#   '好喝',
#   '覺得',
#   '喝到料',
#   '多味',
#   '美的',
#   '濃郁',
#   '濃湯',
#   '濃郁',
#   '原因',
#   '馬鈴薯',
#   '煮',
#   '融入',
#   '湯頭',
#   '美味',
#   '羅勒',
#   '松子',
#   '蒜',
#   '烘',
#   '蛤蠣',
#   '天使',
#   '紅蝦',
#   '麵',
#   '店',
#   '全部',
#   '義大利',
#   '麵',
#   '這道',
#   '使用',
#   '天使',
#   '細',
#   '麵',
#   '口味',
#   '搭配',
#   '直',
#   '麵',
#   '送上來',
#   '不負',
#   '期待',
#   '青醬',
#   '綠',
#   '舒服',
#   '天使',
#   '紅蝦',
#   '超級',
#   '大尾',
#   '一旁',
#   '蛤蠣',
#   '顆顆',
#   '新鮮',
#   '多汁',
#   '大粒',
#   '羅勒',
#   '松子',
#   '蒜',
#   '烘',
#   '蛤蠣',
#   '天使',
#   '紅蝦',
#   '麵',
#   '當天',
#   '漁港',
#   '直送',
#   '天使',
#   '紅蝦',
#   '吃',
#   '超級',
#   '新鮮',
#   '蝦肉',
#   '彈鮮',
#   '甜',
#   '新鮮度',
#   '真的',
#   '一吃',
#   '心領神會',
#   '完全',
#   '不用說',
#   '青醬',
#   '喜愛',
#   '羅勒',
#   '滋味',
#   '香氣',
#   '濃郁',
#   '帶有',
#   '蒜',
#   '香',
#   '蛤蠣',
#   '顆',
#   '肥美',
#   '鮮甜',
#   '天使',
#   '細',
#   '麵',
#   '吸附',
#   '青醬',
#   '口感',
#   '稍',
#   '偏',
#   '軟放',
#   '太久',
#   '吃厚切',
#   '義式',
#   '香料',
#   '里',
#   '肌',
#   '豬排',
#   '整份',
#   '排餐',
#   '送',
#   '份量',
#   '稍稍',
#   '驚嚇',
#   '原來',
#   '這道',
#   '排餐',
#   '適合',
#   '餐桌',
#   '聚會',
#   '一起',
#   '分享',
#   '食用',
#   '巨鼠',
#   '朋友',
#   '兩人',
#   '掉',
#   '厚',
#   '切義式',
#   '香料',
#   '里',
#   '肌',
#   '豬排',
#   '整份',
#   '餐',
#   '含有',
#   '厚切',
#   '豬排',
#   '生菜沙拉',
#   '金黃',
#   '脆薯',
#   '特製',
#   '豬排',
#   '沾醬',
#   '脆薯',
#   '剛剛',
#   '熱炸',
#   '新鮮',
#   '上桌',
#   '真的',
#   '燙口',
#   '已經',
#   '炸好',
#   '放涼',
#   '客人',
#   '點餐',
#   '那種',
#   '生菜',
#   '上面',
#   '有淋上',
#   '醬汁',
#   '酸酸',
#   '開胃',
#   '滋味',
#   '酸甜',
#   '味道',
#   '好像',
#   '之前',
#   '吃過',
#   '巴薩',
#   '米醋',
#   '身為',
#   '主角',
#   '厚切',
#   '義式',
#   '香料',
#   '里',
#   '肌',
#   '豬排',
#   '部分',
#   '店家',
#   '使用',
#   '現在',
#   '盛行',
#   '低溫',
#   '烹調',
#   '舒肥',
#   '方式',
#   '豬排',
#   '溫度',
#   '左右',
#   '進行',
#   '緩慢',
#   '熟成',
#   '料理',
#   '手法',
#   '於今',
#   '年',
#   '台灣',
#   '各地',
#   '餐廳',
#   '普遍',
#   '聽到',
#   '優點',
#   '巨鼠',
#   '聽過',
#   '兩點',
#   '度均',
#   '溫讓',
#   '蛋白質',
#   '纖維',
#   '破壞',
#   '肉質',
#   '軟嫩',
#   '店家',
#   '進行',
#   '舒肥',
#   '後',
#   '再',
#   '火',
#   '煎',
#   '兩面',
#   '最後',
#   '入',
#   '烤箱',
#   '火烤',
#   '繁複',
#   '工序',
#   '這道',
#   '厚切',
#   '義式',
#   '香料',
#   '里',
#   '肌',
#   '豬排',
#   '送',
#   '上桌',
#   '表面',
#   '炙燒',
#   '烙痕',
#   '真的',
#   '美味',
#   '豬排',
#   '上方',
#   '看到',
#   '塗上',
#   '厚厚',
#   '一層',
#   '醬汁',
#   '醬汁',
#   '品嘗',
#   '磚塊',
#   '豬肋排',
#   '甜',
#   '中',
#   '鹹',
#   '好',
#   '涮',
#   '嘴',
#   '好',
#   '美味',
#   '厚切',
#   '義式',
#   '香料',
#   '里',
#   '肌',
#   '豬排',
#   '吃軟',
#   '嫩',
#   '有別於',
#   '以往',
#   '吃過',
#   '豬排',
#   '口感',
#   '確切',
#   '來說',
#   '這是',
#   '一塊',
#   '吃',
#   '牛肉',
#   '豬排',
#   '肉質',
#   '略帶',
#   '粉紅',
#   '口感',
#   '脆嫩',
#   '帶汁',
#   '肥厚',
#   '卻',
#   '老柴',
#   '店家',
#   '精選',
#   '整塊',
#   '原肉',
#   '手切',
#   '一塊',
#   '里',
#   '肌',
#   '肥瘦',
#   '兼具',
#   '吃肉',
#   '軟嫩',
#   '有時',
#   '吃',
#   '筋',
#   '嚼',
#   '感',
#   '一次',
#   '滿足',
#   '兩種',
#   '口感',
#   '喜好',
#   '消費者',
#   '朋友',
#   '不愛吃',
#   '筋',
#   '部位',
#   '愛',
#   '咀嚼',
#   '吃全',
#   '瘦肉',
#   '部位',
#   '我則',
#   '吃',
#   '半筋',
#   '半肉處',
#   '整體',
#   '份量',
#   '足夠',
#   '適合',
#   '一起',
#   '共享',
#   '吃',
#   '牛',
#   '朋友',
#   '來到',
#   '飛',
#   '饗',
#   '義',
#   '法典',
#   '藏',
#   '料理',
#   '能品',
#   '嘗',
#   '看看',
#   '這道',
#   '費工',
#   '製作',
#   '美味',
#   '料理',
#   '吃',
#   '開心',
#   '飽足',
#   '打卡',
#   '贈送',
#   '海鹽',
#   '脆薯',
#   '剛熱炸',
#   '上桌',
#   '薯條',
#   '美味',
#   '上方',
#   '海鹽',
#   '增添',
#   '些微',
#   '鹹味',
#   '不錯',
#   '焗',
#   '烤',
#   '起士',
#   '海鹽',
#   '脆薯',
#   '脆薯',
#   '起司',
#   '焗',
#   '烤',
#   '起司',
#   '控',
#   '最愛',
#   '滋味',
#   '鹹',
#   '香',
#   '誘人',
#   '吃',
#   '還會',
#   '牽絲',
#   '喔',
#   '套餐',
#   '加價',
#   '飲品',
#   '私藏',
#   '冰',
#   '鑽',
#   '咖啡',
#   '整份',
#   '私藏',
#   '冰',
#   '鑽',
#   '咖啡',
#   '送上',
#   '一大',
#   '組',
#   '好看',
#   '好玩',
#   '分別',
#   '濃縮',
#   '咖',
#   '咖',
#   '冷凍',
#   '製成',
#   '冰塊',
#   '試管',
#   '濃縮',
#   '咖啡',
#   '燈泡',
#   '鮮奶',
#   '巧克力',
#   '餅乾',
#   '棒',
#   '彩色',
#   '棉花',
#   '糖',
#   '鑽石',
#   '攪拌',
#   '匙',
#   '正',
#   '火紅',
#   '超夯',
#   '燈泡',
#   '試管',
#   '一起',
#   '送上',
#   '私藏',
#   '冰',
#   '鑽',
#   '咖啡',
#   '飲用',
#   '方法',
#   '簡單',
#   '全部',
#   '加進去',
#   '斟酌',
#   '喜歡',
#   '咖啡',
#   '濃度',
#   '調整',
#   '奶量',
#   '濃縮',
#   '咖啡',
#   '量',
#   '喔',
#   '錄影',
#   '取代',
#   '拍照',
#   '好懶',
#   '進食',
#   '巨鼠',
#   '吃喝玩樂',
#   '小天地',
#   '分享',
#   '貼文年',
#   '月',
#   '月',
#   '上午',
#   '張貼',
#   '私藏',
#   '冰',
#   '鑽',
#   '咖啡',
#   '全部一次',
#   '倒進去',
#   '加',
#   '一起',
#   '地品',
#   '嘗無糖',
#   '鐵',
#   '味道',
#   '醇口',
#   '咖啡',
#   '冰鑽塊',
#   '溶化',
#   '咖啡',
#   '濃度',
#   '冰',
#   '咖啡',
#   '稀釋',
#   '掉',
#   '越來越',
#   '濃醇',
#   '重',
#   '咖啡因',
#   '上癮',
#   '喜歡',
#   '濃度',
#   '套餐',
#   '加價',
#   '飲品',
#   '招牌',
#   '秘密',
#   '花園',
#   '玫瑰花',
#   '茶',
#   '最後',
#   '一道',
#   '飲品',
#   '送上',
#   ...],
#  ['騷烤',
#   '家',
#   '前鋒',
#   '總店',
#   ' ',
#   '之前',
#   '住',
#   '日木',
#   '本來',
#   '騷烤',
#   '家',
#   '吃',
#   '晚餐',
#   '當天',
#   '組',
#   '部落',
#   '客約',
#   '約',
#   '喬喬',
#   '昨天',
#   '終於',
#   '阿熊',
#   '吃',
#   '騷烤',
#   '家',
#   '火車站',
#   '後',
#   '站',
#   '成',
#   '育樂',
#   '街',
#   '附近',
#   '不算',
#   '難',
#   '找常',
#   '火車站',
#   '附近',
#   '遊走',
#   '卻',
#   '鮮少',
#   '騎到',
#   '這區',
#   '騷烤',
#   '家',
#   '台南市',
#   '東區',
#   '前鋒',
#   '路號',
#   '定時',
#   '公休',
#   '先看',
#   '粉絲',
#   '專頁',
#   '公告',
#   '門口',
#   '高掛',
#   '紅燈籠',
#   '夜晚',
#   '放鬆',
#   '感覺',
#   '人數',
#   '吧台',
#   '區',
#   '簡單',
#   '吃個',
#   '炒飯',
#   '配',
#   '一兩樣',
#   '烤物',
#   '比較',
#   '特別',
#   '店',
#   '大大的',
#   '投影幕',
#   '播放',
#   '新聞',
#   '邊吃',
#   '燒烤',
#   '看電視',
#   '騷烤',
#   '家',
#   '沒什麼',
#   '裝潢',
#   '海安',
#   '路',
#   '路邊',
#   '出現',
#   '燒烤店',
#   '座位',
#   '分為',
#   '兩區',
#   '總共',
#   '多個',
#   '位置',
#   '兩區',
#   '搭',
#   '遮雨棚',
#   '下雨',
#   '影響',
#   '喔',
#   '這次',
#   '坐',
#   '比較',
#   '裡面',
#   '區域',
#   '燈光',
#   '比較',
#   '亮',
#   '感覺',
#   '比較',
#   '溫暖',
#   '些',
#   '聽說',
#   '騷烤',
#   '家',
#   '假日',
#   '人四是',
#   '人',
#   '比較',
#   '少',
#   '平日',
#   '九點',
#   '左右',
#   '人到',
#   '騷烤',
#   '家',
#   '小酌',
#   '一番',
#   '碗',
#   '杯子',
#   '櫃台',
#   '附近',
#   '自取',
#   '好好',
#   '放在',
#   '烘碗',
#   '機裡',
#   '灰塵',
#   '飲料',
#   '自取',
#   '清楚',
#   '貼',
#   '價格',
#   '冷藏櫃',
#   '上頭',
#   '清楚',
#   '寫上',
#   '騷烤',
#   '家',
#   '理念',
#   '老闆',
#   '說',
#   '大部分',
#   '店家',
#   '則是',
#   '炸過',
#   '再',
#   '紅外線',
#   '烤騷',
#   '烤家',
#   '堅持',
#   '木炭',
#   '鹽',
#   '烤',
#   '保留',
#   '食物',
#   '最佳',
#   '風味',
#   '酒',
#   '飲料',
#   '喝酒',
#   '喝開',
#   '喜',
#   '最爽',
#   '價位',
#   '表',
#   '餐點',
#   '醬',
#   '烤',
#   '油條',
#   '酥脆',
#   '豆皮',
#   '鹽',
#   '烤豬',
#   '肋排',
#   '酥脆',
#   '七里香',
#   '鹽',
#   '烤',
#   '甜不辣',
#   '酥脆',
#   '七里香',
#   '酥',
#   '炸',
#   '肥腸',
#   '農家',
#   '小炒',
#   '肉',
#   '鹹',
#   '酥',
#   '豬肝',
#   '鹽',
#   '烤',
#   '甜不辣',
#   '氣',
#   '酥脆',
#   '雞腿',
#   '蔬菜',
#   '雙拼',
#   '蒜頭',
#   '雞小',
#   '餐點',
#   '內容',
#   '乾',
#   '一杯',
#   '烏龍茶',
#   '餐點',
#   '就咻咻咻',
#   '上桌',
#   '之快',
#   '品味',
#   '烤',
#   '蛤',
#   '仔元',
#   '蛤蜊',
#   '新鮮肉',
#   '嫩',
#   '好像',
#   '海裡',
#   '撈',
#   '加入',
#   '米酒',
#   '蛤蜊',
#   '鮮美',
#   '外還',
#   '帶些',
#   '酒香',
#   '阿熊別',
#   '浪費',
#   '盒內',
#   '湯汁',
#   '喝',
#   '光光',
#   '農家',
#   '小炒',
#   '肉元騷',
#   '烤家',
#   '烤物',
#   '炒',
#   '老闆娘',
#   '來自',
#   '大陸',
#   '覺得',
#   '家鄉',
#   '吃',
#   '一道',
#   '覺得',
#   '美味',
#   '加入',
#   '菜單',
#   '肉嫩',
#   '炒',
#   '青',
#   '辣椒',
#   '香辣',
#   '開胃',
#   '辣度',
#   '需要',
#   '配',
#   '飲料',
#   '愛吃辣',
#   '朋友',
#   '點',
#   '一份',
#   '喔',
#   '蔬菜',
#   '雙拼',
#   '元',
#   '吃',
#   '燒烤',
#   '一定',
#   '要來',
#   '份',
#   '蔬菜',
#   '一份',
#   '青椒',
#   '香菇',
#   '組成',
#   '烤乾',
#   '保有',
#   '水份',
#   '香菇',
#   '吃水',
#   '嫩',
#   '水嫩',
#   '青椒',
#   '清脆',
#   '帶有',
#   '炭香及',
#   '芝麻',
#   '香刷',
#   '甜甜',
#   '鹹鹹的',
#   '醬汁',
#   '超級',
#   '清爽',
#   '好',
#   '入口',
#   '鹹',
#   '酥',
#   '豬肝',
#   '元',
#   '一份',
#   '老闆',
#   '推薦',
#   '阿熊',
#   '覺得',
#   '豬肝',
#   '太乾',
#   '覺得',
#   '粉粉',
#   '太',
#   '硬',
#   '鹹',
#   '酥',
#   '口味',
#   '適合',
#   '下酒菜',
#   '鹹',
#   '香入裡',
#   '涮',
#   '嘴',
#   '鹽',
#   '烤',
#   '甜不辣',
#   '元',
#   '一份',
#   '明明',
#   '普通',
#   '知道',
#   '好吃',
#   '意思',
#   '喜歡',
#   '外皮',
#   '脆',
#   '甜不辣',
#   '這份',
#   '外皮',
#   '焦脆',
#   '耶',
#   '中間',
#   '軟嫩彈',
#   '帶有',
#   '魚漿',
#   '香氣',
#   '莫名',
#   '一直',
#   '夾它',
#   '塞進',
#   '嘴裡',
#   '這份',
#   '鹽',
#   '烤',
#   '甜不辣',
#   '超',
#   '好吃',
#   '必點',
#   '之後',
#   '查',
#   '一下',
#   '資料',
#   '騷烤',
#   '家用',
#   '甜不辣',
#   '委託',
#   '台南',
#   '年',
#   '老店',
#   '遵循',
#   '古法',
#   '每日',
#   '手工',
#   '現作',
#   '濃濃',
#   '魚漿',
#   '不含',
#   '雜粉',
#   '好吃',
#   '扭',
#   '蒜頭',
#   '雞小元',
#   '這份',
#   '老闆',
#   '推薦',
#   '兩個',
#   '人',
#   '喝小份',
#   '裡面',
#   '雞肉',
#   '塊',
#   '蒜頭',
#   '飽滿',
#   '蒜頭',
#   '煮',
#   '綿綿',
#   '辛口',
#   '直接',
#   '吃',
#   '雞肉',
#   '嫩',
#   '好像',
#   '雞肉',
#   '界',
#   '小寶寶',
#   '湯也',
#   '夭壽',
#   '好喝',
#   '雞肉',
#   '高麗菜',
#   '蒜頭',
#   '煮',
#   '甘甜',
#   '這鍋',
#   '很快',
#   '喝到',
#   '見底',
#   '天冷',
#   '一鍋',
#   '不錯',
#   '選擇',
#   '推推',
#   '人氣',
#   '酥脆',
#   '雞腿',
#   '元',
#   '一份',
#   '阿熊想',
#   '吃',
#   '覺得',
#   '想像',
#   '以為',
#   '炸雞腿',
#   '酥脆',
#   '雞腿',
#   '表皮',
#   '烤',
#   '薄',
#   '中間',
#   '肉扎實',
#   '新鮮',
#   '油',
#   '屬於',
#   '口味',
#   '比較',
#   '清淡',
#   '些',
#   '沾些',
#   '胡椒',
#   '鹽',
#   '比較',
#   '美味',
#   '酥脆',
#   '七里香',
#   '元',
#   '一份',
#   '覺得',
#   '酥脆',
#   '雞腿',
#   '路線',
#   '外皮',
#   '薄脆',
#   '中間',
#   '肉嫩',
#   '帶有',
#   '肉汁',
#   '這份',
#   '繃',
#   '繃',
#   '感覺',
#   '一點兒',
#   '油膩',
#   '喜歡',
#   '雞屁股',
#   '錯過',
#   '醬',
#   '烤',
#   '油條',
#   '元',
#   '這份',
#   '老闆',
#   '推薦',
#   '吃',
#   '服務',
#   '人員',
#   '幫端',
#   '叮嚀',
#   '先吃脆',
#   '脆',
#   '口感',
#   '最棒',
#   '愛',
#   '油條',
#   '不脆',
#   '油會',
#   '人',
#   '感傷',
#   '騷烤',
#   '家',
#   '這份',
#   '醬',
#   '烤',
#   '油條',
#   '不油',
#   '喔',
#   '上面',
#   '烤醬',
#   '十分',
#   '討喜脆',
#   '香',
#   '吃',
#   '滿嘴',
#   '油膩',
#   '值得',
#   '一吃',
#   '酥脆',
#   '豆皮元',
#   '一份',
#   '騷烤',
#   '家',
#   '得意之作',
#   '地方',
#   '吃',
#   '不到',
#   '喔',
#   '拍',
#   '油條',
#   '相',
#   '好吃',
#   '外皮',
#   '超級',
#   '酥脆',
#   '會喀滋喀滋',
#   '中間',
#   '豆皮',
#   '濕潤且',
#   '香濃',
#   '豆香',
#   '烤',
#   '醬',
#   '醬',
#   '烤',
#   '油條',
#   '相似',
#   '同樣',
#   '鹹',
#   '甜',
#   '夠味',
#   '兩樣',
#   '路線',
#   '美味',
#   '好吃',
#   '必點',
#   '酥',
#   '炸',
#   '肥腸',
#   '元',
#   '一份',
#   '老闆',
#   '推薦',
#   '表皮',
#   '顏色',
#   '很漂亮',
#   '完全',
#   '油膩感',
#   '完全',
#   '腥味',
#   '好',
#   '嚼',
#   '之外',
#   '內層',
#   '軟嫩',
#   '帶點',
#   '蔥',
#   '香特愛',
#   '肥腸',
#   '阿熊',
#   '喜歡',
#   '一道',
#   '鹽',
#   '烤豬',
#   '肋',
#   '排元',
#   '一份',
#   '四支',
#   '肉質',
#   '不柴',
#   '嚼',
#   '費力',
#   '稠狀',
#   '醬料',
#   '沾點',
#   '胡椒',
#   '提味',
#   '好吃',
#   '偏愛',
#   '外表',
#   '再',
#   '焦脆',
#   '一些',
#   '開心',
#   '吃飯',
#   '喊',
#   '餓',
#   '大胃',
#   '王阿熊',
#   '吃',
#   '滿滿',
#   '一桌',
#   '超',
#   '澎湃',
#   '吃光',
#   '老闆',
#   '推薦',
#   '蒜頭',
#   '雞鹽',
#   '烤',
#   '甜不辣',
#   '酥',
#   '炸',
#   '肥腸',
#   '醬',
#   '烤',
#   '油條',
#   '酥炸豆',
#   '皮',
#   '鹹',
#   '酥',
#   '豬肝',
#   '品味',
#   '烤蛤仔',
#   '幾樣',
#   '經典',
#   '知道',
#   '吃',
#   '參考',
#   '幾樣',
#   '再',
#   '增加',
#   '幾樣',
#   '平常',
#   '喜歡',
#   '喔',
#   '騷烤',
#   '家',
#   '無論是',
#   '炒',
#   '湯品',
#   '串燒',
#   '肉質',
#   '相當',
#   '嫩皮',
#   '薄',
#   '好好',
#   '鎖住',
#   '肉汁',
#   '脆',
#   '油香',
#   '不膩',
#   '食材',
#   '不錯',
#   '烤功',
#   '當天',
#   '服務',
#   '人員',
#   '熱情',
#   '親切',
#   '一直',
#   '積極',
#   '幫',
#   '收盤',
#   '子',
#   '住手',
#   '上面',
#   '椒鹽',
#   '我還',
#   '沾',
#   '夠朋友',
#   '聚餐',
#   '宵',
#   '夜場',
#   '小酌',
#   '兩杯',
#   '適合',
#   '喔',
#   '分享',
#   '囉',
#   '騷烤',
#   '家',
#   '資訊',
#   '台南市',
#   '東區',
#   '前鋒',
#   '路號',
#   '定時',
#   '公休',
#   '先看',
#   '粉絲',
#   '專頁',
#   '公告',
#   '讚',
#   '接收',
#   '第一手',
#   '好吃',
#   '好玩',
#   '訊息',
#   '喔',
#   '本篇',
#   '食',
#   '部落',
#   '騷烤',
#   '家',
#   '合作',
#   '下載',
#   '食',
#   '免費',
#   '超',
#   '省錢',
#   '優惠',
#   '下載',
#   '連結',
#   '騷烤',
#   '家',
#   '優惠',
#   '輸入',
#   '優惠',
#   '序號',
#   '無限',
#   '次',
#   '使用',
#   '專屬',
#   '優惠',
#   '喔',
#   '這天',
#   '來到',
#   '府城',
#   '騷烤',
#   '家',
#   '吃',
#   '燒烤',
#   '本來',
#   '挺',
#   '擔心',
#   '位置',
#   '火車站',
#   '應該',
#   '很難',
#   '停車',
#   '出乎意外',
#   '超好',
#   '停車',
#   '說',
#   '以前',
#   '很常',
#   '台南',
#   '火車站',
#   '附近',
#   '繞',
#   '卻',
#   '發現',
#   '這家',
#   '店',
#   '這家',
#   '店',
#   '競爭',
#   '台南美食',
#   '界',
#   '已經',
#   '存活',
#   '七年',
#   '想必',
#   '過人之處',
#   '店家',
#   '座位',
#   '熱炒',
#   '店',
#   '氣氛',
#   '吧檯',
#   '區的',
#   '座位',
#   '店',
#   '外頭',
#   '冰櫃',
#   '放',
#   '當日',
#   '現',
#   '進食',
#   '材',
#   '賣完',
#   '囉',
#   '手腳',
#   '店家',
#   '現點',
#   '現烤',
#   '生食',
#   '烤',
#   '熟食',
#   '需要',
#   '耐心',
#   '等候',
#   '店家',
#   '菜單',
#   '約莫',
#   '幾種',
#   '標騷',
#   '字樣',
#   '店家',
#   '推薦',
#   '菜色',
#   '喔',
#   '酥脆',
#   '豆皮',
#   '豆皮',
#   '吃',
#   '酥',
#   '酥脆',
#   '脆',
#   '帶些',
#   '燒烤',
#   '香氣',
#   '越',
#   '吃',
#   '涮',
#   '嘴',
#   '感覺',
#   '鹽',
#   '烤',
#   '甜不辣',
#   '老闆',
#   '十顧',
#   '茅廬',
#   '得到',
#   '魚漿',
#   '材料',
#   '店家',
#   '獲得',
#   '入選',
#   '台南',
#   '府城',
#   '觀光',
#   '護照',
#   '以現',
#   '做',
#   '魚漿',
#   '製成',
#   '甜不辣',
#   '吃',
#   '有種',
#   '綿綿',
#   '口感',
#   '放久',
#   '甜不辣',
#   '增加',
#   '脆度',
#   '好吃',
#   '咖哩',
#   '牛',
#   '肋條',
#   '手工',
#   '牛',
#   '肋條',
#   '肉質',
#   '嚼',
#   '勁',
#   '咖哩',
#   '醃製',
#   '六小時',
#   '後',
#   '咖哩',
#   '味',
#   '融入',
#   '牛',
#   '肋條',
#   '裡',
#   '黑胡椒',
#   '牛',
#   '肋條',
#   '更愛的',
#   '黑胡椒',
#   '牛',
#   '肋條',
#   '吃',
#   '肉質',
#   '更嫩',
#   '蔬菜',
#   '雙拼',
#   '青椒',
#   '香菇',
#   '雙拼',
#   '超',
#   '好吃',
#   '青椒',
#   '烤過',
#   '乾',
#   '保有',
#   '脆度',
#   '香菇',
#   '水分',
#   '鎖住',
#   '超級',
#   '多汁',
#   '掃',
#   '完整',
#   '盤',
#   '蔬菜',
#   '頂級',
#   '松阪',
#   '豬肉',
#   '不愧',
#   '頂級',
#   '肉',
#   '紋理',
#   '超',
#   '分明',
#   '松阪',
#   '豬肉',
#   '雖有',
#   '嚼',
#   '勁',
#   '卻',
#   '好',
#   '咬',
#   '喔',
#   '醬',
#   '烤',
#   '油條',
#   '火鍋',
#   '名菜',
#   '油條',
#   '燒烤',
#   '想',
#   '應該',
#   '獨步',
#   '全',
#   '台',
#   '透過',
#   '火烤',
#   '逼',
#   '油條',
#   '吃',
#   '油膩',
#   '酥脆',
#   '感',
#   '醬料',
#   '吃香',
#   '帶些',
#   '甜味',
#   '米酒',
#   '加柴',
#   '魚片',
#   '麥芽',
#   '調',
#   '成',
#   '獨家',
#   '醬料',
#   '級',
#   '秋刀魚',
#   '他家',
#   '整隻',
#   '魚是',
#   '燒烤',
#   '保留',
#   '魚肉',
#   '水分',
#   '不小',
#   '筷子',
#   '長度',
#   '本來',
#   '擔心',
#   '刺',
#   '老闆',
#   '俐落',
#   '幾個',
#   '步驟',
#   '幫',
#   '去除',
#   '魚刺',
#   '鹽',
#   '酥',
#   '杏鮑菇',
#   '外面',
#   '酥脆',
#   '炸皮裡',
#   '面則',
#   '多汁',
#   '杏鮑菇',
#   '吃',
#   '一個',
#   '接',
#   '一個',
#   '川味',
#   ...],
#  ['小',
#   '銅鍋',
#   '義式',
#   '餐廳',
#   '德安',
#   '誠品',
#   '店',
#   ' ',
#   '位於',
#   '德安',
#   '百貨',
#   '小',
#   '銅鍋',
#   '提供',
#   '多樣',
#   '義式',
#   '料理',
#   '排餐',
#   '招牌',
#   '舒芙蕾',
#   '飲品',
#   '甜食',
#   '環境',
#   '寬敞',
#   '清幽',
#   '質感',
#   '後方',
#   '座位',
#   '區還',
#   '透過',
#   '落地',
#   '玻璃',
#   '遠眺',
#   '綠意',
#   '公園',
#   '整個',
#   '用餐',
#   '感覺',
#   '放鬆',
#   '情侶',
#   '約會',
#   '姊妹',
#   '聚會',
#   '不錯',
#   '呦',
#   '適合',
#   '多人',
#   '聚餐',
#   '活動',
#   '再',
#   '汽車',
#   '機車',
#   '停放',
#   '方便',
#   '更是',
#   '用餐',
#   '好',
#   '地點',
#   '搭',
#   '電梯',
#   '抵達',
#   '走出',
#   '電梯門',
#   '看見',
#   '小',
#   '銅鍋',
#   '百貨公司',
#   '設計',
#   '裝潢',
#   '感覺',
#   '很棒',
#   '一旁',
#   '誠品',
#   '書店',
#   '用餐',
#   '後',
#   '還能',
#   '找',
#   '找',
#   '書籍',
#   '逛商場',
#   '小',
#   '銅鍋',
#   '用餐',
#   '只',
#   '一次',
#   '裝潢',
#   '沒什麼',
#   '變化',
#   '倒',
#   '這天',
#   '遇上',
#   '一群',
#   '辦',
#   '活動',
#   '聚餐',
#   '客人',
#   '聲音',
#   '控制',
#   '用餐',
#   '過程',
#   '並不受',
#   '影響',
#   '整個',
#   '空間',
#   '裡',
#   '座位',
#   '數量',
#   '挺',
#   '喜歡',
#   '安排',
#   '座位',
#   '間距',
#   '挺',
#   '寬敞',
#   '擁擠',
#   '只不過',
#   '圓桌',
#   '安排',
#   '四人桌',
#   '用餐',
#   '太',
#   '問題',
#   '走',
#   '最後',
#   '方有',
#   '一大',
#   '面',
#   '落地',
#   '玻璃',
#   '透入',
#   '明亮',
#   '光線',
#   '望出去',
#   '視野',
#   '自然',
#   '好好',
#   '愛',
#   '坐在',
#   '窗邊',
#   '位置',
#   '餐時',
#   '還能',
#   '望出去',
#   '看看',
#   '綠意',
#   '那端',
#   '公園',
#   '景色',
#   '底下人',
#   '車',
#   '來往',
#   '熱鬧',
#   '畫面',
#   '放個',
#   '空個',
#   '餐',
#   '悠閒',
#   '隔壁',
#   '台南',
#   '文化',
#   '中心',
#   '家庭',
#   '朋友',
#   '相約',
#   '散散步',
#   '這一區',
#   '假日',
#   '熱鬧',
#   '不行',
#   '愜意',
#   '安靜',
#   '時光',
#   '下',
#   '走動',
#   '來往',
#   '人車',
#   '倒',
#   '一種',
#   '對比',
#   '小',
#   '銅鍋',
#   '招牌',
#   '餐點',
#   '披薩',
#   '油品',
#   '披薩',
#   '料理',
#   '區旁',
#   '展示',
#   '直接',
#   '看著',
#   '廚師',
#   '一邊',
#   '挪',
#   '麵',
#   '粉入',
#   '烤箱',
#   '放',
#   '配料',
#   '美味',
#   '畫面',
#   '整個',
#   '採',
#   '開放式',
#   '製作',
#   '過程',
#   '小',
#   '銅鍋',
#   '水',
#   '藍色',
#   '餐本',
#   '還滿',
#   '慢活',
#   '步調',
#   '感覺',
#   '餐點',
#   '多樣化',
#   '唷',
#   '主以',
#   '義式',
#   '料理',
#   '為主',
#   '主餐',
#   '排餐',
#   '選擇',
#   '主廚',
#   '秘',
#   '製',
#   '酥',
#   '炸',
#   '德國',
#   '豬腳',
#   '莎妞',
#   '每來',
#   '必畫',
#   '餐點',
#   '值得一提的是',
#   '舒芙蕾',
#   '更是',
#   '必點餐',
#   '後',
#   '甜食',
#   '唷',
#   '飲料',
#   '選項',
#   '挺',
#   '豐富',
#   '點來',
#   '配主餐',
#   '吃',
#   '飽足',
#   '幸福感',
#   '不知',
#   '何點',
#   '推薦',
#   '直接',
#   '選擇',
#   '分享',
#   '餐',
#   '共有',
#   '三種',
#   '人',
#   '組合',
#   '方式',
#   '莎妞莎媽',
#   '莎嬤來',
#   '吃',
#   '午餐',
#   '選擇',
#   '人',
#   '分享',
#   '餐再',
#   '加點',
#   '一份',
#   '披薩',
#   '滿足',
#   '低消',
#   '規定',
#   '義大利',
#   '麵',
#   '燉',
#   '飯',
#   '披薩',
#   '種',
#   '種類',
#   '選',
#   '一份',
#   '沙拉',
#   '開胃菜',
#   '主菜',
#   '種',
#   '種類',
#   '各選',
#   '一份',
#   '例湯',
#   '飲',
#   '品種',
#   '種類',
#   '各選',
#   '二份',
#   '用餐',
#   '需',
#   '加收',
#   '一成',
#   '服務費',
#   '兩份',
#   '例湯',
#   '法國',
#   '麵',
#   '包湯品',
#   '有義式',
#   '巧達',
#   '濃湯',
#   '及義式',
#   '番茄',
#   '濃湯',
#   '選任',
#   '選',
#   '兩款',
#   '義式',
#   '巧達',
#   '濃湯',
#   '鮮紅',
#   '新鮮',
#   '番茄',
#   '下去',
#   '熬',
#   '湯湯',
#   '品',
#   '色澤',
#   '實在',
#   '亮眼',
#   '開胃',
#   '想大口',
#   '喝',
#   '小心',
#   '湯品',
#   '燙',
#   '口',
#   '喔',
#   '湯品',
#   '一點',
#   '馬虎',
#   '唷',
#   '撈起來',
#   '好多',
#   '配料',
#   '喜歡',
#   '番茄',
#   '酸香',
#   '清爽',
#   '紅蘿蔔',
#   '薄片',
#   '嚼',
#   '軟軟',
#   '湯口酸香',
#   '明顯',
#   '刺激',
#   '食慾',
#   '唷',
#   '義式',
#   '巧達',
#   '濃湯',
#   '裡頭',
#   '放',
#   '許多',
#   '蘑菇',
#   '濃湯',
#   '熱呼',
#   '奶香',
#   '濃郁',
#   '份量',
#   '很大',
#   '碗',
#   '整個',
#   '套餐',
#   '量',
#   '還滿',
#   '豐富',
#   '稍微',
#   '暖個',
#   '胃',
#   '覺得',
#   '唷',
#   '法國',
#   '麵',
#   '包',
#   '套餐',
#   '湯品',
#   '附',
#   '法國',
#   '麵',
#   '包',
#   '法國',
#   '麵',
#   '包',
#   '組織',
#   '帶有',
#   '嚼',
#   '勁',
#   '口感',
#   '麵',
#   '包香',
#   '瀰漫',
#   '嘴裡',
#   '沾',
#   '巧達',
#   '濃湯',
#   '提味',
#   '奶香',
#   '好吃',
#   '套餐',
#   '選',
#   '二杯',
#   '飲品',
#   '雪碧冰',
#   '美式',
#   '美式',
#   '咖啡',
#   '酸澀',
#   '順口',
#   '正好',
#   '搭',
#   '披薩',
#   '比較',
#   '不乾口',
#   '白酒',
#   '蒸烤',
#   '香草',
#   '海鮮',
#   '套餐',
#   '選',
#   '一道',
#   '開胃菜',
#   '喜愛',
#   '海鮮',
#   '料理',
#   '朋友',
#   '莎',
#   '妞',
#   '推薦',
#   '一款',
#   '莎妞想',
#   '吃',
#   '蝦子',
#   '就點',
#   '海鮮',
#   '食材',
#   '不讓',
#   '人',
#   '失望',
#   '海鮮',
#   '蝦子',
#   '蛤蠣',
#   '花枝',
#   '玉米',
#   '筍',
#   '花椰菜',
#   '菇類',
#   '感覺',
#   '洋蔥',
#   '為底',
#   '熬',
#   '煮湯',
#   '頭',
#   '加入',
#   '海鮮',
#   '熬',
#   '煮',
#   '嚐',
#   '相當',
#   '鹹',
#   '香',
#   '帶上',
#   '甜',
#   '唷',
#   '湯量',
#   '真的',
#   '多分',
#   '喝',
#   '還真',
#   '有點',
#   '過癮',
#   '櫃檯',
#   '旁有',
#   '提供',
#   '兒童',
#   '餐具',
#   '方便',
#   '孩子',
#   '用餐',
#   '家庭',
#   '提供',
#   '餐具',
#   '木碗',
#   '需要',
#   '再',
#   '拿取',
#   '自行',
#   '取用',
#   '木碗',
#   '裝',
#   '海鮮',
#   '吃',
#   '感覺',
#   '很棒',
#   '蝦肉',
#   '彈脆',
#   '鮮香',
#   '花枝',
#   '彈牙',
#   '蛤蠣',
#   '飽滿',
#   '顆',
#   '湯頭',
#   '真的',
#   '濃郁',
#   '義式',
#   '番茄',
#   '沙拉',
#   '餐點',
#   '前',
#   '先來',
#   '份',
#   '沙拉',
#   '清爽',
#   '一下',
#   '味蕾',
#   '裡頭',
#   '生菜',
#   '番茄',
#   '玉米',
#   '筍',
#   '水煮蛋',
#   '再灑',
#   '多樣',
#   '堅果',
#   '提香',
#   '口感',
#   '一盤',
#   '份量',
#   '不小',
#   '耶三人分',
#   '吃',
#   '前面',
#   '湯和',
#   '麵',
#   '包及',
#   '開胃菜',
#   '已經',
#   '感覺',
#   '五六分',
#   '生菜',
#   '清脆',
#   '水潤淋上',
#   '油醋',
#   '醬汁',
#   '鹹',
#   '香',
#   '好吃',
#   '唷',
#   '嚼',
#   '堅果',
#   '顆顆',
#   '口感',
#   '香氣',
#   '番茄',
#   '增添',
#   '酸',
#   '香味',
#   '玉米',
#   '筍',
#   '甜香',
#   '脆口',
#   '西班牙',
#   '海鮮',
#   '燉',
#   '飯',
#   '這盤',
#   '海鮮',
#   '豐富',
#   '耶',
#   '滿滿的',
#   '海鮮',
#   '蛤蠣',
#   '鮮蝦',
#   '花枝',
#   '一個',
#   '淡菜',
#   '米飯',
#   '加入',
#   '特殊',
#   '香料',
#   '一起',
#   '燉煮',
#   '呈現',
#   '一種',
#   '金黃色',
#   '調',
#   '視覺',
#   '還挺',
#   '好看',
#   '感覺',
#   '吃',
#   '身心',
#   '暖呼呼',
#   '坐在',
#   '窗邊',
#   '取景',
#   '覺得',
#   '有點',
#   '好看',
#   '耶',
#   '蝦子',
#   '肥美',
#   '飽滿',
#   '好鮮',
#   '甜',
#   '蛤蠣',
#   '一顆顆',
#   '肥碩',
#   '咬下',
#   '鹹',
#   '香',
#   '湯汁',
#   '流出',
#   '拌',
#   '一口',
#   '燉',
#   '飯',
#   '溼潤',
#   '米飯',
#   '增加',
#   '鹹味',
#   '層次',
#   '風味',
#   '唷',
#   '海鮮',
#   '食材',
#   '發現',
#   '有肉塊',
#   '唷',
#   '咬',
#   '下',
#   '鹹',
#   '鹹',
#   '滋味',
#   '米飯',
#   '燉',
#   '剛剛',
#   '好帶',
#   '感且',
#   '溼潤',
#   '度',
#   '挺',
#   '特別',
#   '加入',
#   '九層',
#   '塔',
#   '一起',
#   '加入',
#   '燉煮',
#   '口感',
#   '清爽',
#   '一些',
#   '放入',
#   '嘴裡',
#   '嚼',
#   '嚼',
#   '一股',
#   '超濃',
#   '九層',
#   '塔香',
#   '瞬間',
#   '覺得',
#   '有點',
#   '台味料裡',
#   '遠方',
#   '似乎',
#   '製作',
#   '莎妞點',
#   '披薩',
#   '順手',
#   '拍',
#   '下',
#   '過程',
#   '喔',
#   '唷',
#   '切下',
#   '披薩',
#   '瞬間',
#   '傳來',
#   '咔滋聲',
#   '超',
#   '悅耳',
#   '黑松',
#   '露',
#   '大地',
#   '野菇',
#   '披薩',
#   '一定',
#   '要點',
#   '一份',
#   '披薩',
#   '底層',
#   '番茄',
#   '抹',
#   '醬',
#   '吃',
#   '酸酸',
#   '香香的',
#   '風味',
#   '原本',
#   '擔心',
#   '野菇',
#   '吃',
#   '有點',
#   '單調',
#   '沒想到',
#   '裡頭',
#   '餡料',
#   '卻',
#   '超級',
#   '每口',
#   '咬',
#   '得到',
#   '餡料',
#   '變化',
#   '滋味',
#   '黑松',
#   '露',
#   '直接',
#   '披薩',
#   '烤完',
#   '之後',
#   '一片',
#   '放',
#   '黑松',
#   '露醬',
#   '不用',
#   '擔心',
#   '吃',
#   '不到',
#   '松露',
#   '覺得',
#   '這款',
#   '披薩',
#   '還真',
#   '有點',
#   '高檔',
#   '耶',
#   '披薩',
#   '一定',
#   '吃',
#   '唷',
#   '一拉起',
#   '披薩',
#   '疼',
#   '感受',
#   '那股',
#   '起士',
#   '威力',
#   '放得',
#   '起士量',
#   '還還',
#   '真',
#   '拉絲',
#   '拉',
#   '超高',
#   '餅皮',
#   '屬於',
#   '薄脆',
#   '披薩',
#   '類型',
#   '一口',
#   '咬下',
#   '麵',
#   '皮',
#   '酥脆',
#   '香氣',
#   '薄薄的',
#   '帶上',
#   '番茄',
#   '酸感',
#   '適合',
#   '夏天',
#   '點來',
#   '吃',
#   '再來',
#   '蔬菜',
#   '玉米',
#   '筍',
#   '大量',
#   '菇類',
#   '水潤',
#   '口感',
#   '整體',
#   '風味',
#   '一整片',
#   '吃',
#   '完並',
#   '覺得',
#   '乾口',
#   '唷',
#   '莎',
#   '妞',
#   '超愛',
#   '直接',
#   '咬',
#   '中心',
#   '起士',
#   '段',
#   '鹹',
#   '香奶味',
#   '濃郁',
#   '披薩',
#   '搭',
#   '滿滿',
#   '蔬菜',
#   '意外',
#   '人',
#   '喜愛',
#   '主廚',
#   '秘',
#   '製',
#   '酥',
#   '炸',
#   '德國',
#   '豬腳',
#   '吃過',
#   '一回',
#   '愛上',
#   '豬腳',
#   '一整隻',
#   '豬腳',
#   '先',
#   '油炸',
#   '再',
#   '切成',
#   '數塊',
#   '方便',
#   '取食',
#   '一旁',
#   '搭',
#   '特製',
#   '酸菜',
#   '新鮮',
#   '蔬菜',
#   '特調',
#   '芥茉',
#   '醬',
#   '自行',
#   '提味',
#   '豬腳',
#   '炸',
#   '過後',
#   '乾口',
#   '難',
#   '嚼',
#   '外層',
#   '豬皮',
#   '炸得',
#   '酥',
#   '酥脆',
#   '脆',
#   '油膩',
#   '裡邊',
#   '肉質',
#   '好',
#   '嫩',
#   '好',
#   '嫩',
#   '中間',
#   '膠質',
#   '則是',
#   '滑溜',
#   '湯汁',
#   '依然',
#   '保留',
#   '嚼',
#   '肉',
#   '香氣',
#   '濃郁',
#   '瘦肉',
#   '部位',
#   '稍微',
#   '乾口些',
#   '整體',
#   '風味',
#   '人',
#   '喜愛',
#   '沾上',
#   '特調',
#   '芥末',
#   '醬',
#   '嗆',
#   '辣',
#   '死',
#   '甜',
#   '挺',
#   '溫和',
#   '味道',
#   '搭',
#   '酸菜',
#   '一股',
#   '淡淡的',
#   '酸香',
#   '感覺',
#   '再',
#   '吃',
#   '一塊',
#   '覺得',
#   '嘴裡',
#   '太',
#   '膩味',
#   '夾個',
#   '蔬菜',
#   '一起',
#   '搭配',
#   '吃',
#   '轉換',
#   '味道',
#   '莎妞',
#   '超愛沾',
#   '醬汁',
#   '一起',
#   '吃',
#   '了點',
#   '甜甜',
#   '香香的',
#   '氣味',
#   '單吃能',
#   '品嚐',
#   '豬腳',
#   '醃製',
#   '香氣',
#   '很好吃',
#   '囉',
#   '經典',
#   '香草',
#   '舒芙蕾',
#   '小',
#   '銅鍋',
#   '招牌',
#   '甜點',
#   '舒芙蕾',
#   '真的',
#   '別錯過',
#   '端來',
#   '快速',
#   '拍拍',
#   '一會兒',
#   '舒芙蕾',
#   '就要',
#   '塌',
#   '餡',
#   '不美哩',
#   '細看',
#   '顆顆',
#   '黑黑',
#   '小點',
#   '香',
#   '草籽',
#   '使用',
#   '份量',
#   '大方',
#   '上方',
#   '灑上',
#   '一層',
#   '雪白',
#   '糖粉',
#   '挖',
#   '下',
#   '感受',
#   '柔軟',
#   '口感',
#   '好',
#   '綿密',
#   '輕盈',
#   '帶上',
#   '水潤',
#   '感舒芙蕾',
#   '覆',
#   '附上',
#   '一顆',
#   '香草',
#   '冰淇淋',
#   '搭著',
#   '吃',
#   '冰冰涼涼',
#   '帶上',
#   '帶奶',
#   '香',
#   '濃厚',
#   '一杯',
#   '蜂蜜',
#   '自行',
#   '淋醬',
#   '增加',
#   ...],
#  ['聯盈',
#   '發點',
#   '心',
#   '專門店',
#   ' ',
#   '台南',
#   '永康',
#   '一間',
#   '港式',
#   '點心',
#   '專門店',
#   '不論什麼',
#   '門口',
#   '總是',
#   '大排長龍',
#   '好奇',
#   '神奇',
#   '魔力',
#   '這次',
#   '台南',
#   '行',
#   '第一站',
#   '來到',
#   '聯盈發',
#   '天兒',
#   '夭壽',
#   '好吃',
#   '後悔',
#   '這麼晚',
#   '認識',
#   '原文',
#   '出處',
#   '完整',
#   '圖文',
#   '更新',
#   '布丁',
#   '資訊',
#   '請',
#   '關注',
#   '布丁',
#   '粉絲',
#   '頁',
#   '聯盈發',
#   '華麗',
#   '大飯店',
#   '裝潢',
#   '第一眼',
#   '以間',
#   '平凡',
#   '地港',
#   '點店',
#   '店面',
#   '旁',
#   '附設',
#   '大型',
#   '停車場',
#   '知道',
#   '案情',
#   '肯定',
#   '車子',
#   '還沒',
#   '停妥',
#   '先',
#   '下車',
#   '菜單',
#   '卡位',
#   '能少',
#   '一組',
#   '人馬',
#   '一組',
#   '等待',
#   '時',
#   '無聊',
#   '先',
#   '參考',
#   '照片',
#   '劃',
#   '單點',
#   '餐',
#   '布丁',
#   '小',
#   '提醒',
#   '想',
#   '吃',
#   '用力',
#   '給它點',
#   '下去',
#   '客滿',
#   '時',
#   '一輪',
#   '機會',
#   '店家',
#   '忙',
#   '不給',
#   '加點',
#   '喔',
#   '桌上',
#   '備有',
#   '熱茶',
#   '茶資',
#   '另收',
#   '絲襪',
#   '奶茶',
#   '水準',
#   '香港',
#   '喝',
#   '味道',
#   '神似',
#   '吃',
#   '脆皮',
#   '叉燒包',
#   '之前',
#   '心中',
#   '覺得',
#   '這道',
#   '菜色',
#   '最',
#   '經典',
#   '添',
#   '好運',
#   '店家',
#   '想要',
#   '超越',
#   '應該',
#   '困難',
#   '真是',
#   '大錯特錯',
#   '第一道',
#   '臉',
#   '外皮',
#   '酥',
#   '香到',
#   '不像話',
#   '真是',
#   '一山',
#   '一山',
#   '高薄',
#   '透',
#   '外皮',
#   '蝦仁',
#   '腸粉',
#   '露出',
#   '粉紅',
#   '光裡頭',
#   '蝦仁',
#   '跟本',
#   '巨無霸',
#   '著皮',
#   '餡',
#   '一等一',
#   '彈牙',
#   '店家',
#   '會將',
#   '蝦餃',
#   '店',
#   '命名',
#   '聯盈發',
#   '蝦餃',
#   '皇',
#   '例外',
#   '判斷',
#   '一間',
#   '港點',
#   '餐廳',
#   '好不好吃',
#   '點',
#   '蝦餃',
#   '略知一二',
#   '飽滿',
#   '蝦',
#   '餡裡',
#   '吃',
#   '大塊',
#   '蝦肉',
#   '剁',
#   '碎碎的',
#   '蝦',
#   '泥',
#   '比擬',
#   '喔',
#   '一道',
#   '豎起',
#   '大姆指',
#   '菜色',
#   '港式',
#   '牛肉',
#   '撈',
#   '麵',
#   '牛肉',
#   '香',
#   '軟綿',
#   '魚子',
#   '鳳眼',
#   '餃上',
#   '散發',
#   '美食',
#   '可口',
#   '內在',
#   '光亮',
#   '華美',
#   '外衣',
#   '重要',
#   '霸王',
#   '蝦鮮',
#   '金魚',
#   '是不是',
#   '超',
#   '可愛',
#   '小朋友',
#   '肯定',
#   '愛',
#   '一味',
#   '捨不得',
#   '吃',
#   '下肚',
#   '聯盈發',
#   '鮮蝦',
#   '愛好者',
#   '天堂',
#   '鮮美',
#   '蝦',
#   '餡',
#   '出沒',
#   '各道',
#   '好料',
#   '中',
#   '湯匙',
#   '一顆',
#   '沙拉',
#   '龍鬚',
#   '捲',
#   '外皮',
#   '絲絲',
#   '脆',
#   '口感',
#   '相較',
#   '前',
#   '幾樣',
#   '這道',
#   '蝦子',
#   '戲份',
#   '搶走了',
#   '黃金',
#   '流',
#   '沙包',
#   '卡定',
#   '奶黃控',
#   '必點',
#   '一道',
#   '看看',
#   '柔軟',
#   '麵',
#   '皮',
#   '流沙',
#   '完美',
#   '結合',
#   '流沙',
#   '人',
#   '流口水',
#   '平常',
#   '不太',
#   '喜歡',
#   '點',
#   '一味',
#   '會點',
#   '優聯盈發',
#   '鮮蝦',
#   '腐皮',
#   '捲',
#   '真是',
#   '好好',
#   '味豆',
#   '皮帶',
#   '一股',
#   '特殊',
#   '焦',
#   '香氣',
#   '層層',
#   '分明',
#   '酥脆',
#   '外還',
#   '充滿',
#   '空氣',
#   '感是',
#   '地方',
#   '沒吃過',
#   '美味',
#   '誇',
#   '一下',
#   '店家',
#   '炸功',
#   '家鄉',
#   '鹹水',
#   '角',
#   '外皮',
#   '放涼',
#   '吃',
#   '回縮',
#   '完全',
#   '油膩',
#   '吃',
#   '炸',
#   '麻',
#   '糬',
#   '般的',
#   '口感',
#   '餡料',
#   '更是',
#   '炒得',
#   '鹹',
#   '香',
#   '夠味',
#   '通常',
#   '吃',
#   '蘿蔔',
#   '糕',
#   '沒什麼',
#   '記憶',
#   '點但',
#   '港式',
#   '蘿蔔',
#   '糕',
#   '卻',
#   '好吃',
#   '耶',
#   '今天',
#   '一道',
#   '雷都',
#   '厲害',
#   '金屋藏嬌',
#   '人不知',
#   '葫蘆',
#   '裡賣藥',
#   '這餐',
#   '高潮',
#   '真是',
#   '一波未平',
#   '一波又起',
#   '咬下',
#   '麻',
#   '糬',
#   '外皮',
#   '一瞬間',
#   '知道',
#   '黃金',
#   '流餡',
#   '美味',
#   '壓垮',
#   '最後',
#   '一籠',
#   '稻草',
#   '大塊頭',
#   '圓籠',
#   '馬拉',
#   '糕',
#   '還好',
#   '店家',
#   '打包',
#   '服務',
#   '失心',
#   '瘋點',
#   '太多留',
#   '著當',
#   '點心',
#   '慢慢',
#   '回味',
#   '以後',
#   '吃',
#   '聯盈',
#   '發聯盈',
#   '發港味',
#   '點心',
#   '專門店',
#   '地址',
#   '台南市',
#   '永康',
#   '區正強',
#   '街號',
#   '電話',
#   '時間',
#   '資訊',
#   '屁桃',
#   '超人',
#   '食空',
#   '旅聯盈',
#   '發點',
#   '心',
#   '專門店',
#   '終於',
#   '想',
#   '好久',
#   '聯盈',
#   '發點',
#   '心',
#   '專門店',
#   '點半',
#   '已經',
#   '四組',
#   '人候',
#   '位',
#   '號碼牌',
#   '十號',
#   '候位',
#   '時',
#   '先點',
#   '單離',
#   '開時',
#   '結帳',
#   '菜單',
#   '猶豫',
#   '好久',
#   '先跑',
#   '吃',
#   '老弟',
#   '說花',
#   '幾百塊',
#   '吃',
#   '分飽害',
#   '知道',
#   '吃',
#   '飽飽',
#   '要花',
#   '少少',
#   '兩個',
#   '人',
#   '最後',
#   '只點',
#   '五樣',
#   '帶位',
#   '工作人員',
#   '告知',
#   '再',
#   '加點',
#   '小',
#   '後悔',
#   '多點',
#   '菜單',
#   '價目表',
#   '忙',
#   '翻',
#   '工作人員',
#   '堆好',
#   '高好',
#   '高',
#   '蒸籠',
#   '生意',
#   '真的',
#   '超好熱',
#   '普洱茶',
#   '免費',
#   '供應',
#   '清清',
#   '淡淡的',
#   '熱的',
#   '天氣',
#   '想',
#   '喝點',
#   '涼裡面',
#   '冷氣',
#   '很強',
#   '擠',
#   '座位',
#   '十分鐘',
#   '第一道',
#   '菜',
#   '終於',
#   '錦老拌',
#   '雲吞',
#   '辣顆',
#   '元超',
#   '好吃',
#   '皮餡',
#   '好',
#   '開胃',
#   '辣度',
#   '十分鐘',
#   '菜',
#   '陸續',
#   '一直',
#   '對別',
#   '桌',
#   '望穿秋水',
#   '珍珠',
#   '鮮肉',
#   '丸顆',
#   '元',
#   '珍珠',
#   '丸還',
#   '不錯',
#   '前面',
#   '雲吞',
#   '就略',
#   '普通',
#   '蜜汁',
#   '叉燒包',
#   '顆元',
#   '印象',
#   '中吃過',
#   '叉燒包',
#   '好吃',
#   '太乾',
#   '鬆軟',
#   '紮實',
#   '甜甜的',
#   '餡好',
#   '好吃',
#   '皮',
#   '比例',
#   '抓好',
#   '吃',
#   '完',
#   '一直',
#   '想',
#   '喝',
#   '東西',
#   '潤喉',
#   '一下',
#   '終於',
#   '知道',
#   '普洱茶',
#   '重要',
#   '蝦子',
#   '燒賣',
#   '皇顆',
#   '元',
#   '雲吞',
#   '餡',
#   '好像',
#   '絞肉',
#   '像是',
#   '外',
#   '皮包',
#   '一顆',
#   '丸子',
#   '比較',
#   '不夠',
#   '味',
#   '建議',
#   '點錦老',
#   '拌',
#   '雲吞',
#   '好',
#   '黃金',
#   '流',
#   '沙包',
#   '顆元來',
#   '之前',
#   '一直',
#   '估狗流',
#   '沙包',
#   '終於',
#   '好',
#   '好吃',
#   '預想',
#   '味道',
#   '濃',
#   '很好吃',
#   '一直',
#   '擔心',
#   '剝開',
#   '餡流',
#   '還好',
#   '失望',
#   '流沙',
#   '餡光',
#   '照片',
#   '超',
#   '美味',
#   '好',
#   '想',
#   '再',
#   '衝去',
#   '吃',
#   '甜甜',
#   '鹹鹹的',
#   '蛋黃',
#   '餡',
#   '一口',
#   '接',
#   '一口',
#   '餡量',
#   '剛剛',
#   '好太少',
#   '太膩',
#   '吃',
#   '完流',
#   '沙包',
#   '感覺',
#   '好',
#   '滿足',
#   '回味',
#   '再三',
#   '必點',
#   '推薦',
#   '本來',
#   '以為點',
#   '五樣',
#   '不夠',
#   '吃',
#   '沒想到',
#   '吃',
#   '完',
#   '還蠻',
#   '兩個',
#   '人不貴',
#   '每樣',
#   '東西',
#   '好吃',
#   '冷氣',
#   '也夠',
#   '涼',
#   '尤其',
#   '雲吞',
#   '流',
#   '沙包',
#   '下次',
#   '想',
#   '試試',
#   '招牌',
#   '排隊',
#   '值得',
#   '聯盈',
#   '發點',
#   '心',
#   '專門店',
#   '地址',
#   '台南市',
#   '永康',
#   '區正強',
#   '街號',
#   '電話',
#   '營業時間',
#   '屁桃',
#   '超人',
#   '食空',
#   '旅',
#   '台南',
#   '行',
#   '貪',
#   '心想',
#   '所有',
#   '口袋',
#   '名單',
#   '一網打盡',
#   '深藍',
#   '慕',
#   '紅豆',
#   '土托魚',
#   '羹',
#   '牛肉湯',
#   '時間',
#   '有限',
#   '肚子',
#   '容量',
#   '有限',
#   '先',
#   '老少咸宜',
#   '店家',
#   '下手',
#   '笑',
#   '第一站',
#   '來到',
#   '位於',
#   '永康',
#   '名氣',
#   '相當',
#   '響叮噹',
#   '聯盈',
#   '發點',
#   '心',
#   '專門店',
#   '這是',
#   '一間',
#   '專賣',
#   '港式',
#   '點心店',
#   '全家',
#   '大小',
#   '一起',
#   '吃飯',
#   '應該',
#   '相當',
#   '合適',
#   '約',
#   '早',
#   '上點',
#   '多些',
#   '抵達',
#   '當時',
#   '店內',
#   '已經',
#   '坐',
#   '幾組',
#   '客人',
#   '屬早',
#   '鳥',
#   '順利',
#   '入座',
#   '港式',
#   '飲茶',
#   '必備',
#   '茶',
#   '飲',
#   '價格',
#   '自助',
#   '佐料',
#   '區',
#   '脆皮',
#   '叉燒包',
#   '一道',
#   '早點',
#   '點阿如',
#   '先點',
#   '一份',
#   '味道',
#   '不錯',
#   '原先',
#   '叉燒',
#   '增加',
#   '波蘿',
#   '表皮',
#   '香氣',
#   '口感',
#   '蝦仁',
#   '腸粉',
#   '算是',
#   '中規中矩',
#   '一道',
#   '說',
#   '阿如',
#   '覺得',
#   '腸粉',
#   '吃',
#   '鮮蝦',
#   '花枝',
#   '煎餅',
#   '口感',
#   '紮實',
#   '沾酸',
#   '辣醬',
#   '味道',
#   '更顯',
#   '豐富',
#   '清燉雞',
#   '肉湯',
#   '湯頭',
#   '清爽',
#   '甘甜',
#   '白灼',
#   '芥藍菜',
#   '吃',
#   '菜菜',
#   '均衡',
#   '一下',
#   '豆豉',
#   '蒸',
#   '排骨',
#   '這道',
#   '豆豉',
#   '蒸',
#   '排骨',
#   '家去',
#   '吃',
#   '茶餐廳',
#   '必點',
#   '要求',
#   '比較',
#   '高',
#   '味道',
#   '不夠',
#   '有點',
#   '油',
#   '上海',
#   '小籠',
#   '湯包',
#   '吃',
#   '中規中矩',
#   '阿如',
#   '私心',
#   '偏愛',
#   '熱河',
#   '街',
#   '阿拉',
#   '上海',
#   '鮮肉',
#   '生',
#   '煎',
#   '湯包',
#   '港式',
#   '雲吞',
#   '湯',
#   '麵',
#   '吃不飽',
#   '而點',
#   '麵',
#   '食',
#   '吃',
#   '一般般',
#   '沙拉',
#   '龍鬚',
#   '捲',
#   '節目',
#   '介紹',
#   '過的',
#   '錯過',
#   '道理',
#   '恩',
#   '外表',
#   '包裹',
#   '冬粉',
#   '下去',
#   '炸',
#   '咬嘴',
#   '中',
#   '口感',
#   '很妙',
#   '卡滋卡滋的裡',
#   '面包',
#   '沙拉',
#   '蝦富',
#   '趣味',
#   '港式',
#   '蘿蔔',
#   '糕',
#   '表面',
#   '煎',
#   '吃',
#   '香香的',
#   '價格',
#   '親切',
#   '不錯',
#   '蝦子',
#   '燒賣',
#   '皇',
#   '味道',
#   '口感',
#   '算',
#   '不錯',
#   '黃金',
#   '流',
#   '沙包',
#   '阿如',
#   '喜歡',
#   '吃流',
#   '沙包',
#   '家人',
#   '不愛吃',
#   '甜',
#   '一道',
#   '包奶味',
#   '很重',
#   '味道',
#   '蠻香',
#   '家鄉',
#   '鹹水',
#   '角',
#   '這道',
#   '某次',
#   '帶二',
#   '姊',
#   '吃',
#   '飲',
#   '茶點',
#   '過後',
#   '想',
#   '說',
#   '點來',
#   '吃',
#   '麻',
#   '糬',
#   '外皮',
#   '炸過',
#   '之後',
#   '口感',
#   '更好',
#   '裡面',
#   '餡',
#   '鮮香',
#   '滋味',
#   '麥歹',
#   '這天',
#   '一共',
#   '大人',
#   '吃花',
#   '不到',
#   '元',
#   '算是',
#   '經濟',
#   '囉',
#   '聯盈發',
#   '港式',
#   '點心',
#   '專門店',
#   '台南市',
#   '永康',
#   '區正強',
#   '街號',
#   '吃',
#   '完要',
#   '走裡面',
#   '已經',
#   '全滿',
#   '外面',
#   '大排長龍',
#   '平日',
#   '超人氣',
#   '名店',
#   '佩服',
#   '佩服',
#   '店家',
#   '資訊',
#   '餐廳',
#   '名稱',
#   '聯盈發',
#   '港式',
#   '點心',
#   '專門店',
#   '地址',
#   '台南市',
#   '永康',
#   '區正強',
#   '街號',
#   '電話',
#   '營業時間',
#   '官方',
#   '臉書',
#   '聯盈發',
#   '備註',
#   '排隊',
#   '店',
#   '不想',
#   '排隊',
#   '久候',
#   '中午',
#   '請前',
#   '店',
#   '菜單',
#   '聯盈',
#   '發有',
#   '兩間',
#   '店面',
#   '港式',
#   '點心',
#   '專賣店',
#   '同條',
#   '路',
#   '對角線',
#   '賣東西',
#   '不太',
#   '今天',
#   '吃',
#   '港式',
#   '點心',
#   '專門店',
#   '直接',
#   '菜色',
#   '囉',
#   '脆皮',
#   '叉燒包',
#   '粒',
#   '熱熱',
#   '端上來',
#   '外表',
#   '酥脆',
#   '內部',
#   '餡料',
#   '鹹',
#   '甜',
#   '鹹',
#   '甜還',
#   '不錯',
#   '吃',
#   '一人',
#   '一顆',
#   '就夠',
#   '再',
#   '吃',
#   '感覺',
#   '太',
#   '膩滑',
#   '雞',
#   '臘腸',
#   '盅',
#   '頭飯',
#   '這是',
#   '網友',
#   '推才點',
#   '吃',
#   '普通',
#   '感覺',
#   '雞肉',
#   '香腸',
#   '飯',
#   '還好',
#   '太軟',
#   '爛',
#   '朋友',
#   '不愛',
#   '鮮肉',
#   '魚翅',
#   ...],
#  ['OMAYA',
#   '春川',
#   '炒',
#   '雞',
#   '台南',
#   '永華',
#   '店',
#   ' ',
#   '今日',
#   '店家',
#   '提供',
#   '小菜',
#   '五種',
#   '分別',
#   '泡菜',
#   '海帶',
#   '芽',
#   '珊瑚',
#   '草',
#   '青椒',
#   '百香果',
#   '南瓜',
#   '泡菜',
#   '以外',
#   '屬於',
#   '比較',
#   '清爽',
#   '口味',
#   '無限量',
#   '加點',
#   '喔',
#   '韓式',
#   '奶油',
#   '麵',
#   '這白',
#   '綿綿',
#   '鮮奶油',
#   '好',
#   '討喜',
#   '奶油',
#   '麵',
#   '真的',
#   '特別',
#   '裏頭',
#   '麵',
#   '條',
#   '採用',
#   '烏龍',
#   '麵',
#   '搭配',
#   '咖哩',
#   '醬',
#   '上頭',
#   '鋪蓋',
#   '滿滿的',
#   '鮮奶油',
#   '鮮奶油',
#   '多餘',
#   '調味',
#   '用來',
#   '增加',
#   '麵',
#   '條的',
#   '香氣',
#   '口感',
#   '烏龍',
#   '麵',
#   '搭配',
#   '濃郁',
#   '咖哩',
#   '味道',
#   '裡面',
#   '許多',
#   '豬肉',
#   '塊',
#   '紅蘿蔔',
#   '餐點',
#   '單調',
#   '這道',
#   '料理',
#   '建議',
#   '吃',
#   '烏龍',
#   '麵',
#   '涼',
#   '掉',
#   '以後',
#   '口感',
#   '遜色',
#   '奶油',
#   '帶點',
#   '微微',
#   '甜味',
#   '韓式',
#   '拌',
#   '飯',
#   '拌',
#   '飯裡面',
#   '豆芽菜',
#   '紅蘿蔔',
#   '絲波菜',
#   '泡菜',
#   '玉米粒',
#   '豬肉',
#   '片',
#   '共計',
#   '道',
#   '菜色',
#   '非常豐富',
#   '店家',
#   '提供',
#   '韓式',
#   '辣椒醬',
#   '喜好',
#   '調整',
#   '辣度',
#   '拌',
#   '飯',
#   '好',
#   '以後',
#   '即可',
#   '食用',
#   '豐富',
#   '配菜',
#   '料理',
#   '口感',
#   '米飯',
#   '軟硬',
#   '適中',
#   '韓式',
#   '辣椒醬',
#   '鹹味',
#   '無須再',
#   '添加',
#   '佐料',
#   '豬肉',
#   '片',
#   '帶有',
#   '油花',
#   '部位',
#   '軟嫩',
#   '老柴',
#   '蔬菜',
#   '脆',
#   '玉米',
#   '甜',
#   '蛋黃',
#   '香',
#   '一道',
#   '層次',
#   '料理',
#   '韓式',
#   '厚',
#   '煎餅',
#   '海鮮',
#   '煎餅',
#   '海鮮',
#   '厚',
#   '煎餅',
#   '外皮',
#   '酥脆',
#   '內餡',
#   '飽滿',
#   '軟嫩',
#   '餡',
#   '豐富',
#   '海鮮',
#   '以外',
#   '許多',
#   '蔬菜',
#   '添加',
#   '裡頭',
#   '口感',
#   '極好',
#   '這道',
#   '料理',
#   '建議',
#   '吃',
#   '外皮',
#   '冷掉',
#   '以後',
#   '酥脆',
#   '海鮮',
#   '煎餅',
#   '擁有',
#   '獨特',
#   '醬汁',
#   '刁嘴',
#   '喜歡',
#   '不沾醬',
#   '煎餅',
#   '調味',
#   '原味',
#   '咖賀甲',
#   '石板',
#   '拌',
#   '飯',
#   '石板',
#   '拌',
#   '飯',
#   '韓式',
#   '拌',
#   '飯',
#   '加熱',
#   '版',
#   '配菜',
#   '完全',
#   '一模一樣',
#   '差別',
#   '放置',
#   '熱騰騰',
#   '石',
#   '鍋貼',
#   '心小',
#   '提醒',
#   '食用',
#   '避免',
#   '碰觸',
#   '石鍋',
#   '燙傷',
#   '店員',
#   '幫忙',
#   '攪拌',
#   '後',
#   '變成',
#   '超愛',
#   '石板',
#   '拌',
#   '飯',
#   '底層',
#   '鍋巴',
#   '蔬菜',
#   '石板',
#   '溫度',
#   '後',
#   '美味',
#   '刁嘴',
#   '認為',
#   '東西',
#   '熱熱',
#   '比較',
#   '好吃',
#   '銅板',
#   '燒肉',
#   '豬肉',
#   '看見',
#   '漂亮',
#   '銅盤',
#   '盤',
#   '蔬菜',
#   '豆腐',
#   '金針菇',
#   '冬粉',
#   '擺設',
#   '盤子',
#   '四周',
#   '中間',
#   '空間',
#   '用來',
#   '烤肉',
#   '片',
#   '食用',
#   '之前',
#   '店家',
#   '倒',
#   '高湯',
#   '熬',
#   '煮',
#   '四周',
#   '食材',
#   '有種',
#   '火烤',
#   '兩吃',
#   '概念',
#   '店家',
#   '提供',
#   '豬肉',
#   '片',
#   '已經',
#   '醃漬',
#   '肉片',
#   '烤完',
#   '無需',
#   '沾醬',
#   '味道',
#   '肉片',
#   '帶點',
#   '油花',
#   '軟嫩',
#   '老柴',
#   '服務生',
#   '會先',
#   '幫忙',
#   '倒入',
#   '高湯',
#   '一旁',
#   '蔬菜',
#   '慢慢',
#   '浸入',
#   '高湯',
#   '中',
#   '開心',
#   '銅盤',
#   '烤',
#   '豬肉',
#   '看著',
#   '肉汁',
#   '銅盤',
#   '紋路',
#   '流入',
#   '高湯',
#   '中好療',
#   '癒',
#   '辛普森',
#   '湯起司',
#   '部隊',
#   '鍋',
#   '炒飯',
#   '這道',
#   '辛普森',
#   '湯刁',
#   '嘴',
#   '必點',
#   '想',
#   '知道',
#   '詳細',
#   '過程',
#   '請二訪',
#   '新',
#   '菜色',
#   '新體驗',
#   '辛普森',
#   '湯',
#   '觀看',
#   '看著',
#   '一旁',
#   '起司',
#   '慢慢',
#   '融化',
#   '我夾',
#   '一塊',
#   '雞肉',
#   '起司',
#   '卷上',
#   '一圈',
#   '超',
#   '美味',
#   '吃',
#   '完',
#   '中間',
#   '部隊',
#   '鍋',
#   '後',
#   '服務生',
#   '隨即',
#   '送上',
#   '韓式',
#   '炒飯',
#   '配料',
#   '幫忙',
#   '炒飯',
#   '畫面',
#   '太美',
#   '驚艷之餘',
#   '拍照',
#   '起司',
#   '炒飯',
#   '飛舞',
#   '畫面',
#   '湯匙',
#   '一勺',
#   '令',
#   '刁嘴',
#   '朝思暮想',
#   '牽絲',
#   '韓國',
#   '炒飯',
#   '綠',
#   '薄荷',
#   '浩克',
#   '氣泡',
#   '飲甜',
#   '檸奇亞籽',
#   '野玫瑰',
#   '氣泡',
#   '飲',
#   '芒果',
#   '思酪',
#   '氣泡',
#   '飲綠',
#   '薄荷',
#   '浩克',
#   '氣泡',
#   '飲',
#   '野玫瑰',
#   '氣泡',
#   '飲',
#   '芒果',
#   '思酪',
#   '氣泡',
#   '飲老',
#   '實說',
#   '三杯',
#   '氣泡',
#   '飲偏',
#   '甜',
#   '太',
#   '適合',
#   '刁嘴',
#   '倒',
#   '甜',
#   '檸奇亞籽',
#   '添加',
#   '奇亞籽',
#   '口感',
#   '加入',
#   '檸檬',
#   '喝',
#   '感覺',
#   '像是',
#   '冬瓜',
#   '檸檬',
#   '紫薯',
#   '蕎麥',
#   '寒天',
#   '冰沙',
#   '宇治',
#   '蕎麥',
#   '抹茶',
#   '冰沙',
#   '紫薯',
#   '蕎麥',
#   '寒天',
#   '冰沙',
#   '當今',
#   '少女',
#   '最愛',
#   '粉紅',
#   '系',
#   '飲品',
#   '紫薯',
#   '冰沙',
#   '甜膩',
#   '寒天',
#   '口感',
#   '宇治',
#   '蕎麥',
#   '抹茶',
#   '冰沙',
#   '宇治',
#   '抹茶',
#   '茶',
#   '香味',
#   '濃',
#   '甜味',
#   '來自',
#   '底層',
#   '紅豆',
#   '泥',
#   '韓式',
#   '雪花',
#   '冰冰',
#   '品',
#   '真的',
#   '特別',
#   '雪花',
#   '冰有',
#   '淡淡的',
#   '牛奶',
#   '香氣',
#   '黃黃',
#   '粉狀',
#   '物',
#   '應該',
#   '麵',
#   '茶',
#   '地香',
#   '刁嘴',
#   '兒時',
#   '記憶',
#   '味道',
#   '紅豆',
#   '杏仁',
#   '片',
#   '增加',
#   '冰品',
#   '口感',
#   '甜味',
#   '店家',
#   '淋上',
#   '糖水',
#   '不會太甜',
#   '超級',
#   '爽口',
#   '適合',
#   '飯',
#   '一碗',
#   '韓式',
#   '拌',
#   '冰上',
#   '頭',
#   '六種',
#   '水果',
#   '三種',
#   '甜點',
#   '鋪',
#   '雪花',
#   '冰上',
#   '一旁',
#   '日式',
#   '小點',
#   '紅豆',
#   '牛奶',
#   '冰',
#   '整體',
#   '份量',
#   '挺',
#   '驚人',
#   '水果',
#   '選',
#   '新鮮',
#   '吃',
#   '像是',
#   '水果',
#   '牛奶',
#   '雪花',
#   '冰淋上',
#   '草莓醬',
#   '樣子',
#   '菜單',
#   '囉',
#   '春川',
#   '炒',
#   '雞',
#   '台南',
#   '永華',
#   '店',
#   '地址',
#   '台南市',
#   '中西區',
#   '永華',
#   '路',
#   '一段',
#   '號',
#   '電話',
#   '營業時間',
#   '週一',
#   '週日',
#   '最後',
#   '收客',
#   '時間',
#   '午間',
#   '晚間',
#   '官方',
#   '臉書春川',
#   '炒',
#   '雞',
#   '台南',
#   '永華',
#   '店',
#   '備註',
#   '用餐',
#   '時間',
#   '限',
#   '分鐘',
#   '台南',
#   '永華',
#   '店店',
#   '內亦會',
#   '不定期',
#   '舉辦',
#   '打卡',
#   '傳送',
#   '氣泡',
#   '飲料',
#   '優惠活動',
#   '建議',
#   '欲',
#   '前往',
#   '嚐鮮',
#   '朋友',
#   '提早',
#   '預約',
#   '久候',
#   '喔',
#   '以上',
#   '純屬',
#   '美食',
#   '分享',
#   '感受',
#   '僅供參考',
#   '喜歡',
#   '小',
#   '刁嘴',
#   '文章',
#   '別忘了',
#   '讚',
#   '分享',
#   '喔',
#   '謝謝',
#   '以下',
#   '小',
#   '刁嘴',
#   '最近',
#   '剛創',
#   '粉絲',
#   '專頁',
#   '想',
#   '隨時',
#   '追蹤',
#   '台南',
#   '好吃',
#   '好玩',
#   '請',
#   '讚',
#   '加入',
#   '喔',
#   '春川',
#   '炒',
#   '雞',
#   '台南',
#   '永華',
#   '店',
#   '說',
#   '這間',
#   '店',
#   '一點',
#   '陌生',
#   '一季',
#   '新',
#   '菜單',
#   '巨鼠',
#   '算是',
#   '春川',
#   '炒',
#   '雞',
#   '粉絲',
#   '最近',
#   '聽到',
#   '夏季',
#   '菜單',
#   '新',
#   '上市',
#   '消息',
#   '馬',
#   '上下班',
#   '約',
#   '同事',
#   '吃',
#   '一攤',
#   '這次',
#   '新',
#   '餐點',
#   '韓式',
#   '拌',
#   '飯',
#   '奶油',
#   '麵',
#   '部份',
#   '陪伴',
#   '迎接',
#   '酷暑',
#   '到來',
#   '還出',
#   '兩款',
#   '韓式',
#   '拌',
#   '冰',
#   '飲品',
#   '菜單',
#   '更新',
#   '巨鼠',
#   '發現',
#   '餐飲業',
#   '真的',
#   '不好',
#   '做',
#   '連鎖',
#   '餐廳',
#   '用心',
#   '推陳出新',
#   '研發',
#   '新',
#   '菜單',
#   '每次',
#   '新',
#   '發現',
#   '永遠',
#   '充滿',
#   '驚奇',
#   '新感受',
#   '直接',
#   '這次',
#   '巨鼠',
#   '吃',
#   '新',
#   '好料',
#   '春川',
#   '炒',
#   '雞',
#   '台南',
#   '永華',
#   '店',
#   '永華',
#   '路上',
#   '對面',
#   '家樂福',
#   '再',
#   '過去',
#   '台南市',
#   '政府',
#   '這段',
#   '永華',
#   '路',
#   '說',
#   '台南美食',
#   '餐廳',
#   '戰區',
#   '日式',
#   '韓式',
#   '泰式',
#   '美式',
#   '通通',
#   '單點',
#   '簡餐',
#   '套餐',
#   '吃',
#   '一應俱全',
#   '春川',
#   '炒',
#   '雞',
#   '台南',
#   '永華',
#   '店',
#   '韓國',
#   '料理',
#   '覺得',
#   '走',
#   '比較',
#   '像是',
#   '韓國',
#   '特色',
#   '料理',
#   '韓國',
#   '煎餅',
#   '韓國',
#   '拌',
#   '飯春川',
#   '炒',
#   '雞',
#   '鍋巴',
#   '烤雞',
#   '起士鍋',
#   '視覺效果',
#   '十足',
#   '豪華',
#   '美味',
#   '好料',
#   '興趣',
#   '參考',
#   '舊',
#   '文章',
#   '保證',
#   '看到',
#   '吃',
#   '自覺',
#   '說出',
#   '喔',
#   '媽呀',
#   '夭壽',
#   '好吃',
#   '外地人',
#   '這也',
#   '方便',
#   '店前',
#   '公車站',
#   '牌',
#   '囉',
#   '號',
#   '公車',
#   '喔',
#   '家樂福',
#   '站',
#   '下車',
#   '春川',
#   '炒',
#   '雞',
#   '台南',
#   '永華',
#   '店',
#   '正值',
#   '週年',
#   '慶',
#   '飲料',
#   '全面',
#   '半價',
#   '超',
#   '划算',
#   '店家',
#   '現在',
#   '沒低',
#   '消',
#   '喔',
#   '意思',
#   '朋友',
#   '只想',
#   '喝',
#   '飲料',
#   '吃',
#   '冰',
#   '一些',
#   '首爾',
#   '美食',
#   '祭',
#   '平日',
#   '優惠價',
#   '平日',
#   '吃',
#   '真的',
#   '棒棒',
#   '感覺',
#   '省春川',
#   '炒',
#   '雞',
#   '台南',
#   '永華',
#   '店',
#   '門外',
#   '工業',
#   '風黃',
#   '黑',
#   '斑馬線',
#   '工地',
#   '風',
#   '外面',
#   '等待',
#   '時',
#   '韓國',
#   '歐巴',
#   '歐逆',
#   '欣賞',
#   '來過',
#   '介紹',
#   '內部空間',
#   '想',
#   '了解',
#   '文末',
#   '舊文',
#   '連結',
#   '歡迎',
#   '點入',
#   '參考',
#   '今天',
#   '回味',
#   '投票數',
#   '最高',
#   '最愛',
#   '菜色',
#   '辛普森',
#   '湯外',
#   '新',
#   '菜色',
#   '一定',
#   '要來',
#   '吃',
#   '吃',
#   '坐',
#   '上桌',
#   '無限',
#   '供應',
#   '小菜',
#   '先送',
#   '海帶',
#   '芽',
#   '微鹹',
#   '青椒',
#   '絲',
#   '害怕',
#   '獨特',
#   '椒',
#   '味',
#   '味道',
#   '鹹',
#   '香',
#   '涼拌',
#   '南瓜',
#   '口感',
#   '微脆',
#   '滋味',
#   '甜帶',
#   '酸',
#   '韓國泡菜',
#   '酸辣',
#   '很脆',
#   '涼拌',
#   '珊瑚',
#   '草蒜味',
#   '淡雅',
#   '口感',
#   '脆韌',
#   '吃',
#   '完',
#   '無限',
#   '續加',
#   '銅板',
#   '燒肉',
#   '豬肉',
#   '送上',
#   '銅板',
#   '燒肉',
#   '豬肉',
#   '牛肉',
#   '選擇',
#   '選',
#   '豬肉',
#   '菜單',
#   '寫著',
#   '這是',
#   '單人',
#   '份',
#   '覺得',
#   '至少',
#   '兩人',
#   '一起',
#   '吃',
#   '整份',
#   '餐點',
#   '銅板',
#   '周圍',
#   '一圈',
#   '好料',
#   '蔬菜',
#   '鮮蝦',
#   '粉絲',
#   '喔',
#   '感覺',
#   '蔬菜',
#   '給的',
#   '滿多',
#   '補充',
#   '一下',
#   '外食族',
#   '不足',
#   '維生素',
#   '纖維素',
#   '豬肉',
#   '部分',
#   '盛裝',
#   '一盤',
#   '一併',
#   '送上',
#   '豬肉',
#   '片',
#   '每片',
#   '色澤',
#   '紋理',
#   '很漂亮',
#   '上方',
#   '洋蔥',
#   '絲',
#   '點綴',
#   '擺盤',
#   '一起',
#   '炒來',
#   '吃',
#   '喔',
#   '開動',
#   '店家',
#   '加入',
#   '高湯',
#   '菜',
#   '部分',
#   '加熱',
#   '下會',
#   '自動',
#   '煮熟',
#   '烤肉',
#   '一片片',
#   '放在',
#   '中間',
#   '烤',
#   '面紅',
#   '變白',
#   '灰色',
#   '翻面',
#   '簡單',
#   '豬肉',
#   '肥瘦',
#   '厚薄',
#   '恰到好處',
#   '吃',
#   '好',
#   '嫩',
#   '肉片',
#   '事先',
#   '醃過',
#   '甜甜',
#   '滋味',
#   '不用',
#   '沾醬',
#   ...],
#  ['歐',
#   '加里',
#   '台南',
#   '大學',
#   '店',
#   ' ',
#   '大學',
#   '路巷',
#   '異國',
#   '餐廳',
#   '林立',
#   '成功',
#   '大學',
#   '對面',
#   '最',
#   '著名',
#   '兩條',
#   '巷子',
#   '巷巷',
#   '充滿著',
#   '滿滿',
#   '台南人',
#   '美食',
#   '聚餐',
#   '記憶',
#   '總',
#   '感覺',
#   '此地',
#   '台南',
#   '巷弄',
#   '美食',
#   '起源地',
#   '走入',
#   '碰著',
#   '外國人',
#   '身處',
#   '異地',
#   '氣氛',
#   '一家',
#   '營業',
#   '年',
#   '餐廳',
#   '巷內',
#   '換過',
#   '老闆',
#   '屹立不搖',
#   '美味',
#   '嚐嚐',
#   '原文',
#   '覓',
#   '秘食',
#   '小',
#   '旅行',
#   '整路',
#   '巷內',
#   '找',
#   '各國',
#   '料理',
#   '多年',
#   '下來',
#   '餐廳',
#   '更換',
#   '總以',
#   '攏絡',
#   '喜愛',
#   '各族',
#   '群',
#   '用餐',
#   '客哩',
#   '餐廳',
#   '外觀',
#   '品味',
#   '滴',
#   '入口',
#   '旁似',
#   '庭園',
#   '般的',
#   '風格',
#   '一旁',
#   '處大面',
#   '玻璃',
#   '用餐',
# ...
#   '登場',
#   '永華',
#   '路',
#   '餐廳',
#   '安平',
#   '家樂福',
#   '韓國',
#   '料理台',
#   '南',
#   '東區',
#   '春川',
#   '炒',
#   '雞',
#   '台南',
#   '東門',
#   '店',
#   '韓味',
#   '來襲',
#   ...],
#  ['五五',
#   '禾',
#   '概念',
#   '套餐',
#   ' ',
#   '之前',
#   '吃過',
#   '看店',
#   '來客',
#   '量',
#   '人',
#   '知道',
#   '中',
#   '華北',
#   '路上',
#   '一間',
#   '用心',
#   '餐廳',
#   '自私',
#   '收藏',
#   '想',
#   '做',
#   '店',
#   '位置',
#   '並不',
#   '特別',
#   '真心',
#   '覺得',
#   '料理',
#   '好吃',
#   '很想',
#   '推薦',
#   '知道',
#   '五五',
#   '禾',
#   '概念',
#   '套餐',
#   '地址',
#   '台南市',
#   '北區',
#   '中華',
#   '北路',
#   '二段',
#   '號',
#   '電話',
#   '營業時間',
#   '週四',
#   '週二',
#   '公休日',
#   '每週',
#   '三位',
#   '中',
#   '華北',
#   '路上',
#   '餐廳',
#   '聚集',
#   '路段',
#   '前',
#   '兩次',
#   '開',
#   '過頭',
#   '請',
#   '認明',
#   '門口',
#   '可愛',
#   '公仔',
#   '店面',
#   '並不大',
#   '卻',
#   '弄',
#   '舒心',
#   '整潔',
#   '店',
#   '內外',
#   '剛剛',
#   '說店',
#   '位置',
#   '真的',
#   '照片',
#   '中',
#   '看到',
#   '位子',
#   '多人',
#   '聚餐',
#   '人要',
#   '坐',
#   '一起',
#   '應該',
#   '問題',
#   '店內',
#   '看到',
#   '兒童座椅',
#   '有帶',
#   '小朋友',
#   '不用',
#   '擔心',
#   '喔',
#   '暖色',
#   '系',
#   '空間',
#   '舒服',
#   '桌上',
#   '放置',
#   '菜單',
#   '自行',
#   '填完',
#   '後',
#   '拿到',
#   '櫃台',
#   '囉',
#   '先送',
#   '熱麥',
#   '茶',
#   '一直',
#   '覺得',
#   '家',
#   '茶具',
#   '簡單',
#   '卻',
#   '典雅',
#   '菜',
#   '單點',
#   '一份',
#   '香',
#   '煎',
#   '松阪',
#   '豬和熟',
#   '烤牛肉',
#   '搭配',
#   '蕈',
#   '菇',
#   '拌',
#   '飯',
#   '一份',
#   '唐辛',
#   '雞腿肉',
#   '搭配',
#   '微',
#   '烏龍',
#   '麵',
#   '每份',
#   '套餐',
#   '附上',
#   '沙拉',
#   '飲料',
#   '甜品',
#   '先送',
#   '沙拉',
#   '家',
#   '沙拉',
#   '蔬果',
#   '新鮮',
#   '爽脆',
#   '外',
#   '不同之處',
#   '製',
#   '柚子',
#   '醬',
#   '上頭',
#   '木瓜',
#   '籤',
#   '木瓜',
#   '籤',
#   '甜甜的',
#   '超愛',
#   '媽媽',
#   '製',
#   '柚子',
#   '醬',
#   '讚譽',
#   '有加',
#   '殘留',
#   '醬汁',
#   '喝掉',
#   '欸',
#   '送餐',
#   '速度',
#   '很快',
#   '收餐',
#   '服務',
#   '好',
#   '喔',
#   '沙拉',
#   '吃',
#   '完',
#   '媽媽',
#   '唐辛',
#   '雞腿飯',
#   '搭配',
#   '微',
#   '咖哩',
#   '烏龍',
#   '麵',
#   '套餐',
#   '湯品',
#   '蒸蛋',
#   '五五',
#   '禾',
#   '料理',
#   '精緻',
#   '份量',
#   '夠',
#   '整份',
#   '吃',
#   '完',
#   '飽足',
#   '感',
#   '媽媽',
#   '很愛吃',
#   '烏龍',
#   '麵',
#   '同樣',
#   '烏龍',
#   '麵',
#   '讚譽',
#   '加說',
#   '麵',
#   '條軟',
#   '硬度',
#   '媽媽',
#   '挑惕',
#   '咖哩',
#   '味道',
#   '濃厚',
#   '以致於',
#   '吃久膩',
#   '口',
#   '涮',
#   '嘴',
#   '口味',
#   '雞腿肉',
#   '一塊',
#   '相當',
#   '厚度',
#   '外皮',
#   '煎',
#   '酥脆',
#   '肉質',
#   '卻',
#   '保持',
#   '多汁',
#   '軟嫩',
#   '撒',
#   '七味',
#   '粉',
#   '搭配',
#   '一旁',
#   '製',
#   '沾',
#   '肉醬',
#   '鹹',
#   '鹹',
#   '甜甜',
#   '一點',
#   '點點',
#   '辣',
#   '真的',
#   '現在',
#   '回味',
#   '主餐',
#   '比較',
#   '重',
#   '口味',
#   '湯品則',
#   '平衡',
#   '口中',
#   '鹹度',
#   '湯喝',
#   '清甜',
#   '裡面',
#   '杏鮑菇',
#   '排骨',
#   '娃娃',
#   '菜',
#   '海帶',
#   '芽',
#   '食材',
#   '排骨',
#   '燉',
#   '軟爛',
#   '真的',
#   '好喝',
#   '料理',
#   '美味',
#   '外',
#   '容器',
#   '能持',
#   '溫',
#   '東西',
#   '吃',
#   '味道',
#   '更棒',
#   '蒸蛋',
#   '口感',
#   '滑嫩',
#   '入口',
#   '即化',
#   '帶著',
#   '舒服',
#   '蛋',
#   '香味',
#   '蛤蜊',
#   '味',
#   '挖開',
#   '裡面',
#   '蛤蜊',
#   '肉',
#   '原來',
#   '家',
#   '蒸蛋',
#   '鮮',
#   '蛋液',
#   '加',
#   '新鮮',
#   '蛤蜊湯',
#   '汁',
#   '比例',
#   '溫度',
#   '時間',
#   '更是',
#   '重要',
#   '熟',
#   '烤牛肉',
#   '搭配',
#   '蕈',
#   '菇',
#   '拌',
#   '飯',
#   '寫到',
#   '好像',
#   '滿是',
#   '稱讚',
#   '繼續',
#   '稱讚',
#   '家蕈',
#   '菇',
#   '拌',
#   '飯',
#   '真的',
#   '歐伊',
#   '係',
#   '粒粒',
#   '分明',
#   '米飯',
#   '染上',
#   '菇',
#   '顏色',
#   '吃菇',
#   '氣味',
#   '濃郁',
#   '一口',
#   '吃',
#   '成丁',
#   '菇',
#   '老闆',
#   '說',
#   '碗飯',
#   '程序',
#   '相當',
#   '費工',
#   '菇類',
#   '切細',
#   '丁再',
#   '炒',
#   '香',
#   '再',
#   '熬',
#   '煮',
#   '料理',
#   '成功',
#   '熟',
#   '烤牛肉',
#   '熟度',
#   '恰恰好',
#   '軟嫩',
#   '完全',
#   '失嚼勁',
#   '一份',
#   '五片',
#   '肉',
#   '整個',
#   '套餐',
#   '吃得飽',
#   '這肉',
#   '好吃',
#   '希望',
#   '老闆',
#   '再多加',
#   '幾片',
#   '香',
#   '煎',
#   '松阪豬',
#   '搭配',
#   '蕈',
#   '菇',
#   '拌',
#   '飯',
#   '旁邊',
#   '搭配',
#   '贅述',
#   '拉松阪豬',
#   '外面',
#   '煎',
#   '稍微',
#   '帶有',
#   '嚼',
#   '勁',
#   '肉質',
#   '越嚼',
#   '越香',
#   '一點',
#   '肉',
#   '腥味',
#   '食材',
#   '新鮮',
#   '補上',
#   '一張',
#   '清湯',
#   '頭卻',
#   '意外',
#   '甘甜',
#   '好喝',
#   '吃',
#   '完送',
#   '甜點',
#   '囉',
#   '店家',
#   '製',
#   '果凍',
#   '百香',
#   '口味',
#   '附',
#   '餐飲',
#   '料選',
#   '柳橙汁',
#   '七葉',
#   '養生茶',
#   '七葉',
#   '養生茶',
#   '裡頭',
#   '茶',
#   '包',
#   '店家',
#   '裝的',
#   '藥材',
#   '喔',
#   '裡面',
#   '七葉',
#   '膽',
#   '枸杞',
#   '菊花',
#   '喝',
#   '苦甘',
#   '味道',
#   '帶著',
#   '菊花',
#   '香氣',
#   '完食',
#   '謝謝',
#   '招待',
#   '真的',
#   '太',
#   '美味',
#   '吃',
#   '完後店',
#   '陸續',
#   '人',
#   '應該',
#   '假日',
#   '關係',
#   '假',
#   '日來',
#   '先',
#   '訂位',
#   '喔',
#   '總結',
#   '如果說',
#   '每個',
#   '人',
#   '美食',
#   '標準',
#   '媽來',
#   '比喻',
#   '好',
#   '標準',
#   '挑惕',
#   '嘴',
#   '挑食',
#   '吃',
#   '吃',
#   '五五',
#   '禾',
#   '少數',
#   '幾間',
#   '會邊',
#   '吃邊',
#   '讚美',
#   '美味',
#   '不在話下',
#   '不用說',
#   '早就',
#   '光顧',
#   '兩三次',
#   '以上',
#   '五五',
#   '禾',
#   '料理',
#   '人',
#   '感受',
#   '用心',
#   '料理',
#   '吸',
#   '用心',
#   '料理',
#   '馬虎',
#   '吃進',
#   '嘴裡',
#   '自然',
#   '感受',
#   '缺點',
#   '附近',
#   '真的',
#   '好',
#   '停車',
#   '還拉',
#   '下次',
#   '再來',
#   '吃',
#   '菜單',
#   '選擇',
#   '不多',
#   '卻',
#   '樣樣',
#   '做到',
#   '最好',
#   '賣',
#   '一堆',
#   '東西',
#   '新鮮',
#   '好',
#   '吃來',
#   '實在',
#   '中午',
#   '知道',
#   '吃',
#   '突然',
#   '想到',
#   '最近',
#   '網路上',
#   '常看到',
#   '有人',
#   '推',
#   '一間',
#   '店',
#   '我家',
#   '附近',
#   '索性',
#   '一探',
#   '店家',
#   '資訊',
#   '五五',
#   '禾',
#   '概念',
#   '套餐',
#   '地址',
#   '台南市',
#   '北區',
#   '中華',
#   '北路',
#   '二段',
#   '號',
#   '電話',
#   '營業時間',
#   '週四',
#   '週二',
#   '公休日',
#   '每週三',
#   '五五',
#   '禾',
#   '門口',
#   '公仔',
#   '笑咪咪',
#   '臉越',
#   '越',
#   '可愛',
#   '環境',
#   '屬於',
#   '狹長',
#   '型',
#   '走',
#   '暖色調',
#   '裝潢',
#   '風格',
#   '用到',
#   '大量',
#   '木作',
#   '橘色',
#   '牆面',
#   '裡面',
#   '用餐',
#   '人蠻',
#   '放鬆',
#   '知道',
#   '是不是',
#   '暖色調',
#   '裝潢',
#   '給人',
#   '感覺',
#   '一些',
#   '可愛',
#   '裝飾品',
#   '妝點',
#   '用餐',
#   '空間',
#   '好像',
#   '畫龍點睛',
#   '作用',
#   '吼',
#   '整個',
#   '環境',
#   '比較',
#   '單調',
#   '隨手',
#   '拍',
#   '幾張',
#   '環境',
#   '後',
#   '沙拉',
#   '新鮮',
#   '爽脆',
#   '蔬果',
#   '搭配',
#   '酸甜',
#   '沙拉醬',
#   '汁',
#   '整個',
#   '越',
#   '吃',
#   '越',
#   '餓',
#   '還好',
#   '沙拉',
#   '吃',
#   '完主餐',
#   '原諒',
#   '照片',
#   '拍',
#   '有點',
#   '糊',
#   '一下',
#   '個別',
#   '照片',
#   '看拉',
#   '五五',
#   '禾',
#   '餐點',
#   '選擇',
#   '簡單',
#   '蕈',
#   '菇',
#   '拌',
#   '飯',
#   '微',
#   '咖哩',
#   '烏龍',
#   '麵',
#   '選擇',
#   '搭配',
#   '主餐',
#   '五種',
#   '選擇',
#   '牛豬',
#   '雞',
#   '魚蝦',
#   '微',
#   '咖哩',
#   '烏龍',
#   '麵',
#   '蝦子',
#   '選擇',
#   '點了',
#   '唐辛',
#   '雞腿肉',
#   '配微',
#   '咖哩',
#   '烏龍',
#   '麵',
#   '烏龍',
#   '麵',
#   '讚',
#   '歧',
#   '烏龍',
#   '麵',
#   '吃',
#   '保有',
#   '麵',
#   '體的度',
#   '吸收',
#   '咖哩',
#   '醬汁',
#   '說',
#   '雞腿肉',
#   '更是',
#   '吮指',
#   '雞皮',
#   '脆脆',
#   '咬',
#   '雞腿肉',
#   '扎實',
#   '卻',
#   '軟嫩',
#   '越',
#   '咀嚼',
#   '越',
#   '感受',
#   '肉汁',
#   '鮮甜',
#   '雞腿肉',
#   '不用',
#   '沾醬',
#   '很好吃',
#   '老闆',
#   '附',
#   '醬肉',
#   '真的',
#   '搭',
#   '醬汁',
#   '味道',
#   '微酸',
#   '微甜',
#   '搭配',
#   '雞肉',
#   '鹹',
#   '香',
#   '太',
#   '味道',
#   '莫名',
#   '有股',
#   '清爽',
#   '感',
#   '側面',
#   '一塊',
#   '肉',
#   '厚實',
#   '雞腿',
#   '真的',
#   '很好吃',
#   '讚',
#   '岐',
#   '烏龍',
#   '麵',
#   '說',
#   '拉麵',
#   '要求',
#   '軟爛',
#   '沒味道',
#   '家',
#   '烏龍',
#   '麵',
#   '處理',
#   '出色',
#   '一個',
#   '大大的',
#   '讚',
#   '上頭',
#   '有顆',
#   '黑豆',
#   '蒸蛋',
#   '打開',
#   '好像',
#   '感覺',
#   '特別',
#   '吃',
#   '感受',
#   '店家',
#   '用心',
#   '容器',
#   '保有',
#   '蒸蛋',
#   '熱度',
#   '有種',
#   '冬天',
#   '吃熱',
#   '豆花',
#   '那種',
#   '幸福感',
#   '蒸蛋',
#   '裡頭還',
#   '暗藏',
#   '蛤蜊',
#   '肉',
#   '清淡',
#   '帶有',
#   '淡',
#   '香味',
#   '微微',
#   '甜味',
#   '湯品',
#   '強大',
#   '附餐',
#   '卻',
#   '一點',
#   '隨便',
#   '打開',
#   '蓋子',
#   '看到',
#   '滿滿的',
#   '料',
#   '重點',
#   '熱度',
#   '很夠',
#   '討厭',
#   '旁邊',
#   '湯菜',
#   '冷冷的',
#   '有時候',
#   '湯是熱',
#   '吃',
#   '完主餐',
#   '喝',
#   '冷掉',
#   '五五',
#   '禾',
#   '容器',
#   '蠻能',
#   '保溫',
#   '喝',
#   '很快',
#   '冷掉',
#   '湯品',
#   '甘蔗',
#   '雞湯',
#   '喝',
#   '清甜',
#   '搭配',
#   '比較',
#   '重',
#   '口味',
#   '主餐',
#   '有種',
#   '油解膩',
#   '感覺',
#   '裡頭',
#   '大塊',
#   '雞肉',
#   '塊',
#   '玉米',
#   '筍',
#   '蔬菜',
#   '菇類',
#   '看到',
#   '枸杞',
#   '養生',
#   '湯品',
#   '喔',
#   '喝',
#   '真的',
#   '清爽',
#   '油膩',
#   '喉嚨',
#   '覺得',
#   '好',
#   '舒服',
#   '最後',
#   '結尾',
#   '甜點',
#   '飲料',
#   '飲料',
#   '我選',
#   '熱咖啡',
#   '飲料',
#   '另有',
#   '紅茶',
#   '柳橙汁',
#   '七葉',
#   '養生茶',
#   '選擇',
#   '甜點',
#   '抹茶',
#   '巧克力',
#   '有點像',
#   '布丁',
#   '口感',
#   '綿密',
#   '滑順',
#   '好吃',
#   '期待',
#   '下',
#   '吃',
#   '好吃',
#   '食物',
#   '心',
#   '情變',
#   '超好',
#   '好像',
#   '預期',
#   '挖',
#   '寶藏',
#   '下次',
#   '想帶',
#   '家人',
#   '吃',
#   '蕈',
#   '菇',
#   '拌',
#   '飯',
#   '很強',
#   '店家',
#   '資訊',
#   '五五',
#   '禾',
#   '概念',
#   '套餐',
#   '地址',
#   '台南市',
#   '北區',
#   '中華',
#   '北路',
#   '二段',
#   '號',
#   '電話',
#   '營業時間',
#   '週四',
#   '週二',
#   '公休日',
#   '每週三',
#   '今天',
#   '姐姐',
#   '一家',
#   '三口',
#   '桃園',
#   '殺來',
#   '台南',
#   '帶著',
#   '可愛',
#   '小',
#   '姪',
#   '女',
#   '姐姐',
#   '食物',
#   '挑剔',
#   '人',
#   '特別',
#   '囑咐',
#   '我要',
#   '一家',
#   '三口',
#   '吃',
#   '好料',
#   '身為',
#   '妹妹',
#   '疼愛',
#   '姪',
#   '女阿姨',
#   '決定',
#   '不負',
#   '所望',
#   '之前',
#   '吃過',
#   '五五',
#   '禾',
#   '概念',
#   '料理',
#   '這次',
#   '記錄',
#   '一下',
#   '美食',
#   '分享',
#   '這家',
#   '店中',
#   '華北',
#   '路上',
#   '招牌',
#   '門口',
#   '公仔',
#   '一排',
#   '人行道',
#   '房子',
#   '中',
#   '有點',
#   '容易',
#   '忽略',
#   '第一次',
#   '騎',
#   '過頭',
#   '附近',
#   '停車位',
#   '好找',
#   '對開',
#   '車一族',
#   '來說',
#   '方便',
#   '許多',
#   '一進到',
#   '店內',
#   '店家',
#   '注意',
#   '有帶',
#   '小朋友',
#   '貼心',
#   ...],
#  ['雅悅',
#   '會館',
#   '雅悅',
#   '會館',
#   ' ',
#   '台南',
#   '館',
#   ' ',
#   '燈光',
#   '美',
#   '氣氛',
#   '佳',
#   '餐點',
#   '美味',
#   '南紡夢',
#   '時代',
#   '雅悅',
#   '會館',
#   '看飯編',
#   '最近',
#   '文章',
#   '開頭',
#   '知道',
#   '最近',
#   '出車禍',
#   '親戚家',
#   '白吃白喝',
#   '休養',
#   '手邊',
#   '文案',
#   '餐車',
#   '設計',
#   '案',
#   '一邊',
#   '進行',
#   '中撞',
#   '頭部',
#   '辦法',
#   '用腦',
#   '太久',
#   '閒著',
#   '閒著',
#   '決定',
#   '寫',
#   '一些',
#   '想',
#   '寫',
#   '整理',
#   '一些',
#   '以前',
#   '拍過',
#   '東西',
#   '寫',
#   '想',
#   '寫',
#   '東西',
#   '創作',
#   '方面',
#   '比較',
#   '自由',
#   '比較',
#   '受',
#   '時間',
#   '壓迫',
#   '今天',
#   '介紹',
#   '台南',
#   '婚宴',
#   '場地',
#   '雅悅',
#   '會館',
#   '飯',
#   '編結',
#   '婚飯編',
#   '兒時',
#   '玩伴',
#   '喔',
#   '非常感謝',
#   '這次',
#   '邀請',
#   '做',
#   '婚禮',
#   '紀錄',
#   '攝影',
#   '一次',
#   '滿足',
#   '美食',
#   '旅遊',
#   '婚宴',
#   '會館',
#   '三種',
#   '主題',
#   '每次',
#   '逛',
#   '夢',
#   '時代',
#   '色彩',
#   '太過',
#   '綺麗',
#   '搶眼',
#   '想',
#   '一眼',
#   '門口',
#   '每次',
#   '一看',
#   '櫃台',
#   '認為',
#   '看著',
#   '蠢蠢欲動',
#   '想要',
#   '招待',
#   '小姐',
#   '眼神',
#   '移開',
#   '這次',
#   '總算',
#   '真的',
#   '機會',
#   '一次',
#   '看得出',
#   '小姐',
#   '用心',
#   '觀察',
#   '感謝',
#   '這對',
#   '新人',
#   '機會',
#   '共享',
#   '美好',
#   '浪漫',
#   '婚宴',
#   '資訊',
#   '店家',
#   '名稱',
#   '雅悅',
#   '會館',
#   '台南',
#   '館',
#   '地址',
#   '台南市',
#   '東區',
#   '中華',
#   '東路',
#   '一段',
#   '號樓',
#   '南紡夢',
#   '時代',
#   '營業時間',
#   '店家',
#   '臉書雅悅',
#   '會館',
#   '進入',
#   '裡面',
#   '專人',
#   '協助',
#   '帶路',
#   '紅色',
#   '炸彈',
#   '確定',
#   '前往',
#   '一間',
#   '囉',
#   '進入',
#   '會館',
#   '前',
#   '簽到',
#   '場地',
#   '像是',
#   '海洋生物',
#   '燈飾',
#   '充滿',
#   '藝術',
#   '感前',
#   '婚禮',
#   '小物',
#   '擺設',
#   '一旁',
#   '造景',
#   '適合',
#   '拍',
#   '一張',
#   '浪漫',
#   '回憶',
#   '一面',
#   '可愛',
#   '小馬',
#   '繽紛',
#   '夢幻',
#   '粉色',
#   '系',
#   '牆面',
#   '新娘子',
#   '相當',
#   '漂亮',
#   '再來',
#   '偷襲',
#   '一下',
#   '新娘',
#   '休息室',
#   '算是',
#   '幕後',
#   '花絮',
#   '休息室',
#   '裡面',
#   '空間',
#   '相當',
#   '寬敞',
#   '舒適',
#   '提供',
#   '精緻',
#   '小點心',
#   '太忙',
#   '拍攝',
#   '主要',
#   '拍攝',
#   '活動',
#   '紀錄',
#   '抬頭',
#   '望去',
#   '就連',
#   '燈飾',
#   '氣派',
#   '典雅',
#   '人',
#   '一種',
#   '享受',
#   '高檔',
#   '氣氛',
#   '感覺',
#   '忙碌',
#   '準備',
#   '過程',
#   '中',
#   '忙碌',
#   '拍攝',
#   '角落',
#   '裡面',
#   '燈光',
#   '氣氛',
#   '人',
#   '感覺',
#   '相當',
#   '舒適',
#   '明亮',
#   '寬敞',
#   '刺眼',
#   '後方',
#   '星空',
#   '背景',
#   '點綴',
#   '添加',
#   '浪漫',
#   '幸福',
#   '氛圍',
#   '裡面',
#   '水晶',
#   '燈飾',
#   '華麗',
#   '帶有',
#   '質感',
#   '身為',
#   '美食',
#   '部落',
#   '客',
#   '順便',
#   '寫',
#   '一篇',
#   '食記',
#   '說',
#   '實在',
#   '裡面',
#   '食物',
#   '調味',
#   '還算蠻',
#   '不錯',
#   '食記',
#   '會館',
#   '桌子',
#   '寬敞',
#   '坐',
#   '相當',
#   '舒適',
#   '桌上',
#   '可愛',
#   '造型',
#   '文具',
#   '用餐',
#   '完',
#   '以後',
#   '直接',
#   '收編',
#   '喔',
#   '桌上',
#   '餐巾',
#   '擺放',
#   '相當',
#   '整齊',
#   '令人',
#   '賞心悅目',
#   '上方',
#   '貼心',
#   '標示',
#   '位子',
#   '繽紛',
#   '花朵',
#   '裝飾',
#   '整體',
#   '相當',
#   '整齊',
#   '美觀',
#   '兼具',
#   '質感',
#   '餐桌上',
#   '紅酒',
#   '柳橙汁',
#   '選擇',
#   '提供',
#   '巧克力',
#   '平常',
#   '看過',
#   '不算',
#   '便宜',
#   '上方',
#   '今天',
#   '會出',
#   '菜色',
#   '名稱',
#   '用著',
#   '喜氣',
#   '詞語',
#   '修飾',
#   '滿足',
#   '大人',
#   '小朋友',
#   '需求',
#   '喝酒',
#   '服務生',
#   '詢問',
#   '收走',
#   '比較',
#   '占',
#   '空間',
#   '上方',
#   '魔鏡',
#   '桌邊',
#   '提供',
#   '紙盒',
#   '婚宴',
#   '食材',
#   '比較',
#   '多怕',
#   '吃不完',
#   '打包',
#   '開胃菜',
#   '主要',
#   '一些',
#   '冷盤',
#   '為主',
#   '內容',
#   '物有',
#   '雞肉',
#   '魷魚',
#   '梅子',
#   '烏魚',
#   '子串',
#   '地瓜',
#   '球',
#   '小菜',
#   '調味',
#   '主菜',
#   '出色',
#   '鮮甜',
#   '小巧',
#   '精緻',
#   '做',
#   '一個',
#   '美妙',
#   '開場',
#   '烏魚子',
#   '串燒',
#   '形式',
#   '呈現',
#   '爽口',
#   '方便',
#   '分食',
#   '主菜',
#   '出場',
#   '囉',
#   '一下',
#   '壯觀',
#   '龍蝦',
#   '真的',
#   '一出場',
#   '高檔',
#   '食材',
#   '沙拉',
#   '不算',
#   '大份',
#   '吃',
#   '得到',
#   '鮮甜',
#   '飽滿',
#   '龍蝦',
#   '清爽',
#   '蔬菜',
#   '風',
#   '醬料',
#   '相當',
#   '開胃',
#   '一道',
#   '料理',
#   '再來',
#   '魚翅',
#   '湯的',
#   '部分',
#   '湯頭',
#   '部分',
#   '濃郁',
#   '鮮甜',
#   '不膩',
#   '口',
#   '整體',
#   '來說',
#   '味道',
#   '相當',
#   '不錯',
#   '通常',
#   '特別',
#   '吃',
#   '魚翅',
#   '蔡',
#   '這道',
#   '使用',
#   '帝王',
#   '蟹',
#   '腳',
#   '冬粉',
#   '結合',
#   '主食',
#   '相當',
#   '氣派',
#   '忙',
#   '做',
#   '婚禮',
#   '紀錄',
#   '辦法',
#   '拍',
#   '完整',
#   '樣貌',
#   '還被',
#   '說',
#   '拍',
#   '每桌',
#   '親友團',
#   '拍',
#   '食物',
#   '很久沒',
#   '吃',
#   '飽滿',
#   '鮮甜',
#   '蟹肉',
#   '殼',
#   '部分',
#   '相當',
#   '貼',
#   '心切',
#   '方便',
#   '食用',
#   '每次',
#   '都問',
#   '老媽',
#   '說',
#   '螃蟹',
#   '不長',
#   '蛤蜊',
#   '撥開',
#   '吃',
#   '老媽',
#   '生來',
#   '給你',
#   '吃',
#   '一部分',
#   '螃蟹',
#   '身體',
#   '油飯',
#   '結合',
#   '部分',
#   '比較',
#   '機會',
#   '吃螃蟹',
#   '蛋',
#   '油飯',
#   '部',
#   '分則',
#   '味道',
#   '相當',
#   '層次',
#   '食材',
#   '香氣',
#   '融入',
#   '飯中',
#   '清爽',
#   '不膩',
#   '口',
#   '再來',
#   '這道',
#   '芋頭',
#   '上面',
#   '有著',
#   '鮑魚',
#   '組合',
#   '旁邊',
#   '地瓜',
#   '球',
#   '蘆薈',
#   '點綴',
#   '一道',
#   '菜色',
#   '相當',
#   '豐富',
#   '海鮮',
#   '鮮甜',
#   '芋頭',
#   '香氣',
#   '結合',
#   '新鮮',
#   '美味',
#   '不太敢',
#   '吃',
#   '芋頭',
#   '店家',
#   '芋',
#   '頭條',
#   '配',
#   '相當',
#   '清爽',
#   '帶有',
#   '香氣',
#   '吳郭魚',
#   '羊小排',
#   '忙',
#   '記錄',
#   '只',
#   '拍',
#   '杯盤狼藉',
#   '樣子',
#   '重',
#   '口味',
#   '敘述',
#   '吳郭魚',
#   '部分',
#   '相當',
#   '大隻',
#   '豪邁',
#   '口感',
#   '新鮮',
#   '調味',
#   '不錯',
#   '羊小排',
#   '部分',
#   '主要',
#   '黑胡椒',
#   '醬',
#   '調味',
#   '紫色',
#   '洋蔥',
#   '點綴',
#   '羊',
#   '味道',
#   '偏重',
#   '愛吃',
#   '羊排',
#   '這道',
#   '相當',
#   '美味',
#   '肉',
#   '口感',
#   '適中',
#   '嚼',
#   '勁',
#   '清爽',
#   '不膩',
#   '口',
#   '胡椒',
#   '調味',
#   '夠味',
#   '太',
#   '嗆鼻',
#   '烏骨雞',
#   '湯人',
#   '想到',
#   '中華',
#   '一番',
#   '中',
#   '帶來',
#   '不幸',
#   '雞湯',
#   '頭',
#   '使用',
#   '烏骨雞',
#   '火腿',
#   '干貝',
#   '原料',
#   '整個',
#   '精華',
#   '湯頭',
#   '裡啊',
#   '相當',
#   '鮮甜',
#   '美味',
#   '整體',
#   '吃',
#   '下來',
#   '覺得',
#   '菜色',
#   '調配',
#   '相當',
#   '美味',
#   '精緻',
#   '最後',
#   '甜點',
#   '部分',
#   '總共',
#   '三種',
#   '形式',
#   '甜點',
#   '第一',
#   '部分',
#   '式',
#   '海鮮',
#   '塔',
#   '樣貌',
#   '就讓',
#   '人',
#   '蠢蠢欲動',
#   '準備',
#   '嘗試',
#   '味道',
#   '囉',
#   '海鮮',
#   '塔',
#   '主要',
#   '以起司',
#   '番茄',
#   '海鮮',
#   '玉米',
#   '鳳梨',
#   '原料',
#   '組成',
#   '溫度',
#   '偏溫',
#   '是從',
#   '烤箱',
#   '出爐',
#   '稍微',
#   '散熱',
#   '般',
#   '溫度',
#   '相當',
#   '豐富',
#   '配料',
#   '海鮮',
#   '塔',
#   '吃',
#   '相當',
#   '層次',
#   '口中',
#   '咀嚼',
#   '充滿',
#   '爆炸性',
#   '口感',
#   '刺激',
#   '味蕾',
#   '像是',
#   '披薩',
#   '般',
#   '濃郁',
#   '口感',
#   '吃',
#   '還會',
#   '牽絲',
#   '水果',
#   '結合',
#   '不膩',
#   '口塔底',
#   '部分',
#   '扎實',
#   '原味',
#   '口感',
#   '相當',
#   '出色',
#   '海鮮',
#   '塔',
#   '部分',
#   '整體',
#   '來說',
#   '相當',
#   '美味',
#   '第二種',
#   '形式',
#   '甜點',
#   '甜湯',
#   '喝',
#   '應該',
#   '算是',
#   '海',
#   '燕窩',
#   '口感',
#   '清爽',
#   '解渴',
#   '不膩',
#   '口中',
#   '式',
#   '甜湯',
#   '相當',
#   '棒',
#   '最後',
#   '要來',
#   '一份',
#   '冰淇淋',
#   '做',
#   '一個',
#   '完美',
#   '結尾',
#   '店家',
#   '提供',
#   '哈根達斯',
#   '迷你',
#   '杯算',
#   '誠意',
#   '很甜',
#   '式',
#   '草莓',
#   '口味',
#   '酸酸甜甜',
#   '戀愛',
#   '滋味',
#   '喔',
#   '一人',
#   '一杯',
#   '散播',
#   '幸福',
#   '剛剛',
#   '好',
#   '最後',
#   '看看',
#   '完整',
#   '菜色',
#   '名稱',
#   '太長',
#   '記不起來',
#   '好像',
#   '哈根達斯',
#   '冰淇淋',
#   '最',
#   '白話',
#   '試',
#   '婚宴',
#   '菜色',
#   '取名',
#   '主題',
#   '真的',
#   '花',
#   '心思',
#   '看出',
#   '中國',
#   '詞彙',
#   '奧妙',
#   '環境',
#   '裝潢',
#   '再給',
#   '一下',
#   '簽到',
#   '場地',
#   '部分',
#   '上面',
#   '有著',
#   '可愛',
#   '小熊',
#   '裝飾',
#   '裝',
#   '糖果',
#   '類似',
#   '下午茶',
#   '擺盤',
#   '方式',
#   '呈現',
#   '相當',
#   '精緻',
#   '優雅',
#   '可愛',
#   '婚禮',
#   '小物',
#   '小',
#   '氣球',
#   '氣流',
#   '小馬',
#   '結合',
#   '拍照',
#   '景色',
#   '進入',
#   '會館',
#   '前水水',
#   '新娘新郎',
#   '合照',
#   '不用',
#   '擔心',
#   '走錯',
#   '棚裡面',
#   '有趣',
#   '燈光',
#   '變化',
#   '方便',
#   '觀看',
#   '投影',
#   '螢幕',
#   '心貼心',
#   '主持人',
#   '整場',
#   '活動',
#   '相當',
#   '順利',
#   '流暢地',
#   '進行',
#   '走廊',
#   '部分',
#   '相當',
#   '看到',
#   '許多',
#   '裝潢',
#   '擺設',
#   '開放式',
#   '空間',
#   '視野',
#   '相當',
#   '寬敞',
#   '戶外',
#   '走走',
#   '呼吸',
#   '新鮮空氣',
#   '應該',
#   '一個',
#   '地方',
#   '走',
#   '會館',
#   '周邊',
#   '許多',
#   '婚禮',
#   '小物',
#   '擺設',
#   '典雅',
#   '椅子',
#   '寬敞',
#   '空間',
#   '顯得',
#   '相當',
#   '氣派',
#   '典雅',
#   '新娘',
#   '進場',
#   '前',
#   '燈光',
#   '秀',
#   '部分',
#   '錄影',
#   '還沒',
#   '整理',
#   '檔案',
#   '之後',
#   '會放',
#   '走廊',
#   '一個',
#   '拍造',
#   '場地',
#   '叫做',
#   '幸福',
#   '拍照',
#   '區',
#   '運用',
#   '剪影',
#   '座',
#   '造型',
#   '相當',
#   '浪漫',
#   '可愛',
#   '外部',
#   '拍攝',
#   '會館',
#   '形象',
#   '婚紗',
#   '婚禮',
#   '小物',
#   '背景',
#   '部分',
#   '充滿',
#   '浪漫',
#   '可愛',
#   '感覺',
#   '寫法',
#   '相當',
#   '可愛',
#   '叫做',
#   '老媽',
#   '朋友',
#   '白話',
#   '充滿',
#   '一種',
#   '親切',
#   '逗趣',
#   '感覺',
#   '抽',
#   '新娘',
#   '禮物',
#   '活動',
#   '喔',
#   '可愛',
#   '小妹妹',
#   '抽',
#   '中',
#   '中獎',
#   '會館',
#   '提供',
#   '可愛',
#   '刮刮卡',
#   '中三心',
#   '有禮',
#   '喔',
#   '飯編',
#   '永遠',
#   '抽獎',
#   '運',
#   '會館',
#   '提供',
#   '彩帶',
#   '花束',
#   '新娘新郎',
#   '進場',
#   '親友團',
#   '獻上',
#   '滿滿',
#   '祝福',
#   '最後',
#   '祝福',
#   '這對',
#   '新人',
#   '長長',
#   '久久',
#   '永浴愛河',
#   '鶼鰈情深',
#   '幸福美滿',
#   '喔',
#   '店家',
#   '特色',
#   '氣派',
#   '典雅',
#   '環境',
#   '貼心',
#   '完善',
#   '服務',
#   '美味',
#   '誘人',
#   '餐點',
#   '浪漫',
#   '可愛',
#   '氣氛',
#   '位於',
#   '南紡夢',
#   '時代',
#   '機能',
#   '方便',
#   '親切',
#   '符合',
#   '年輕',
#   '族群',
#   '點我',
#   '支持',
#   '原文',
#   '連結',
#   '延伸',
#   '閱讀',
#   '台南',
#   '東區',
#   '夢',
#   '時代',
#   '餐廳',
#   '老爺',
#   '行旅',
#   '甘粹',
#   '餐廳',
#   '台南',
#   '東區',
#   '南紡夢',
#   '時代',
#   '麻布',
#   '茶房',
#   '值',
#   '超高',
#   '雙人',
#   '套餐',
#   '台南',
#   ...]]

# %% [markdown]
# # 6. 把gensim, Doc2Vec的套件匯入

# %%
import gensim
Lsent = gensim.models.doc2vec.LabeledSentence
def labelizeNews(food, label_type):
    labelized = []
    #enumertate include index
    for i, v in enumerate(food):
        label = '%s_%s' %(label_type,i)
        labelized.append(Lsent(v, [label]))
    return labelized

# for i,v in enumerate()
# i為流水號，1  2  3
# v為每篇文章的，第1個字全部  第2個字全部  第3個字全部
# label_type為type標籤
# labelized = []
# for i,v in enumerate(Eat_List):
#     label = '%s_%s' %('Eat',i)
#     labelized.append(Lsent(v, [label]))

# 將第一篇的文字全部上Eat_1的標籤
# 將第二篇的文字全部上Eat_2的標籤
# 以此類推
# Out:
# D:\Anaconda3\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.

# %% [markdown]
# # 7. 將每個問題的文章給一個標籤，方便分析完對應

# %%
Train_Eat = labelizeNews(Eat_List,'Eat')
Train_Ser = labelizeNews(Ser_List,'Serve')
Train_Env = labelizeNews(Env_List,'Enviroment')

# %%
print(type(Train_Eat))
print(type(Train_Eat[1]))
Train_Eat[0]#為上完標籤的gensimlabel
# Out:
# <class 'list'>
# <class 'gensim.models.doc2vec.LabeledSentence'>
# LabeledSentence(words=['食下', '約', ' ', '想法', '廚房', ' ', '天氣', '冷吃個', '鍋', '內容', '比較', '一篇', '介紹', '無', '制式', '餐點', '本篇', '介紹', '花雕', '鍋', '有別於', '之前', '吃', '蹄膀', '雞肉', '這次', '吃', '比較', '少見', '蝦煲', '牛肉', '煲', '食下', '約', '主要', '提供', '套餐', '鍋物', '無', '制式', '套餐', '下午', '茶食', '下約', '想法', '廚房', '地址', '台南市', '安平', '區郡', '平路號', '電話', '營業時間', '粉絲', '專頁', '葷', '有素', '兒童座椅', '店家', '介紹', '食下', '約', '億載', '國', '小', '斜對面', '馬路邊', '相當', '好找', '一樓', '創意', '料理', '食下', '約', '二樓', '蔬食', '餐廳', '食蔬', '茶', '齋', '三到', '六樓', '則是', '民宿', '會館', '整體', '走', '比較', '沉穩', '食材', '美味', '度經', '考驗', '路線', '茶具', '元素', '電梯', '覺得', '老少咸宜', '長輩', '住', '適合', '旁邊', '很大', '空地', '停車', '相當', '便利', '不用', '停車費', '招牌', '寫', '早', '午餐', '下午茶', '晚餐', '供應', '店內', '環境', '晚上', '氛圍', '比較', '沉穩', '和緩', '些', '店', '兩人座', '八人座', '約會', '親友', '聚餐', '適合', '店裡', '最大', '座位', '區這區', '型', '長型', '沙發', '方便', '放置', '包包', '雜物', '店內', '貼心', '備有', '兒童座椅', '這次', '比較', '特別', '靠近', '雙人', '座', '旁邊', '種植', '食用', '生菜', '裝飾', '店內', '具有', '保鮮', '作用', '覺得', '可愛', '食下', '約', '價格表', '菜單', '價位', '食下', '約', '菜單', '這次', '做', '一些', '小', '變動', '低', '消元', '用餐', '時間', '小時', '免費', '無', '制式', '菜單', '料理', '選', '主菜', '主食', '醬汁', '飲料', '主菜', '選項', '雞肉', '魚肉', '牛肉', '豬肉', '鴨肉', '海鮮', '主食', '選項', '有機', '麵', '條', '造型', '麵', '進口', '壽司', '米燉', '飯', '醬汁', '選項', '紅醬', '青醬', '咖哩', '醬', '墨西哥', '辣醬', '紅酒', '醬', '白酒', '醬', '食材', '品質', '好', '醬汁', '熬', '煮', '沒什麼', '雷選', '喜歡', '口味', '即可', '套餐', '價格', '元', '自選', '主菜', '主食', '醬汁', '飲品', '附', '甜點', '四種', '褒類', '價格', '元', '飲料', '甜點', '美式', '南瓜', '鍋義式', '番茄', '鍋', '日本', '梅鍋', '台式', '麻', '油鍋', '墨西哥', '勁辣鍋', '素食者', '吃', '蔬食', '鍋', '同樣', '元選', '主食', '澳洲', '牛板', '肉', '匈牙利', '松阪', '豬跑', '山雞', '雞腿肉', '整尾', '驢魚', '桌上', '水', '自助', '這次', '吃', '餐點', '經典', '花雕', '煲', '系列', '花雕', '蝦煲', '花雕', '煲', '系列', '附', '飲料', '甜點', '伴著', '花雕', '鍋', '上桌', '附上', '白飯', '補充', '古早', '味', '私房', '滷汁', '滷汁', '帶點', '花雕酒', '香氣', '有著', '清爽', '不膩', '口', '鹹味', '配飯', '吃', '相當', '涮', '嘴', '美味', '食下', '約', '雕花', '蝦煲', '嚴選', '大蝦', '入鍋', '大蝦', '六七隻', '左右', '鍋裡', '堆成', '一座', '小山', '蝦子', '蝦界', '老爺', '男生', '大拇指', '大小', '飽滿', '新鮮', '彈牙', '彷彿', '蝦剛', '海裡', '捕撈', '煮熟', '送入', '口中', '一鍋', '一家子', '吃個', '一兩隻', '內心', '充滿', '平安', '喜樂', '鍋內', '蝦子', '熟', '之外', '菜', '煮', '滴', '控制', '想要', '熟度', '旁邊', '絲瓜', '南瓜', '娃娃', '菜', '杏鮑菇', '蝦子', '飽滿', '新鮮肉', '菜', '快速', '消滅', '花雕', '牛煲', '牛煲', '滿滿的', '肉', '堆疊', '一份', '錢', '一份', '貨啊', '菜單', '寫', '說', '優質', '牛肉', '不用', '吃', '品質', '好', '牛肉', '軟嫩', '一個', '爆', '應該', '牛腩', '軟嫩', '好', '入口', '爸', '牙齒', '不好', '中年人', '吃', '愉快', '旁邊', '一堆', '新鮮', '飽滿', '蔬菜', '整鍋', '相當', '營養', '清爽', '食材', '好', '反正', '預算', '夠錢會花', '值得', '蝦煲', '牛肉', '煲', '醬汁', '不太蝦', '煲', '稍', '鹹', '一些', '特別', '下飯', '牛肉', '煲湯', '適合', '當湯', '喝', '清爽', '帶有', '淡淡', '酒香', '好喝', '暖', '胃', '暖', '心狂', '喝', '特喝', '好喝', '這一鍋', '吃', '好喝', '清爽', '湯底', '新鮮', '蔬菜', '軟嫩', '美味', '具有', '份量', '牛肉', '附', '餐飲', '料熱', '伯爵', '茶飲料', '器皿', '設計', '感', '原本', '食下', '約', '飲料', '比較', '果汁', '類目', '前', '改為', '茶品', '餐點', '提升', '些許', '精緻', '度', '茶葉', '放在', '漂亮', '櫃子', '台上', '做', '展示', '冰', '歐式', '莓', '果茶', '喝', '順口', '淡淡', '果香', '糖冰', '調整', '附餐', '甜點', '最後', '甜點', '伯爵', '奶酪', '底下', '一些', '伯爵', '茶葉', '渣渣濃', '醇香', '細膩', '度', '也夠', '好', '好吃', '喔', '吃', '完', '一個', '還會', '想', '再', '吃', '兩個', '餐點', '小', '總結', '之前', '吃過', '蹄膀', '覺得', '不錯', '完全', '顛覆', '蹄膀', '印象', '原本', '以為', '吃', '油', '清爽', '不膩', '滷汁', '這次', '改良', '變得', '黏稠', '原本', '適合', '淋在', '飯', '新版', '特別', '牛煲', '喝', '補補', '清爽', '口味', '迷人', '蝦', '牛肉', '好吃', '食材', '等級', '軟嫩度', '適合', '嘴刁', '長輩', '說', '老少咸宜', '天氣', '冷冷的', '食下', '約', '吃', '吃', '美味', '花雕', '鍋', '囉', '食下', '約', '初訪', '中午', '篇', '食下', '約', '無', '制式', '菜單', '篇', '小食', '代', '讚', '接收', '台南', '各地', '好吃', '好玩', '訊息', '喔', '去年', '時間', '皮皮', '吃食', '下有', '約', '吃', '完', '覺得', '肉', '飲料', '厲害', '這次', '晚上', '家人', '店家', '做', '餐點', '調整', '雕花', '煲', '口味', '小菜', '提升', '些許', '精緻', '度食', '下', '約', '主要', '提供', '套餐', '鍋物', '無', '制式', '套餐', '下午', '茶食', '下約', '想法', '廚房', '地址', '台南市', '安平', '區郡', '平路號', '電話', '營業時間', '粉絲', '專頁', '葷', '有素', '兒童座椅', '店家', '介紹', '食下', '約', '億載', '國', '小', '斜對面', '馬路邊',  ...

# %% [markdown]
# # 8. 設定Doc2Vec參數 (使用seed or save model 來排除訓練的隨機成分，如果需要每次的向量結果相同
# 每一個Corpus產出400維的向量，預設使用3個核心做運算

# %%
size = 400   
model_dm = gensim.models.Doc2Vec(min_count=1, window=10, size=size, sample=1e-3, negative=5, workers=3)
model_dbow = gensim.models.Doc2Vec(min_count=1, window=10, size=size, sample=1e-3, negative=5,dm=0, workers=3)

#兩種訓練model 一種dm=0 另一種沒這參數

# %% [markdown]
# # 9. 訓練集，把Label後的新聞List接起來

# %%
Train_All =  Train_Eat + Train_Ser + Train_Env

# %%
Train_All[137] #把所有文章順序斷詞+標籤_編號 加(list)起來
# Out:
# LabeledSentence(words=['椰庭', '景觀', '餐廳', ' ', '台南', '遊玩', '安排', '草綠色', '隧道', '行程', '推薦', '順道', '一訪', '椰庭', '景觀', '餐廳', '感受', '濃濃的', '鄉村', '風情', '料', '多味', '美的', '蚵', '仔', '麵', '線', '更是', '人', '回味無窮', '椰庭', '位置', '有點', '隱密', '入口', '需從', '四草', '大道', '小徑', '進入', '馬路邊', '明顯', '招牌', '特別', '放慢', '速度', '停好車', '後', '目光', '爭妍', '花朵', '吸引', '艷麗', '花朵', '中', '許多', '浪漫', '造景', '原來', '荒廢', '的魚', '塭', '老闆', '多年', '整理', '終於', '打造出', '充滿', '悠閒', '氛圍', '園地', '園區', '裡的', '花草', '植物', '人', '感受', '清新自然', '綠意', '心情', '自覺', '放鬆', '餐廳', '建築', '外觀', '華麗', '氣派', '門面', '走', '純樸', '農村', '風格', '人', '溫馨', '親切', '門口', '擺放', '石磨', '古早', '味', '椅子', '兩台', '復古', '機車', '自然', '散發出', '悠閒', '鄉村', '風情', '餐廳', '內部', '裝潢', '擺設', '簡約', '農村', '元素', '主點', '餐', '結帳', '櫃檯', '許多', '竹子', '組合', '放置', '餐廳', '擺櫃', '充滿著', '鄉村', '風情', '餐桌上', '畫面', '寶小銘滿', '喜歡', '一壺', '茶水', '貼著', '奉', '茶', '字樣', '有意思', '椰庭', '菜單', '多以', '台式', '風味', '餐點', '為主', '一些', '古早', '味冰', '品茶', '品點', '好', '餐後寶小銘', '來到', '角落', '看看', '傳統', '家具', '農具', '擺設', '歷經', '年代', '細細品味', '挺', '有趣', '上桌', '店裡', '招牌', '蔥香', '蚵', '仔', '麵', '線元', '這道', '料理', '一桌', '有點', '表層', '舖', '大量', '鮮', '蚵', '一顆', '蚵', '仔', '飽滿', '肥嫩', '入口', '後', '嚐', '得出', '新鮮度', '十足', '帶有', '自然', '鮮甜', '滑嫩', '順口', '滋味', '搭配', '蔥香', '美味', '人', '一口', '接', '一口', '吃', '不停', '麵', '線', '口感', '不錯', '滑溜', '順口', '軟爛香', '煎', '虱目', '魚肚', '元', '這也', '台南', '常見', '傳統', '小吃', '細嫩', '魚肉', '裡', '帶有', '豐富', '油脂', '散發出', '香氣', '同樣', '令人', '難以', '抗拒', '炒水蓮元', '炒過', '水蓮', '吃', '爽脆', '可口', '加入', '時蔬', '食材', '整體', '口感', '豐富', '粉圓', '鮮奶', '茶元裡頭', '純手工', '製', '粉圓', '頗受', '好評', '純手工', '製成', '口感', '顯得', '嫩', '再', '搭配', '鮮奶', '茶', '濃純', '香沁涼', '滋味', '帶有', '滿滿的', '幸福感', '室內', '座位', '外', '戶外', '用餐', '區', '樹蔭', '底下', '用餐', '不用', '晒', '太陽', '園區', '裡', '看見', '許多', '全家人', '同遊', '享', '天倫之樂', '畫面', '品嚐', '完', '美味', '後', '園區', '裡', '悠閒', '漫步', '餐廳', '外頭', '看見', '許多', '高大挺拔', '椰子樹', '應該', '椰庭', '由來', '吊床', '設施', '更讓人', '感受', '慵懶', '氣息', '適合', '放空', '整個', '下午', '走著', '走', '著還', '遇見', '松鼠', '鳥兒', '人', '忍不住', '靠近', '觀察', '可愛', '模樣', '隻', '金雞', '羽毛', '真是', '漂亮', '椰庭', '保留', '了魚', '塭', '原始', '景觀', '叢林', '裡的', '小朋友', '大開眼界', '魚', '塭', '發現', '特別', '景觀', '這是', '園主', '茅草', '搭', '建成', '桶', '間', '寮', '又稱', '探', '寮', '主要', '漁民', '裡頭', '過夜', '便於', '看守', '魚', '塭', '現在', '椰庭桶', '間', '寮', '功用', '休閒', '之用', '以往', '造訪', '景觀', '餐廳', '多以', '異國', '風情', '特色', '這次', '來到', '椰庭', '感受', '親切', '鄉村', '氣息', '園區', '裡有', '多元', '自然景觀', '綠意', '植栽', '可愛', '小', '動物', '像是', '一個', '充滿', '幸福感', '開心', '農場', '非常適合', '全家', '同遊', '來到', '椰庭', '別忘了', '點', '一份', '蚵', '仔', '麵', '線', '不虛此行', '椰庭', '景觀', '餐廳', '地址', '台南市', '安南', '區四草', '大道', '號', '電話', '營業時間', '週二', '週五', '週六', '週日', '週一', '若遇', '國定假日', '照常營業', '官方', '椰庭', '部落', '格有', '旅遊', '美食', '分享', '寶小銘', '天空', '寶小銘', '天空', '一併', '推廣', '粉絲', '專頁', '前', '陣子', '來到', '台南', '旅遊', '三天', '兩夜', '輕', '旅行', '吃', '許多', '小吃', '住', '兩間', '不賴', '民宿', '皮亞家', '民宿', '夢想', '套房', '民宿', '來到', '這間', '中', '漂亮', '美麗', '景觀', '餐廳', '椰庭', '景觀', '餐廳', '位於', '安南', '區四草', '大道', '椰庭', '餐廳', '裡面', '真的', '大有', '來頭', '從種', '花草樹木', '走', '道', '走進', '真的', '大開眼界', '感覺', '花草樹木', '之外', '小橋流水', '像是', '仙境', '綠意', '圍繞', '輕鬆', '愜意', '感覺', '很棒', '養', '一些', '小', '動物', '好', '自然', '感覺', '話', '說', '原本', '規劃', '想要', '弄個', '船屋', '民宿', '可惜', '程序', '問題', '現在', '辦法', '實現', '夢幻', '民宿', '喜鵲', '不停', '網子', '裡', '飛來飛去', '陳先生', '拍', '合不攏嘴', '白色', '屋子', '裡頭', '餐廳', '用餐', '區分', '成', '室內', '室外', '想', '吃', '古', '早味', '走', '便是', '屋外', '綠地', '角度', '拍照', '美', '屋前', '椰子樹', '特別', '高聳', '顯眼', '大自然', '美', '隨處', '發現', '漂流', '木', '搭', '建成', '鞦韆', '一個', '利用', '下午', '時光', '休憩', '吊床', '許多', '遊客', '喜歡', '站', '柵欄', '旁', '餵', '飼料', '鴨子', '魚兒', '欣賞', '夕陽', '美找', '屏障', '視線', '看到', '美的', '餘暉', '店內', '復古', '東西', '牆上', '蓑衣', '斗笠', '魚籃', '竹籃', '一台', '清除', '稻穀', '中', '雜物', '風鼓難', '見到', '復古', '物品', '室內', '蠻多', '座位', '欣賞', '完', '戶外', '自然風景', '裡頭', '找個', '順眼', '喜愛', '位子', '好好', '坐', '下來', '享受', '一頓', '美味', '復古', '小', '茶壺', '倒杯水', '喝', '特別', '味道', '當天', '手工', '粉圓', '剩下', '最後', '一碗', '碗', '來客', '人', '手工', '粉圓', '吃', '工作人員', '忙', '搓', '湯圓', '弭', '補', '安撫', '一下', '遠道而來', ...

# %% [markdown]
# # 由有順序的句子建立model詞彙(讓model讀懂用的) 輸入的資料必須是((文章的有順序斷詞list)的list)

# %%
model_dm.build_vocab(Train_All)
model_dbow.build_vocab(Train_All)

# %% [markdown]
# # 10. 訓練十次，每次隨機交換文章順序 (由於是隨機, 要每次結果完全相同也可以固定訓練次序)¶

# %%
for epoch in range(10):
    
    #總共幾篇文章(假設225) 對1~225做隨機排序的array 做10次
    perm = np.random.permutation(len(Train_All))
    
    #將所有的文章隨機順序丟進去訓練 並告知model 共有225個example  5種時?
    model_dm.train([Train_All[x] for x in perm],total_examples=model_dm.corpus_count,epochs=model_dm.iter)
    model_dbow.train([Train_All[x] for x in perm],total_examples=model_dbow.corpus_count,epochs=model_dbow.iter)

# %%
perm
# Out:
# array([205, 183, 149,  10, 115, 132, 118,  93, 138, 188, 186, 135,  35,
#         59, 151, 171,  69, 190,  34, 219,  45, 116,  31, 217,  48, 192,
#        187,  19, 193,  79, 173,  38,   9, 207, 175, 111, 199, 136,   4,
#        122, 203,  21, 224, 164,  41,  27,  85, 215, 208, 104, 172, 165,
#        159, 144,   1, 216,  97, 198,  87, 109, 161,  76, 110, 147,  26,
#        143, 218, 157, 141, 177, 202,  67, 102,  84, 222, 145,  77,  17,
#         89,  49, 120,  90, 221,   5,   8,  18,  28,  22, 185, 191, 209,
#        114, 140,  70,  30, 121, 180,  52,  40, 201, 179,  72,  61,  25,
#         53,  55, 112,   6,  86,  15,  47, 200, 170, 134, 142,  81,  44,
#        214, 155,  24,  71,  58, 146,  13, 169,  94,  98, 126,  11,  96,
#        107,  36, 212, 153, 148, 113, 137,  64,  33, 197, 162,  92,  91,
#        178, 167,  63,   7, 213,  37, 150, 124, 195, 181,  56, 174,  74,
#          2,  32, 189, 204,  12,  66,  54,  39, 108, 156, 182,  62,  78,
#        103,   0, 210, 184, 133, 139,  50, 154, 100,  88,  75, 168,  95,
#        152, 117, 125,  83, 220, 128, 158,  80,  68, 131, 129, 194, 119,
#        176, 223, 211,  57, 106,  46,  51,   3, 101, 105,  60, 127, 196,
#         99,  14,  42,  23, 130, 160, 166,  16,  73,  65,  43, 163, 123,
#         29,  20, 206,  82])

# %% [markdown]
# # 10-1. 可以把模型存起來，下次直接取回向量

# %%
model_dm.save('D:/Data/doc2verData/model_dm')
model_dbow.save('D:/Data/doc2verData/model_dbow')
# model_dm=gensim.models.Doc2Vec.load('D:/Data/doc2verData/model_dm')
# model_dbow=gensim.models.Doc2Vec.load('D:/Data/doc2verData/model_dbow')

# %% [markdown]
# # 11. 取出文章向量

# %%
def getVecs(model, corpus, size):
    vecs = [model.docvecs[z.tags[0]].reshape((1, size)) for z in corpus]
    return np.concatenate(vecs)

# %% [markdown]
# # 12. 取出兩個模型 dm, dbow

# %%
Train_Eat_vecs_dm = getVecs(model_dm, Train_Eat, size)
Train_Eat_vecs_dbow = getVecs(model_dbow, Train_Eat, size)
Eat_train_vecs = np.hstack((Train_Eat_vecs_dm, Train_Eat_vecs_dbow))

# %%
Train_Ser_vecs_dm = getVecs(model_dm, Train_Ser, size)
Train_Ser_vecs_dbow = getVecs(model_dbow, Train_Ser, size)
Ser_train_vecs = np.hstack((Train_Ser_vecs_dm, Train_Ser_vecs_dbow))

# %%
Train_Env_vecs_dm = getVecs(model_dm, Train_Env, size)
Train_Env_vecs_dbow = getVecs(model_dbow, Train_Env, size)
Env_train_vecs = np.hstack((Train_Env_vecs_dm, Train_Env_vecs_dbow))

# %% [markdown]
# # 13. 載入scikit learn 套件 kmeans; 並將Doc2Vec的向量做分群  將所有新聞嘗試分50群，並找出比較小的群體做觀察

# %%
from sklearn.cluster import KMeans
#固定random state 隨機初始值 fixed the seed
All_vecs = np.vstack((Eat_train_vecs, Ser_train_vecs, Env_train_vecs))
All_kmeans = KMeans(n_clusters=50, random_state=0).fit(All_vecs)
Eat_kmeans = KMeans(n_clusters=5, random_state=0).fit(Eat_train_vecs)
Ser_kmeans = KMeans(n_clusters=5, random_state=0).fit(Ser_train_vecs)
Env_kmeans = KMeans(n_clusters=5, random_state=0).fit(Env_train_vecs)

# %%
#清一下記憶體
import gc
gc.collect()
# Out:
# 225

# %% [markdown]
# # 14. 將分群結果塞回各問題的DataFrame

# %%
#將所有新聞合併成一個DataFraem 請注意順序
All_News_df = Eat_df.copy()
All_News_df = All_News_df.append(Serve_df).append(Enviroment_df)

# %%
#全部斷詞後的List 請注意順序!
All_List = Eat_List + Ser_List + Env_List

# %%
#經分類結果分類放到原本的Dataframe
All_News_df['Cluster'] = All_kmeans.labels_
Eat_df['Cluster'] = Eat_kmeans.labels_
Serve_df['Cluster'] = Ser_kmeans.labels_
Enviroment_df['Cluster'] = Env_kmeans.labels_

# %%
#輸出分類結果
All_News_df.to_excel('D:/Data/doc2verData/All_Food_50gp.xlsx')
Eat_df.to_excel('D:/Data/doc2verData/Good_Eat.xlsx')
Serve_df.to_excel('D:/Data/doc2verData/Good_Serve.xlsx')
Enviroment_df.to_excel('D:/Data/doc2verData/Good_Enviroment.xlsx')

# %%
gc.collect()
# Out:
# 200

# %% [markdown]
# # 15. 輸出文字雲　將每個分群的文章接起來，格式是斷詞後並以空格連結的字串，用文字雲單純觀看高頻文字，嘗試解釋分群，可以到輸出的Excel，把同一群的文章內容看一下
# ps. 這邊是顯示第五群的文字雲，主要是當時火熱的同婚議題，但是也有一些不相干的文章被納入這個群體。

# %%
WC_Str=''
for i, x in enumerate(Env_kmeans.labels_):
    if x == 4:
        WC_Str += ' '.join(All_List[i])

ww = WordCloud(max_font_size=100, relative_scaling=1,max_words=40,width=800, height=600,background_color='white',random_state=0,\
               stopwords=['記者','指出','報導','表示','台灣','今天','可以','一起','除了','自己'])\
               .generate(WC_Str)
ww.font_path = 'C:\Windows\Fonts\msjhbd' #微軟正黑體的路徑；字體可以自己設定，預設是英文的遇到中文會讀不出來
ww.to_image()
#ww.to_file('./pic/50gp_5.jpg') 可輸出圖檔
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x23D757F0>
