# %%
from selenium import webdriver

driver = webdriver.PhantomJS(executable_path=r'D:\phantomjs\phantomjs-2.1.1-windows\bin\phantomjs.exe')  # PhantomJs
driver.get('http://pala.tw/js-example/')  # 輸入範例網址，交給瀏覽器 
pageSource = driver.page_source  # 取得網頁原始碼
print(pageSource)
# Out:
# <!DOCTYPE html><!--[if lt IE 8]><html class="no-js ie7" lang="zh-tw"><![endif]--><!--[if IE 8]><html class="no-js ie8" lang="zh-tw"><![endif]--><!--[if IE 9]><html class="no-js ie9" lang="zh-tw"><![endif]--><!--[if IE 10]><html class="no-js ie10" lang="zh-tw"><![endif]--><!--[if gt IE 10]><!--><html class="js webkit webkit538 rgba calc columns multibackground backgroundsize touch placeholder no-highpixeldensity no-smartscroll compact" lang="zh-tw"><!--<![endif]--><head><script type="text/javascript" src="https://cm.g.doubleclick.net/pixel?google_nid=amnettw_dmp&amp;google_cm&amp;cygcookie=CAESEEFKxIQGuasSsoYGuLoYZlw"></script><script type="text/javascript" id="vm5ad-js-sdk" data-mode="cymmetrics" src="https://pt.cymmetrics.com.tw/ckmp/vm5_ckmp.php?gcookie_id=CAESEEFKxIQGuasSsoYGuLoYZlw&amp;vm5_ck=b2ec116a-83bb-11e7-8d10-0a580a000174ef209fa0-4724-4e02-af41-a1a3ff296d0f"></script><script src="https://pt.cymmetrics.com.tw/aclient/ctl_iPeen.php?cymsrc=1&amp;gcookie_id=CAESEEFKxIQGuasSsoY
# ...

# %%
soup=bs(pageSource,'lxml')

# %%
soup.select('#word')[0].text
# Out:
# 'JavaScript渲染才看得到這行'
