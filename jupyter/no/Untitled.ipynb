# %%
import time
import requests
import pprint
import json
count = 0
d = 1
tbikelist = []
while True:
    res = requests.get("http://tbike.tainan.gov.tw:8081/Service/StationStatus/Json")
    count += 1
    tbikelist.append(res.json())
    if count % 1440 == 0:
        d = d + 1
        tbikelist = []
    if count % 5 == 0:
        print(str(time.ctime()))
        with open("D:/Data/JsonData/Tbike/" + str(time.ctime().replace(" ", "_").replace(":", "-"))[:10] + "-" + str(
                d) + ".json", "w") as f:
            json.dump(tbikelist, f)
    time.sleep(60)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-1-0781b20f3da8> in <module>()
#       9     res = requests.get("http://tbike.tainan.gov.tw:8081/Service/StationStatus/Json")
#      10     count += 1
# ---> 11     tbikelist.append(res.json())
#      12     if count % 1440 == 0:
#      13         d = d + 1
#
# D:\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# D:\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# D:\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# D:\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import json
with open('D:/Data/JsonData/TainanFood/bigtable_1.0.json') as f:
    data=json.load(f)

# %%
data[1]
# Out:
# {'Ncomment': 20,
#  'TF_IDF': {'一下': 0.001754501360184754,
#   '一些': 0.0006625475617136504,
#   '一份': 0.0007419207797875924,
#   '一個': 0.0009011414526338026,
#   '一口': 0.0007756626542362902,
#   '一塊': 0.0016496494731986523,
#   '一定': 0.0008443769623054691,
#   '一層': 0.015352262498748439,
#   '一杯': 0.001353826701220603,
#   '一片': 0.0022637444136620805,
#   '一直': 0.0007011741054788505,
#   '一種': 0.0014483774876304326,
#   '一起': 0.0009444982977212441,
#   '一點': 0.0011415350190847838,
#   '上面': 0.002314750148874417,
#   '下': 0.0003777377902097156,
#   '下午': 0.0009425675388220927,
#   '下午茶': 0.0028464248333637645,
#   '下去': 0.0011392210691898194,
#   '不到': 0.0006020124265266177,
#   '不膩': 0.0011451610859728118,
#   '中': 0.000562689048181557,
#   '中西區': 0.0006462439017702225,
#   '中間': 0.001313807085719198,
#   '之前': 0.0005377198023828408,
#   '之旅': 0.0019174165007028313,
#   '享受': 0.0011135675528753195,
#   '人': 0.0005973312819124789,
#   '今天': 0.0007198594499395265,
#   '介紹': 0.0007171346059520806,
#   '以上': 0.001373086522030121,
#   '以為': 0.0008694200824537764,
#   '任選': 0.0024520771993347904,
#   '伯爵': 0.004004390454626511,
#   '來到': 0.0006259120953525316,
#   '依序': 0.0019197799046853246,
#   '做': 0.0012200454739781277,
#   '做好': 0.0019996826110857692,
#   '價': 0.00023628329728190187,
#   '價位': 0.0011743167432928749,
#   '價格': 0.0005116607017859035,
#   '價錢': 0.0011890268625368355,
#   '優惠': 0.0011578738306319656,
#   '元': 0.002202579649616044,
#   '先': 0.0007498750945510632,
#   '克林姆': 0.005946190235287108,
#   '入口即化': 0.0018917823521926002,
#   '內用': 0.0016587257789928247,
#   '全台': 0.0017546104715205526,
#   '公園': 0.0014496791420121526,
#   '再': 0.000525540590141907,
#   '冬季': 0.0016407892288953937,
#   '冰櫃': 0.002065651547404624,
#   '分享': 0.001180427004615761,
#   '切片': 0.004163148490578865,
#   '加入': 0.0005690658745029373,
#   '包裝': 0.0015146027338281303,
#   '千層': 0.08331614806482851,
#   '卡龍': 0.0024396682060785274,
#   '卻': 0.0010290192648166117,
#   '原味': 0.0064564712800896035,
#   '原本': 0.0010565701443626505,
#   '厲害': 0.0020417589156560088,
#   '叉子': 0.002218704898338947,
#   '口味': 0.004766013276388438,
#   '口感': 0.002720430140089734,
#   '只': 0.0004548513106642053,
#   '只好': 0.0009375004617506682,
#   '只為': 0.0029528414754596234,
#   '可惜': 0.0006758929062792816,
#   '可愛': 0.000819215632933515,
#   '可麗餅': 0.0025303876260771483,
#   '台南': 0.0019572598767993565,
#   '台南市': 0.0010374322657902527,
#   '吃': 0.003973700441216766,
#   '吃過': 0.0007341903099205914,
#   '同事': 0.0022474799197892445,
#   '味': 0.0001676965225408979,
#   '味道': 0.0009296152978892242,
#   '咖啡': 0.002578627526394122,
#   '咖啡館': 0.0016318838120536123,
#   '品嚐': 0.0012374539763749994,
#   '唷': 0.0010557506364876268,
#   '喔': 0.002329411484507291,
#   '喜歡': 0.0006171718874483995,
#   '喝': 0.000784865969445452,
#   '單片': 0.00439913896895744,
#   '單點': 0.0010684443656210705,
#   '囉': 0.0013637552825264587,
#   '地圖': 0.0007370406500720258,
#   '地址': 0.0009846757852223725,
#   '地疊': 0.005114553224016839,
#   '外': 0.0002050048310316329,
#   '外帶': 0.0029099638494798985,
#   '多層': 0.003325010511348337,
#   '大億': 0.004591638961602792,
#   '太': 0.00039927842910175547,
#   '失望': 0.001396576425306119,
#   '套餐': 0.0016432119567638286,
#   '奶油': 0.004573564197887603,
#   '好': 0.0016437701987628362,
#   '好像': 0.0005058972876924691,
#   '好吃': 0.0011746082314482349,
#   '完': 0.00025222548746608114,
#   '完美': 0.0013036649995732442,
#   '官網': 0.0018998910940736342,
#   '客人': 0.0010541226343071966,
#   '家': 0.00019440313009744183,
#   '對面': 0.0010197782132450699,
#   '小': 0.0005689141486493769,
#   '就要': 0.001580246436333156,
#   '層': 0.001895239446548432,
#   '層層': 0.0035672791810626493,
#   '巧克力': 0.008813763331217347,
#   '已經': 0.0009229271154738624,
#   '幫': 0.0010384174028102947,
#   '平整': 0.0035466332826219944,
#   '幸福': 0.0009560206284549688,
#   '幾層': 0.00439913896895744,
#   '店': 0.00026508013571457446,
#   '店內': 0.0016139792919943824,
#   '店家': 0.0006507307085224569,
#   '店面': 0.0006552739220781376,
#   '府連': 0.01329987480983248,
#   '延伸': 0.00106259225010437,
#   '很棒': 0.0008031001733361546,
#   '很貴': 0.0016210334537712482,
#   '後': 0.0006119509958492503,
#   '心': 0.00030119545135472056,
#   '想': 0.0011693360643831303,
#   '想要': 0.0009496376740393357,
#   '意思': 0.0009305307940440914,
#   '愛吃': 0.0008140528187511318,
#   '感': 0.00029412871753376656,
#   '感覺': 0.0011593855230896525,
#   '應該': 0.0012881179020007808,
#   '手': 0.00032186343901173444,
#   '手工': 0.0013606610729879958,
#   '抹茶': 0.008995738551415928,
#   '拍': 0.0007818529340198289,
#   '挑': 0.0010150976555029383,
#   '挺': 0.000534162681940108,
#   '提供': 0.001500606142999896,
#   '搭配': 0.0005772537503514856,
#   '摩卡': 0.004613123253864624,
#   '整個': 0.0011329847056939016,
#   '文章': 0.0006183152279078598,
#   '新鮮': 0.0005941596831516773,
#   '斷面': 0.002609593580360417,
#   '日常生活': 0.005201888921819412,
#   '早上': 0.0009835073767704115,
#   '早茶': 0.0030481230559872186,
#   '早餐': 0.003592374583725842,
#   '明亮': 0.0012136098990446554,
#   '是不是': 0.0009837504942915324,
#   '時': 0.00037719268971548377,
#   '時尚': 0.001232472719511342,
#   '時段': 0.0021111738012229726,
#   '時間': 0.000668473458334089,
#   '普普': 0.0012946110695021234,
#   '最': 0.0011477699718230251,
#   '最後': 0.0010423518676909499,
#   '最貴': 0.0028472231405604538,
#   '有人': 0.0018038495366739418,
#   '有沒有': 0.0008495214047935083,
#   '有點': 0.0012651967671772329,
#   '朋友': 0.0009247090586162112,
#   '本來': 0.0012277583394996988,
#   '東區': 0.0031296404887253574,
#   '東路': 0.00865209462580414,
#   '柔順': 0.0032224536445169846,
#   '栗子': 0.021142910842414472,
#   '機會': 0.0009191072197187961,
#   '檢視': 0.0009152084100739023,
#   '每個': 0.0007170154713412266,
#   '比較': 0.0014951987273301097,
#   '決定': 0.001016516702623018,
#   '法式': 0.0027872856115222972,
#   '泥': 0.0019731564645283505,
#   '派': 0.008318064299391508,
#   '淡淡的': 0.0010797125347308523,
#   '深藍': 0.028437549346054712,
#   '清爽': 0.0007756688459177296,
#   '滋味': 0.0013329125167068254,
#   '濃郁': 0.001492353934975461,
#   '無': 0.00032023736698338066,
#   '無法': 0.0010875378957082074,
#   '焦糖': 0.008441217893919247,
#   '熬': 0.0008026578403055406,
#   '營業時間': 0.0009237945676564508,
#   '特別': 0.0006067564517706318,
#   '現在': 0.0008239004703026068,
#   '現場': 0.0007823136589095039,
#   '甘納許': 0.003168442643813114,
#   '甜度': 0.0030621035516692385,
#   '甜點': 0.0014676310255693412,
#   '男友': 0.002218704898338947,
#   '男子': 0.007076131250992637,
#   '界': 0.0038427099800398315,
#   '皮': 0.0005145025568584033,
#   '盤子': 0.001113513462822089,
#   '目前': 0.0007448191628672102,
#   '直接': 0.0007749240980075088,
#   '相當': 0.0009584854891508529,
#   '看到': 0.001309075105782422,
#   '看看': 0.0006452875364430393,
#   '真': 0.0001977758450351842,
#   '真的': 0.001669691420978477,
#   '知道': 0.0008797335256932012,
#   '秀': 0.0014604147203948412,
#   '簡單': 0.000824288979525042,
#   '糖': 0.0006716715605130983,
#   '約': 0.0007426996039395966,
#   '紅豆': 0.0030056300064748467,
#   '級': 0.0006480303621864732,
#   '細緻': 0.002138472103106303,
#   '終於': 0.0017415768061022953,
#   '組合': 0.0010851199168549048,
#   '網友': 0.0011430720244033448,
#   '緻': 0.001971629433468769,
#   '美味': 0.0009926212137850025,
#   '美食': 0.00040253352886844226,
#   '老媽': 0.0015860437675855672,
#   '老爸': 0.0016509796509699263,
#   '耶': 0.0010652924198299252,
#   '聽說': 0.0015022674764547787,
#   '舖': 0.0016110161256412256,
#   '芒果': 0.0026588307118379974,
#   '芙烈': 0.008494947516238718,
#   '芝麻': 0.004807160637114631,
#   '花': 0.00032414920545439165,
#   '茶': 0.000881089843853116,
#   '草莓': 0.004307958046771384,
#   '蔬菜': 0.0011925623430101124,
#   '薄餅': 0.004020471407892335,
#   '號': 0.0008822722384799172,
#   '號稱': 0.0035535759636721124,
#   '蚌': 0.010454277853303695,
#   '蛋': 0.0006180968040406456,
#   '蛋皮': 0.007715458770028534,
#   '蛋糕': 0.046396724783829356,
#   '裝潢': 0.001049850584853161,
#   '裡的': 0.0015576402714828018,
#   '裡面': 0.0009628591528695281,
#   '要來': 0.0006977900081621364,
#   '要價': 0.0020854061099441386,
#   '覺得': 0.0013008924479106093,
#   '記得': 0.0008108962168087166,
#   '設計': 0.001050473755284427,
#   '試試': 0.0008477524477086616,
#   '誘人': 0.0015693553084950322,
#   '說': 0.0015609717413075158,
#   '請': 0.0005379966027375666,
#   '貴': 0.0007786565075130574,
#   '買': 0.000986043056407908,
#   '賣': 0.0007853595385640119,
#   '超': 0.0011558826490376882,
#   '軟綿': 0.001290940306080834,
#   '較大': 0.0008870056052966088,
#   '這家': 0.0014180836524217224,
#   '這是': 0.0014776949612577475,
#   '這杯': 0.0019985169162957386,
#   '這次': 0.0009661083813754133,
#   '週一': 0.0010863277678727602,
#   '週日': 0.0008648706362910521,
#   '進門': 0.0014454346794325423,
#   '達': 0.0016240356854590346,
#   '適合': 0.0005192087014051473,
#   '選': 0.0005571734725964307,
#   '選擇': 0.0006609998273339215,
#   '還蠻': 0.0018105620011981643,
#   '那天': 0.001839395523331192,
#   '那種': 0.0017207636494255823,
#   '部分': 0.0008188170159529263,
#   '酥脆': 0.0008939823522749862,
#   '醬': 0.0011053287899693222,
#   '重點': 0.0009116961980035208,
#   '鐵': 0.0008926397809387893,
#   '閱讀': 0.0012407120636084969,
#   '附上': 0.0007527254073461857,
#   '電話': 0.0008406816392429206,
#   '風格': 0.0007393610375507884,
#   '飲品': 0.0007611691050518639,
#   '飲料': 0.0018237248062633366,
#   '餅乾': 0.0020295060615182128,
#   '餅皮': 0.003091737631657422,
#   '香': 0.00038752907504507926,
#   '香氣': 0.0026509666563333217,
#   '香甜': 0.0012128732694439103,
#   '馬': 0.0009539051925648147,
#   '體': 0.0004894479733150304,
#   '高': 0.0005165976038600657,
#   '鮮奶': 0.001496995182599457,
#   '鮮奶油': 0.005834543106811582,
#   '鮮果': 0.003654487332092566,
#   '麗': 0.0015513376918354592,
#   '黑森林': 0.0032414242832880667,
#   '點': 0.0001306749291481888,
#   '點的': 0.0011901064396907183},
#  'contentcut': '原文 台南 東區 深藍咖啡館 號稱 蛋糕 界 千層 蛋糕 大人 口味 黑森林 蛋糕 早茶 在當 貴婦 普普 時尚 風格 超像 藝文 咖啡館 女子 休假 計劃 新加坡 吃 好吃 喜歡 香嫩 蛋皮裡 裏 慕斯 香甜 滋味 聽說 台南 厲害 號稱 蛋糕 界 千層 蛋糕 選 早茶 時段 前來 進門 冷氣 還蠻強 冰櫃 透明 窗上 結上 一層 水氣 店內 呈現 普普 風格 給人 現代 時尚 感 一致性 水藍及 白色 系列 設計 主軸 設計 感 空間 寬敞 自覺 有點 來到 藝文 咖啡館 外帶 盒 普普 圓點 風格 年 獲得 紅點 大賞 送禮 自已 提 回家 吃 氣派 早茶 時段 蛋糕 栗子 千層 蛋糕 再 加碼 挑 最愛 吃 黑森林 蛋糕 早茶 蛋糕 提供 一份 任選 蛋糕 一壺 茶 黑森林 蛋糕 荔汁 白茶 選用 美國 有機 茶 含 咖啡因 茶 包泡 茶味 不香 荔汁味 水味 多於 茶味 有點 失望 黑森林 蛋糕 表層 酒漬 過後 黑 櫻桃 配上 微苦 巧克力 片 底層 慕絲 層層 堆疊 濕潤 蛋糕 體 奶油 空氣 感 柔順 湯匙 挖至 底層 絕妙 大人 成熟 滋味 非常好吃 栗子 千層 蛋糕 網友 號稱 蛋糕 界 千層 蛋糕 高度 薄度 忍不住 數了 一下 聽說 店家 已經 厲害 製成 多層 唷 細緻 柔順 法國 精選 栗子 熬 煮成 醬 舖 表層 另將 奶油 香甜 栗子 一層 一層 費工 舖 一片 蛋皮 放在 冰櫃 太久 蛋皮略 硬 有點 可惜 結論 挑 早午 茶 時段 前來 吃 千層 蛋糕 新鮮 現做 服務態度 挺 好 認真 介紹 深藍咖啡館 網址 地址 台南市 府連 東路 號 電話 營業時間 週一 週日 咖啡 茶 飲品 蛋糕 免 服務費 無 限時 插座 低銷 一份 餐點 檢視 較大 地圖 早上 八點 營業 深藍咖啡館 網友 說 全台 最 好吃 千層 蛋糕 知名 美食 節目 報導 每日 定時 供應 種 口味 千層 若想 吃 愛的 口味 碰碰運氣 文字 男子 攝影 男子 深藍咖啡館 男子 日常生活 男子 日常生活 台南 時間 決定 中午 前 先 過來 原本 以為 一大 早來 不用擔心 吃 不到 想 吃 口味 原來 深藍咖啡館 每個 時段 只 提供 部分 口味 固定 時間 提供 一種 口味 想要 吃 想 吃 口味 真的 看運氣 焦糖 原味 最 想 品嚐 失望 焦糖 千層 中有 層 深藍咖啡館 千層 蛋糕 原本 以為 甜膩 焦糖 口感 淡淡 焦糖 香氣 甜度 不膩口 原味 千層 層 滿滿的 鮮奶油 香氣 原味 旁 附上 水蜜桃 醬 原味 口感 多了點 果香 不會太甜 軟綿 口感 整體 清新 好吃 任選 口味 千層 蛋糕 一份 飲品 一杯 任選 組成 套餐 價 優惠 組合 店家 當時 現場 為主 深藍咖啡館 地址 台南市 東區 府連 東路 號 電話 營業時間 週一 週日 官網 深藍咖啡館 深藍咖啡館 收取 服務費 深藍咖啡館 官網 深藍咖啡館 深藍咖啡館 檢視 較大 地圖 男子 日常生活 閱讀 手記 以上 評論 男子 意見 提供 參考 圖文 版權所有 如欲 分享 請 載明 出處 告知 文章 食記 時效性 如欲 造訪 可先 店家 官網 查詢 若為 商業 邀約 試吃 文 均會 載明 請安 心 服用 歡迎 加入 男子 日常生活 男子 日常生活 男子 日常生活 一併 推廣 粉絲 專頁 台南 延伸 閱讀 綠皮 開心果 台南 中西區 走進 小巷 白屋 只為 日光 下 微笑 開心果 冰淇淋 台南 孔廟 台南 東區 日式 洋 菓 子 專賣店 只 記憶 裡的 復古 再現 小聚 台南 中西區 舊式 樓房 裡的 道 家常 地中海 料理 第一個 小聚 片刻 異國 料理 墨西哥 菜 老厝一九三三 台南市 中西區 三合 庭院 老房子 燒烤 啤酒 時光 燈籠 高掛 午夜 一時 最近 寫 愛評 千層 蛋糕 故事集 不停 吃 甜點 中 謎 之音 明明 愛吃 假日 午後 原本 吃 深藍 可惜 千層 蛋糕 界 名不虛傳 周日 下午 三點 門市 滿滿 人 話 說 沒吃過 深藍 奇怪 聽說 很貴 一直 吃 寫 千層 蛋糕 時 總 有人 問那 深藍 一定 要來 試試 囉 現場 只 剩 切片 抹茶 口味 切片 原味 整顆 可憐 最 討厭 抹茶 口味 只好 揮手 說 幸好 今日 出差 幫 買 囉 超 謝謝 親愛 先來 張 深藍 千層 蛋糕 斷面 秀 這是 芝麻 口味 先 一下 店面 深藍咖啡館 地址 台南市 東區 府連 東路 號 電話 打電話 問 蛋糕 剩餘 量 現場 為主 保證 下個 客人 買 店內 誘人 蛋糕 貴桑 桑 價位 表 聽說 之前 內用 低消 一杯 飲料 外帶 確定 周一 外帶 時 聽到 內用 客人 單點 蛋糕 想 單點 先 確認 一下 單片 抹茶 千層 周日 僅剩 非 千層 蛋糕 選項 便宜 一點 破百 喔 店裡 賣 手工 餅乾 價位 咖啡館 一罐 左右 終於 種類 千層 蛋糕 切片 選了 這是 今天 週一 買 時 拍 所有 口味 喔 心動 先 一下 價錢 再點 食 千層 元起 挑 說 原本 想點 甘納許 巧克力 千層 看到 要價 元怕 罵 默默 改點 摩卡 默 很貴 有點 想 吃 也許 一邊 偷 罵 一邊 吃 店內 簡單 裝潢 明亮 咖啡廳 特別 重點 千層 蛋糕 外帶 包裝 簡單 大方 一下 兩塊 千層 放在 一起 作 比例尺 是不是 不太大 實際 要來 開箱 好 期待 喔 免俗 台南 三間 比較 一下 依序 億 麗 緻 巧克力 千層 蛋糕 體 最大 芙烈 達 栗子 千層 切片 最美 克林姆 之家 巧克力 千層 奶油 最 價位 部分 深藍 芝麻 千層 元 大億 麗 緻 巧克力 千層 元 克林姆 巧克力 千層 元 芙烈 達 摩卡 千層 元 外帶 價 千層 蛋糕 最 重要 斷面 秀 主角 深藍 斷面 秀 芝麻 摩卡 家得 斷面 秀 依序 同上 喔 依序 億 麗 緻 巧克力 千層 芙烈 達 栗子 千層 克林姆 之家 巧克力 千層 終於 吃 台南 深藍 深藍 口感 他家 相比 算是 蛋皮 那層 比較 入口即化 價位 相較 之下 比較 高 芝麻 千層 失望 真 濃濃 芝麻 味 愛吃 芝麻糊 人 一定 超級愛 摩卡 千層 屬於 濃郁 口感 千層 蛋糕 很棒 深藍 奶油 接受 今天 吃玩 一個 切片 謎 之音 今天 晚餐 重點 很貴 只會 吃 一次 吃 完 再 卡路里 已經 作個 小 比較 蛋糕 體 大小 大億 麗 緻 芙烈 達 深藍 克林姆 家 大億 麗 緻 內用 外 外帶 家裡 盤子 相比 感覺 好像 大小 蛋皮 入口即化 程度 深藍 芙烈 達 大億 麗 緻 克林姆 家 蛋皮 比較 在意 部分 奶油 接受程度 深藍 大億 麗 緻 芙烈 達 克林姆 家 奶油 想法 比較 偏甜 奶油 比較 不敢 吃 價格 深藍 芝麻 千層 元 大億 麗 緻 巧克力 千層 元 克林姆 巧克力 千層 元 芙烈 達 摩卡 千層 元 外帶 價 以上 純屬 口感 吃 甜點 變 胖胖 之旅 無法 結束 深藍咖啡館 千層 蛋糕 曾 票選 全台 最 好吃 千層 蛋糕 小 蚌 蚌 已經 慕名 已 久 一片 價錢 點點 下 手 一片 口 小 蚌 蚌 嘴巴 比較 就要 元 價位 花 下去 這次 趁剛 拿到 年終獎金 之際 決定 給他 開 下去 週末 老爸 老媽 一場 深藍咖啡館 小 奢華 早餐 深藍咖啡館 無法 訂位 小 蚌 蚌 客滿 趕在 點 開門 報到 店內 座位 擺放 寬敞 擁擠 一家 適合 位 好友 聊天 聚餐 好去處 店門口 蛋糕 櫃 陳列 目前 切片 內用 外帶 蛋糕 口味 早餐 提供 蛋糕 飲料 元 喔 值比 單片 蛋糕 元 高出 太 這是 早起 鳥兒 有蟲 吃 意思 一早 提供 蛋糕 口味 齊全 小 蚌 蚌 當天 提供 蛋糕 口味 原味 焦糖 芝麻 栗子 鮮果 千層 蛋糕 冬季 提供 鮮果 千層 草莓 口味 必點 上場 老爸 點的 栗子 千層 蛋糕 有沒有 看到 層層 分明 糕 皮 一層 一口 保有 蛋糕 濕潤 度外 還吃得 濃濃的 栗子 香 重點 不會過甜 知道 栗子 口味 做成 甜點 非常容易 過甜及 膩口 深藍咖啡館 栗子 千層 完全 問題 甜度 栗子 鮮奶油 濃度 把持 厲害 這是 老爸 搭配 飲料 伯爵 鮮奶 茶 深藍 伯爵 鮮奶 茶 帶點 佛手柑 香氣 搭配 鮮 奶奶 香 順口 喔 甜度 部分 店家 附 糖包 由客 倌 自行 酌量 加入 這是 小 蚌 蚌 老媽 點的 芝麻 千層 蛋糕 糕 皮 芝麻 鮮奶油 層層 地疊 每口 充滿 芝麻 香 做 千層 蛋糕 光看 密密麻麻 層次 知道 耗 功夫 千層 蛋糕 真的 貴在 手工 老媽 點的 巧克力 牛奶 甜度 上面 還放 一些 鮮奶油 不錯 喝 喔 最後 重頭戲 草莓 千層 蛋糕 這款 冬天 喔 一點 吃 害怕 早餐 時段 無 提供 草莓 口味 好險 幸運 終於 吃 草莓 口味 原味 千層 蛋糕 草莓 切片 這款 鮮奶油 比例 口味 來得 還不錯 吃 愛吃 鮮奶油 愛吃 草莓 點 這款 喔 小 蚌 蚌 三款 嚐試 後 栗子 芝麻 草莓 口味 小蚌蚌點 飲料 摩卡 咖啡 同樣 上面 一些 鮮奶油 深藍 摩卡 咖啡 真的 不錯 喝 巧克力 濃度 甜度 真的 推 喔 以上 這次 小 蚌 蚌 深藍咖啡館 初體驗 幾天 嘗試 一間 千層 蛋糕 好吃 分享 下 篇文章 囉 掰掰 餐廳 資訊 餐廳 名稱 深藍咖啡館 電話 地址 台南市 府連 東路 號 營業時間 週一 週日 詳細 文章 本來 行程 拿掉 現在 出去玩 習慣 行程 排 好好 不在 亂亂 ...
#  'featurescores': {'份量大': 0.07,
#   '偏甜': 0.58,
#   '其他正面情緒': 0.83,
#   '划算': -0.63,
#   '小份量': 0.1,
#   '服務好': -0.09,
#   '環境好': 0.38,
#   '食物很香': 0.61,
#   '食物精緻漂亮': 0.49,
#   '食物美味': 0.56},
#  'name': '深藍咖啡館',
#  'pinCountMaxper5': {'': 100,
#   '不太喜歡': 1,
#   '不好吃': 1,
#   '不愛': 1,
#   '不愛吃': 1,
#   '不斐': 1,
#   '不會過甜': 1,
#   '不油膩': 1,
#   '不用擔心': 1,
#   '不膩口': 1,
#   '也不錯': 1,
#   '亂': 4,
#   '令人驚豔': 1,
#   '偏甜': 2,
#   '價位真是一點都不可愛': 1,
#   '優雅': 3,
#   '入口即化': 5,
#   '划算': 2,
#   '剛好': 8,
#   '可愛': 5,
#   '多層次': 3,
#   '天然食材': 2,
#   '太多了': 1,
#   '太甜': 4,
#   '好吃': 22,
#   '好喝': 2,
#   '好食': 1,
#   '小吃': 1,
#   '屹立不搖': 1,
#   '很划算': 1,
#   '很好吃': 3,
#   '很有值感': 1,
#   '很有質感': 1,
#   '很甜': 1,
#   '很精緻': 1,
#   '很美味': 1,
#   '很貴': 3,
#   '很香': 1,
#   '擺盤': 1,
#   '整齊': 2,
#   '明亮': 4,
#   '最好姿態': 2,
#   '會膩': 2,
#   '有別於一般': 1,
#   '有層次': 2,
#   '有彈性': 1,
#   '有蟲': 2,
#   '有貴': 1,
#   '正咩': 1,
#   '沒有限時間': 1,
#   '油膩': 1,
#   '浪漫': 1,
#   '清爽': 4,
#   '漂亮': 4,
#   '無法忘懷': 1,
#   '特別': 5,
#   '甘願排隊': 1,
#   '甜而不膩': 2,
#   '算貴': 1,
#   '精緻': 3,
#   '精美': 2,
#   '綿密口感': 1,
#   '綿綿的': 1,
#   '美味': 8,
#   '美麗紋路': 2,
#   '耐吃': 1,
#   '膩口': 3,
#   '舒適': 2,
#   '薄可透光': 2,
#   '裝潢': 5,
#   '親切': 1,
#   '誘人': 5,
#   '讓人不發胖': 3,
#   '讚不絕口': 1,
#   '貴': 19,
#   '貴桑': 1,
#   '超大': 1,
#   '超好吃': 1,
#   '超愛': 2,
#   '超級愛': 1,
#   '退步': 1,
#   '這麼好吃': 1,
#   '過癮': 1,
#   '還不錯': 2,
#   '酥脆': 4,
#   '開心': 3,
#   '非常厲害': 1,
#   '非常好吃': 1,
#   '香氣': 17,
#   '香氣撲鼻': 1,
#   '馬上就': 2,
#   '高檔': 1},
#  'score': 7.569999999999998,
#  'style': '西點烘焙、麵包',
#  'tags': ['服務較差',
#   '偏甜',
#   '栗子',
#   '食物美味',
#   '非常貴',
#   '千層',
#   '食物很香',
#   '其他正面情緒',
#   '蛋糕',
#   '一層',
#   '深藍',
#   '西點烘焙、麵包'],
#  'wordCount': [['千層', 172],
#   ['蛋糕', 163],
#   ['吃', 101],
#   ['深藍咖啡館', 52],
#   ['一層', 51],
#   ['口味', 48],
#   ['好', 41],
#   ['深藍', 37],
#   ['台南', 35],
#   ['栗子', 32],
#   ['巧克力', 31],
#   ['口感', 29],
#   ['原味', 27],
#   ['派', 27],
#   ['抹茶', 26],
#   ['說', 25],
#   ['元', 24],
#   ['焦糖', 23],
#   ['喔', 22],
#   ['真的', 19],
#   ['想', 18],
#   ['奶油', 17],
#   ['東路', 17],
#   ['香氣', 17],
#   ['最', 16],
#   ['好吃', 15],
#   ['一下', 15],
#   ['府連', 15],
#   ['界', 14],
#   ['台南市', 14],
#   ['芝麻', 14],
#   ['比較', 14],
#   ['蚌', 14],
#   ['東區', 13],
#   ['號', 13],
#   ['咖啡', 13],
#   ['鮮奶油', 13],
#   ['人', 13],
#   ['早餐', 13],
#   ['覺得', 13],
#   ['外帶', 12],
#   ['蛋皮', 12],
#   ['層', 12],
#   ['超', 12],
#   ['看到', 12],
#   ['草莓', 12],
#   ['上面', 12],
#   ['有點', 11],
#   ['醬', 11],
#   ['甜度', 11],
#   ['飲料', 11],
#   ['小', 11],
#   ['感覺', 11],
#   ['店內', 10],
#   ['地址', 10],
#   ['囉', 10],
#   ['切片', 10],
#   ['這是', 10],
#   ['做', 10],
#   ['應該', 10],
#   ['下午茶', 10],
#   ['味道', 10],
#   ['提供', 9],
#   ['電話', 9],
#   ['男子', 9],
#   ['中', 9],
#   ['一點', 9],
#   ['後', 9],
#   ['紅豆', 9],
#   ['這家', 9],
#   ['茶', 8],
#   ['營業時間', 8],
#   ['時間', 8],
#   ['麗', 8],
#   ['緻', 8],
#   ['濃郁', 8],
#   ['一個', 8],
#   ['伯爵', 8],
#   ['喝', 8],
#   ['法式', 8],
#   ['還蠻', 8],
#   ['那種', 8],
#   ['朋友', 8],
#   ['喜歡', 7],
#   ['滋味', 7],
#   ['厲害', 7],
#   ['層層', 7],
#   ['店家', 7],
#   ['多層', 7],
#   ['一片', 7],
#   ['先', 7],
#   ['一種', 7],
#   ['套餐', 7],
#   ['分享', 7],
#   ['下', 7],
#   ['甜點', 7],
#   ['時', 7],
#   ['有人', 7],
#   ['買', 7],
#   ['客人', 7],
#   ['價位', 7],
#   ['賣', 7],
#   ['終於', 7],
#   ['摩卡', 7],
#   ['芙烈', 7],
#   ['達', 7],
#   ['克林姆', 7],
#   ['鮮果', 7],
#   ['知道', 7],
#   ['裡面', 7],
#   ['芒果', 7],
#   ['卻', 7],
#   ['餅皮', 7],
#   ['泥', 7],
#   ['美味', 7],
#   ['薄餅', 7],
#   ['整個', 7],
#   ['號稱', 6],
#   ['聽說', 6],
#   ['選', 6],
#   ['時段', 6],
#   ['再', 6],
#   ['任選', 6],
#   ['已經', 6],
#   ['唷', 6],
#   ['細緻', 6],
#   ['日常生活', 6],
#   ['一杯', 6],
#   ['官網', 6],
#   ['以上', 6],
#   ['一定', 6],
#   ['幫', 6],
#   ['手工', 6],
#   ['餅乾', 6],
#   ['拍', 6],
#   ['一起', 6],
#   ['大億', 6],
#   ['下去', 6],
#   ['這次', 6],
#   ['香', 6],
#   ['最後', 6],
#   ['那天', 6],
#   ['店', 6],
#   ['耶', 6],
#   ['同事', 6],
#   ['一塊', 6],
#   ['感', 5],
#   ['挑', 5],
#   ['柔順', 5],
#   ['介紹', 5],
#   ['原本', 5],
#   ['品嚐', 5],
#   ['閱讀', 5],
#   ['裡的', 5],
#   ['下午', 5],
#   ['誘人', 5],
#   ['內用', 5],
#   ['單片', 5],
#   ['今天', 5],
#   ['簡單', 5],
#   ['裝潢', 5],
#   ['特別', 5],
#   ['入口即化', 5],
#   ['高', 5],
#   ['就要', 5],
#   ['太', 5],
#   ['點的', 5],
#   ['一口', 5],
#   ['鮮奶', 5],
#   ['本來', 5],
#   ['現在', 5],
#   ['選擇', 5],
#   ['這杯', 5],
#   ['中間', 5],
#   ['享受', 5],
#   ['幾層', 5],
#   ['蛋', 5],
#   ['相當', 5],
#   ['約', 5],
#   ['馬', 5],
#   ['最貴', 5],
#   ['蔬菜', 5],
#   ['黑森林', 4],
#   ['早茶', 4],
#   ['咖啡館', 4],
#   ['香甜', 4],
#   ['進門', 4],
#   ['冰櫃', 4],
#   ['設計', 4],
#   ['一份', 4],
#   ['失望', 4],
#   ['體', 4],
#   ['舖', 4],
#   ['新鮮', 4],
#   ['週一', 4],
#   ['全台', 4],
#   ['決定', 4],
#   ['只', 4],
#   ['部分', 4],
#   ['想要', 4],
#   ['優惠', 4],
#   ['組合', 4],
#   ['請', 4],
#   ['心', 4],
#   ['延伸', 4],
#   ['只為', 4],
#   ['愛吃', 4],
#   ['一直', 4],
#   ['試試', 4],
#   ['斷面', 4],
#   ['秀', 4],
#   ['單點', 4],
#   ['價錢', 4],
#   ['要價', 4],
#   ['明亮', 4],
#   ['重點', 4],
#   ['包裝', 4],
#   ['是不是', 4],
#   ['味', 4],
#   ['家', 4],
#   ['之旅', 4],
#   ['無法', 4],
#   ['皮', 4],
#   ['搭配', 4],
#   ['地疊', 4],
#   ['一些', 4],
#   ['男友', 4],
#   ['級', 4],
#   ['記得', 4],
#   ['看看', 4],
#   ['完美', 4],
#   ['平整', 4],
#   ['貴', 4],
#   ['做好', 4],
#   ['幸福', 4],
#   ['不膩', 4],
#   ['機會', 4],
#   ['對面', 4],
#   ['公園', 4],
#   ['糖', 4],
#   ['可愛', 4],
#   ['叉子', 4],
#   ['清爽', 4],
#   ['直接', 4],
#   ['吃過', 4],
#   ['淡淡的', 4],
#   ['鐵', 4],
#   ['酥脆', 4],
#   ['卡龍', 4],
#   ['可麗餅', 4],
#   ['普普', 3],
#   ['時尚', 3],
#   ['風格', 3],
#   ['來到', 3],
#   ['網友', 3],
#   ['熬', 3],
#   ['可惜', 3],
#   ['挺', 3],
#   ['週日', 3],
#   ['飲品', 3],
#   ['無', 3],
#   ['檢視', 3],
#   ['較大', 3],
#   ['地圖', 3],
#   ['早上', 3],
#   ['美食', 3],
#   ['以為', 3],
#   ['不到', 3],
#   ['每個', 3],
#   ['附上', 3],
#   ['軟綿', 3],
#   ['價', 3],
#   ['現場', 3],
#   ['文章', 3],
#   ['加入', 3],
#   ['中西區', 3],
#   ['很貴', 3],
#   ['要來', 3],
#   ['只好', 3],
#   ['店面', 3],
#   ['之前', 3],
#   ['甘納許', 3],
#   ['依序', 3],
#   ['真', 3],
#   ['很棒', 3],
#   ['完', 3],
#   ['外', 3],
#   ['盤子', 3],
#   ['好像', 3],
#   ['價格', 3],
#   ['手', 3],
#   ['花', 3],
#   ['老爸', 3],
#   ['老媽', 3],
#   ['點', 3],
#   ['適合', 3],
#   ['目前', 3],
#   ['意思', 3],
#   ['冬季', 3],
#   ['有沒有', 3]]}
