# %%
with open("D:\Data\csvtest\MyDict.csv") as f:
    csv=f.read()
x=[i.split(",")[1:] for i in csv.split("\n") if i.split(",")[0]!=""]
pins=[]
for i in x:
    for j in i:
        pins.append(j)
        
pins=[i for i in pins if i!=""]

# %%
import json
with open("D:\Data\JsonData\TainanFood\TainanUniqueXY.json") as f:
    rawtable=json.load(f)
print(len(rawtable))
rawtable[0]
# Out:
# 5768
# {'address': '台南市安南區安北路433號',
#  'average_consumption': '42',
#  'business_hours': '09:00~23:00',
#  'comment': [{'click': 1004,
#    'content': '簡單、傳統的安平豆花，純白的豆花特別的挑逗我們的胃口。安平，兼具了台南傳統與現代的一個區域，而作為安平代表的傳統美食，一如我們所知的就是安平豆花與周氏蝦捲了。今天，帶點炎熱的天氣，是來點清涼降火冰品的好日子，當然是來喊個豆花消暑了，而吃安平豆花當然是要去最著名的同記安平豆花。同記安平豆花光是在安平就有兩個店面，相距只有一公里左右，今天我們來到的是總店。雖然是平日下午，但店內一副忙碌的景象。剛有客人離開，趕緊搶佔一桌，店內用的是原木的大張長桌以及長椅，很有古風呢。牆上擺的是這些年來到過安平豆花的名人，真的是不少。同記安平豆花在安平已經有四十多年的歷史了，取名「同」記是因為最早的創始人黃慶同名字中有個同字。從小推車一路叫賣開始，到現在成為台南十大傳統名產之一，其中艱辛不足與外人道(所以我們當然不知道了，跳過)；從1993年成立店面後，原本大家稱呼的安平豆花也正式的掛上了「同記」的前綴了。不過雖然安平區的豆花店逐漸變多，但是大家只要說到安平豆花，就知道是指同記安平豆花說。快快來點豆花了，種類並不是非常多，但是道道都是經典。我們選了最正宗、最傳統的紅豆豆花跟綠豆豆花各一碗。一切依古法精製，非基因改造有機黃豆製作，光看成色就令人心動。紅豆部分，則是由來自屏東萬丹的極品紅豆，經過數小時的熬煮後，以最佳的紅豆香氣呈現在我們眼前。好吃，加點一碗紅豆豆花，每顆紅豆都保持著完整的外觀，入口都很有口感說。每一口豆花的口感都是軟嫩細緻，入口傳統的黃豆香氣，手工製作跟用洋菜粉勾芡出來的口感就是不一樣。另外綠豆豆花則除了軟透心的綠豆外，搭著嫩豆花以及微甜的甘蔗糖水一起入口，高雅芬芳得猶如在咖啡館享用下午茶。好吃的豆花，來到安平千萬不要錯過，在老街逛累了，順便來碗冰涼透心的豆花，真是大享受啊！同記安平豆花(總店)(09:00~23:00)台南市安平區安北路433號(06-3915385‧3915057)http://www.tongji.com.tw/',
#    'date': '2015-12-30 21:13:57',
#    'message': ['感謝分享，也幫我推一個，謝謝http://www.ipeen.com.tw/comment/943950'],
#    'name': 'sherry家人小窩',
#    'push': 15,
#    'title': '[食記@台南安平]同記安平豆花，傳統好滋味，入口細嫩綿密，來安平必點實用',
#    'url': 'http://www.ipeen.com.tw/comment/971680'},
#   {'click': 791,
#    'content': '來到台南就來試試這家老字號豆花店古早味啊非常有名的一家店裡面人也很多但我不懂哈哈我覺得吃起來跟其他店沒甚麼差別拉可能又是我舌頭頓吧老字號自然歷史悠久牆上掛滿了名人照可以家不同料配豆花我們點了紅豆小珍珠綠豆豆花很軟入口即化湯特別甜',
#    'date': '2015-08-22 13:35:35',
#    'message': None,
#    'name': '觀音',
#    'push': 5,
#    'title': '同記安平豆花台南總店',
#    'url': 'http://www.ipeen.com.tw/comment/904564'},
#   {'click': 712,
#    'content': '這家是在地人推薦的安平豆花喔老字號豆花當然要來嘗試ㄧ下阿在這炎熱的天氣裡最需要來ㄧ碗甜品了阿這天是平日的暑假店裡還是很多人來朝聖呢牆上滿滿的照片都是很多名人和電視來專訪的喔看來這間真的很夯喔這是我吃得珍珠豆花珍珠超級無敵小顆的比外面飲料的小珍珠還小顆呢滿Q的但是吃進去就沒什麼口感有點可惜這個豆花吃起來很滑嫩豆味也滿香的整體吃起來還不錯',
#    'date': '2015-08-06 15:11:12',
#    'message': None,
#    'name': '洪圓圓',
#    'push': 10,
#    'title': '[台南]同記安平豆花--傳統味實用',
#    'url': 'http://www.ipeen.com.tw/comment/896140'},
#   {'click': 5631,
#    'content': '這間上過電視好幾次的周記安平豆花，老婆在台南唸書時也來吃過好幾次，反而是我第一次造訪，一來就充滿了人潮，果然是人氣豆花店，酷熱吃一點豆花好消暑。-------------------------------------------------------★左豪★痞客邦(更多吃吃喝喝):http://permio1.pixnet.net/blog★左豪★FB粉絲團(一起來歡樂):www.facebook.com/permio1台南美食整理區、南部旅遊整理區-------------------------------------------------------有分內用區跟外帶區，豆花主要有：原味、紅豆、綠豆、珍珠、檸檬豆花。賣豆花賣到有一、二樓，真的是生意驚人的好，還沒下午就高朋滿座。牆上好多名人的合照，店裡面人太多了，我就沒靠過去看了。有冷氣、有二樓，不過建議有點麵食者還是坐一樓，方便拿麵。二樓坐位區豆花也有圖片有分黃豆與黑豆兩種基本豆花，一律是30元的統一價，另外也有賣鮮奶豆花，則賣35元。外帶區也是一杯接著一杯賣。點了三種豆花來解解酷熱，就珍珠豆花與紅豆豆花。珍珠豆花（30元）：豆花又稱作豆腐腦，由豆漿凝固成果凍狀，這邊的珍珠不是波霸珍珠，而是粉圓那種小巧可愛的珍珠，豆花吃起來比較細膩，不像有的吃起來比較粗澀。粉圓我覺得可以再給得多一點啊~~~紅豆豆花（30元）：紅豆香甜又有燉到軟爛，這紅豆我還蠻愛的，糖水也不會太甜，果然是人氣小吃。同記豆花吃起來有淡淡的黃豆味，兩種豆花我覺得紅豆的表現比珠珍更有香氣，，感覺檸檬豆花也不少人吃，來到安平可以吃豆花歇腳一下。--------------------------------------店家名稱:同記安平豆花（安平總店）店家地址:臺南市安平區安北路433號店家電話:06-3915385營業時間:AM09:00～PM23:00--------------------------------------台南美食&旅遊相關連結:台南美食整理區南部旅遊整理區',
#    'date': '2015-04-08 09:02:46',
#    'message': ['到台南好像不能錯過安平的豆花耶給你非常實用也希望你能給我實用喔【電影類別 / 動作】玩命關頭7-復仇之路 回歸到起點',
#     '推~~~同是台南人XD這家真的好吃http://www.ipeen.com.tw/comment/838440麻煩支持 一下喔:)'],
#    'name': '左豪',
#    'push': 12,
#    'title': '[食記]台南安平同記安平豆花（安平總店）實用',
#    'url': 'http://www.ipeen.com.tw/comment/836486'},
#   {'click': 742,
#    'content': 'ㄟ~~肚子餓的嘰哩咕嚕叫的我們..怎麼來到安平豆花咧..!!昭瑢說:裡面有賣鍋燒麵~好吃咧!!...哄豆尼...!!我們來這麼多次..還不知道的大發現呢!!嗯~來吃鍋燒麵+豆花!!哇~~嚇數人...已經1點了...人潮依然強強滾ㄚ!!先來找位置坐下來吧~小孩們..餓的只想吃冰~牛奶雪花冰~雪花冰可以選2種配料!!小朱朱的草莓+煉乳我們家2隻小鬼的~珍珠+煉乳3個大人..不約而同的選擇..珍珠豆花HANK媽喜歡口感QQ的小珍珠!!安平豆花旁的松霖茶坊有賣飲料和鍋燒麵~這家是安平豆花的老闆小孩開的ㄛ~所以!!來吃豆花..也可以吃飽飽ㄛ!!好多鍋的鍋燒麵一起煮鍋燒意麵大碗的鍋燒意麵..記得好像是70.-元吧...料好多ㄛ!!感覺超便宜的~鍋燒烏龍鍋燒麵裡面的料多多..除了有蛋、蛤蜊、菜、蟹肉棒、火腿片等..值得推薦的是它的肉感覺是加了黑胡椒醃過的肉吃起來很嫩也有淡淡的胡椒味口味超特別的!!而且!!它的湯頭超好喝的啦!!~下一次來安平豆花..又多了一種選擇了ㄛ!!同記安平豆花台南市安平區安北路433號營業時間：9:00AM~11:00PM06-3915385‧3915057http://www.tongji.com.tw/',
#    'date': '2015-03-02 13:40:04',
#    'message': ['鍋燒意麵這款中山店沒有賣!!!!'],
#    'name': 'hank媽',
#    'push': 19,
#    'title': '同記安平豆花&松霖茶坊實用',
#    'url': 'http://www.ipeen.com.tw/comment/818344'},
#   {'click': 583,
#    'content': '【安平-同記安平豆花】來安平總有一種糾結感、在有限胃囊裡要抉擇周記蝦捲還是陳家蚵捲?要吃布丁還是豆花?▼同記安平豆花是最具代表的老店，這次特別來到比較偏僻的總店來吃。▼9點多來，沒什麼人，位置超多!▼點了一個純豆花/30元▼創辦人的故事就不再贅述，看這面牆就知道......晚近的報導，已經根本不CARE~▼傳統豆花+金黃糖水，糖水味道蠻像寧夏豆花莊的，沒加冰、偏甜。▼南部豆花除了豆花香、豆花超嫩外，多了一種綿感~<扁桃腺發言>一府二鹿三艋舺，如今府城舊街巷處處可見年輕人，艋舺新公園偏偏都是老傢伙....',
#    'date': '2015-01-06 21:45:40',
#    'message': None,
#    'name': '扁桃腺發言',
#    'push': 12,
#    'title': '【扁桃腺發言之玖拾貳-同記安平豆花】實用',
#    'url': 'http://www.ipeen.com.tw/comment/789054'},
#   {'click': 709,
#    'content': '故事從去土溝村看幾米開始，早上六點出門到現在又餓又渴的，土溝村的食物不吸引我，用估狗搜尋只找到醬鴨工廠，女兒問啥是醬鴨，我說在杭州爸爸有點過，不好吃。外地人在後壁找不到東西吃，父女倆打算買醬鴨吞了，是有多餓呀。我堅持要吃小七，父女派說在台南吃小七是膚淺的行為，就這樣兩派相爭，小七沒吃著，老街飯店也沒下落，中午才開張的割稻飯還在煮，只是啥是割稻飯呀。後壁真的沒我們需要的早午餐，只好往新營方向，邊
!總店要走到接近一公里遠...是在哪裡呢?總店營業時間比分店來得長有機會來總店吃一下甜點，看看跟分店有什麼不同豆花英文是BeanJelly意思是豆的果凍???豆花的單價大約在NT30~35之間雪花冰55左右比起台北便宜了大約五元到十五元左右.除了傳統白豆花也有新口味竹炭黑豆豆花價格是一樣NT30元如果喜歡吃牛奶口味多五元可以點鮮奶豆花豆花也有禮盒?很特別耶但沒有看到是長什麼樣子除了賣豆花也賣...咖啡這個也太多角化經營了豆花選一種料30元店內裝潢大都採用木頭和古物擺設很有情調的吊扇但室內座位不是很舒服就是老木頭老檜木木香香氣宜人我喜歡這種味道~~~珍珠白豆花NT30分量還好，珍珠是小顆粒珍珠，沒有特別厲害口感豆花細膩帶有鹼味是傳統豆花沒錯，傳統豆花和雞蛋豆花不同，傳統豆花結塊比較易碎雞蛋豆花柔軟有彈性破碎後依舊如蛋花湯般的美麗甜度有點甜，大約正常甜的程度鮮奶綠豆花NT35鮮奶是某個大牌子的鮮奶鮮奶本身的香氣和豆花香氣融為一體綠豆本身帶有甜味，而煮的恰到好處的綠豆本身香氣並不會影響豆花與牛奶的香氣雖然小編不是很愛吃綠豆，但這個甜點口感還不錯價格對台北人來說算是蠻便宜的同記安平豆花(二店)地址：708安北路433號電話：063915385營業時間:08:00-21:00跟著王子去旅行！',
#    'date': '2014-07-25 12:20:21',
#    'message': ['竹炭豆畫...黑色的嘛==?', '感覺鮮奶的比較好吃', '去安平，必吃美食~~讚！'],
#    'name': '王子新',
#    'push': 19,
#    'title': '[台南/安平甜點]老街中的好味道:同記安平豆花實用',
#    'url': 'http://www.ipeen.com.tw/comment/701796'},
#   {'click': 693,
#    'content': '以前在市府交通局上班，有一團中午吃飯團，常常中午到安平吃鍋燒意麵，來一碗豆花，這個地方就是『同記安平豆花』，這裡的鍋燒意麵很好吃，豆花還好，安平蝦餅我只吃『松霖茶坊』的，所以安平的蝦餅、蜜餞、豆花都在這裡吃得到喔。同記安平豆花‧松霖茶坊地址：台南市安平區安北路433‧431號。豆花是黃慶同先生開創的，松霖茶坊是同記黃老板的兒子開的(1994年)。豆花訂購專線：06-3915385‧3915057(和松霖茶坊訂購專線同一支)今天我們是要買蝦餅，準備去旅遊時的零嘴，順便吃豆花。▼紅豆豆花和綠豆豆花，甜滋滋的糖水配豆花最好吃。▼松霖茶坊鍋燒意麵很好吃，但是天氣熱，只來買蝦餅。▼同記安平豆花生意超好的，幾乎都是遊客，老台南人不流行來這裡吃豆花。▼幾乎每個人都是一碗鍋燒意麵，再來一碗豆花。▼安平美食在同記安平豆花和松霖茶坊都找得到喔，要吃鹹的甜的通通有。',
#    'date': '2014-06-13 15:43:36',
#    'message': ['好像我去過這家！很面熟，但是不太確定。'],
#    'name': 'potato',
#    'push': 20,
#    'title': '安平美食在同記安平豆花和松霖茶坊實用',
#    'url': 'http://www.ipeen.com.tw/comment/676952'},
#   {'click': 642,
淚直飆，原來我還沒攪拌，就直接把一口糖水配豆花送進嘴裡。誰知道，那一口竟然通通都是檸檬汁吧我猜，後來攪拌了之後，酸甜的味道，跟超滑嫩的豆花，再加上超小的QQ粉圓，但咬到後來，粉圓太多了，怎麼覺得好像下巴咬的都有點酸了~~店面的牆上也掛著安平豆花的"同"的招牌。店裡面外觀再來一張其實經過這裡的時候，門口都已經滿滿的都是滿滿的人了。以上小介紹…謝謝大家。------------------------------------------------------------------------------------------------------------------歡迎繼續閱讀:[食記]台南哈密瓜冰。泰成水果店瓜瓜冰四款一起介紹~[食記]台南府城。蝦仁肉圓[食記]台南府城。60年老店葉家小捲米粉[食記]台南府城。醇涎坊鍋燒意麵[食記]台南。阿鳳浮水虱目魚羹[住宿]台南民宿。保安路謝宅|有故事的老房子[攝影]台南。四草的綠色隧道Sicaogreentunnel(景點|交通|門票|路線|時間)[Travel]日本篇(沖繩。東京)住宿|美食|藥妝|採購|景點|攻略[Travel]23天法義自助行全記錄。巴黎-南法-尼斯-米蘭-威尼斯-佛羅倫斯-羅馬',
#    'date': '2014-04-20 01:53:08',
#    'message': ['回推囉，豆花看起來不錯呢！'],
#    'name': 'Elsayang',
#    'push': 8,
#    'title': '[食記]台南。同記安平豆花',
#    'url': 'http://www.ipeen.com.tw/comment/646210'},
#   {'click': 993,
#    'content': '來喔~來喔~喝加ㄟ島揮箇來囉~~BeMo來到在安平區赫赫有名的豆花店府城感覺甚麼都很有歷史又是一家老店的感覺:D一來到這邊外面就開始排隊了前面也停滿機車店有名到甚至對面還開了一個同記豆花專門的停車場O口O!!!來進去吃吃看吧~看起來是不是很消暑阿~~~~有很多冰品，當然冬天要來暖暖的熱品也是有的上次BeMo正夏天來時還不知道這家豆花路過結果錯過哈哈雖然這次是冬天來，但是是正中午豆花當然就是要給它冰~~下去啊!!XD很快就上菜了呢不過其實這應該也不用準備很久的感覺啦XDD來跟美美的名片合照一張這是米默點的珍珠豆花珍珠部分米默表示很好吃~可是豆花就~~一般一般的豆花這是嘎逼我的紅豆豆花~~~~~(灑花我這個人最古早味了哈哈哈整個配起來超搭啊!!!XDD紅豆吃起來好香~~~豆花我吃起來感覺真的就~跟平常的差不多吧哈哈豆花這食物真的也是視覺系偶像呢XD小珍珠配豆花好可愛哈哈哈好想一口咻~的吸進去>W<左擁右抱~~~哈哈哈幸福美味的感覺~~~~整體吃起來是還不錯啦看大家怎麼搭配料吧，BeMo這次走的是平民風~~哈哈這家店的店內空間超~~寬敞以一家豆花店來說根本旗艦店(?)的規模阿哈哈哈高朋滿座的許多藝人還有有名的人物也都來光臨過呢!!!厲害吧~~~~而且每張都不一樣喔!!!XDDD不是像上次BeMo吃的某家店，用同次參訪的好多張照片充數哈哈牆上有著同記安平豆花的故事有興趣的讀者到場可以詳加閱讀在這就不多做解釋了~:)店內四處掛有對聯不知是人家送的還是店家自己掛的這也是老店常有的東西XD牆上也有幾幅素描描繪著以前同記豆花的故事會不會是有藝術技藝的客人送的阿(?:D吃到一半再去拍拍人潮真的是越來越多....它還有提供外帶服務喔挖塞~~~~紀念章耶!!!!哈哈哈BeMo到處旅行就是最愛找紀念章了可以蓋滿本本~~有時太多紀念章還會不節制，貼到都沒地方寫字(掩面名片之類的只好貼去別頁了Orz...這次的同記豆花就介紹到這囉~~BeMo台南遊也剩下沒幾篇了大家敬請期待囉~~^^店家資訊:地址:臺南市安平區安北路433號營業時間:09:00A.M.-11:00P.M.連絡電話:06-3915385‧3915057FB:同記安皮豆花歡迎加入粉絲團~~~^^BeMo⋈小旅行',
#    'date': '2014-03-13 20:20:32',
#    'message': ['感覺你們玩超多天的耶XD',
#     '呵呵 我跟阿左去三天兩夜都感覺沒有你們玩得多呢',
#     '我喜歡粉圓豆花。',
#     '這一家商妮去台南玩的時候也有去吃，人好多~'],
#    'name': 'BeMo♥',
#    'push': 38,
#    'title': '|台南|四十年歲月累積的同記安平豆花實用',
#    'url': 'http://www.ipeen.com.tw/comment/628060'},
#   {'click': 1184,
#    'content': '趁著過年連假期間我們到台南看J寶外婆啦！話說...在台北果凍魚可以看著地圖趴趴走，可是一到台南雖然有車，但是人生地不熟實在是很怕迷路QQ還好J寶的表姊--瑋瑋姊在我們抵達台南第二天就回來台南啦！有她帶路這樣果凍魚就不用傷透腦筋了XD這家同記安平豆花其實在2011年去台南的時候，瑋瑋姊就帶我們去吃過啦！不過那時候很少在寫部落格就沒記錄了！這一次瑋瑋姊一問要去哪裡，果凍魚第一個就想到要去這家豆花！不過瑋瑋姊這個在地人應該都膩了，對果凍魚來說還是很新鮮呢！同記安平豆花的官網寫在台南分別有四間店，高雄則是有一間，我們這天去的是位於安平古堡附近的總店嚕！除了內用外，店家也有提供禮盒裝的豆花，12杯裝NT.355，小桶裝的話則是NT.425。豆花部分的菜單提供給大家參考唷！看不清楚的話點圖可以放大^^另外也有雪花冰的選擇，不過大家來這邊都在吃豆花很少人點雪花冰呢！店內的用餐環境，呈現復古的感覺，實際上的用餐環境比照片中還要大一點，照片的左右兩側都還有座位，不過因為人太多匆匆拍照，就沒有拍全景啦！同記安平豆花的人潮真的不少，已經有一堆人外帶了，但是店內的座位還是滿滿滿呢！不過翻桌率也很高，想要內用的話也不用等太久唷！牆上也有許多關於同記安平豆花媒體介紹的剪報呢！今天我們三個人點了三碗豆花，分別是珍珠傳統白豆花、檸檬竹碳黑豆花和紅豆鮮奶豆花。珍珠傳統白豆花NT.30以傳統的黃豆搭配上糖水在淋上珍珠就是這碗白豆花嚕！豆花吃起來帶有黃豆香，口感相當細緻綿密，搭配上Q軟的珍珠一起吃，香甜十足呢！話說...果凍魚很討厭吃那種軟滑的豆花，吃起來口感就跟布丁大同小異，還是這種細緻綿密的豆花才討果凍魚喜愛啊！！！話說...有沒有人可以推薦一下台北哪裡有這種口感的豆花啦>"""<果凍魚之前吃幾家都是布丁口感好討厭T︿T檸檬竹碳黑豆花NT.30黑豆花的口感感覺比較稍微"粗"一點，沒有白豆花那麼細緻，不過差異很小，所以其實感覺不太出來XD第一次吃到搭配檸檬的豆花，店家淋上的是新鮮的檸檬原汁，黑
#    'url': 'http://www.ipeen.com.tw/comment/610540'},
#   {'click': 1234,
#    'content': '到台南玩不能錯過的還有這間同記安平豆花~台南的天氣比較熱,涼涼冰冰的東西很受歡迎呢,我們前一次來玩被滿滿的排隊人潮吸引進去,這一次跟老公來玩當然也不會錯過啦,畢竟安平也有不少必遊的景點,順道來吃個冰很開心捏!是說,相隔不遠之處也有一間名字一樣疑似是分店的,生意就差很多,這間店面比較大客人又比較多旁邊還有停車場,怎麼樣最後都會選這間吃的~不過我們來到豆花店卻不想吃豆花,兩個人都點了冰哪~哇哈哈哈粉圓冰~30元我很喜歡這裡的粉圓,好Q好有嚼勁,所以這次乾脆就點了一整碗的粉圓冰來吃,不是我在說,雖然這裡是豆花店,但是冰品可是一點都不會遜色喔!你看看,滿滿的一碗粉圓,吃起來很過癮喔!牛奶雪花冰~55元可以選擇兩種配料,老公挑了草莓粉圓~雪花冰的份量不少,又可以搭配兩種配料,感覺很划算呢~以上~來到安平想吃點涼的記得來這裡湊熱鬧喔!!同記安平豆花地址:台南市安南區安北路433號TEL:06-3915385相關文章2013-6-25台南~金得春捲2013-6-25台南~文章牛肉湯2013-6-26台南~集品蝦仁飯2013-6-26台南~阿堂鹹粥2011-7-16台南~度小月擔仔麵2011-7-16台南~旗哥牛肉湯台南~同記安平豆花2011-7-15台南安平~壹等品霸王豬腳2011-7-15台南安平~周氏蝦捲2013-6-25白河~阿和蓮花園2013-6-25台南~白河蓮花季(路邊的蓮花)2011-7-16台南~孔廟2005台南~走馬瀨農場赤崁樓安平古堡七股鹽山文章分類"台灣餐廳美食"索引導覽文章分類"台灣名勝景點"索引導覽靡靡與13姐的粉絲專頁也可以宣傳你的粉絲專頁',
#    'date': '2013-08-05 12:39:31',
#    'message': ['我喜歡粉圓加檸檬，酸酸甜甜又清涼',
#     '上次去台南很猶豫要吃這間還是黑豆花，結果選了黑豆花',
#     '太太太銷魂了',
#     '謝謝分享'],
#    'name': '靡靡',
#    'push': 33,
#    'title': '台南~同記安平豆花實用',
#    'url': 'http://www.ipeen.com.tw/comment/508760'},
#   {'click': 1458,
#    'content': '★。★。★。★。★。★。★。★。★。★。★。★。★。★。★來到台南安平生日旅遊怎麼可以忘記來吃有名的『同記安平豆花』★。★。★。★。★。★。★。★。★。★。★。★。★。★。★↑非常醒目的招牌因為假日常常都會爆滿所以這家店的對面有一間機車停車場呢★。★。★。★。★。★。★。★。★。★。★。★。★。★。★↑珍珠豆花(30元)這陣子爆發了毒澱粉風波我和男友還是很勇敢的點了"珍珠豆花"((明明就是店家有合格證明))因為我本身很愛吃豆花吃過的豆花也不少呢但是我覺得安平豆花很古早味呢豆花吃起來頗綿密&軟嫩湯的部分雖然甜但是不至於甜死人XD珍珠雖然是小顆的但是還是有口感的唷整體吃起來蠻有飽足感的!!!★。★。★。★。★。★。★。★。★。★。★。★。★。★。★↑平日店況★。★。★。★。★。★。★。★。★。★。★。★。★。★。★↑店內可以蓋紀念章唷★。★。★。★。★。★。★。★。★。★。★。★。★。★。★http://www.tongji.com.tw/index.php↑同記安平豆花官網',
#    'date': '2013-06-27 17:19:05',
#    'message': ['超愛珍珠豆花的啦~~~~~~', '檸檬也蠻好吃的~', '隔壁鍋燒意麵也好吃'],
#    'name': 'Star-Rain',
#    'push': 28,
#    'title': '❤古早味的好滋味-同記安平豆花實用',
#    'url': 'http://www.ipeen.com.tw/comment/489370'},
#   {'click': 1625,
#    'content': '比起布丁豆花我更愛傳統豆花多一點但是傳統豆花很容易酸敗所以夏季的時候很少有賣傳統豆花的店家每次都要到冬季才比較容易吃上一碗軟綿綿的傳統豆花安平的同記豆花是我每到台南安平必吃的糖水之一原因不外乎是那軟綿綿的豆花一碰即碎同記豆花生意很好店內的擺設也不向賣傳統甜品的店家除了有古色古香的桌子之外也陳設了許多古董花瓶、樂器因為不是第一次造訪所以也沒留下幾張店內的相片而這次拍豆花PO上的原因是........同記豆花我還沒PO過拉附上一張菜單豆花總匯一覽表~~哈哈最特別的就是竹炭豆花了雖說是竹炭豆花價錢也沒比較貴售價起跳都是30元古色古香的木桌木椅還蠻有特色也很舒服有別一班的甜品小吃店雖然是做糖水生意店內卻一點也不黏膩清潔衛生非常好店內有幾隻仿古花瓶我覺得顏色很漂亮就隨手攝入紀念雖然我看不懂花瓶上的畫內容為何是八仙過海嗎???幾個同事點的豆花紅豆/鮮奶/竹炭~還有我的檸檬豆花這幾款都不錯耶豆花基底都一樣差別在配料上的不同我比較偏愛檸檬多一點好像檸檬與糖水搭配起來比較不易膩口紅豆豆花紅豆煮得很綿密入口即化雖然我愛綠豆比紅豆多一點偶而也會吃紅豆但紅豆那種特殊的沙沙口感還是不太討喜竹炭豆花這款就沒有啥特殊的味道了長的就是黑豆花的感覺味道也沒有很奇特我想這竹炭豆花對於喜愛嘗鮮的好朋友們是不錯的選擇珍珠檸檬豆花這款是我點的酸酸甜甜好好吃豆花又好細好棉隨便用湯匙一舀就碎的稀巴爛所以吃這種傳統豆花不能攪吃多少舀多少才不會整碗豆花變得很噁爛店內還提供了古早的彈珠台耶我們一行幾人都玩得超開心彈一次4顆珠子最低分10分最高分90以前小時候有沉迷過一陣子都偷挖老爸的豬公去玩彈珠台結果挖豬挖得太兇了豬在短時間瘦太快被我老爸發現後修理得很慘小時候的回憶還是很鮮明呢同步發表隨意窩',
#    'date': '2013-02-22 23:21:25',
#    'message': ['好久沒吃了! 上次很像點珍珠檸檬豆花~好吃也喜歡酸甜感',
#     '我上次也是點檸檬的耶!  紅豆看起來挺不賴的',
#     '這不是排隊排慘的那家嗎XD',
#     '豆花好綿啊~看起來就很好吃',
#     '可惜我上回去~找不到這家，最後隨便路邊找了一間進去吃，結果難吃到爆~~~',
#     '我也超愛這家豆花，只要有到安平我都會來這家，記的以前他們還沒出名時，我就常去那吃，當時是家小小的店，店裡桌以才3~4張而已呢',
#     '檸檬的超好吃!!!他們家的鍋燒意面也很不錯~下次可以試試~!',
#     '\t※ 引述 ✿花露露✿ 之言：\t檸檬的超好吃!!!\t他們家的鍋燒意面也很不錯~下次可以試試~!蝦密??還有賣鍋燒意麵阿?真的假的去很多次了耶~都沒發現....XD',
#     '\t※ 引述 品味廣東粥 之言：\t我也超愛這家豆花，只要有到安平我都會來這家，記的以前他們還沒出名時，我就常去那吃，當時是家小小的店，店裡桌以才3~4張而已呢有些店家有名氣之後味道也跟著變了還好同記豆花每次吃味道都一樣難怪品味廣東粥會喜歡呢',
#     '\t※ 引述 suplumpnes 之言：\t好久沒吃了! 上次很像點珍珠檸檬豆花~好吃也喜歡酸甜感大家都有志一同耶檸檬豆花真的超讚每次去我都只會點這一款',
#     '\t※ 引述 吃喝玩樂紅豆 之言：\t我上次也是點檸檬的耶!  紅豆看起來挺不賴的紅豆的料超多的價錢也不會很貴~價錢實在我發覺珍珠檸檬真的比較好吃耶酸酸甜甜~謝謝吃喝玩樂紅豆送來的糖',
#     '\t※ 引述 ♥心心♥ 之言：\t這不是排隊排慘的那家嗎XD真的嗎?我每次去都沒有排隊耶有次是吃完豆花後等了一個小時的公車......嗚',
#     '\t※ 引述 豬贏 之言：\t豆花好綿啊~看起來就很好吃傳統豆花真的比較好吃綿綿綿~一碰即碎很多布丁都花吃起來口感都太硬了呢',
#     '\t※ 引述 鴨比媽 之言：\t可惜我上回去~找不到這家，最後隨便路邊找了一間進去吃，結果難吃到爆~~~哈哈~真的假的!!!秀秀黑這家離安平老街比較遠一點所以有些的遊客都比較不清楚如果有去安平樹屋的話就會經過呢',
#     '每次去我也必玩彈珠台~~那根本事大家的童年回憶阿~~',
#     '老闆好雅致吃豆花還有藝術品可欣賞啊~',
#     '好久沒到台南去吃吃這豆花了,真想念它.',
#     '\t※ 引述 幸福寶貝果子 之言：\t好久沒到台南去吃吃這豆花了,真想念它.高雄到台南不遠~哪天跟老大休假就可以帶旦旦一起去走走拉順便吃豆花看海浪~超浪漫的',
#     '豆花好吃草莓雪花冰也好好吃'],
#    'name': 'Pixy',
#    'push': 51,
#    'title': '[食。台南/安平]同記豆花/古早味的軟綿豆花毆衣細實用',
#    'url': 'http://www.ipeen.com.tw/comment/423910'},
#   {'click': 1806,
#    'content': '來到安平一定要吃豆花同記是滿有名的一家看到長長的排隊人潮就知道有白豆花,黑豆花跟鮮奶豆花三種可以加兩種料另外也有雪花冰跟紅茶等料有紅豆,綠豆,珍珠跟檸檬幾種原味就是只有糖水豆花妹細心的分裝豆花一杯滿滿的豆花30元我選的是傳統豆花加紅豆跟珍珠料加得還滿多的喔豆花質地很細嫩但湯匙挖下去不會很容易就破碎算是帶有一點彈性豆花的口感滿綿密細緻的裡面沒有空隙吃起來也充滿豆香滿天然的味道單吃也好吃糖水也不會過甜恰恰好襯托出原味豆花的香醇料的部分紅豆煮得微爛,又保持一點口感珍珠雖然是小顆的但也算煮得不錯,有QQ的咬勁太大顆反而會搶去豆花的風采了同記豆花果然有名店的水平價位也很親民來到安平別忘了順手帶上一碗!',
#    'date': '2013-01-02 09:11:50',
#    'message': None,
#    'name': 'Froda生活日記',
#    'push': 24,
#    'title': '府城美食之旅-同記安平豆花實用',
#    'url': 'http://www.ipeen.com.tw/comment/400814'}],
#  'coordinate': {'lat': 22.9999252, 'lng': 120.1534308},
#  'coupon': None,
#  'image': None,
#  'introduction': '同記安平豆花(安平總店)是一個有台南小吃、豆花、安平美食的剉冰、豆花，網友認為值得推薦的有：珍珠豆花、紅豆豆花、檸檬豆花、珍珠檸檬豆花、原味豆花',
#  'name': '同記安平豆花(安平總店)',
#  'style': '剉冰、豆花',
#  'tag': None,
#  'tel': '063915385'}

# %%
import json
with open("D:\Data\JsonData\TainanFood\MyDictPrice.json") as f:
    pricetable=json.load(f)
print(len(pricetable))
pricetable[0]["price"]
# Out:
# 5768
# 2.04

# %%
import json
with open("D:\Data\JsonData\TainanFood\TFIDFTable.json") as f:
    tfidftable=json.load(f)
print(len(tfidftable))
tfidftable[0]
# Out:
# 5768
# {'Ncomment': 20,
#  'TF_IDF': {'一下': 0.0005634393331149615,
#   '一個': 0.0008139148100223864,
#   '一口': 0.0013077527366750165,
#   '一定': 0.0005084299198928792,
#   '一家': 0.0011237862149287283,
#   '一張': 0.0014579745415025532,
#   '一杯': 0.0010869173871837863,
#   '一次': 0.0008449702463452307,
#   '一碗': 0.004429666659221711,
#   '一種': 0.0009967091312932672,
#   '一起': 0.0011374331969887345,
#   '一間': 0.0006565365312943577,
#   '一點': 0.0012219725111579588,
#   '三種': 0.0011375225600803959,
#   '上次': 0.0015558003981493821,
#   '上面': 0.0006968974079722043,
#   '下': 0.0001949567919716747,
#   '不用': 0.0009490672845530912,
#   '不知': 0.0010662962830992676,
#   '中午': 0.0011840833079356117,
#   '久': 0.0005288374071046689,
#   '之後': 0.0007200937979180292,
#   '二樓': 0.0017070511683660698,
#   '人': 0.0012173607844583785,
#   '人潮': 0.0028807927880091623,
#   '今天': 0.0006935254727321259,
#   '介紹': 0.0006909003092857428,
#   '以上': 0.00082678507534791,
#   '以前': 0.0009205760301953049,
#   '位置': 0.0012843484972295312,
#   '來到': 0.004020099403706157,
#   '來說': 0.0006451093707734647,
#   '依舊': 0.001404212671209001,
#   '便宜': 0.0007468024994189467,
#   '假日': 0.0008862055300640222,
#   '做': 0.00044078011382974814,
#   '停車場': 0.0017587370865102092,
#   '傳統': 0.00853448660120824,
#   '價位': 0.0006060845140855463,
#   '元': 0.0014367739748218588,
#   '入口': 0.0009220955995105974,
#   '入口即化': 0.001366932722305254,
#   '內用': 0.0011985345682121718,
#   '兩種': 0.0026092063454807393,
#   '再': 0.0007383763431588787,
#   '再來': 0.0010632269296473819,
#   '冰': 0.0032565523827933246,
#   '冰品': 0.0012203870850354453,
#   '冰淇淋': 0.0010307351615658686,
#   '分店': 0.002133813960457587,
#   '前': 0.0002770444747161589,
#   '加': 0.0005489133097642806,
#   '勁': 0.0007891282746521764,
#   '動力': 0.0017732127584539103,
#   '北路': 0.008887130780792075,
#   '區': 0.000697834707133347,
#   '區安': 0.009380564031758028,
#   '十足': 0.0011915590460448385,
#   '南部': 0.0017705605778352879,
#   '卻': 0.0007081254067248398,
#   '原味': 0.0014398796159424475,
#   '原本': 0.0007634389347517576,
#   '參考': 0.0007728919060859468,
#   '口味': 0.0014348945177911786,
#   '口感': 0.002937227919772775,
#   '古色古香': 0.002060802813748286,
#   '只': 0.000547764862775852,
#   '可愛': 0.0012331984327537226,
#   '台': 0.00018229224191979135,
#   '台北': 0.0010248184528888664,
#   '台南': 0.002761143801785001,
#   '台南市': 0.0005354361455709373,
#   '台南美食': 0.0017406970371804447,
#   '台灣': 0.0008416153573956502,
#   '吃': 0.00407471203355057,
#   '同事': 0.0013532889770693582,
#   '同學': 0.004306453951894961,
#   '同記': 0.010333513746384759,
#   '同記安平豆花': 0.03392639639880137,
#   '名人': 0.0025257590547134797,
#   '味': 0.00030292843123876486,
#   '味道': 0.0007836570081271777,
#   '咖啡': 0.0007166238149761212,
#   '咬': 0.0006267482323810031,
#   '哈哈哈': 0.003017550038047099,
#   '唷': 0.002542822627801974,
#   '喔': 0.0017851564647625967,
#   '喜歡': 0.0009555982037585557,
#   '囉': 0.0008211663984238089,
#   '回': 0.0005286747597197362,
#   '地址': 0.0011858178348071828,
#   '地方': 0.0006846551275317727,
#   '坐': 0.0006448036326070894,
#   '外': 0.0003291755364317452,
#   '外帶': 0.001752194520848377,
#   '多一點': 0.0021685800173603786,
#   '天氣': 0.002435926327330362,
#   '太': 0.0005770079728434447,
#   '好': 0.0008690694241790162,
#   '好像': 0.0008123174962146988,
#   '好吃': 0.0012259417999076103,
#   '好多': 0.0013009888141604295,
#   '姊': 0.002177464680785684,
#   '嫩': 0.0008797287744892185,
#   '安平': 0.021288547819692673,
#   '安平古堡': 0.0024319172217526753,
#   '官網': 0.0011439931687946716,
#   '客人': 0.0005440503239434053,
#   '家': 0.00023411431688637185,
#   '實在': 0.0007986405026093115,
#   '對面': 0.0009210680390658074,
#   '小': 0.0008719805642850262,
#   '小女孩': 0.002814169209527408,
#   '小孩': 0.0012097626560794619,
#   '小顆': 0.0024592084904343104,
#   '左右': 0.0013703590138297778,
#   '已經': 0.001296698221429009,
#   '市場': 0.00113967141647101,
#   '布丁': 0.0018711658331567614,
#   '帶有': 0.0013046031727403696,
#   '幫': 0.00062526868980967,
#   '平日': 0.0017792704887515,
#   '年': 0.0005372204483013629,
#   '店': 0.001010890824627587,
#   '店內': 0.0015549365248373114,
#   '店家': 0.001679265017415381,
#   '店裡': 0.0010149239604614203,
#   '店面': 0.0013152137910869607,
#   '府城': 0.002445733542582418,
#   '座位': 0.0009381654368031922,
#   '很好吃': 0.0007260408492214337,
#   '後': 0.00040941981772439086,
#   '必吃': 0.0015909897758295418,
#   '想': 0.0007040995527861039,
#   '愛': 0.00037416225482080556,
#   '感覺': 0.0017770021101561025,
#   '應該': 0.0004653734369578255,
#   '我點': 0.001065033031141871,
#   '找': 0.0012102225886364555,
#   '抹茶': 0.002083330639154043,
#   '拍': 0.0006277092536589992,
#   '捲': 0.0018599926902121604,
#   '掉': 0.0007559859732836422,
#   '排隊': 0.00398527004501514,
#   '推': 0.0004550136611091974,
#   '推薦': 0.0006089210876862482,
#   '提供': 0.0012047590039927958,
#   '搭配': 0.0024330975832571964,
#   '撐': 0.0013616470665682077,
#   '故事': 0.001907817343280378,
#   '整個': 0.0009745872635284181,
#   '整理': 0.001807156308923264,
#   '整體': 0.0006429725813409241,
#   '文化': 0.0013798184174670441,
#   '文章': 0.0009928265875796876,
#   '料': 0.00048731814802771534,
#   '新': 0.0004115888830738625,
#   '旅行': 0.0012534808709524098,
#   '旅遊': 0.001810395037437298,
#   '早味': 0.0016620489161683085,
#   '晚餐': 0.0009811758811294022,
#   '景點': 0.0016327010753684227,
#   '最': 0.0006047245996404023,
#   '最大': 0.0020257655018431375,
#   '最後': 0.0006276377734694505,
#   '有名': 0.002060281532829588,
#   '有點': 0.000969590045874141,
#   '朋友': 0.0005568007816233795,
#   '木頭': 0.0022308311170726155,
#   '東西': 0.0008540535196374893,
#   '松霖': 0.01385845896948221,
#   '果凍': 0.008343755218995727,
#   '桌子': 0.001193001019829534,
#   '檸檬': 0.005802908061542416,
#   '歡迎': 0.0007026100888524113,
#   '歷史': 0.0013787336043927156,
#   '比較': 0.0020578588625622873,
#   '消暑': 0.0015260042122820824,
#   '淋上': 0.0016110310902438753,
#   '淡淡的': 0.0009752009742929526,
#   '準備': 0.0009451893300773737,
#   '滿滿的': 0.001757933112423943,
#   '濃郁': 0.0006739502249738981,
#   '無敵': 0.001289506891894457,
#   '照片': 0.0014284142476249633,
#   '煮': 0.001746832128140424,
#   '熱': 0.00037653687588520086,
#   '營業時間': 0.0013906253338219602,
#   '牆上': 0.0027855391306698648,
#   '牛奶': 0.0019525655030160664,
#   '特別': 0.0013152600468555378,
#   '特殊': 0.0011660987334788202,
#   '玩': 0.0011041553820690612,
#   '珍珠': 0.02369546836061819,
#   '現在': 0.0009922005663724317,
#   '瑋': 0.008183808647307222,
#   '甜': 0.0004601211471857188,
#   '甜品': 0.0015710200632094015,
#   '甜度': 0.001005710912831285,
#   '甜點': 0.001009958561940527,
#   '生意': 0.0017733384211036478,
#   '發現': 0.0005351276881388788,
#   '相當': 0.0011542775850655132,
#   '看到': 0.0003941207427956424,
#   '真的': 0.0011641260824220678,
#   '知道': 0.0009080903759396537,
#   '碗': 0.0018263891564415586,
#   '竹炭': 0.01013757048887915,
#   '第一次': 0.0006989072277283017,
#   '粉圓': 0.010304014068741431,
#   '粉絲團': 0.001011940896083359,
#   '精製': 0.0030892753275956653,
#   '粿': 0.004069344566085553,
#   '糖水': 0.012495218708121335,
#   '紀念章': 0.004504808776738938,
#   '紅豆': 0.01568492098617003,
#   '細緻': 0.0030045199953300395,
#   '綠豆': 0.007947156444078488,
#   '綿密': 0.0024401920449299837,
#   '總店': 0.005345182871883034,
#   '美食': 0.0012926933441542855,
#   '老字號': 0.0025686905505093206,
#   '老店': 0.0016304890283882789,
#   '老街': 0.0021532269759474807,
#   '耶': 0.000855268146583527,
#   '肉': 0.0002914876932753829,
#   '臺南市': 0.002429596625929036,
#   '興趣': 0.0009687523545084436,
#   '花': 0.0011710917889981094,
#   '花瓶': 0.004551678271571781,
#   '花香': 0.0023932474007442423,
#   '茶坊': 0.008294375854537486,
#   '草莓': 0.0017293182724467237,
#   '菜單': 0.0005348747623250117,
#   '蘭': 0.001586483388931098,
#   '號': 0.0007355742047838109,
#   '虱目': 0.0015488015434240645,
#   '蝦': 0.0009499827493043813,
#   '蝦餅': 0.0034230279941339322,
#   '裡面': 0.0006625969528043595,
#   '製作': 0.0010973761354726413,
#   '要來': 0.0011204389628166392,
#   '覺得': 0.001205099094192636,
#   '許多': 0.0012106543042952281,
#   '話': 0.00030070088235844444,
#   '說': 0.0009775142664123861,
#   '請': 0.000485920830109431,
#   '讚': 0.000899498868179031,
#   '豆': 0.0007700309384525024,
#   '豆花': 0.10746411498893459,
#   '買': 0.0010178266300361622,
#   '資訊': 0.0006804144214569669,
#   '賣': 0.001486236380246448,
#   '走': 0.00048129140496585643,
#   '超': 0.0008119985587476594,
#   '迷你': 0.0017418681155972355,
#   '送': 0.0005494705640814244,
#   '這家': 0.0015180079566644636,
#   '這是': 0.0010677283218059987,
#   '這次': 0.0017451864352482434,
#   '這種': 0.001132941248684568,
#   '這間': 0.0020269645669606967,
#   '通通': 0.0012146420600698225,
#   '遊客': 0.001833959179402728,
#   '道': 0.0005173847819822096,
#   '選': 0.000559157178773899,
#   '選擇': 0.0017512524130326222,
#   '還不錯': 0.0009554984199681616,
#   '還好': 0.0009127601420924113,
#   '還蠻': 0.001090204889907039,
#   '那種': 0.0007771005399441965,
#   '部分': 0.0014791180541846585,
#   '配': 0.0004382945379832437,
#   '配料': 0.0026414204228368482,
#   '酸酸甜甜': 0.0012025196864357528,
#   '醬鴨': 0.003982475302173202,
#   '錯過': 0.0013493471849715256,
#   '鍋燒意麵': 0.005612242066908483,
#   '鍋燒麵': 0.004478943535169497,
#   '長': 0.0005831011968139918,
#   '開心': 0.0009045696019774435,
#   '附近': 0.0010595094282508225,
#   '雪花': 0.007947156444078488,
#   '電話': 0.0008999197016432153,
#   '飛': 0.001321011710053561,
#   '食記': 0.0014026922623260837,
#   '飲料': 0.0005989803769569836,
#   '餓': 0.0013814830890892375,
#   '香': 0.0005444723141599089,
#   '香氣': 0.0018779328705039314,
#   '香濃': 0.0014370548464230418,
#   '香甜': 0.0010954723187968029,
#   '高朋滿座': 0.0022959046282418523,
#   '魚': 0.001556738327851998,
#   '鮮奶': 0.007932275675167856,
#   '黃': 0.0007476397330375606,
#   '黃豆': 0.006067184336003203,
#   '黑豆': 0.008129595804420074,
#   '點': 0.0002098242743064821,
#   '點了': 0.0017164311583683343},
#  'contentcut': '簡單 傳統 安平 豆花 純白 豆花 特別 挑逗 胃口 安平 兼具 台南 傳統 現代 一個 區域 而作 安平 代表 傳統 美食 一如 所知 安平 豆花 周氏 蝦 捲 今天 帶點 炎熱 天氣 來點 清涼 降火 冰品 好日子 喊 豆花 消暑 吃 安平 豆花 最 著名 同記安平豆花 同記安平豆花 光是在 安平 兩個 店面 相距 公里 左右 今天 來到 總店 平日 下午 但店 一副 忙碌 景象 剛有 客人 離開 趕緊 搶佔 一桌 店內用 原木 大張 長桌 長椅 古風 牆
#  'name': '同記安平豆花(安平總店)',
#  'style': '剉冰、豆花',
#  'wordCount': {'一下': 4,
#   '一個': 6,
#   '一口': 7,
#   '一定': 3,
#   '一家': 5,
#   '一張': 4,
#   '一杯': 4,
#   '一次': 5,
#   '一碗': 16,
#   '一種': 4,
#   '一起': 6,
#   '一間': 3,
#   '一點': 8,
#   '三種': 3,
#   '上次': 4,
#   '上面': 3,
#   '下': 3,
#   '不用': 4,
#   '不知': 3,
#   '中午': 4,
#   '久': 3,
#   '之後': 3,
#   '二樓': 4,
#   '人': 22,
#   '人潮': 9,
#   '今天': 4,
#   '介紹': 4,
#   '以上': 3,
#   '以前': 3,
#   '位置': 5,
#   '來到': 16,
#   '來說': 3,
#   '依舊': 3,
#   '便宜': 3,
#   '假日': 3,
#   '做': 3,
#   '停車場': 4,
#   '傳統': 27,
#   '價位': 3,
#   '元': 13,
#   '入口': 4,
#   '入口即化': 3,
#   '內用': 3,
#   '兩種': 8,
#   '再': 7,
#   '再來': 4,
#   '冰': 20,
#   '冰品': 3,
#   '冰淇淋': 3,
#   '分店': 5,
#   '前': 3,
#   '加': 6,
#   '勁': 3,
#   '動力': 4,
#   '北路': 12,
#   '區': 8,
#   '區安': 10,
#   '十足': 4,
#   '南部': 4,
#   '卻': 4,
#   '原味': 5,
#   '原本': 3,
#   '參考': 3,
#   '口味': 12,
#   '口感': 26,
#   '古色古香': 3,
#   '只': 4,
#   '可愛': 5,
#   '台': 3,
#   '台北': 3,
#   '台南': 41,
#   '台南市': 6,
#   '台南美食': 4,
#   '台灣': 3,
#   '吃': 86,
#   '同事': 3,
#   '同學': 8,
#   '同記': 12,
#   '同記安平豆花': 36,
#   '名人': 3,
#   '味': 6,
#   '味道': 7,
#   '咖啡': 3,
#   '咬': 3,
#   '哈哈哈': 7,
#   '唷': 12,
#   '喔': 14,
#   '喜歡': 9,
#   '囉': 5,
#   '回': 4,
#   '地址': 10,
#   '地方': 3,
#   '坐': 3,
#   '外': 4,
#   '外帶': 6,
#   '多一點': 4,
#   '天氣': 7,
#   '太': 6,
#   '好': 18,
#   '好像': 4,
#   '好吃': 13,
#   '好多': 4,
#   '姊': 5,
#   '嫩': 5,
#   '安平': 63,
#   '安平古堡': 3,
#   '官網': 3,
#   '客人': 3,
#   '家': 4,
#   '實在': 4,
#   '對面': 3,
#   '小': 14,
#   '小女孩': 3,
#   '小孩': 3,
#   '小顆': 3,
#   '左右': 4,
#   '已經': 7,
#   '市場': 3,
#   '布丁': 5,
#   '帶有': 4,
#   '幫': 3,
#   '平日': 5,
#   '年': 4,
#   '店': 19,
#   '店內': 8,
#   '店家': 15,
#   '店裡': 4,
#   '店面': 5,
#   '府城': 6,
#   '座位': 4,
#   '很好吃': 3,
#   '後': 5,
#   '必吃': 3,
#   '想': 9,
#   '愛': 4,
#   '感覺': 14,
#   '應該': 3,
#   '我點': 3,
#   '找': 7,
#   '抹茶': 5,
#   '拍': 4,
#   '捲': 6,
#   '掉': 3,
#   '排隊': 11,
#   '推': 4,
#   '推薦': 4,
#   '提供': 6,
#   '搭配': 14,
#   '撐': 3,
#   '故事': 4,
#   '整個': 5,
#   '整理': 4,
#   '整體': 3,
#   '文化': 3,
#   '文章': 4,
#   '料': 6,
#   '新': 4,
#   '旅行': 3,
#   '旅遊': 5,
#   '早味': 4,
#   '晚餐': 3,
#   '景點': 4,
#   '最': 7,
#   '最大': 5,
#   '最後': 3,
#   '有名': 6,
#   '有點': 7,
#   '朋友': 4,
#   '木頭': 4,
#   '東西': 4,
#   '松霖': 9,
#   '果凍': 12,
#   '桌子': 3,
#   '檸檬': 18,
#   '歡迎': 3,
#   '歷史': 3,
#   '比較': 16,
#   '消暑': 3,
#   '淋上': 5,
#   '淡淡的': 3,
#   '準備': 3,
#   '滿滿的': 7,
#   '濃郁': 3,
#   '無敵': 3,
#   '照片': 6,
#   '煮': 9,
#   '熱': 3,
#   '營業時間': 10,
#   '牆上': 8,
#   '牛奶': 6,
#   '特別': 9,
#   '特殊': 3,
#   '玩': 5,
#   '珍珠': 41,
#   '現在': 5,
#   '瑋': 8,
#   '甜': 5,
#   '甜品': 3,
#   '甜度': 3,
#   '甜點': 4,
#   '生意': 6,
#   '發現': 3,
#   '相當': 5,
#   '看到': 3,
#   '真的': 11,
#   '知道': 6,
#   '碗': 10,
#   '竹炭': 11,
#   '第一次': 3,
#   '粉圓': 15,
#   '粉絲團': 4,
#   '精製': 3,
#   '粿': 8,
#   '糖水': 19,
#   '紀念章': 4,
#   '紅豆': 39,
#   '細緻': 7,
#   '綠豆': 13,
#   '綿密': 7,
#   '總店': 9,
#   '美食': 8,
#   '老字號': 4,
#   '老店': 4,
#   '老街': 4,
#   '耶': 4,
#   '肉': 3,
#   '臺南市': 4,
#   '興趣': 3,
#   '花': 9,
#   '花瓶': 4,
#   '花香': 3,
#   '茶坊': 9,
#   '草莓': 4,
#   '菜單': 3,
#   '蘭': 4,
#   '號': 9,
#   '虱目': 3,
#   '蝦': 4,
#   '蝦餅': 5,
#   '裡面': 4,
#   '製作': 4,
#   '要來': 4,
#   '覺得': 10,
#   '許多': 5,
#   '話': 3,
#   '說': 13,
#   '請': 3,
#   '讚': 5,
#   '豆': 5,
#   '豆花': 206,
#   '買': 6,
#   '資訊': 3,
#   '賣': 11,
#   '走': 3,
#   '超': 7,
#   '迷你': 3,
#   '送': 3,
#   '這家': 8,
#   '這是': 6,
#   '這次': 9,
#   '這種': 5,
#   '這間': 10,
#   '通通': 3,
#   '遊客': 3,
#   '道': 7,
#   '選': 5,
#   '選擇': 11,
#   '還不錯': 4,
#   '還好': 3,
#   '還蠻': 4,
#   '那種': 3,
#   '部分': 6,
#   '配': 4,
#   '配料': 8,
#   '酸酸甜甜': 3,
#   '醬鴨': 3,
#   '錯過': 4,
#   '鍋燒意麵': 9,
#   '鍋燒麵': 5,
#   '長': 3,
#   '開心': 3,
#   '附近': 5,
#   '雪花': 13,
#   '電話': 8,
#   '飛': 3,
#   '食記': 5,
#   '飲料': 3,
#   '餓': 4,
#   '香': 7,
#   '香氣': 10,
#   '香濃': 4,
#   '香甜': 3,
#   '高朋滿座': 3,
#   '魚': 9,
#   '鮮奶': 22,
#   '黃': 4,
#   '黃豆': 8,
#   '黑豆': 11,
#   '點': 4,
#   '點了': 7}}

# %%
from gensim.models import word2vec
from gensim import models
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
model = models.Word2Vec.load('D:/Data/word2VecData/Tainan.model.bin')
# Out:
# D:\Anaconda3\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.
# 2017-09-01 00:28:35,898 : INFO : loading Word2Vec object from D:/Data/word2VecData/Tainan.model.bin
# 2017-09-01 00:28:35,976 : INFO : loading wv recursively from D:/Data/word2VecData/Tainan.model.bin.wv.* with mmap=None
# 2017-09-01 00:28:35,977 : INFO : loading syn0 from D:/Data/word2VecData/Tainan.model.bin.wv.syn0.npy with mmap=None
# 2017-09-01 00:28:36,006 : INFO : setting ignored attribute syn0norm to None
# 2017-09-01 00:28:36,006 : INFO : loading syn1neg from D:/Data/word2VecData/Tainan.model.bin.syn1neg.npy with mmap=None
# 2017-09-01 00:28:36,036 : INFO : setting ignored attribute cum_table to None
# 2017-09-01 00:28:36,037 : INFO : loaded D:/Data/word2VecData/Tainan.model.bin

# %% [markdown]
# # Name style WordCount contentcut n score(price) TF_IDF W2Vmodel
# ## >>want to get tag!!!

# %%
import json
bigtable=[]
for raws,scores,tfidfs in zip(rawtable,pricetable,tfidftable):
#     print(raws["name"])
    dien={}
    dien["name"]=raws["name"]
    dien["style"]=raws["style"]
    dien["wordcount"]=tfidfs["wordCount"]
    dien["contentcut"]=scores["contentcut"]
    dien["N"]=scores["n"]
    try:
        dien["score"]=scores["price"]
    except:
        dien["score"]=0
    dien["tfidf"]=tfidfs["TF_IDF"]
    bigtable.append(dien)
    
with open("D:\Data\JsonData\TainanFood\BigTable.json","w") as f:
    json.dump(bigtable,f)

# %%
import pandas
bigpandas=pandas.DataFrame(bigtable)
pandas.DataFrame(bigtable)
# Out:
#        N                                         contentcut  \
# 0     20  簡單 傳統 安平 豆花 純白 豆花 特別 挑逗 胃口 安平 兼具 台南 傳統 現代 一個 區...
# 1     20  原文 台南 東區 深藍咖啡館 號稱 蛋糕 界 千層 蛋糕 大人 口味 黑森林 蛋糕 早茶 在...
# 2     20  阿堂鹹粥 店家 資訊 電話 地址 台南市 西門 路 一段 號 營業時間 每週 公休 總評 美...
# 3     20  台南 中西 排隊 美食 手工 平民 美食 富盛號碗粿 來到 台南 永樂 市場 好吃 美食 沒...
# 4     20  最近 感覺 真是 吹起 一股 抹茶 旋風 嵐 推出 抹茶 飲品 後 蠻多 店家 紛紛 推出 ...
# 5     20  天氣 冷 吃 個鍋 內容 比較 一篇 介紹 無 制式 餐點 本篇 介紹 花雕 鍋 有別於 之...
# 6     20  飛 饗 義 法典 藏 料理 旗艦 總店 週日 上班 日 下班 美食 好好 犒賞 同事 跑 飛...
# 7     20  台南美食 特別 傳統 美食 歷久不衰 今天 拜訪 開 一甲子 老牌 水果店 莉莉水果店 中午...
# 5764   1  布莉克 總店 麻豆 之前 金華 路 手機 行 寄賣 時 嚐鮮 週末 偶然 海安 路 發現 已...
# 5765   1  每年 四月 正值 咖啡 開花 季節 東山 村長 約 一場 咖啡 盛宴 美不勝收 咖啡 花開 ...
# 5766   0
# 5767   1  店家 資訊 營業 地址 台南市 安平 區郡 平路 號 營業時間 星期二 晚上 時段 營業 星...
#
#                            name  score     style  \
# 0                  同記安平豆花(安平總店)   2.04     剉冰、豆花
# 1                         深藍咖啡館   3.91   西點烘焙、麵包
# 2                          阿堂鹹粥   2.79      其他小吃
# 3                         富盛號碗粿   2.11      其他小吃
# 4                 依蕾特布丁奶酪(安平門市)   2.06   西點烘焙、麵包
# 5                     食下有約 想法廚房  11.26    其他異國料理
# 6                      飛饗創意西式料理  11.56      義式料理
# 7                         莉莉水果店   2.20     剉冰、豆花
# 8                         連得堂餅舖   1.95      休閒零食
# 9                        矮仔成蝦仁飯   3.73      其他小吃
# 10                        泰成水果店   3.16        果汁
# 11                    騷烤家(前鋒總店)  10.03      炭烤串燒
# 12                         阿松割包   2.61      麵食點心
# 13                        秉醇烘焙坊   5.90   西點烘焙、麵包
# 14                           冰鄉   2.45     剉冰、豆花
# 15               小銅鍋義式餐廳(德安誠品店)  13.17      義式料理
# 16                     周氏蝦捲(總店)   3.91      其他小吃
# 17                       大菜市純薏仁   3.09     甜品、甜湯
# 18                     聯盈發點心專門店   6.97   粵菜 港式飲茶
# 19             OMAYA春川炒雞(台南永華店)   9.09      韓式料理
# 20                 西井村蜂蜜滷味(安平店)   5.45      休閒零食
# 21                          瑞益行   6.09      其他小吃
# 22                        六千牛肉湯   4.45    其它中式料理
# 23                        文章牛肉湯   3.94    其它中式料理
# 24            拿滋派瑞 Nuts Pirates   7.10      休閒零食
# 25                         陳家蚵捲   3.64      其他小吃
# 26                 EVA伊娃日式泡芙專賣店   2.25   西點烘焙、麵包
# 27        A WEEK PANCAKE&COFFEE   6.76       複合式
# 28                       邱家小卷米粉   2.04      其他小吃
# 29                    阿裕現宰牛肉涮涮鍋   5.33    其它中式料理
# ...                         ...    ...       ...
# 5738                  樂雞蛋糕(安平店)   7.20   西點烘焙、麵包
# 5739               達也濱家漁場 安平旗艦店   0.16  生魚片、壽司專賣
# 5740               麻辣風暴小燒鍋(歸仁店)  21.60      麻辣火鍋
# 5741              料理是實 Is Truth   2.88    其它中式料理
# 5742     945夯海鮮燒烤(945夯海鮮燒烤 海安店)   6.64      海鮮餐廳
# 5743                     泰奶yo吐司   7.04     飲料專賣店
# 5744                 台南蔡二代鮮魚湯專賣   8.40    其它中式料理
# 5745                     阿欣越式料理   7.00    其他異國料理
# 5746     The Breakfast Club 小餐事   5.65    其他類型早餐
# 5747                         日十   3.40      西式早餐
# 5748                       轉角抓餅   1.40   蔥油餅、蔥抓餅
# 5749       濰克早午餐 Wake Up Brunch   5.20      西式早餐
# 5750                   水龜伯豆花學甲店   2.32     剉冰、豆花
# 5751                      屋麵うめえ   6.60    其他日式料理
# 5752       98 tea cafe((台南南門店))   5.96       複合式
# 5753                Principe 玩藝   9.24      法式料理
# 11    {'烤': 124, '吃': 116, '騷烤': 94, '家': 91, '鹽': 6...
# 12    {'吃': 101, '割包': 93, '台南': 70, '阿松割包': 60, '包'...
# 13    {'餅乾': 335, '手工': 121, '吃': 93, '巧克力': 89, '口味...
# 14    {'冰': 169, '芒果': 153, '吃': 143, '草莓': 137, '冰鄉...
# 15    {'小': 246, '吃': 236, '銅鍋': 210, '麵': 152, '舒芙蕾...
# 16    {'蝦': 178, '捲': 174, '吃': 93, '周氏': 87, '台南': ...
# 17    {'薏仁': 254, '抹茶': 126, '台南': 96, '吃': 91, '紅豆'...
# 18    {'吃': 199, '台南': 79, '聯盈發': 71, '元': 71, '港式':...
# 19    {'吃': 247, '炒': 205, '永華': 170, '起司': 167, '台南...
# 20    {'滷味': 233, '吃': 194, '西井': 151, '村': 137, '蜂蜜...
# 21    {'餅乾': 171, '吃': 94, '手工': 82, '瑞益行': 73, '巧克力...
# 22    {'吃': 167, '牛肉湯': 157, '牛肉': 155, '台南': 120, '...
# 23    {'牛肉': 152, '牛肉湯': 131, '吃': 87, '台南': 77, '文章...
# 24    {'惡魔': 183, '酥': 125, '滋': 120, '夏威夷': 96, '吃'...
# 25    {'蚵': 163, '捲': 160, '吃': 93, '蝦': 88, '台南': 8...
# 26    {'芙': 146, '泡': 139, '吃': 107, '冰淇淋': 58, '口味'...
# 27    {'煎餅': 227, '台南': 75, '吃': 72, '水果': 69, '咖啡':...
# 28    {'小卷': 117, '米粉': 116, '吃': 77, '台南': 56, '街':...
# 29    {'牛肉': 213, '吃': 143, '台南': 128, '阿裕': 98, '牛肉...
# ...                                                 ...
# 5738  {'雞蛋糕': 20, '台南': 15, '安平': 12, '口味': 12, '起司'...
# 5739  {'安平': 5, '金魚': 5, '老爺': 5, '鮭魚': 5, '達': 4, '...
# 5740  {'吃': 23, '火鍋': 19, '台南': 16, '花雕': 11, '肉質': ...
# 5741  {'料理': 17, '老闆': 16, '吃': 13, '真的': 11, '已經': ...
# 5742  {'蝦米': 13, '店家': 6, '吃': 6, '套餐': 6, '營業': 5, ...
# 5743  {'系列': 10, '好': 7, '吐司': 6, '吃': 6, '飲料': 5, '...
# 5744  {'虱目': 6, '吃': 5, '台南': 3, '蔡': 3, '覺得': 3, '味...
# 5745  {'越南': 9, '元': 7, '吃': 6, '包': 6, '喔': 5, '麵':...
# 5746  {'台南': 24, '早午餐': 19, '美食': 12, '街': 10, '三明治'...
# 5747  {'元': 7, '日十': 4, '生菜': 4, '早午': 3, '食': 3, '餐...
# 5748  {'抓餅': 3, '轉角': 2, '育樂': 2, '便宜': 2, '關東煮': 2,...
# 5749  {'元': 6, '濰克早午餐': 5, '喔': 3, '有點': 3, '餐點': 3,...
# 5750  {'吃': 7, '台南': 5, '豆花': 4, '先生': 4, '配料': 3, '...
# 5751  {'台南': 37, '中西區': 17, '吃': 9, '麵': 9, '推薦': 8,...
# 5752  {'茶': 6, '餐點': 4, '三高': 4, '飲料': 4, '店家': 3, '...
# 5753  {'店家': 8, '真的': 7, '吃': 7, '料理': 6, '麵': 6, '紅...
# 5754  {'地瓜': 7, '烤': 6, '台南': 5, '先生': 4, '吃過': 2, '...
# 5755  {'吃': 43, '昭和': 16, '料理': 15, '居酒屋': 14, '日式':...
# 5756  {'吐司': 28, '蛋': 16, '老闆': 11, '肉排': 10, '元': 9...
# 5757  {'用餐': 5, '吃': 5, '藥膳': 4, '麻油雞': 4, '米': 4, '...
# 5758  {'台南': 19, '東區': 17, '食': 15, '咖哩': 5, '美食': 5...
# 5759                                            {'': 1}
# 5760  {'分享': 15, '鐵板燒': 13, '元': 12, '幫': 9, '家': 8,...
# 5761  {'店家': 5, '大腸': 5, '麵線': 4, '餡餅': 4, '白河': 3, ...
# 5762  {'犬': 16, '掌燒': 15, '老闆': 12, '喔': 8, '屋': 6, ...
# 5763  {'吃': 20, '麻辣': 14, '食材': 7, '區': 7, '養生': 7, ...
# 5764  {'吃': 4, '路': 3, '冰棒': 3, '布莉克': 2, '之前': 2, '...
# 5765  {'咖啡': 25, '東山': 7, '村長': 4, '滿山遍野': 3, '美不勝收'...
# 5766                                            {'': 1}
# 5767  {'蝦米': 13, '台南': 9, '吃': 7, '鍋': 7, '店家': 5, '...
#
# [5768 rows x 7 columns]

# %%
from collections import Counter
feature=[Counter(i).most_common(5) for i in list(bigpandas.tfidf)]
for i in feature:
    for j in i:
        if j[0] in list(bigpandas.name):
            i.remove(j)

# %%
feature[60]
# Out:
# [('龍蝦', 0.029747733334401543),
#  ('牛排', 0.01933191576600086),
#  ('田螺', 0.0165593896359082),
#  ('蚌', 0.011364806311682388)]

# %%
for i,j in zip(bigtable,feature):
    i['tag']=[k[0] for k in j]
with open("D:\Data\JsonData\TainanFood\BigTable.json","w") as f:
    json.dump(bigtable,f)

# %%
#同義字
with open("D:\Data\csvtest\MyDict.csv") as f:
    csv=f.read()
x=[{j:i.split(",")[1] for j in i.split(",")[1:]} for i in csv.split("\n") if i.split(",")[0]!=""]
pinsameword={}
for i in x:
    pinsameword.update(i)
del pinsameword[""]

# %%
##做各種評論的分數加總

#i為每家店的json
for i in bigtable:
    featurescore={}
    #j為每個詞
    for j in i['wordcount']:
        #pinsameword為同義字字典
        if j in pinsameword:
            
            
            if not pinsameword[j] in featurescore:
                if not pinsameword[j][1:] in featurescore:
                    if pinsameword[j][0]=="否":
                        featurescore[pinsameword[j][1:]]=0
                    else:
                        featurescore[pinsameword[j]]=0
                
                
                
#                 #(分數由同義詞出現次數/評論數)*
                if pinsameword[j][0]=="否":
                    featurescore[pinsameword[j][1:]]-=round(i['wordcount'][j]/i["N"],1)*1
                else:
                    featurescore[pinsameword[j]]+=round(i['wordcount'][j]/i["N"],1)
        
    if len(featurescore)==0:
        featurescore["無評"]=1
    i['featurescore']=featurescore

# %%
featurescore
# Out:
# {'份量大': 1.0, '划算': -1.0, '環境好': 1.0, '食物很香': 2.0, '食物精緻漂亮': 1.0, '食物美味': 2.0}

# %%
x=55
print(bigtable[x]['name'])
print(bigtable[x]['N'])
print(bigtable[x]['featurescore'])
print(bigtable[x]['score'])
print(bigtable[x]['tag'])
print(bigtable[x]['tag'])
# Out:
# 益生堂凡吉力樂園
# 20
# {'食物精緻漂亮': 1.3, '食物很香': 1.0, '食物美味': 0.9, '其他正面情緒': 0.3}
# 3.22
# ['漢方', '益生堂', '楂', '梅桂仙', '宋陳丸']
# ['漢方', '益生堂', '楂', '梅桂仙', '宋陳丸']

# %%
with open("D:\Data\JsonData\TainanFood\BigTable.json","w") as f:
    json.dump(bigtable,f)

# %%
#算出每個評論的評論數N時的最大最小值 for標準化

allpin=[i.split(",")[1] for i in csv.split("\n") if i.split(",")[0]!="" and i.split(",")[1][0]!="否"]
standard={}
for what in allpin:
    for j in [0,5,10,15]:
#         get={}
        x=[i['featurescore'][what] for i in bigtable if what in i['featurescore'] and i["N"]>j]
        b=0
        g=0
        for i in x:
            if i <b:
                b=round(i,1)
            if i >g:
                g=round(i,1)
#         get[what+str(j)]=((g+b)/2,g-(g+b)/2)
#         standard.update(get)
        print(what+"+"+str(j)+"\t"+str(g)+"\t"+str(b))
# Out:
# 食物美味+0	19.0	-14.0
# 食物美味+5	5.6	-2.6
# 食物美味+10	5.6	-2.6
# 食物美味+15	3.1	-2.6
# 划算+0	15.0	-5.0
# 划算+5	3.2	-1.3
# 划算+10	3.0	-0.4
# 划算+15	1.4	-0.4
# 環境好+0	5.0	-3.0
# 環境好+5	1.5	-0.3
# 環境好+10	1.5	0
# 環境好+15	1.5	0
# 服務好+0	3.0	-2.0
# 服務好+5	1.4	-0.4
# 服務好+10	0.8	0
# 服務好+15	0.7	0
# 食物精緻漂亮+0	11.0	0
# 食物精緻漂亮+5	8.9	0
# 食物精緻漂亮+10	8.9	0
# 食物精緻漂亮+15	4.0	0
# 食物很香+0	19.0	0
# 食物很香+5	4.7	0
# 食物很香+10	4.7	0
# 食物很香+15	3.4	0
# 其他正面情緒+0	6.0	-2.0
# 其他正面情緒+5	1.7	-0.3
# 其他正面情緒+10	0.8	-0.2
# 其他正面情緒+15	0.6	-0.1
# 份量大+0	5.5	0
# 份量大+5	3.4	0
# 份量大+10	3.4	0
# 份量大+15	3.4	0
# 小份量+0	12.0	0
# 小份量+5	3.9	0
# 小份量+10	3.9	0
# 小份量+15	2.1	0
# 重口味+0	3.0	0
# 重口味+5	0.9	0
# 重口味+10	0.8	0
# 重口味+15	0.8	0
# 口味清淡+0	3.0	0
# 口味清淡+5	1.2	0
# 口味清淡+10	1.2	0
# 口味清淡+15	1.2	0
# 偏辣+0	5.0	0
# 偏辣+5	1.5	0
# 偏辣+10	1.5	0
# 偏辣+15	0.8	0
# 偏甜+0	2.0	0
# 偏甜+5	0.8	0
# 偏甜+10	0.6	0
# 偏甜+15	0.4	0
# 偏酸+0	1.0	0
# 偏酸+5	0.3	0
# 偏酸+10	0	0
# 偏酸+15	0	0

# %%
#算出正規化數字 (原數字-(上限+下限)/2)/(上限-(上限+下限)/2)
allpin=[i.split(",")[1] for i in csv.split("\n") if i.split(",")[0]!="" and i.split(",")[1][0]!="否"]
standard={}
for what in allpin:
    for j in [0,5,10,15]:
        get={}
        x=[i['featurescore'][what] for i in bigtable if what in i['featurescore'] and i["N"]>j]
        b=0
        g=0
        for i in x:
            if i <b:
                b=round(i,1)
            if i >g:
                g=round(i,1)
        get[what+str(j)]=(round((g+b)/2,3),round(g-(g+b)/2,3))
        standard.update(get)
#         print(what+"+"+str(j)+"\t"+str(g)+"\t"+str(b))
print(standard)
# Out:
# {'食物美味0': (2.5, 16.5), '食物美味5': (1.5, 4.1), '食物美味10': (1.5, 4.1), '食物美味15': (0.25, 2.85), '划算0': (5.0, 10.0), '划算5': (0.95, 2.25), '划算10': (1.3, 1.7), '划算15': (0.5, 0.9), '環境好0': (1.0, 4.0), '環境好5': (0.6, 0.9), '環境好10': (0.75, 0.75), '環境好15': (0.75, 0.75), '服務好0': (0.5, 2.5), '服務好5': (0.5, 0.9), '服務好10': (0.4, 0.4), '服務好15': (0.35, 0.35), '食物精緻漂亮0': (5.5, 5.5), '食物精緻漂亮5': (4.45, 4.45), '食物精緻漂亮10': (4.45, 4.45), '食物精緻漂亮15': (2.0, 2.0), '食物很香0': (9.5, 9.5), '食物很香5': (2.35, 2.35), '食物很香10': (2.35, 2.35), '食物很香15': (1.7, 1.7), '其他正面情緒0': (2.0, 4.0), '其他正面情緒5': (0.7, 1.0), '其他正面情緒10': (0.3, 0.5), '其他正面情緒15': (0.25, 0.35), '份量大0': (2.75, 2.75), '份量大5': (1.7, 1.7), '份量大10': (1.7, 1.7), '份量大15': (1.7, 1.7), '小份量0': (6.0, 6.0), '小份量5': (1.95, 1.95), '小份量10': (1.95, 1.95), '小份量15': (1.05, 1.05), '重口味0': (1.5, 1.5), '重口味5': (0.45, 0.45), '重口味10': (0.4, 0.4), '重口味15': (0.4, 0.4), '口味清淡0': (1.5, 1.5), '口味清淡5': (0.6, 0.6), '口味清淡10': (0.6, 0.6), '口味清淡15': (0.6, 0.6), '偏辣0': (2.5, 2.5), '偏辣5': (0.75, 0.75), '偏辣10': (0.75, 0.75), '偏辣15': (0.4, 0.4), '偏甜0': (1.0, 1.0), '偏甜5': (0.4, 0.4), '偏甜10': (0.3, 0.3), '偏甜15': (0.2, 0.2), '偏酸0': (0.5, 0.5), '偏酸5': (0.15, 0.15), '偏酸10': (0.0, 0.0), '偏酸15': (0.0, 0.0)}

# %%
#做正規化動作
pipin=['食物美味','划算','環境好','服務好','其他正面情緒']

for i in bigtable:
    for j in i['featurescore']:
        if j !="無評":
#             if j in pipin:
#                 if i["N"]<6:
#                     i['featurescore'][j]=round((i['featurescore'][j]-standard[j+str(0)][0])/standard[j+str(0)][1],2)
#                 elif i["N"]<11 and i["N"]>=6:
#                     i['featurescore'][j]=round((i['featurescore'][j]-standard[j+str(5)][0])/standard[j+str(5)][1],2)
#                 elif i["N"]<16 and i["N"]>=11:
#                     i['featurescore'][j]=round((i['featurescore'][j]-standard[j+str(10)][0])/standard[j+str(10)][1],2)
#                 else:
#                     i['featurescore'][j]=round((i['featurescore'][j]-standard[j+str(15)][0])/standard[j+str(15)][1],2)
#             else:
#                 if i["N"]<6:
#                     i['featurescore'][j]=round((i['featurescore'][j])/standard[j+str(0)][1],2)
#                 elif i["N"]<11 and i["N"]>=6:
#                     i['featurescore'][j]=round((i['featurescore'][j])/standard[j+str(5)][1],2)
#                 elif i["N"]<16 and i["N"]>=11:
#                     i['featurescore'][j]=round((i['featurescore'][j])/standard[j+str(10)][1],2)
#                 else:
#                     i['featurescore'][j]=round((i['featurescore'][j])/standard[j+str(15)][1],2)
            if i["N"]<6:
                i['featurescore'][j]=round((i['featurescore'][j])/standard[j+str(0)][1],2)
            elif i["N"]<11 and i["N"]>=6:
                i['featurescore'][j]=round((i['featurescore'][j])/standard[j+str(5)][1],2)
            elif i["N"]<16 and i["N"]>=11:
                i['featurescore'][j]=round((i['featurescore'][j])/standard[j+str(10)][1],2)
            else:
                i['featurescore'][j]=round((i['featurescore'][j])/standard[j+str(15)][1],2)

# %%
#確認正規化後數字
allpin=[i.split(",")[1] for i in csv.split("\n") if i.split(",")[0]!="" and i.split(",")[1][0]!="否"]
standard={}
for what in allpin:
    for j in [0,5,10,15]:
#         get={}
        x=[i['featurescore'][what] for i in bigtable if what in i['featurescore'] and i["N"]>j]
        b=0
        g=0
        for i in x:
            if i <b:
                b=round(i,1)
            if i >g:
                g=round(i,1)
#         get[what+str(j)]=((g+b)/2,g-(g+b)/2)
#         standard.update(get)
        print(what+"+"+str(j)+"\t"+str(g)+"\t"+str(b))
# Out:
# 食物美味+0	1.4	-0.9
# 食物美味+5	1.4	-0.9
# 食物美味+10	1.4	-0.9
# 食物美味+15	1.1	-0.9
# 划算+0	1.8	-0.6
# 划算+5	1.8	-0.6
# 划算+10	1.8	-0.4
# 划算+15	1.6	-0.4
# 環境好+0	2.0	-0.8
# 環境好+5	2.0	-0.3
# 環境好+10	2.0	0
# 環境好+15	2.0	0
# 服務好+0	2.0	-0.8
# 服務好+5	2.0	-0.4
# 服務好+10	2.0	0
# 服務好+15	2.0	0
# 食物精緻漂亮+0	2.0	0
# 食物精緻漂亮+5	2.0	0
# 食物精緻漂亮+10	2.0	0
# 食物精緻漂亮+15	2.0	0
# 食物很香+0	2.0	0
# 食物很香+5	2.0	0
# 食物很香+10	2.0	0
# 食物很香+15	2.0	0
# 其他正面情緒+0	1.7	-0.5
# 其他正面情緒+5	1.7	-0.4
# 其他正面情緒+10	1.7	-0.4
# 其他正面情緒+15	1.7	-0.3
# 份量大+0	2.0	0
# 份量大+5	2.0	0
# 份量大+10	2.0	0
# 份量大+15	2.0	0
# 小份量+0	2.0	0
# 小份量+5	2.0	0
# 小份量+10	2.0	0
# 小份量+15	2.0	0
# 重口味+0	2.0	0
# 重口味+5	2.0	0
# 重口味+10	2.0	0
# 重口味+15	2.0	0
# 口味清淡+0	2.0	0
# 口味清淡+5	2.0	0
# 口味清淡+10	2.0	0
# 口味清淡+15	2.0	0
# 偏辣+0	2.0	0
# 偏辣+5	2.0	0
# 偏辣+10	2.0	0
# 偏辣+15	2.0	0
# 偏甜+0	2.0	0
# 偏甜+5	2.0	0
# 偏甜+10	2.0	0
# 偏甜+15	2.0	0
# 偏酸+0	2.0	0
# 偏酸+5	2.0	0
# 偏酸+10	0	0
# 偏酸+15	0	0

# %%
with open("D:\Data\JsonData\TainanFood\BigTable.json","w") as f:
    json.dump(bigtable,f)

# %%
x=0
print(bigtable[x]['name'])
print(bigtable[x]['N'])
print(bigtable[x]['featurescore'])
print(bigtable[x]['score'])
# Out:
# 同記安平豆花(安平總店)
# 20
# {'食物美味': 0.25, '食物很香': 0.29, '食物精緻漂亮': 0.25, '其他正面情緒': 0.29}
# 2.04

# %%
pipin=['食物美味','划算','環境好','服務好','其他正面情緒']

y=[]
for i in bigtable:
    x=[]
    for j in i["featurescore"]:
        if j =='食物美味':
            if i["featurescore"][j]>1:
                x.append("非常好吃")
            elif i["featurescore"][j]>0.7:
                x.append("很好吃")
            elif i["featurescore"][j]>0.5:
                x.append("味道還算不錯")
            elif i["featurescore"][j]<-0.2:
                x.append("不是很美味")
            elif i["featurescore"][j]<=-0.4:
                x.append("不好吃")
                
        if j =='划算':
            if i["featurescore"][j]>1.2:
                x.append("非常便宜")
            elif i["featurescore"][j]>0.8:
                x.append("很划算")
            elif i["featurescore"][j]<-0:
                x.append("不是很便宜")
            elif i["featurescore"][j]<=-0.2:
                x.append("價格高昂")
        if j =='環境好':
            if i["featurescore"][j]>1.3:
                x.append("環境美輪美奐")
            elif i["featurescore"][j]>0.6:
                x.append("不錯的環境")
            elif i["featurescore"][j]<-0.1:
                x.append("不是很好的環境")
            elif i["featurescore"][j]<=-0.3:
                x.append("環境較差")
        if j =='服務好':
            if i["featurescore"][j]>1:
                x.append("服務絕讚")
            elif i["featurescore"][j]>0.4:
                x.append("服務還不賴")
            elif i["featurescore"][j]<-0.2:
                x.append("服務不是很好")
            elif i["featurescore"][j]<-0.4:
                x.append("服務較差")
        if j =='其他正面情緒':
            if i["featurescore"][j]>1.2:
                x.append("有會令你開心的特色")
            elif i["featurescore"][j]>0.7:
                x.append("有點正面小特色")
            elif i["featurescore"][j]<-0:
                x.append("可能會有點缺點")
            elif i["featurescore"][j]<=-0.3:
                x.append("有不分類評論缺點")
                
                
                
                
        else:
            if i["featurescore"][j]>0.5:
                x.append(j)
    y.append(x)
    
y
terser=[(e,r) for e,r in zip(  [(i['name'],i['N'])   for i in bigtable],y)]
terser
# [n[0][0] for n in terser if len(n[1])<1 and n[0][1]>5]
# Out:
# [(('同記安平豆花(安平總店)', 20), []),
#  (('深藍咖啡館', 20), ['不是很便宜']),
#  (('阿堂鹹粥', 20), ['不是很便宜']),
#  (('富盛號碗粿', 20), ['小份量', '偏甜']),
#  (('依蕾特布丁奶酪(安平門市)', 20), []),
#  (('食下有約 想法廚房', 20), ['味道還算不錯', '食物美味', '食物很香', '食物精緻漂亮', '不錯的環境', '環境好']),
#  (('飛饗創意西式料理', 20), ['食物很香', '食物精緻漂亮', '不錯的環境', '環境好']),
#  (('莉莉水果店', 20), ['小份量', '不是很便宜']),
#  (('連得堂餅舖', 20), []),
#  (('矮仔成蝦仁飯', 20), ['環境好']),
#  (('泰成水果店', 20), ['食物精緻漂亮', '不是很便宜']),
#  (('騷烤家(前鋒總店)', 20), ['很好吃', '食物美味', '食物精緻漂亮', '食物很香', '有點正面小特色']),
#  (('阿松割包', 20), ['小份量']),
#  (('秉醇烘焙坊', 20), ['食物很香', '食物精緻漂亮', '有會令你開心的特色']),
#  (('冰鄉', 20), []),
#  (('小銅鍋義式餐廳(德安誠品店)', 20), ['食物很香', '很好吃', '食物美味', '不錯的環境', '環境好']),
#  (('周氏蝦捲(總店)', 20), ['小份量']),
#  (('大菜市純薏仁', 20), ['不錯的環境', '環境好', '偏甜']),
#  (('聯盈發點心專門店', 20), ['很好吃', '食物美味', '食物精緻漂亮', '很划算', '划算']),
#  (('OMAYA春川炒雞(台南永華店)', 20), ['食物很香', '不錯的環境', '環境好']),
#  (('西井村蜂蜜滷味(安平店)', 20), ['小份量']),
#  (('瑞益行', 20), ['食物很香', '味道還算不錯', '食物美味', '食物精緻漂亮']),
#  (('六千牛肉湯', 20), []),
#  (('文章牛肉湯', 20), []),
#  (('拿滋派瑞 Nuts Pirates', 20), ['很好吃', '食物美味', '食物精緻漂亮', '食物很香', '有點正面小特色']),
#  (('陳家蚵捲', 20), ['小份量', '不是很便宜']),
#  (('EVA伊娃日式泡芙專賣店', 20), ['食物精緻漂亮', '不是很便宜']),
#  (('A WEEK PANCAKE&COFFEE', 20), ['食物精緻漂亮', '食物很香', '環境好']),
#  (('邱家小卷米粉', 20), []),
#  (('阿裕現宰牛肉涮涮鍋', 20), ['味道還算不錯', '食物美味']),
#  (('山根壽司', 20), ['很划算', '划算']),
#  (('金得春捲', 20), ['小份量']),
#  (('克林台包', 20), ['不是很便宜']),
#  (('Doga香酥脆椒', 20), ['非常好吃', '食物美味', '偏辣']),
#  (('懷舊小棧', 20), []),
#  (('FUN Tower日式可麗餅', 20), ['食物精緻漂亮', '小份量', '不錯的環境', '環境好', '服務絕讚', '服務好']),
#  (('阿憨鹹粥', 20), ['不是很便宜']),
#  (('花見宇治抹茶甘味処', 20), ['不錯的環境', '環境好']),
#  (('鹿早茶屋', 20), []),
#  (('窩吧', 20), ['食物精緻漂亮', '小份量', '不錯的環境', '環境好']),
#  (('Kadoya喫茶店', 20), ['食物精緻漂亮', '不錯的環境', '環境好', '有點正面小特色']),
#  (('王西勢食品行', 20), []),
#  (('窄門咖啡', 20), ['不錯的環境', '環境好']),
#  (('秀治咖啡簡餐(臨安店)', 5), []),
#  (('橋北屋日本家庭料理(永福店)', 20), ['划算', '環境好']),
#  (('歐加里(台南大學店)', 20),
#   ['味道還算不錯', '食物美味', '食物很香', '食物精緻漂亮', '服務絕讚', '服務好', '環境好']),
#  (('華侖婷娜', 20), ['食物精緻漂亮', '環境好', '服務絕讚', '服務好']),
#  (('阿明豬心', 20), ['小份量']),
#  (('旗哥牛肉湯', 20), ['不是很便宜']),
#  (('裕成水果店', 20), ['不是很便宜']),
#  (('太陽牌冰品', 20), []),
#  (('赤崁棺材板', 20), ['小份量', '偏甜']),
#  (('保哥黑輪', 20), ['小份量']),
#  (('KAFFE @ HOME', 20), ['味道還算不錯', '食物美味', '小份量', '食物很香', '不錯的環境', '環境好']),
#  (('福記肉圓(總店)', 20), ['小份量', '偏甜']),
#  (('益生堂凡吉力樂園', 20), ['食物精緻漂亮', '食物很香', '有點正面小特色']),
#  (('府城騷烤家', 20), ['味道還算不錯', '食物美味', '食物很香', '很划算', '划算']),
#  (('修安扁擔豆花', 20), ['可能會有點缺點']),
#  (('無聊郎-懷舊冰品冷飲', 20), ['食物精緻漂亮', '偏甜']),
#  (('食香客雞會站雞排專賣(北門總店)', 20), ['味道還算不錯', '食物美味', '食物很香', '食物精緻漂亮', '小份量', '划算']),
#  (('轉角餐廳', 20), ['食物很香', '食物精緻漂亮', '味道還算不錯', '食物美味', '不錯的環境', '環境好']),
#  (('綣綣屋 霜淇淋專賣', 20), ['服務還不賴', '服務好']),
#  (('葉家小卷米粉', 20), ['小份量']),
#  (("台南晶英酒店-ROBIN'S", 20), ['很好吃', '食物美味']),
#  (('碳佐麻里日式燒肉(台南府前店)', 20), ['很好吃', '食物美味', '不錯的環境', '環境好']),
#  (('1010湘(台南三越西門店)', 20), ['食物精緻漂亮', '重口味']),
#  (('a Room 房間', 19), []),
#  (('永樂燒肉飯', 20), ['偏甜']),
#  (('紙上城市(安平店)', 13), ['重口味']),
#  (('L+B coffee 綠色咖啡館', 20), ['食物精緻漂亮', '小份量', '不錯的環境', '環境好']),
#  (('台南商務會館-港式飲茶', 20), ['味道還算不錯', '食物美味', '不錯的環境', '環境好', '重口味']),
#  (('牛軋本舖', 20), ['食物很香']),
#  (('碗稞蘭', 20), ['味道還算不錯', '食物美味']),
#  (('葡吉麵包店', 20), []),
#  (('WIRE破屋', 20), []),
#  (('周氏蝦捲(老店)', 20), ['小份量', '不是很便宜']),
#  (('義豐冬瓜茶', 20), []),
#  (('黑工號嫩仙草', 20), []),
#  (('武廟肉圓', 20), ['小份量']),
#  (('安平貓小巴', 20), ['食物精緻漂亮', '有點正面小特色']),
#  (('勝利早點', 20), []),
#  (("瑪莉洋房 Marie's House", 20),
#   ['食物很香', '食物精緻漂亮', '味道還算不錯', '食物美味', '不錯的環境', '環境好', '服務絕讚', '服務好']),
#  (('集品蝦仁飯', 20), ['小份量', '不是很便宜']),
#  (('雙全紅茶', 20), []),
#  (('義豐阿川冬瓜茶', 20), []),
#  (('咩 灣裡羊肉(總店)', 17), ['食物精緻漂亮', '不錯的環境', '環境好']),
#  (('鬍扯瓦夫', 20), ['食物精緻漂亮', '味道還算不錯', '食物美味', '有點正面小特色']),
#  (('禾記嫩骨飯HoChe(南門旗艦店)', 8), ['不錯的環境', '環境好']),
#  (('毛丼 丼飯專門店', 20), ['不錯的環境', '環境好']),
#  (('江水號', 20), []),
#  (('進來涼冬瓜茶(兩角銀)(安平總店)', 20), []),
#  (('阿霞飯店', 20), []),
#  (('小豪洲沙茶爐', 20), []),
#  (("貓門咖啡 Cafe' Moment", 20), ['食物精緻漂亮', '有點正面小特色']),
#  (('椰庭景觀餐廳', 12), ['有會令你開心的特色', '服務絕讚', '服務好', '不錯的環境', '環境好']),
#  (('再發號百年八寶肉粽(總店)', 20), []),
#  (('上海好味道小籠湯包', 20), ['環境好', '不是很便宜']),
#  (('尼法咖啡', 20), ['食物精緻漂亮', '食物很香', '服務還不賴', '服務好']),
#  (('Mumu小客廳', 20), ['食物精緻漂亮', '小份量', '不錯的環境', '環境好']),
#  (('小豆豆鍋燒意麵', 20), ['小份量']),
#  (('珍杏擱牛奶鍋物', 20), ['食物很香', '非常便宜', '划算', '不錯的環境', '環境好']),
#  (('名坂奇', 20), ['食物很香']),
#  (('韓金婆婆豆腐酪(安平店)', 20), ['食物很香', '服務還不賴', '服務好']),
#  (('扣扣魔坊', 2), []),
#  (('Genki Juice 元氣果汁', 18), []),
#  (('Mascot Bar  哥德式教堂', 13), ['不錯的環境', '環境好']),
#  (('吐司吐司早餐店', 15), []),
#  (('庫肯花園', 20), []),
#  (('五條港府城伴手禮', 20), []),
#  (('林永泰興蜜餞行', 20), []),
#  (('甘單咖啡館', 20), ['環境好', '服務還不賴', '服務好']),
#  (('采田壽司', 20), []),
#  (('順風號', 16), ['食物精緻漂亮']),
#  (('44 Bit 拍拍咖啡 Cafe Lab(原：44 bit 拍拍 beverage)', 15), ['環境好']),
#  (('台南安平黃家鮮蝦餅', 20), ['食物很香', '偏辣']),
#  (('綠橄欖義大利麵', 20), ['食物很香', '服務絕讚', '服務好', '不錯的環境', '環境好']),
#  (('舟鶴家嫩骨飯(文賢店)', 16), ['味道還算不錯', '食物美味', '環境美輪美奐', '環境好', '划算']),
#  (('王氏魚皮', 20), ['味道還算不錯', '食物美味']),
#  (('阿布丁丁專賣店', 20), []),
#  (('魚之家', 20), []),
#  (('民族鍋燒老店', 20), ['服務還不賴', '服務好']),
#  (('井選日式定食', 20), ['味道還算不錯', '食物美味', '食物很香', '不錯的環境', '環境好']),
#  (('劉家肉粽菜粽專賣(西門店)', 20), []),
#  (('阿鳳浮水虱目魚焿', 19), ['小份量', '偏甜']),
#  (('你我他之家', 20), []),
#  (('阿龍意麵', 20), []),
#  (('Brick磚塊', 20), ['食物很香', '有會令你開心的特色', '不錯的環境', '環境好']),
#  (('吳萬春蜜餞(武廟店)', 20), ['食物很香']),
#  (('吉樂菓義式冰淇淋雪糕', 20), ['食物很香']),
#  (('鴻源金好吃牛肉麵(原：上好吃牛肉麵)', 14), ['非常好吃', '食物美味', '重口味', '環境好', '不是很便宜']),
#  (('Dessert Tree 甜點樹鬆餅甜點坊', 11), ['食物很香', '不錯的環境', '環境好']),
#  (('食蔬茶齋 蔬果料理', 18), ['食物很香', '食物精緻漂亮']),
#  (('Relax.brunch 輕鬆點早午餐', 13), ['環境好']),
#  (('阿江炒鱔魚意麵', 20), []),
#  (('卓家汕頭魚麵(民生老店)', 20), ['小份量', '服務還不賴', '服務好']),
#  (('碳佐麻里日式燒肉(台南中華店)', 20), ['味道還算不錯', '食物美味', '不錯的環境', '環境好']),
#  (('進福炒鱔魚專家', 20), ['小份量', '偏甜', '不是很便宜']),
#  (('Lady MaMa 私房點心', 20), ['食物很香']),
#  (('籃記東山鴨頭', 20), []),
#  (('有間冰舖', 20), []),
#  (("Willy's Grill葳苙二壘", 20), []),
#  (('M&M 音樂廚房', 20), ['食物很香', '食物精緻漂亮', '不錯的環境', '環境好']),
#  (('熱點義式餐館', 11), []),
#  (('派初所鮮火鍋', 15), ['環境美輪美奐', '環境好', '服務還不賴', '服務好']),
#  (('ORO咖啡屋', 20), []),
#  (('牡丹庭 漢風料理', 9), ['食物很香', '食物精緻漂亮', '環境美輪美奐', '環境好']),
#  (("帕里諾咖啡 PANINO CAFE'", 20), []),
#  (("Coffee Cafe' 咖啡珈琲", 20),
#   ['食物很香', '味道還算不錯', '食物美味', '食物精緻漂亮', '不錯的環境', '環境好']),
#  (('Mr.wheat 小麥先生創意料理(台南金華店)', 20), ['不錯的環境', '環境好']),
#  (('信燒烤', 20), ['很好吃', '食物美味', '食物很香', '食物精緻漂亮', '非常便宜', '划算', '偏辣']),
#  (('紅磚布丁', 20), []),
#  (('歐培拉(台南店)', 20), ['味道還算不錯', '食物美味']),
#  (('Picturesque 塗鴉空間書店', 20), ['不錯的環境', '環境好', '不是很便宜']),
#  (('鮮果診所   Juice Clinic', 20), ['不錯的環境', '環境好', '小份量']),
#  (('Queen House法式手工甜點', 20), ['食物很香', '不錯的環境', '環境好', '有點正面小特色']),
#  (('勁辣旋風麻辣鴛鴦鍋(永康旗艦店)', 20), ['划算', '偏辣']),
#  (('薄多義', 20), ['不錯的環境', '環境好']),
#  (('築地壽司', 20), ['不是很便宜']),
#  (('kokoni cafe', 13), ['不錯的環境', '環境好']),
#  (('PIANO PIANO慢慢咖啡', 17), ['食物精緻漂亮', '環境好']),
#  (('馬修嚴選(台南門市)', 20), ['食物很香', '有點正面小特色']),
#  (('鰻丼作', 20), []),
#  (('正義餃子', 18), []),
#  (('銀波布丁(府前老店)', 20), []),
#  (('性格せいかく 早午餐', 19), ['食物精緻漂亮', '服務絕讚', '服務好']),
#  (('陶板屋和風創作料理(忠義店)', 20), ['偏甜']),
#  (('旭屋牛丼專賣', 17), ['偏辣']),
#  (('MissBanana巴娜娜的早午茶趣', 17), ['食物精緻漂亮', '不錯的環境', '環境好', '服務還不賴', '服務好']),
#  (('格那修ganache手作蛋糕', 19), ['食物精緻漂亮', '不錯的環境', '環境好', '偏甜']),
#  (('慕紅豆', 20), ['小份量']),
#  (('愛夏子あいさつ', 20), ['食物精緻漂亮', '不錯的環境', '環境好', '有會令你開心的特色', '服務絕讚', '服務好']),
#  (('ChuChu Pâtisserie 法式甜點', 20),
#   ['食物很香', '食物精緻漂亮', '不錯的環境', '環境好', '服務絕讚', '服務好']),
#  (('阿卿傳統飲品‧冰品', 20), ['小份量', '服務還不賴', '服務好']),
#  (('Sunny Pasta陽光義式廚坊', 20),
#   ['食物很香', '味道還算不錯', '食物美味', '食物精緻漂亮', '非常便宜', '划算', '不錯的環境', '環境好']),
#  (('樂禾田', 16), ['環境好']),
#  (('尚禾黑糖粉圓冰', 19), []),
#  (('祿記肉包', 20), ['不是很便宜']),
#  (('i.mita 愛米塔', 20), ['小份量', '食物精緻漂亮', '不錯的環境', '環境好', '服務還不賴', '服務好']),
#  (('法羅烤箱 Often Oven', 17), ['食物精緻漂亮', '划算', '服務還不賴', '服務好']),
#  (('WiWe 威葳義法餐廳', 20), ['食物精緻漂亮', '食物很香', '服務絕讚', '服務好']),
#  (('樹屋咖啡', 13), ['不是很便宜']),
#  (("棻園 Caf'e No.2", 20), ['食物精緻漂亮', '不錯的環境', '環境好', '服務還不賴', '服務好']),
#  (('小巷裡的拾壹號', 18), ['食物精緻漂亮', '環境好']),
#  (('小杉堡霜淇淋專賣店', 20), ['服務絕讚', '服務好', '環境好']),
#  (('麥多古堡童話餐廳', 20), ['食物精緻漂亮', '服務絕讚', '服務好']),
#  (('MUMU白姆森林', 16), ['食物精緻漂亮', '不錯的環境', '環境好', '划算']),
#  (('度小月擔仔麵(中正旗艦店)', 10), ['不是很便宜']),
#  (('安平東興蚵嗲', 16), ['小份量']),
#  (('小象樹義式冰淇淋', 20), ['食物精緻漂亮', '環境好']),
#  (('度小月擔仔麵(總店)', 20), ['小份量', '不是很便宜']),
#  (('鯨吞燒 地雞料理專門店(赤崁分店)', 16), ['味道還算不錯', '食物美味', '食物精緻漂亮', '食物很香', '偏辣']),
#  (('韓金婆婆豆腐酪(赤崁店)', 20), []),
#  (('茂記安平黑豆花', 20), []),
#  (('正興咖啡館', 16), []),
#  (('山小屋 Yamagoya Taiwan(台南店)', 20),
#   ['味道還算不錯', '食物美味', '食物精緻漂亮', '不錯的環境', '環境好', '服務絕讚', '服務好']),
#  (('阿公阿婆蛋餅', 14), []),
#  (('勾勾鍋 鴛鴦火鍋', 20), ['味道還算不錯', '食物美味', '划算']),
#  (('冰ㄉ• かき氷', 15), ['環境好']),
#  (('台南碳味亭', 20), ['食物精緻漂亮', '有點正面小特色']),
#  (('禮物水果', 20), ['食物精緻漂亮']),
#  (('TASTy 西堤牛排(民族店)', 20), ['服務還不賴', '服務好']),
#  (('喬義思窯烤手作廚房', 14), ['食物很香', '不錯的環境', '環境好']),
#  (('泉屋 二次会專門店', 2), []),
#  (('丸作食茶', 19), ['食物很香', '味道還算不錯', '食物美味', '不錯的環境', '環境好', '有點正面小特色']),
#  (('0628全日早午餐店', 20), ['食物很香', '食物精緻漂亮']),
#  (('小椿食堂', 20), ['味道還算不錯', '食物美味', '非常便宜', '划算']),
#  (('洋蔥咖哩工房', 18), []),
#  (('和喫咖啡', 11), ['食物很香']),
#  (('湧日式涮涮鍋', 19), ['不錯的環境', '環境好']),
#  (('伊都日本料理', 20), ['味道還算不錯', '食物美味']),
#  (('岸本絹花 莊園茶館', 20),
#   ['味道還算不錯', '食物美味', '食物精緻漂亮', '食物很香', '不錯的環境', '環境好', '服務還不賴', '服務好']),
#  (('福記肉圓(二店)', 16), ['可能會有點缺點']),
#  (('一點刈包', 17), ['小份量']),
#  (('小綿羊藥膳養生鍋(海安店)', 20), ['食物精緻漂亮', '口味清淡', '食物很香', '划算']),
#  (('原作杏仁茶', 13), []),
#  (('Aranzi Hotel 阿朗基公寓', 15), ['食物精緻漂亮', '不錯的環境', '環境好', '有點正面小特色']),
#  (('麻豆助碗粿', 1), []),
#  (('張三瘋冰火菠蘿油(正興店)', 15), []),
#  (('KLG卡拉雞(東門店)', 20), ['非常便宜', '划算', '服務絕讚', '服務好', '不錯的環境', '環境好']),
#  (('TIMA異國料理', 20), ['份量大']),
#  (('提摩希歐式餐坊(台南東安店)', 20), ['味道還算不錯', '食物美味', '食物精緻漂亮', '食物很香']),
#  (('De Canelé 露露麗麗', 14), ['食物精緻漂亮', '不錯的環境', '環境好', '有點正面小特色']),
#  (('巫比HOUSE甜點屋', 19), ['食物精緻漂亮', '划算', '小份量']),
#  (('京和野日式煎餃', 11), ['不錯的環境', '環境好']),
#  (('愛咖客咖啡館', 11), ['食物精緻漂亮', '食物很香', '環境美輪美奐', '環境好']),
#  (('茂雄蝦仁肉圓', 18), ['小份量']),
#  (('魚小璐和洋廚房', 20), ['划算']),
#  (('Magma熔岩起司塔專賣店', 20), ['食物很香']),
#  (('奶奶的熊熊', 10), ['不錯的環境', '環境好']),
#  (('美式餐廳AJ Burger', 18), []),
#  (('FUN Tower日式可麗餅-國華店', 7), ['不是很便宜']),
#  (('香格里拉台南遠東大飯店-醉月樓', 20), ['味道還算不錯', '食物美味', '食物精緻漂亮', '不錯的環境', '環境好']),
#  (('栗子咖啡‧輕食', 20), ['服務還不賴', '服務好']),
#  (('O卡桑 の 裸食代', 13), ['食物很香']),
#  (('阿輝 炒鱔魚(西門圓環店)', 11), ['不是很便宜', '偏甜']),
#  (('IORI TEA HOUSE', 14), ['環境好', '服務還不賴']),
#  (('保安路米糕', 17), ['小份量']),
#  (('錦霞樓', 20), ['不錯的環境', '環境好', '服務還不賴', '服務好']),
#  (('地球咖啡(健康總店)', 20), []),
#  (('巴東泰式料理', 20), ['偏甜']),
#  (('原燒優質原味燒肉(台南永華店)', 20), ['食物精緻漂亮', '偏甜']),
#  (('臺邦商旅-帕莎西餐廳', 18), ['環境好', '服務還不賴', '服務好']),
#  (('松村煙燻滷味(赤崁店)', 15), ['環境好']),
#  (('是吉祥精緻火鍋館', 18), []),
#  (('京月居酒屋', 1), ['偏甜']),
#  (('台灣茶奶茶(無)', 19), []),
#  (('莊子土豆仁湯', 17), []),
#  (('醇涎坊鍋燒意麵', 17), ['小份量']),
#  (('香格里拉台南遠東大飯店-遠東Cafe', 20), ['味道還算不錯', '食物美味', '食物精緻漂亮', '環境好', '有點正面小特色']),
#  (('雄雄食社', 17), ['食物精緻漂亮', '環境好']),
#  (('滿足花園', 14), []),
#  (('熊賀家日式涮涮鍋', 16), ['食物精緻漂亮', '很划算', '划算', '環境好']),
#  (('歐納牛排館', 20), ['有點正面小特色']),
#  (('福相麻辣香鍋(中華店)', 15), []),
#  (('御品饗', 20),
#   ['食物很香', '味道還算不錯', '食物美味', '食物精緻漂亮', '不錯的環境', '環境好', '重口味', '偏辣']),
#  (('福樂屋', 17), []),
#  (('三胡町-Bistro', 20),
#   ['味道還算不錯', '食物美味', '食物很香', '食物精緻漂亮', '不錯的環境', '環境好', '划算']),
#  (('太古101', 11), []),
#  (('日光 緩緩', 18),
#   ['味道還算不錯', '食物美味', '非常便宜', '划算', '食物精緻漂亮', '小份量', '不錯的環境', '環境好']),
#  (('港茶經典(永康店)', 5), []),
#  (('CHADOR', 17), ['不錯的環境', '環境好']),
#  (('萬香土產紅燒羊肉爐', 16), ['味道還算不錯', '食物美味', '很划算', '划算', '環境好']),
#  (('炸鷄洋行', 10), []),
#  (("泡卡芙 Puff Cafe'", 18), ['食物精緻漂亮', '食物很香', '環境好']),
#  (('鄭記葱肉餅', 10), ['小份量']),
#  (('鵪鶉鹹派', 17), ['不錯的環境', '環境好']),
#  (('ici cafe', 16), ['環境好']),
#  (('海作壽司屋', 12), ['味道還算不錯', '食物美味', '不錯的環境', '環境好']),
#  (('極鮮火鍋', 19), []),
#  (('鮨奕壽司專賣', 11), ['味道還算不錯', '食物美味', '不錯的環境', '環境好']),
#  (('小星星義大利城堡(青年店)', 19), ['食物精緻漂亮', '環境好']),
#  (('Kinks Pub 老房子', 16), []),
#  (('哈利速食', 15), ['不錯的環境', '環境好']),
#  (('大八潮坊港式飲茶(台南永福店)', 16), ['很好吃', '食物美味']),
#  (('鯨吞燒 串燒酒場(海安總本店)', 13), ['不是很便宜']),
#  (('747 巨無霸 炙燒牛排餐廳', 11), ['不錯的環境', '環境好', '服務絕讚', '服務好']),
#  (('丹丹漢堡(安平店)', 17), ['味道還算不錯', '食物美味', '偏甜']),
#  (('亞米亞米義大利麵專賣店', 15), ['味道還算不錯', '食物美味', '不錯的環境', '環境好', '服務還不賴', '服務好']),
#  (('味道樂', 12), ['食物很香', '環境好', '重口味']),
#  (('快樂小館(德安百貨內)', 17), ['食物很香', '有點正面小特色', '環境好']),
#  (('Double Cheese 手工窯烤披薩', 17), []),
#  (('毛鏗咖啡館', 13), ['不是很便宜']),
#  (('堆疊創意輕食、比利時啤酒', 9), []),
#  (('阿湯哥手工米麻糬', 18), ['食物很香', '食物精緻漂亮', '偏甜']),
#  (('土城海產店', 11), []),
#  (('曹師傅麵包坊', 16), ['環境好', '服務還不賴', '服務好']),
#  (('石精臼蚵仔煎', 16), ['小份量', '不是很便宜', '偏甜']),
#  (('木門朝午洋食 MOMENT', 9), []),
#  (('來呷麵', 1), ['不是很便宜']),
#  (('TWIN coffee 咖啡 云', 14), ['不錯的環境', '環境好']),
#  (('Dazzling Cafe(台南新光三越中山店)', 20), ['不錯的環境', '環境好']),
#  (('新都巷日本料理', 15), ['划算']),
#  (('方蘭川焦皮布丁', 19), ['食物很香']),
#  (('Picturesque 塗鴉空間書店(長榮2店)', 17), ['小份量', '環境好']),
#  (('Daylight光合箱子', 16), ['環境好']),
#  (('德斯啤鮮釀啤酒餐廳', 19), ['食物很香', '味道還算不錯', '食物美味', '食物精緻漂亮', '不錯的環境', '環境好']),
#  (('秋收碳烤', 13), ['環境好']),
#  (('Yellow Bee手創漢堡', 13), []),
#  (('1004 Brunch 早午餐', 20), ['划算']),
#  (('半個鍋-個人火烤兩吃鍋物(永華店)', 19), ['不錯的環境', '環境好', '重口味']),
#  (('虎山雷創意蛋塔', 18), ['不是很美味', '食物精緻漂亮', '食物很香']),
#  (('鐵木匠複合式餐廳', 17), ['食物精緻漂亮', '味道還算不錯', '食物美味', '環境美輪美奐', '環境好', '食物很香']),
#  (('大鋤花間', 16), ['有點正面小特色']),
#  (('諾亞方舟餐廳(台南店)', 16), ['環境好']),
#  (('晚起餐館', 16), ['不錯的環境', '環境好', '服務還不賴', '服務好']),
#  (('惠比壽鯛魚燒', 14), []),
#  (('阿力海百匯自助餐廳(原：桂田酒店-心巴黎百匯餐廳)', 17), []),
#  (('一方日朝食X喫茶', 12),
#   ['味道還算不錯', '食物美味', '不錯的環境', '環境好', '服務絕讚', '服務好', '有點正面小特色']),
#  (('石精臼牛肉湯', 16), ['小份量']),
#  (('南方米造秈稻碗粿', 8), ['環境美輪美奐', '環境好', '偏甜', '服務還不賴']),
#  (('日光徐徐(台南永華店)', 12), ['環境美輪美奐', '環境好', '服務絕讚', '服務好']),
#  (('米谷手作料理食堂', 15), []),
#  (('金蕉條雞蛋糕', 7), ['可能會有點缺點']),
#  (('日日咖啡', 15), ['小份量', '不錯的環境', '環境好']),
#  (('舊烘爐', 8), []),
#  (('波哥(台南誠品店)', 14), []),
#  (('饗麻饗辣麻辣火鍋(台南中華店)', 17), ['食物精緻漂亮', '划算', '有點正面小特色']),
#  (('上原UEHARA日式料理', 14), []),
#  (('宇樂居酒屋', 15), ['食物很香', '不錯的環境', '環境好']),
#  (('T&F 手作吐司', 16), ['味道還算不錯', '食物美味', '食物精緻漂亮', '食物很香', '偏甜']),
#  (('寶島菠蘿團(安平店)', 12), ['服務還不賴', '服務好']),
#  (('瑞比冰淇淋店', 17), []),
#  (('蘇格蕾法式甜點 Le Sucré Pâtisserie', 12), ['食物很香', '環境好']),
#  (('宇田家', 13), ['服務還不賴', '服務好']),
#  (('肉伯火雞肉飯', 14), []),
#  (('赤崁擔仔麵(民族店)', 19), ['小份量', '不錯的環境', '環境好', '不是很便宜']),
#  (('小南米糕', 8), ['不是很便宜']),
#  (('小綿羊藥膳的鍋(健康店)', 16), ['食物精緻漂亮', '偏辣', '不錯的環境', '環境好', '口味清淡']),
#  (('OMAYA春川炒雞(台南東門店)', 16), ['食物很香', '環境好', '服務絕讚', '服務好']),
#  (('福米cafe', 9), ['食物很香', '服務還不賴', '服務好', '不錯的環境', '環境好']),
#  (('慶家食品行', 18), []),
#  (('豪記臭豆腐(台南旗艦店)', 17), []),
#  (('那個時代法式餐廳', 12), ['食物很香', '環境美輪美奐', '環境好', '服務絕讚', '服務好']),
#  (('阿川紅燒魚土魠魚羹', 14), ['小份量']),
#  (('ROBI in house', 14), ['食物精緻漂亮', '環境好', '有點正面小特色', '服務還不賴', '服務好']),
#  (('斜塔義式廚房', 15), []),
#  (('咩 灣裡羊肉(保安店)', 13), ['不錯的環境', '環境好']),
#  (('熨斗目花珈琲 cafe WUDAO', 18), ['不錯的環境', '環境好']),
#  (('藤喜家', 7), []),
#  (('大億麗緻酒店-共同市場歐亞自助餐廳', 17), []),
#  (('土匪烘焙事務所', 12), []),
#  (('134巷內的女巫', 9), []),
#  (('福榮小吃店', 15), ['小份量']),
#  (('Dacci 打趣法式廚房', 16), ['食物精緻漂亮', '食物很香', '不錯的環境', '環境好']),
#  (('湯姆嗑吐司', 15), ['不錯的環境', '環境好']),
#  (('松村燻之味(總店)', 15), ['不是很便宜']),
#  (('台南安平得意蝦餅', 17), []),
#  (('阿杰手工蛋餅', 15), []),
#  (('禾馬烘焙', 15), ['食物很香']),
#  (('咖哩太郎 日式咖哩專賣(國賓店)', 17), ['味道還算不錯', '食物美味', '非常便宜', '划算']),
#  (('芙聿閣菓子屋', 16), ['味道還算不錯', '食物美味', '食物很香', '有點正面小特色']),
#  (('天心岩蔬食餐廳', 14), ['很好吃', '食物美味', '食物很香', '環境美輪美奐', '環境好', '小份量']),
#  (('XM麻辣鍋', 16), ['服務還不賴', '服務好', '不是很便宜']),
#  (('日光緩緩(夏林店)', 14), ['小份量', '很划算', '划算', '不錯的環境', '環境好']),
#  (('永恆天詩義式美食餐廳', 15), ['味道還算不錯', '食物美味', '食物很香', '環境好']),
#  (('五吉堂麵包店', 17), ['食物很香', '很好吃', '食物美味']),
#  (('艾摩多手工杏仁豆腐專賣店', 13), []),
#  (('艾維瓦義式廚房', 3), []),
#  (('桃花源牛肉麵館', 15), ['偏辣', '重口味']),
#  (('多一點咖啡館 A Little More(台南美學館)', 13), ['環境美輪美奐', '環境好']),
#  (('新化葉麥克炸雞', 14), []),
#  (('所長茶葉蛋', 15), []),
#  (('PISTACCHIO綠皮開心果冰淇淋工坊', 13), ['不錯的環境', '環境好', '有點正面小特色', '服務還不賴']),
#  (('阿承紅豆餅', 4), ['不是很便宜']),
#  (('HAPPY FOOD 樂食新鉄板料理', 16),
#   ['味道還算不錯', '食物美味', '食物精緻漂亮', '非常便宜', '划算', '環境好']),
#  (('酒鶴壽司', 14), ['不錯的環境', '環境好']),
#  (('美莉安冰品', 16), ['不錯的環境', '環境好', '服務絕讚', '服務好']),
#  (('奧薇小鎮', 10), []),
#  (('府城黃家蝦捲(原鴨母寮蝦捲)', 14), []),
#  (('福豆屋(德安店)', 15), ['味道還算不錯', '食物美味', '不錯的環境', '環境好']),
#  (('韓朝韓式料理', 13), ['環境好', '重口味']),
#  (('老爺行旅甘粹餐廳', 17), ['不錯的環境', '環境好']),
#  (('Cafe Hermosa 艾爾摩莎', 9), ['食物很香', '不錯的環境', '環境好']),
#  (('菜良日式拉麵', 1), []),
#  (('福吉雅手工焦糖布丁', 15), []),
#  (('DACOZ! 大口吃', 13), ['不錯的環境', '環境好']),
#  (('東大門韓國烤肉料理', 12), ['不錯的環境', '環境好']),
#  (('明森宇治抹茶專賣店', 11), ['食物很香']),
#  (("JERRY'S 異國美食餐廳", 15), []),
#  (('佐佐義', 18), ['不錯的環境', '環境好']),
#  (('小滿食堂', 11), []),
#  (('狸小路手作烘焙', 16), ['食物精緻漂亮', '很好吃', '食物美味', '食物很香', '非常便宜', '划算']),
#  (('H.G 好擠(台南)', 13), []),
#  (('康鼎食品', 14), []),
#  (('My Beverages 賣 飲料', 13), []),
#  (('央米 紅豆餅', 6), ['味道還算不錯', '食物美味']),
#  (('黑麥田鄉村烘焙餐廳', 13), ['環境好']),
#  (('廚房有雞(文平二店)', 12), ['味道還算不錯', '食物美味', '食物很香', '份量大', '不錯的環境', '環境好']),
#  (('邊疆燒烤', 14), []),
#  (('FAT Cat DELI', 11), ['服務還不賴', '服務好']),
#  (('凰商號', 12), ['可能會有點缺點']),
#  (('三十八番居酒屋', 9), ['很好吃', '食物美味', '不是很便宜', '服務不是很好']),
#  (('一風堂拉麵(台南西門店)', 17), ['重口味']),
#  (('開普3號店', 8), ['食物很香']),
#  (('舒芙里法式烘培坊', 13), []),
#  (('21世紀風味館(台南成大店)', 14), ['服務還不賴', '服務好']),
#  (("L'OCCITANE Café 歐舒丹咖啡(南紡夢時代)", 8), ['食物很香']),
#  (('永林牛肉火鍋', 13), ['不是很便宜']),
#  (('劉家莊牛肉爐', 13), ['不是很便宜']),
#  (('石頭鄉烤玉米', 13), ['不是很便宜']),
#  (('台糖長榮酒店', 16), []),
#  (('八寶彬圓仔惠', 14), ['偏甜']),
#  (('Katsu yo cafe 咖自由', 13), ['有點正面小特色', '環境好', '不是很便宜']),
#  (('豬鼻子越式創意美食(無)', 15), ['食物很香', '不錯的環境', '環境好', '重口味', '不是很便宜']),
#  (('明德烘培坊(台南監獄)', 15), []),
#  (('排隊燒物', 14), ['食物很香', '不錯的環境', '環境好', '有會令你開心的特色']),
#  (('果核抵家 Maison the Core', 12), ['服務還不賴', '服務好']),
#  (('義豐冬瓜茶(安平店)', 13), []),
#  (('GO STAY dining room', 14), ['划算', '不錯的環境', '環境好']),
#  (('bistro88 義法餐酒館', 14), ['有點正面小特色']),
#  (('白色曙光 Light Cafe', 15), ['小份量', '不錯的環境', '環境好']),
#  (('甘本堂蛋糕烘焙坊', 12), ['服務還不賴']),
#  (('IZZY CAFE', 14), ['有點正面小特色', '環境好']),
#  (('椰如創意鐵板燒(金華店)', 11), ['環境美輪美奐', '環境好', '划算']),
#  (('章成麥芽餅', 15), []),
#  (('美之牛碳烤牛排', 14), ['很划算', '划算', '不錯的環境', '環境好']),
#  (('山記魚仔店', 11), ['服務還不賴', '服務好']),
#  (('十八卯茶屋', 8), []),
#  (('體育公園杏仁豆腐冰', 14), []),
#  (('半個鍋-個人火烤兩吃鍋物(裕學店)', 14), ['環境好']),
#  (('金色小屋', 12), ['食物精緻漂亮']),
#  (('碳味亭和牛炭火燒肉', 16), ['味道還算不錯', '食物美味', '不錯的環境', '環境好']),
#  (('古堡蚵仔煎專賣店', 14), ['不是很便宜']),
#  (('新一二三冰城', 11), ['服務還不賴', '服務好']),
#  (('稻禾烏龍麵(台南)', 15), []),
#  (('城壽司', 13), []),
#  (('美勝珍蜜餞行', 13), []),
#  (('雙雞牌豆油-萬味香醬園', 14), []),
#  (('逐鹿炭火燒肉(臺南分會)', 9), ['服務還不賴']),
#  (('Lazy Bones懶骨頭美式早午餐', 10), []),
#  (('Lure Late Late Breakfast 鹿耳晚晚早餐', 15), ['不錯的環境', '環境好']),
#  (('西井村蜂蜜滷味(安中店)', 9), ['味道還算不錯', '食物美味']),
#  (('Domo Pann多麼胖', 12), []),
#  (('吾亦私私房菜(永華店)', 13), []),
#  (('鄭記土魠魚羹', 13), ['偏甜']),
#  (('義式屋古拉爵 Café Grazie(台南大遠百成功店)', 15), []),
#  (('奉茶來恁兜(台南公園總店)', 13), []),
#  (('甜在心咖啡', 15), ['服務還不賴']),
#  (('子彈列車拉麵特急', 13), ['環境好']),
#  (('Micasa Recipe溫馨小窩', 9), ['不錯的環境', '環境好']),
#  (('扶桑酒肆', 11), []),
#  (('松仔腳燒烤', 11), ['不是很便宜']),
#  (('那個年代杏仁豆腐冰', 13), []),
#  (('一味品碗粿', 11), ['服務絕讚', '服務好', '偏甜']),
#  (('愛豆屋洋菓子工坊', 12), ['食物很香']),
#  (('一手私藏世界紅茶', 13), []),
#  (('布朗趣 Brunch', 13), []),
#  (('韓國館', 11), []),
#  (('Lazy Day CAFE', 12), ['服務還不賴', '服務好']),
#  (('山代目酒藏', 14), ['味道還算不錯', '食物美味', '食物很香', '不錯的環境', '環境好', '偏辣']),
#  (('阿娟肉粽', 9), []),
#  (('Oleat 葛利特蛋糕店', 11), []),
#  (('8%ice 冰淇淋專門店(新光三台南小西門門市)', 11), ['不錯的環境', '環境好', '偏甜']),
#  (("法利達 Fareda Caf'e Food Brunch", 10), ['食物精緻漂亮', '味道還算不錯', '食物美味', '環境好']),
#  (('南島夢遊', 6), ['食物精緻漂亮', '環境好', '不是很便宜']),
#  (('水仙宮米糕', 8), ['小份量', '偏甜']),
#  (('老曾羊肉店(總店)', 14), []),
#  (('A-Point 都會慢食工作室', 5), []),
#  (('淳金鍋', 11), ['環境美輪美奐', '環境好']),
#  (('FILM 茀立姆早午餐', 9), []),
#  (('燒出名堂', 13), ['味道還算不錯', '食物美味', '不錯的環境', '環境好', '服務絕讚', '服務好']),
#  (('彭峇莊園阿根廷碳烤創意料理', 11), ['食物精緻漂亮', '食物很香']),
#  (('明新食品(總店)', 13), ['不是很便宜']),
#  (('FI5VE urban stay 義大利餐廳', 11), ['食物很香', '不錯的環境', '環境好']),
#  (('秀壽司showsushi', 7), ['不錯的環境', '環境好']),
#  (('秋澄壽喜燒', 14), []),
#  (('唇義義大利餐酒館', 12), ['食物很香', '味道還算不錯', '食物美味', '食物精緻漂亮', '環境美輪美奐', '環境好']),
#  (('郭記慶中街綠豆湯(總店)', 11), []),
#  (('Deli Farm 天田輕食館', 12), ['小份量', '環境好']),
#  (('新裕珍餅舖', 12), []),
#  (('Sweet Tea 鮮奶舖 黑糖粉圓專賣店(崇德店)', 10), []),
#  (('伊莉的店', 12), []),
#  (('大大茶樓(台南德安店)', 13), []),
#  (('長鼻子泰式咖哩', 13), ['食物很香', '不錯的環境', '環境好']),
#  (('合豐排骨飯', 13), []),
#  (('老鄧牛肉麵', 10), []),
#  (('安平小舖', 12), []),
#  (('悅津鹹粥', 11), []),
#  (('漢來海港自助餐廳', 13), ['很好吃', '食物美味']),
#  (('迦南水果店', 11), ['小份量', '不是很便宜', '偏甜']),
#  (('精彩火鍋(台南德安店)', 14), ['有點正面小特色', '不錯的環境', '環境好']),
#  (('儒家花生仁湯', 10), []),
#  (('東春館韓式料理', 11), []),
#  (('ice man小雪人義式冰淇淋(台南文創總店)', 11), ['食物精緻漂亮', '食物很香', '環境美輪美奐', '環境好']),
#  (('棻園cafe', 12), ['環境好']),
#  (('橋上看書 bRidge+', 11), ['不錯的環境', '環境好']),
#  (('藝奇ikki新日本料理(台南公園店)', 13), []),
#  (('麻布茶房(南紡店)', 7), ['不錯的環境', '環境好']),
#  (('炸雞洋行(榮譽店)', 12), []),
#  (('山本堂日式拉麵', 13), ['非常便宜', '划算', '食物很香', '不錯的環境', '環境好']),
#  (('咖啡是實 Is Truth', 13), []),
#  (('老騎士咖哩專賣店', 13), ['不是很便宜']),
#  (('苦主健康茶飲', 12), ['口味清淡']),
#  (('凱吉思PIZZA', 11), []),
#  (('是吉咖啡', 13), []),
#  (('同記安平豆花(安平2店)', 10), []),
#  (('阿美鳳梨酥', 12), ['服務還不賴']),
#  (('西門粉圓冰店(西門店)', 3), ['不是很便宜']),
#  (('同記安平豆花', 6), []),
#  (('十七街 鵝肉海產 日本料理', 12), ['不錯的環境', '環境好']),
#  (('卡加米亞', 11), ['環境好']),
#  (('Toka東加和漢創作料理', 13), ['味道還算不錯', '食物美味', '有點正面小特色']),
#  (('蜂橙複合式餐飲', 11), []),
#  (('彩虹日本料理', 11), []),
#  (('魚羊鮮豆(東豐總店)', 11), []),
#  (('京正拉麵', 11), ['偏辣', '不錯的環境', '環境好']),
#  (('阿忠豆菜麵', 11), ['環境好']),
#  (('阿三意麵', 14), []),
#  (('Ciao義式餐酒館', 11), []),
#  (('OVEN COFFEE(台南東寧)', 5), []),
#  (('Cold Stone酷聖石頂級冰淇淋(台南南新門市)', 17), ['偏甜']),
#  (('村吉無國界創意料理', 8), ['食物很香', '環境好']),
#  (('老乾杯(台南西門店)', 10), ['不是很便宜']),
#  (('塔彼Q & Top-Q', 12), ['食物精緻漂亮', '食物很香', '服務絕讚', '服務好', '不錯的環境', '環境好']),
#  (('韓國先生-大長今(原：大長今韓風館)', 11), ['重口味']),
#  (('金色三麥', 11), ['划算', '不錯的環境', '環境好', '有點正面小特色']),
#  (('鯛福', 11), ['食物很香', '不錯的環境', '環境好', '偏甜']),
#  (('豆哥牛排館', 10), ['很划算', '划算', '不錯的環境', '環境好', '服務還不賴', '服務好', '重口味']),
#  (('小金魚泰式小館', 11), ['偏甜', '不是很便宜']),
#  (('燒肉咬蛋(台南大同店)', 12), []),
#  (("am's foods and goods", 10), ['食物很香', '環境好']),
#  (('果子餅乾果汁專賣店', 10), []),
#  (('舞飛日式燒肉', 8), []),
#  (('遇見果香芒果冰', 10), ['味道還算不錯', '食物美味', '食物很香', '不錯的環境', '環境好']),
#  (('鯛可頌(台南東寧店)', 11), ['食物很香', '不錯的環境', '環境好']),
#  (('櫻波甜食專賣店', 8), []),
#  (('卡加米亞咖啡', 11), ['食物很香', '不錯的環境', '環境好']),
#  (('銀湯匙泰式火鍋(台南新光三越小西門店)', 11), ['不錯的環境', '環境好', '偏甜']),
#  (('夏家魚麵', 10), ['小份量']),
#  (('99 Novantanove', 9), []),
#  (('蝦米工坊', 12), ['食物精緻漂亮', '食物很香', '有會令你開心的特色', '偏辣']),
#  (('親親烘焙屋', 10), []),
#  (('炸雞洋行(國華攤位)', 11), []),
#  (('關於港茶經典-Konger Taste', 11), ['味道還算不錯', '食物美味', '食物很香', '服務還不賴', '服務好']),
#  (('皮耶諾', 11), ['環境好']),
#  (('東區焦糖煉乳包心粉圓(台南旗艦店)', 5), ['不是很便宜']),
#  (('東巧鴨肉羹(原：清珍鴨肉羹)', 11), ['不是很便宜']),
#  (('禾野屋日式家庭料理', 11), ['划算', '不錯的環境', '環境好', '服務還不賴', '服務好', '偏甜']),
#  (('巴人川味', 9), []),
#  (('美麗格藝術蛋糕麵包店', 13), []),
#  (('YES MARIE Bistro 也是瑪莉', 11),
#   ['味道還算不錯', '食物美味', '食物很香', '很划算', '划算', '不錯的環境', '環境好']),
#  (('小吉藏日式炸豬排', 11), ['不錯的環境', '環境好']),
#  (('響道食堂', 11), ['偏辣', '不錯的環境', '環境好']),
#  (('小黑琵大幸福', 11), ['有點正面小特色']),
#  (('小香港茶餐廳', 10), []),
#  (('麻古茶坊(台南民族總店)', 12), ['服務絕讚', '服務好', '不錯的環境', '環境好']),
#  (('福樓餐廳', 5), []),
#  (('可露語手作甜點', 4), []),
#  (('翻滾吧，蛋捲!', 10), []),
#  (('津華香香鍋-永大店', 14), ['非常便宜', '划算', '不錯的環境', '環境好']),
#  (('七輪燒肉本舖', 10), []),
#  (('極牛溫體牛肉火鍋', 8), ['味道還算不錯', '食物美味', '食物很香', '不錯的環境', '環境好']),
#  (('阿喬師水粄粥', 10), ['小份量']),
#  (('饗食天堂(台南小西門店)', 12), ['有點正面小特色']),
#  (('阿村第二代牛肉湯', 8), []),
#  (('鳳冰果舖', 8), ['服務還不賴']),
#  (('永通虱目魚粥', 12), ['服務還不賴']),
#  (('名東現烤蛋糕', 10), []),
#  (('小林煎餅(台南門市部)', 12), []),
#  (('舒果新米蘭蔬食(台南府前店)', 12), []),
#  (('仟合和洋廚房', 11), ['划算', '環境好']),
#  (('上牛村牛肉火鍋', 10), ['很好吃', '食物美味', '食物很香']),
#  (('和民居食屋(台南店)', 11), []),
#  (('進福花生糖', 12), ['食物很香']),
#  (('green space綠色空間', 12), ['不是很便宜']),
#  (('阿太伯臭豆腐', 12), ['味道還算不錯', '食物美味', '食物很香']),
#  (('京嘆號', 10), ['不錯的環境', '環境好', '服務還不賴']),
#  (('輕井澤鍋の物(台南店)', 10), ['不錯的環境', '環境好']),
#  (('公主茶園', 10), ['不錯的環境', '環境好']),
#  (('伯龍坊', 11), []),
#  (('名牌手工包子', 9), ['食物很香']),
#  (('Angry Burger  美式餐廳', 12), ['不錯的環境', '環境好']),
#  (('Autumn舒芙蕾熱鬆餅', 9), ['不錯的環境', '環境好']),
#  (('La Bottega coffee', 9), []),
#  (('炸雞洋行-安平店', 10), []),
#  (('鮨次郎壽司專賣店', 10), ['食物精緻漂亮', '食物很香']),
#  (('食內嗑泰式小食肆', 11), ['食物很香', '划算', '偏辣']),
#  (('why東西', 8), ['食物精緻漂亮']),
#  (('ok bird 杯子蛋糕', 5), []),
#  (('阿桐意麵', 11), ['小份量']),
#  (('8818 披薩屋', 10), []),
#  (('小茂屋', 12), []),
#  (('上好烤滷味', 9), []),
#  (('楊哥楊嫂肉粽(總店)', 10), ['不是很便宜']),
#  (('陶林日式涮涮鍋', 12), ['划算', '不錯的環境', '環境好']),
#  (('倉庫早頓', 7), ['食物精緻漂亮']),
#  (('壹零捌 · 一', 10), ['服務還不賴', '服務好']),
#  (('糖人? 館', 10), []),
#  (('柊御食事處', 10), []),
#  (('春日小舖', 10), ['食物很香', '環境好']),
#  (('萬川號', 10), ['不是很便宜']),
#  (('艋舺雞排(台南中正店)', 10), ['食物很香']),
#  (('纓風壽司', 11), ['味道還算不錯', '食物美味', '食物很香', '划算', '不錯的環境', '環境好']),
#  (('肉皮張滷味(台南忠義店)', 11), ['不錯的環境', '環境好']),
#  (('Mr.Mark Italian bistro 義大利小館', 9), ['食物很香']),
#  (('小西門時光驛棧', 7), ['食物很香', '不錯的環境', '環境好']),
#  (('生哥豆漿店', 6), []),
#  (('HIH CAFE', 11), ['食物很香', '不錯的環境', '環境好']),
#  (('阿文豬心', 8), []),
#  (('貝絲貝絲bacibaci手工甜點', 9), ['不錯的環境', '環境好']),
#  (('文青好好笑', 5), []),
#  (('spot-life 手工窯烤PIZZA', 16), ['食物很香', '食物精緻漂亮']),
#  (('Impronta Cafe 腳印咖啡', 10), ['食物精緻漂亮', '食物很香', '不錯的環境', '環境好']),
#  (('小星星義大利莊園Villa Mini Star(慶中店)', 10), []),
#  (('文川梅仔雞', 11), []),
#  (('斑鳩的窩(台南崇學店)', 9), ['不錯的環境', '環境好']),
#  (('吉米thai 泰式料理', 11), ['很划算', '划算', '重口味']),
#  (('阿財牛肉湯', 8), []),
#  (('燒肉神保町', 5), []),
#  (('延齡堂', 8), []),
#  (('東興洋行', 10), []),
#  (('INS飲食坊', 9), []),
#  (('恭仔肉燥意麵', 9), []),
#  (('櫻波布丁(銀波貝特美布丁)', 11), []),
#  (('我們 Our', 9), []),
#  (('老厝一九三三', 7), ['不是很便宜']),
#  (('蛋蛋豪', 9), ['很好吃', '食物美味', '食物很香', '不錯的環境', '環境好']),
#  (('瓜瓜園', 12), ['環境好']),
#  (('阿娟鴨肉羹 咖哩飯', 9), []),
#  (('落成米糕店', 10), ['小份量']),
#  (('芋豆賞', 8), []),
#  (('周氏蝦捲(中山店)', 10), ['不是很便宜']),
#  (('榮盛米糕', 5), []),
#  (('桃山日本料理', 9), []),
#  (('酒鬍子鍋物', 11), ['划算', '不錯的環境', '環境好', '服務還不賴', '服務好']),
#  (('森茂碗粿(赤崁店)', 9), []),
#  (('雞蛋發高燒', 10), []),
#  (("Jerry's Restaurant 義式料理", 3), []),
#  (('飛魚音樂餐廳', 9), []),
#  (('南園街鍋貼', 7), ['偏酸']),
#  (('POP PIE', 9), ['食物很香', '不錯的環境', '環境好']),
#  (('春喜炭火燒肉(健康店)', 11), []),
#  (('双生 Shuànsên Cafe', 8), ['環境好']),
#  (('Café IsShoNi 一緒二', 7), ['不錯的環境', '環境好', '不是很便宜']),
#  (('壹等品霸王豬腳', 10), []),
#  (('布萊恩紅茶(正興店)', 8), ['不是很便宜']),
#  (('瓦地加芋圓', 6), []),
#  (('趙家臘味', 9), ['重口味']),
#  (('Hawaii Grill夏威夷烤烤', 8), ['味道還算不錯', '食物美味']),
#  (('老夫子牛肉麵(旗艦總店)', 10), ['不錯的環境', '環境好']),
#  (('長春健康素食(大同店)', 10), ['環境美輪美奐', '環境好', '服務還不賴', '服務好', '不是很便宜']),
#  (('Mer Mer Coffee', 1), ['食物精緻漂亮']),
#  (('佳佳餐飲屋', 8), []),
#  (('蛤蚧燒貨舖', 10), ['重口味']),
#  (('芳鄰小館', 11), ['小份量']),
#  (('夏慕尼新香榭鐵板燒(永華店)', 11), ['不錯的環境', '環境好']),
#  (('金可可敲敲冰', 8), []),
#  (('上品鐵板燒餐廳', 9), ['服務不是很好']),
#  (('貳拾捌號倉', 9), ['很好吃', '食物美味']),
#  (('忠味麵館(裕忠店)', 8), ['不是很便宜']),
#  (('佛都愛玉(國華店)', 7), []),
#  (('小江戶日式和漢料理(原：築蠻亭)', 10), ['食物很香', '環境好']),
#  (('鳳凰來手作炸雞屋', 10), ['環境好']),
#  (('小草堂', 10), ['偏甜']),
#  (('游爸爸蕃薯椪 白糖粿', 9), []),
#  (('Mr.Wheat 小麥先生創意料理(文平義式館)', 9), ['食物很香', '不錯的環境', '環境好']),
#  (('CHEERYWOOD 櫻桃木', 9), ['不錯的環境', '環境好']),
#  (('不老蒸氣養生料理', 9), ['味道還算不錯', '食物美味']),
#  (('奇美咖啡館(成大店)', 11), ['偏甜']),
#  (('TAIKOO Cafe 太古咖啡', 8), ['環境好']),
#  (('讚岐廚房', 7), ['重口味']),
#  (('澄花日式壽喜燒(台南店)', 8), []),
#  (('湯咖哩', 9), []),
#  (('阿魯香腸熟肉', 9), ['可能會有點缺點', '不是很便宜']),
#  (('安平貴記美食文化館', 9), ['小份量']),
#  (('歐貝拉(台南支店)', 9), []),
#  (('永記虱目魚丸', 8), ['小份量', '不錯的環境', '環境好', '偏甜', '不是很便宜']),
#  (('MISO樂坐屋', 10), []),
#  (("ST.1 Cafe'", 8), ['環境好', '偏甜', '服務還不賴']),
#  (('Perfume Dance 跳舞香水(南紡門店)', 10), ['不錯的環境', '環境好']),
#  (('阿全碗粿', 4), []),
#  (('清水堂愛玉專賣店', 8), ['非常好吃', '食物美味']),
#  (('Apt.slow 慢公寓', 6), ['服務還不賴', '服務好', '環境好']),
#  (('岬角', 11), ['食物很香', '小份量', '有點正面小特色']),
#  (('友誠蝦仁肉圓專賣店', 9), ['可能會有點缺點']),
#  (('韓鍋人(永康店)', 11), ['很划算', '划算', '食物很香', '偏甜', '不錯的環境', '環境好']),
#  (('LeWAY 樂の本味(台南崇學店)', 9), []),
#  (("米果創意果汁 C'mingle", 6), ['食物精緻漂亮', '划算', '不錯的環境', '環境好']),
#  (('Good day 輕食咖啡下午茶', 7), ['不錯的環境', '環境好']),
#  (('華味香鴨肉羹(新進店)', 9), ['不是很便宜']),
#  (('路易先生早午餐', 8), ['不錯的環境', '環境好', '服務還不賴', '服務好']),
#  (('康樂街牛肉湯', 9), []),
#  (('果然是好咖', 9), ['環境美輪美奐', '環境好']),
#  (('好味乾拌麵', 10), ['不錯的環境', '環境好']),
#  (('雙品香酥豬排', 8), ['服務還不賴']),
#  (('福神町拉麵燒(台南花園夜市)', 3), []),
#  (('辛德克萊 coffee house', 10), ['食物很香']),
#  (('明仁鍋貼', 8), ['環境好']),
#  (('鬥牛士二鍋(台南中山店)', 13), []),
#  (('小覓秘', 8), ['不錯的環境', '環境好']),
#  (('東京益田', 8), ['不是很便宜']),
#  (('洁沐創義料理', 9), ['食物很香', '食物精緻漂亮', '味道還算不錯', '食物美味', '不錯的環境', '環境好']),
#  (('神奈川日式平價料理', 8), ['食物很香', '划算', '有點正面小特色']),
#  (('度小月擔仔麵', 9), ['不是很便宜']),
#  (('高麗館', 8), ['不是很便宜']),
#  (('八寸和風時尚細工壽司', 6), ['偏甜', '偏辣']),
#  (('mini coffee', 8), ['環境好']),
#  (('天下大飯店', 10), ['食物很香', '不錯的環境', '環境好']),
#  (('台南-寮國咖啡', 8), []),
#  (('太古●TAIKOO', 7), ['不是很好的環境']),
#  (('初食手作廚房', 8), []),
#  (('卡布里義大利麵', 8), []),
#  (('天滿橋日式洋食專賣店', 10), []),
#  (('佳里肉圓-包仔福', 4), []),
#  (('小茶壺鴛鴦鮮奶茶', 10), ['不錯的環境', '環境好']),
#  (('蜜露爾', 9), []),
#  (('葉陶楊坊', 9), []),
#  (('阿星鹹粥', 8), []),
#  (('北澤壽喜燒(台南公園俱樂部)', 8), []),
#  (("T.G.I.Friday's 星期五美式餐廳(安平店)", 8), ['服務還不賴']),
#  (('竹屋火鍋', 8), []),
#  (('老恆春碳烤店', 9), ['食物很香']),
#  (('龍興冰品店', 8), []),
#  (('漢來蔬食(台南店)', 10), ['味道還算不錯', '食物美味', '食物很香']),
#  (('Capricciosa 卡布里喬莎(台南西門三越店)', 4), []),
#  (('邦喬諾', 6), ['環境好']),
#  (('三大牛肉火鍋', 7), []),
#  (('七股阿宗蚵嗲蚵仔麵線', 6), ['小份量']),
#  (('DORY', 7), []),
#  (('吉品家手作烤餅', 9), ['食物很香']),
#  (('小餐桌2F (預約制)', 7), ['味道還算不錯', '食物美味']),
#  (('胡攪蝦餃', 8), ['偏辣', '不是很便宜']),
#  (('榮寓冰室', 8), ['食物很香', '環境好', '服務還不賴']),
#  (('謙備伯冰店', 5), []),
#  (('新泰城泰雲小館(台南分店)', 8), ['重口味']),
#  (('老店菜粽', 8), ['小份量']),
#  (('炸去啃', 7), ['不錯的環境', '環境好']),
#  (('夢森林鮮果冰淇淋', 9), ['食物精緻漂亮', '偏酸']),
#  (('佳里阿安牛肉湯(台南店)', 7), []),
#  (('BON', 7), ['不錯的環境', '環境好']),
#  (('老友小吃店', 8), []),
#  (('泰灣曼谷', 8), []),
#  (('銀座杏子日式豬排', 9), ['味道還算不錯', '食物美味', '不錯的環境', '環境好']),
#  (('可斯里咖啡烘焙', 6), ['環境好']),
#  (('夢東籬(永華店)', 8), ['環境美輪美奐', '環境好']),
#  (('丹丹漢堡(仁德店)', 9), ['偏甜', '不是很便宜']),
#  (('好味紅燒土魠魚羹', 8), ['服務不是很好']),
#  (('阿美深海鮮魚湯', 7), []),
#  (('麻辣風暴(北門直營店)', 8), ['不錯的環境', '環境好', '有點正面小特色']),
#  (('添福麵館', 9), []),
#  (('台南雲象泰式餐廳', 7), ['重口味']),
#  (('kokoni green', 6), ['食物精緻漂亮']),
#  (('伊莉絲廚房', 8), []),
#  (('永樂米糕', 8), ['小份量']),
#  (('牛角日式炭火燒肉(台南南紡店)', 8), ['不是很便宜']),
#  (('吃麵吧Jai Mi Ba', 8), []),
#  (('福相麻辣香鍋(公園店)', 7), ['偏辣']),
#  (('籃色鴨子', 8), ['偏甜']),
#  (('菓子手作吐司盒子', 3), []),
#  (('Coffee Cape station', 7), ['小份量', '不錯的環境', '環境好']),
#  (('二鍋壽喜燒、涮涮鍋火鍋吃到飽(Focus館)', 8), []),
#  (('HUZI Cafe鬍子煎餅', 7), []),
#  (('蘭姐1899關東煮串燒', 9), ['不錯的環境', '環境好']),
#  (('酷柏德式廚房', 4), []),
#  (('銀波布丁(台南安平店)', 7), []),
#  (('謬思手作屋', 6), ['偏甜', '不是很便宜']),
#  (('YANA cafe 人拿咖啡吧', 6), []),
#  (('明和菜粽', 4), []),
#  (('Merci Kitchen英式司康專賣所', 8), []),
#  (('古都碗粿(東門分店)', 7), []),
#  (('怪獸茶舖', 8), ['環境好']),
#  (('冰ㄉ• かき氷 no.2', 8), []),
#  (('福記水煎包', 8), []),
#  (('阿官火鍋專家(台南加盟店)', 9), []),
#  (('鬼匠拉麵(台南西門店)', 9), ['划算', '食物很香', '不錯的環境', '環境好', '偏辣']),
#  (('檸檬辣椒泰式主題餐廳', 5), []),
#  (('旅人 關東煮', 7), []),
#  (('地球咖啡烘焙美食(永康旗艦店)', 7), ['食物很香']),
#  (('華味香(JTT Plaza店)', 9), ['不錯的環境', '環境好']),
#  (("O'lala 越法小館", 7), ['味道還算不錯', '食物美味', '不錯的環境', '環境好', '口味清淡']),
#  (('每每 純鮮奶雞蛋糕', 7), []),
#  (('双品香酥豬排', 7), []),
#  (('御品川 麻辣·鴛鴦火鍋', 10), ['食物很香']),
#  (('阿財點心', 7), ['偏辣']),
#  (('凸凹餐酒館', 8), ['食物很香']),
#  (('甜菓冰舖奶酪布丁專賣店', 7), ['偏甜']),
#  (('銀鋒冰果室', 8), ['不錯的環境', '環境好']),
#  (('銅盤嚴選韓式烤肉(中山店)', 7), []),
#  (('安哥海產開基店', 8), []),
#  (('Bungy Jump Korean BBQ 笨豬跳 - 台南店', 8), []),
#  (('Grimm House 格林洋房', 7), ['不錯的環境', '環境好']),
#  (('哞王 原味炭烤牛排', 8), ['非常便宜', '划算', '食物很香', '不錯的環境', '環境好']),
#  (('慶山日本料理', 7), ['偏辣']),
#  (('香草鋪子(府中店)', 6), []),
#  (('香格里拉台南遠東大飯店-大廳茶軒', 7), []),
#  (('正合興蜜餞行', 7), []),
#  (('紅記早點(原：紅姐早點)', 7), []),
#  (('Room A', 7), ['不錯的環境', '環境好']),
#  (('西海岸活蝦之家餐廳(台南總店)', 7), ['重口味']),
#  (('源湯鍋物創意料理', 7), ['重口味', '不錯的環境', '環境好']),
#  (('Cape cafe開普咖啡', 7), ['不錯的環境', '環境好']),
#  (('北海燒炒物語', 7), ['不是很便宜']),
#  (('Mr. 拉麵', 8), []),
#  (('兜齊私廚', 7), ['不錯的環境', '環境好']),
#  (('小廚獅幸福豆花', 8), ['不錯的環境', '環境好']),
#  (('Mr.wheat 小麥先生創意料理(永康旗艦店)', 8), ['食物很香', '不錯的環境', '環境好']),
#  (('真心食府', 4), []),
#  (('福泰飯桌', 7), ['偏甜', '重口味']),
#  (('好禮道商行', 7), []),
#  (('拾參', 7), []),
#  (('渝苑川菜餐廳', 7), ['不是很便宜']),
#  (('涓豆腐(台南)', 8), []),
#  (('日光大道健康廚坊Sonnentor Cafe(台南店)', 6), []),
#  (('江水號(海安店)', 6), ['食物很香', '環境好']),
#  (('蒂兒咖啡', 5), []),
#  (('健康燒肉屋 貴一郎', 7), ['食物精緻漂亮', '味道還算不錯', '食物美味', '不是很便宜']),
#  (('轟丼', 3), []),
#  (('喜得碳烤三明治', 7), []),
#  (('倫敦玫瑰', 6), ['有點正面小特色', '不錯的環境', '環境好', '不是很便宜']),
#  (('大豆豆麵店', 8), ['份量大']),
#  (('小聚‧Stammtisch', 5), []),
#  (('郭師傅飯鍋料理', 9), ['食物很香']),
#  (('下大道米糕', 7), []),
#  (('香茅魚', 7), ['重口味']),
#  (('海鮮河粉乾麵', 6), ['重口味']),
#  (('第三代虱目魚丸', 7), ['不是很便宜']),
#  (('開元紅燒土魠魚羹', 7), ['偏甜']),
#  (('崁頂山野味餐廳土雞城', 4), ['不是很便宜']),
#  (('未艾閱讀咖啡', 7), []),
#  (('蜜桃香冷飲店', 7), []),
#  (('黑橋牌(中正店)', 7), []),
#  (('鴻達 臭豆腐 大腸麵線', 6), []),
#  (('龍泉冰店', 7), []),
#  (('濃園滿漢餐廳', 7), ['不錯的環境', '環境好', '服務還不賴']),
#  (('春水堂人文茶館(台南德安店)', 8), []),
#  (('花見小路', 8), []),
#  (('慢慢來義式餐廳 Pian Piano', 6), ['環境好']),
#  (('小南人燒烤', 5), []),
#  (('古城豆花庄', 7), []),
#  (('甘簞行瓦 x Mvsa 西班牙酒莊餐廳', 7), ['食物很香']),
#  (('神田日本料理', 6), ['不是很便宜', '偏甜']),
#  (('漢豆府', 6), ['食物很香', '環境美輪美奐', '環境好']),
#  (('Malibu(二館)', 4), ['不是很好的環境', '偏酸']),
#  (('東京豚骨拉麵', 6), ['環境好', '不是很便宜', '重口味']),
#  (('Mr.wheat 小麥先生創意料理(新市創始店)', 7), []),
#  (('泰星球', 8), []),
#  (('金曜日咖哩專門店', 7), ['重口味']),
#  (('陳記真正紅燒土魠魚羹', 7), ['份量大']),
#  (('古早味蚵嗲', 3), []),
#  (('炸蛋蔥油餅', 6), ['小份量']),
#  (('鈺雪冰枝店', 7), []),
#  (('米藍花巷129異國料理餐廳', 7), ['不是很好的環境']),
#  (('Junkies打氣吧', 5), ['不是很便宜', '可能會有點缺點']),
#  (('旺德實驗室', 6), ['食物精緻漂亮']),
#  (('餵公子吃餅', 6), []),
#  (('Love Ice Cream 造型馬卡龍冰淇淋', 3), ['食物精緻漂亮', '偏甜', '偏酸']),
#  (('Felicità 費尼希卡義式冰淇淋', 7), []),
#  (('義麵愛PASTA LOVE', 7), ['食物精緻漂亮', '味道還算不錯', '食物美味']),
#  (('老胡記', 7), []),
#  (('廣成愛手工水果菓子棒', 1), ['食物很香']),
#  (('廚房有雞', 7), []),
#  (('席瑪朵咖啡烘培棧', 7), []),
#  (('昭和五五', 6), []),
#  (('鬼椒一番鍋(東門店)', 7), ['食物很香', '不錯的環境', '環境好']),
#  (('夏花司康茶屋', 6), ['環境好', '不是很便宜']),
#  (('安平陳記高粱黑豬肉香腸', 8), ['食物很香', '小份量', '不錯的環境', '環境好']),
#  (('小方舟串燒酒場', 6), ['不是很便宜']),
#  (('Mmm Brunch', 6), ['不錯的環境', '環境好']),
#  (('青森Dryad時尚餐廳', 7), ['味道還算不錯', '食物美味', '不錯的環境', '環境好', '服務還不賴', '服務好']),
#  (('麴町食堂兒玉傳統家庭料理', 5), []),
#  (('五號倉安平店', 4), ['食物精緻漂亮']),
#  (('io design studio', 8), ['服務還不賴']),
#  (('日光徐徐(成功店)', 7), []),
#  (('Hawaii Grill 夏威夷廚房', 5), []),
#  (('樂樂屋可樂餅專賣店', 6), ['食物精緻漂亮']),
#  (('AJ Brunch', 6), ['環境好', '不是很便宜']),
#  (('夏慕尼新香榭鐵板燒(台南公園店)', 8), ['很好吃', '食物美味', '食物很香', '環境好']),
#  (("L'avenue Cafe 拉芙尼咖啡", 5), []),
#  (('Curry+ Kitchen 誠欣廚房', 6), ['味道還算不錯', '食物美味', '食物很香', '不錯的環境', '環境好']),
#  (('瓏豐海鮮庭園式景觀餐廳', 7), ['味道還算不錯', '食物美味', '份量大']),
#  (('城邊真味炒鱔魚專家', 7), ['偏甜']),
#  (('上海華都小吃', 7), []),
#  (('劉家酸菜白肉鍋', 6), ['味道還算不錯', '食物美味', '不是很便宜', '環境好', '重口味']),
#  (('秀里蚵嗲', 6), ['味道還算不錯', '食物美味']),
#  (('台南東區焦糖煉乳包心粉圓(安平店)', 6), ['偏甜']),
#  (('水餃之家', 6), []),
#  (('らあめん花月嵐拉麵(台南新光西門店)', 7), ['重口味', '服務不是很好']),
#  (('阿川粉圓', 5), []),
#  (('海丘工作室/Pâtisserie seaknoll', 6), ['食物很香']),
#  (('阿美飯店', 4), []),
#  (('麻古茶坊', 7), ['很好吃', '食物美味', '不錯的環境', '環境好', '服務還不賴', '服務好']),
#  (('瘋牛排洋食', 6), []),
#  (('沾米廚房 Jami kitchen', 6), ['環境美輪美奐', '環境好']),
#  (('山林事務所', 7), []),
#  (('綠色空間(原怡平店)', 7), []),
#  (('東咔滋日式定食屋(原東日本料理)', 6), ['重口味']),
#  (('田媽媽下營鵝肉美食店', 7), []),
#  (('丹丹漢堡(成功店)', 7), []),
#  (('RÊVE Café 黑浮咖啡(台南永華店)', 6), ['環境好']),
#  (('浮游咖啡', 3), []),
#  (('芙烈達千層蛋糕', 6), ['不是很便宜']),
#  (('聖保羅烘焙花園(新營店)', 8), []),
#  (('疆疆串燒烤肉店', 6), []),
#  (('杏本善', 6), ['服務絕讚', '服務好']),
#  (('麗都大冰果', 3), []),
#  (('清閣水樓台南旗艦店(崇明總店)', 7), []),
#  (('鯨吞燒-精肉食堂(海安店)', 3), []),
#  (('Takeat 輕享原食', 8),
#   ['味道還算不錯', '食物美味', '小份量', '食物精緻漂亮', '食物很香', '偏辣', '不錯的環境', '環境好']),
#  (('來享鮮餐廳', 7), ['味道還算不錯', '食物美味', '食物很香', '服務絕讚', '服務好']),
#  (('阿元麵館', 7), []),
#  (('藍屋日本料理(南紡夢時代)', 9), ['不錯的環境', '環境好', '不是很便宜']),
#  (('ZiZA咖啡', 7), []),
#  (('滿福亭 まんぷくてい', 5), []),
#  (('豆腐花 DofuWhat', 5), []),
#  (('ICHIRO，ㄧ起囉！', 7), ['味道還算不錯', '食物美味', '食物很香', '不錯的環境', '環境好']),
#  (('Do - Li  BAKERY CAFE 多麗咖啡烘焙美食', 7), ['不是很便宜']),
#  (('饕公麻辣燙', 7), []),
#  (('福來伯臭豆腐', 6), ['味道還算不錯', '食物美味', '份量大']),
#  (('華味香鴨肉羹(第一店)', 6), ['不是很好的環境', '不是很便宜']),
#  (('瑪西達', 8), ['味道還算不錯', '食物美味', '食物很香']),
#  (('打翻泡菜 김치 엎어', 8), ['重口味']),
#  (('許家芋粿', 6), []),
#  (('比薩斜塔pizzastyle', 7), ['很好吃', '食物美味', '食物精緻漂亮', '偏辣', '重口味']),
#  (('綠麥田', 6), ['食物精緻漂亮', '小份量', '食物很香', '不錯的環境', '環境好']),
#  (('阿松臭豆腐', 7), ['小份量', '不是很好的環境', '不是很便宜']),
#  (('Mo-Mo-Paradise', 6), ['環境好', '重口味']),
#  (('橘象泰早安(台南永康店)', 7), []),
#  (('小西腳青草茶', 6), []),
#  (('格樓主題餐廳-Grimm House', 8),
#   ['食物精緻漂亮', '食物很香', '不錯的環境', '環境好', '服務絕讚', '服務好']),
#  (('府城藝術轉角', 5), []),
#  (('黃記鱔魚意麵', 6), ['小份量']),
#  (('餓魚咬冰', 6), ['食物精緻漂亮']),
#  (('花川日本料理', 7), []),
#  (('陳氏蚵捲', 8), []),
#  (('橫須賀海軍咖哩', 7), []),
#  (('金門館', 6), ['不是很便宜']),
#  (('羊城油雞', 7), ['不錯的環境', '環境好']),
#  (('水鳥和洋創作料理-府城店', 6), []),
#  (('大億麗緻-風尚庭園咖啡下午茶', 7), ['偏甜']),
#  (('奶控', 8), ['食物很香', '環境美輪美奐', '環境好']),
#  (('金帝元薑母鴨', 8), ['食物很香', '環境好']),
#  (('木銅咖啡屋', 3), []),
#  (('王記好吃雞肉便當', 5), []),
#  (('NO.17 Brunch table & More', 7), ['不錯的環境', '環境好']),
#  (('小石子義式廚房', 8), ['環境好']),
#  (('狐狸小屋', 5), []),
#  (('彩虹糖輕食義大利麵館', 6), ['食物很香', '小份量', '服務還不賴', '服務好', '偏辣']),
#  (('金站麻辣鍋', 6), ['味道還算不錯', '食物美味', '服務還不賴', '服務好', '環境好']),
#  (('烹大師涮涮鍋', 6), ['划算', '環境好', '服務還不賴', '服務好']),
#  (('台南艾咖啡', 6), []),
#  (('富士達人日本拉麵(東寧店)', 6), ['不是很便宜']),
#  (('Dreaming cafe 綺飛 法式甜點', 5), []),
#  (('蕎琪義大利麵', 6), ['環境好']),
#  (('井煲仔沙茶爐', 7),
#   ['食物精緻漂亮', '味道還算不錯', '食物美味', '很划算', '划算', '食物很香', '環境美輪美奐', '環境好']),
#  (('Pizza Hut 必勝客(台南南科店)', 7), []),
#  (('XM麻辣鍋(湖美旗艦店)', 7), ['食物精緻漂亮']),
#  (('Double Yummy', 6), []),
#  (('水工坊早餐咖啡屋', 6), []),
#  (('庵六花 京都濃咖哩專賣', 6), ['重口味']),
#  (('佳里韓春館한춘관', 7), []),
#  (('ORO(凱旋店)', 6), ['不錯的環境', '環境好']),
#  (('艾芙迪髮型沙龍咖啡 Aphrodite Cafe', 6), ['不錯的環境', '環境好', '不是很便宜']),
#  (('5號樹屋', 6), ['重口味', '不是很便宜']),
#  (('Mr. Deer', 6), ['味道還算不錯', '食物美味', '不錯的環境', '環境好']),
#  (('新化老攤雞蛋糕', 3), []),
#  (('多多巧思現烤蛋糕', 3), []),
#  (('哈根達斯 Häagen-Dazs(台南中山店)', 3), ['不是很便宜']),
#  (('陶板屋和風創作料理(台南勝利店)', 8), []),
#  (('關子嶺茶壺雞', 7), []),
#  (('萬客樓餐館', 6), []),
#  (('狗啃玉米', 7), ['食物很香']),
#  (('王城珍饌牛肉麵', 6), ['不是很便宜']),
#  (('1900 Café Focus in 生活文創(台南知事官邸)', 6), ['環境好']),
#  (('9分10刻 西式新料理(中正店)', 6), ['偏甜']),
#  (('布老虎廚房', 6), []),
#  (('關廟鳳梨酥', 6), []),
#  (('鴨桐伯薑母鴨', 3), []),
#  (('高麗館韓國料理', 5), ['不是很便宜']),
#  (('呷霸白北浮水魚羹', 7), []),
#  (('品田牧場(台南勝利店)', 7), ['偏甜', '服務還不賴', '服務好']),
#  (('喆發樂樂鍋', 7), ['很划算', '划算']),
#  (('湯婆婆拉麵', 6), []),
#  (('溫室烘焙屋(市府店)', 6), []),
#  (('BELLINI Pasta Pasta 貝里尼(台南夢時代店)', 7), []),
#  (('85度C咖啡蛋糕烘焙專賣店(台南北門店)', 6), []),
#  (('查理理查', 5), []),
#  (('CT Life X 小日子', 5), []),
#  (('小南碗粿', 5), []),
#  (('御私藏鮮奶茶專賣店(安平店)', 7), ['食物很香', '划算', '不錯的環境', '環境好']),
#  (('紙的部屋咖哩輕食', 6), []),
#  (('しゃぶしゃぶ温野菜日本涮涮鍋專門店Taiwan On-Yasai', 7),
#   ['食物很香', '不錯的環境', '環境好', '服務還不賴', '服務好']),
#  (('喜茶咖啡Season cafe', 6), []),
#  (('Tra di noi 塔蒂諾', 4), ['食物很香']),
#  (('台南 秘氏咖啡', 5), []),
#  (('勝利路西.B', 4), []),
#  (('神田のLa Vie 風格誌', 6), ['食物精緻漂亮']),
#  (('聖記軟骨飯專賣店', 5), []),
#  (('尊客平價牛排(中華店)', 6), ['非常便宜', '划算', '環境好']),
#  (('慶中街綠豆湯', 6), ['偏甜', '不是很便宜']),
#  (('韓金婆婆食品行(育賢店)', 6), ['食物很香', '偏甜']),
#  (('比薩茶坊', 6), ['不是很便宜', '不是很好的環境']),
#  (('淙泉雪花冰', 5), []),
#  (('阿福羊肉', 6), ['服務還不賴', '服務好']),
#  (('夏帕焗烤專賣(台南夢時代店)', 6), ['不錯的環境', '環境好']),
#  (('咖啡平方隨行吧(崇德店)', 6), ['很划算', '划算', '食物很香', '不錯的環境', '環境好']),
#  (('小銅鍋咖啡館(新光小西門店)', 4), []),
#  (('東城麵家', 5), []),
#  (('OILILY CAFE', 6), []),
#  (('府城夯也(仁德總店)', 3), []),
#  (('吉藏日本料理', 5), ['服務不是很好']),
#  ...]

# %%
from notebook.auth import passwd
passwd()
# Out:
# Enter password: ········
# Verify password: ········
# 'sha1:c5c7bd492be9:5fe71327c3ce8af924cd98373fb1509edee00c38'
