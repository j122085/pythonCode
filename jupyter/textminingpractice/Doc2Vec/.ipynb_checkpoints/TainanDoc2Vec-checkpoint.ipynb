# %% [markdown]
# # try doc2vec

# %%
# model = Doc2Vec(contentcutlist, size=100, window=8, min_count=5, workers=4)
import pandas as pd
import numpy as np
import jieba
#改為中文繁體字典,預設是簡體，可到jieba的GitHub下載
jieba.set_dictionary(r'D:\WordLibrary\JiebaUse\jieba_dict.txt.big') 
from wordcloud import WordCloud
import random
import json

# %%
with open(r"D:\Data\JsonData\TainanFood\bigtable_1.3.json") as f:
    BigAnalyzeTable=json.load(f)

# %%
def StopWdFilter(user_input, stop_words):
    """Sanitize using intersection and list.remove()"""
    # Downsides:
    #   - Looping over list while removing from it?
    #     http://stackoverflow.com/questions/1207406/remove-items-from-a-list-while-iterating-in-python
    stop_words = set()
    with open('D:/WordLibrary/JiebaUse/stopwords.txt', 'r', encoding='utf-8') as sw:
        for line in sw:
            stop_words.add(line.strip('\n'))
    for sw in stop_words.intersection(user_input):
        while sw in user_input:
            user_input.remove(sw)

    return user_input

# %%
def CutWithFilter(CorpusList):
    result=[]
    for y in [jieba.cut(x) for x in CorpusList]:
        content = StopWdFilter([ _ for _ in y], stopwords)
        result.append(content)
    return result
#所以我選擇所過濾的是跟「文意」比較無關的符號
stopwords = ['〔','〕','／','（','）','「','」','『','』','\n','nan']
#像下面這種比較是傳統文字探勘在過濾字詞可能過濾的一些字詞
#stopwords = ['〔','〕','／','（','）','「','」','『','』','的','就是','這個','可以','一定'\
#             ,'一個','nan','沒有','我們','不是','不用','不是','自己','只要','大家','覺得','因為'\
#             ,'對於','起來','如果','每個','很多','一樣','時候','加上','使用','只是']

# %%
#只留下店名跟文章做分類分析
FoodArticle=[{'name':dien["name"],'content':"".join(dien['contentcut'].split(" "))} for dien in BigAnalyzeTable]

# %%
FoodArticle[0]
# Out:
# {'content': '簡單傳統安平豆花純白豆花特別挑逗胃口安平兼具台南傳統現代一個區域而作安平代表傳統美食一如所知安平豆花周氏蝦捲今天帶點炎熱天氣來點清涼降火冰品好日子喊豆花消暑吃安平豆花最著名光是在安平兩個店面相距公里左右今天來到總店平日下午但店一副忙碌景象剛有客人離開趕緊搶佔一桌店內用原木大張長桌長椅古風牆上擺這些年來到過安平豆花名人真的安平已經四十多年歷史取名記是最早創始人黃慶同名字中有個同字推車一路叫賣現在成為台南十大傳統名產艱辛不足外人道知道跳過年成立店面後原本稱呼安平豆花正式掛上同記前綴安平區的豆花店逐漸變只要說安平豆花知道指說快快來點豆花種類道道經典選最正宗最傳統紅豆豆花綠豆豆花一碗古法精製非基因改造有機黃豆製作光看成色令人心動紅豆部分則是來自屏東萬丹極品紅豆數小時熬煮後最佳紅豆香氣呈現眼前好吃加點一碗紅豆豆花每顆紅豆保持完整外觀入口口感說一口豆花口感軟嫩細緻入口傳統黃豆香氣手工製作洋菜粉勾芡口感綠豆豆花軟透心綠豆外搭著嫩豆花微甜甘蔗糖水一起入口高雅芬芳猶如咖啡館享用下午茶好吃豆花來到安平錯過老街逛累順便來碗冰涼透心豆花真是享受總店台南市安平區安北路來到台南試試這家老字號豆花店古早味有名一家店裡面人懂覺得吃店差別拉舌頭頓老字號自然歷史悠久�
# ...                         ...
# 5738                  樂雞蛋糕(安平店)
# 5739               達也濱家漁場 安平旗艦店
# 5740               麻辣風暴小燒鍋(歸仁店)
# 5741              料理是實 Is Truth
# 5742     945夯海鮮燒烤(945夯海鮮燒烤 海安店)
# 5743                     泰奶yo吐司
# 5744                 台南蔡二代鮮魚湯專賣
# 5745                     阿欣越式料理
# 5746     The Breakfast Club 小餐事
# 5747                         日十
# 5748                       轉角抓餅
# 5749       濰克早午餐 Wake Up Brunch
# 5750                   水龜伯豆花學甲店
# 5751                      屋麵うめえ
# 5752       98 tea cafe((台南南門店))
# 5753                Principe 玩藝
# 5754                     志倫甕烤地瓜
# 5755                  昭和九十八 居酒屋
# 5756           晨吉司漢肉排蛋吐司(新市中興店)
# 5757           Walking Su 藥膳麻油雞
# 5758  食べオム。ta be o mu 洋食歐姆蓋飯專賣店
# 5759                         開味
# 5760                    京享平價鐵板燒
# 5761                     廟口麵線餡餅
# 5762                   Bow屋-犬掌燒
# 5763                麻花重慶火鍋(善化店)
# 5764             布莉克手工冰棒 gogo胖卡
# 5765           高原村長天池咖啡園 村長莊園咖啡
# 5766                     村長莊園咖啡
# 5767                      大福涮涮鍋
#
# [5768 rows x 2 columns]

# %%
Food = Food_df.name+ " " + Food_df.content

# %%
Food
# Out:
# 0       同記安平豆花(安平總店) 簡單傳統安平豆花純白豆花特別挑逗胃口安平兼具台南傳統現代一個區域而...
# 1       深藍咖啡館 原文台南東區號稱蛋糕界千層蛋糕大人口味黑森林蛋糕早茶在當貴婦普普時尚風格超像藝文...
# 2       阿堂鹹粥 店家資訊電話地址台南市西門路一段營業時間每週公休總評美味程度值服務品質空間舒適再訪...
# 3       富盛號碗粿 台南中西排隊美食手工平民美食來到台南永樂市場好吃美食沒話說這次介紹這家許多部落客...
# 4       依蕾特布丁奶酪(安平門市) 最近感覺真是吹起一股抹茶旋風嵐推出抹茶飲品後蠻多店家紛紛推出抹茶...
# 5       食下有約 想法廚房 天氣冷吃個鍋內容比較一篇介紹無餐點本篇介紹花雕鍋有別於之前吃蹄膀雞肉這次...
# 6       飛饗創意西式料理 飛饗義法典藏料理旗艦總店週日上班日下班美食好好犒賞同事跑飛饗義法典藏料理吃...
# 7       莉莉水果店 台南美食特別傳統美食歷久不衰今天拜訪開一甲子老牌水果店中午人潮真的滿多一堆慕名而...
# 8       連得堂餅舖 台南火車站前站出發走路分鐘即可抵達當天只家人小妹依稀記憶親切老闆娘電話中提醒很快...
# 9       矮仔成蝦仁飯 店家資訊地址台南市中西區海安路一段開放時間星期三星期一星期二公休電話總評美味程...
# 10      泰成水果店 吃完霜淇淋再對面傳統水果行店使用人超多併桌翻桌率很快不用太久門口擺滿各式各樣新鮮...
# 11      騷烤家(前鋒總店) 之前住日木本來騷烤家吃晚餐當天組部落客約約喬喬昨天終於阿熊吃騷烤家火車站...
# 12      阿松割包 台南中西排隊美食市場小吃排隊美食介紹完忘掉對面割包特別特別食材夠新鮮簡單只賣三種普...
# 13      秉醇烘焙坊 說手工餅乾一定第一個想到秉醇以前團購送人好吃體面價格還算合理台北目前都還沒找到比...
#  '安平',
#  '豆花',
#  '純白',
#  '豆花',
#  '特別',
#  '挑逗',
#  '胃口',
#  '安平',
#  '兼具',
#  '台南',
#  '傳統',
#  '現代',
#  '一個',
#  '區域',
#  '而作',
#  '安平',
#  '代表',
#  '傳統',
#  '美食',
#  '一如',
#  '所知',
#  '安平',
#  '豆花',
#  '周氏',
#  '蝦捲',
#  '今天',
#  '帶點',
#  '炎熱',
#  '天氣',
#  '來點',
#  '清涼',
#  '降火',
#  '冰品',
#  '好日子',
#  '喊',
#  '豆花',
#  '消暑',
#  '吃',
#  '安平',
#  '豆花',
#  '最',
#  '著名',
#  '光是在',
#  '安平',
#  '兩個',
#  '店面',
#  '相距',
#  '公里',
#  '左右',
#  '今天',
#  '來到',
#  '總店',
#  '平日',
#  '下午',
#  '但店',
#  '一副',
#  '忙碌',
#  '景象',
#  '剛有',
#  '客人',
#  '離開',
#  '趕緊',
#  '搶佔',
#  '一桌',
#  '店內用',
#  '原木',
#  '大張',
#  '長桌',
#  '長椅',
#  '古風',
#  '牆上',
#  '擺',
#  '年',
#  '來到',
#  '安平',
#  '豆花',
#  '名人',
#  '真的',
#  '安平',
#  '已經',
#  '四十多年',
#  '歷史',
#  '取名',
#  '記是',
#  '最早',
#  '創始人',
#  '黃',
#  '慶同',
#  '名字',
#  '中有個',
#  '同字',
#  '推車',
#  '一路',
#  '叫賣',
#  '現在',
#  '成為',
#  '台南',
#  '十大',
#  '傳統',
#  '名產',
#  '艱辛',
#  '不足',
#  '外人道',
#  '知道',
#  '跳',
#  '過年',
#  '成立',
#  '店面',
#  '後',
#  '原本',
#  '稱呼',
#  '安平',
#  '豆花',
#  '正式',
#  '掛上',
#  '同記',
#  '前綴',
#  '安平',
#  '區的',
#  '豆花',
#  '店逐',
#  '漸變',
#  '只',
#  '要說',
#  '安平',
#  '豆花',
#  '知道',
#  '指說',
#  '快快',
#  '來點',
#  '豆花',
#  '種類',
#  '道',
#  '道',
#  '經典',
#  '選',
#  '最',
#  '正宗',
#  '最',
#  '傳統',
#  '紅豆',
#  '豆花',
#  '綠豆',
#  '豆花',
#  '一碗',
#  '古法',
#  '精製',
#  '非',
#  '基因',
#  '改造',
#  '有機',
#  '黃豆',
#  '製作',
#  '光看',
#  '成色',
#  '令人',
#  '心動',
#  '紅豆',
#  '部',
#  '分則',
#  '來自',
#  '屏東',
#  '萬丹',
#  '極品',
#  '紅豆',
#  '數',
#  '小時',
#  '熬',
#  '煮',
#  '後',
#  '最佳',
#  '紅豆',
#  '香氣',
#  '呈現',
#  '眼前',
#  '好吃',
#  '加點',
#  '一碗',
#  '紅豆',
#  '豆花',
#  '每顆',
#  '紅豆',
#  '保持',
#  '完整',
#  '外觀',
#  '入口',
#  '口感',
#  '說',
#  '一口',
#  '豆花',
#  '口感',
#  '軟嫩',
#  '細緻',
#  '入口',
#  '傳統',
#  '黃豆',
#  '香氣',
#  '手工',
#  '製作',
#  '洋菜',
#  '粉',
#  '勾芡',
#  '口感',
#  '綠豆',
#  '豆花',
#  '軟',
#  '透心',
#  '綠豆',
#  '外',
#  '搭',
#  '著嫩',
#  '豆花',
#  '微甜',
#  '甘蔗',
#  '糖水',
#  '一起',
#  '入口',
#  '高雅',
#  '芬芳',
#  '猶如',
#  '咖啡館',
#  '享用',
#  '下午茶',
#  '好吃',
#  '豆花',
#  '來到',
#  '安平',
#  '錯過',
#  '老街',
#  '逛累',
#  '順便來',
#  '碗',
#  '冰涼',
#  '透心',
#  '豆花',
#  '真是',
#  '享受',
#  '總店',
#  '台南市',
#  '安平',
#  '區安',
#  '北路',
#  '來到',
#  '台南',
#  '試試',
#  '這家',
#  '老字號',
#  '豆花',
#  '店古',
#  '早味',
#  '有名',
#  '一家',
#  '店裡面',
#  '人',
#  '懂',
#  '覺得',
#  '吃店',
#  '差別',
#  '拉',
#  '舌頭',
#  '頓',
#  '老字號',
#  '自然',
#  '歷史悠久',
#  '牆上',
#  '掛滿',
#  '名',
#  '料配',
#  '豆',
#  '花點',
#  '紅豆',
#  '小',
#  '珍珠',
#  '綠豆',
#  '豆花',
#  '很軟',
#  '入口',
#  '即化',
#  '湯',
#  '特別',
#  '甜',
#  '這家',
#  '地人',
#  '推薦',
#  '安平',
#  '豆花',
#  '喔',
#  '老字號',
#  '豆花',
#  '要來',
#  '嘗試',
#  '下',
#  '炎熱',
#  '天氣',
#  '裡最',
#  '需要',
#  '碗',
#  '甜品',
#  '這天',
#  '平日',
#  '暑假',
#  '店裡',
#  '人來',
#  '朝聖',
#  '牆上',
#  '滿滿的',
#  '照片',
#  '多名',
#  '人',
#  '電視',
#  '專訪',
#  '喔',
#  '這間',
#  '真的',
#  '夯',
#  '喔',
#  '這是',
#  '吃',
#  '珍珠',
#  '豆花',
#  '珍珠',
#  '超級',
#  '無敵',
#  '小顆',
#  '外面',
#  '飲料',
#  '小',
#  '珍珠',
#  '還小顆',
#  '吃',
#  '沒什麼',
#  '口感',
#  '有點',
#  '可惜',
#  '豆花',
#  '吃',
#  '滑',
#  '嫩',
#  '豆味',
#  '滿香',
#  '整體',
#  '吃還',
#  '不錯',
#  '這間',
#  '電視',
#  '好',
#  '幾次',
#  '周記',
#  '安平',
#  '豆花',
#  '老婆',
#  '台南',
#  '唸書',
#  '時吃過',
#  '好',
#  '幾次',
#  '第一次',
#  '造訪',
#  '充滿',
#  '人潮',
#  '人氣',
#  '豆花',
#  '店',
#  '酷熱',
#  '吃',
#  '一點',
#  '豆花',
#  '好',
#  '消暑',
#  '左豪痞',
#  '客邦',
#  '吃吃喝喝',
#  '左豪',
#  '粉絲團',
#  '歡樂',
#  '台南美食',
#  '整理',
#  '區',
#  '南部',
#  '旅遊',
#  '整理',
#  '區分',
#  '內用區',
#  '外帶',
#  '區',
#  '豆花',
#  '主要',
#  '原味',
#  '紅豆',
#  '綠豆',
#  '珍珠',
#  '檸檬',
#  '豆花',
#  '賣',
#  '豆花',
#  '賣',
#  '二樓',
#  '真的',
#  '生意',
#  '驚人',
#  '好還',
#  '下午',
#  '高朋滿座',
#  '牆上',
#  '好多',
#  '名人',
#  '合照',
#  '店裡面',
#  '人太多',
#  '沒靠',
#  '過去',
#  '冷氣',
#  '二樓',
#  '建議',
#  '有點',
#  '麵',
#  '食者',
#  '坐',
#  '一樓',
#  '方便',
#  '麵',
#  '二樓',
#  '坐位',
#  '區',
#  '豆花',
#  '圖片',
#  '有分',
#  '黃豆',
#  '黑豆',
#  '兩種',
#  '豆花',
#  '一律',
#  '元',
#  '統一價',
#  '賣',
#  '鮮奶',
#  '豆花',
#  '則賣元',
#  '外帶',
#  '區也',
#  '一杯',
#  '一杯',
#  '賣點',
#  '三種',
#  '豆花',
#  '解解',
#  '酷熱',
#  '珍珠',
#  '豆花',
#  '紅豆',
#  '豆花',
#  '珍珠',
#  '豆花',
#  '元',
#  '豆花',
#  '又稱',
#  '作',
#  '豆腐腦',
#  '豆漿',
#  '凝固',
#  '成果',
#  '凍狀',
#  '珍珠',
#  '波霸',
#  '珍珠粉',
#  '圓',
#  '那種',
#  '小巧',
#  '可愛',
#  '珍珠',
#  '豆花',
#  '吃',
#  '比較',
#  '細膩',
#  '不像',
#  '吃',
#  '比較',
#  '粗澀',
#  '粉圓',
#  '覺得',
#  '再給',
#  '多一點',
#  '紅豆',
#  '豆花',
#  '元',
#  '紅豆',
#  '香甜',
#  '燉',
#  '軟爛',
#  '紅豆',
#  '還蠻',
#  '愛的',
#  '糖水',
#  '不會太甜',
#  '人氣',
#  '小吃',
#  '同記',
#  '豆花',
#  '吃',
#  '淡淡的',
#  '黃豆',
#  '味',
#  '兩種',
#  '豆花',
#  '覺得',
#  '紅豆',
#  '表現',
#  '比珠珍',
#  '香氣',
#  '感覺',
#  '檸檬',
#  '豆花',
#  '人',
#  '吃',
#  '來到',
#  '安平',
#  '吃',
#  '豆花',
#  '歇腳',
#  '一下',
#  '店家',
#  '名稱',
#  '安平',
#  '總店',
#  '店家',
#  '地址',
#  '臺南市',
#  '安平',
#  '區安',
#  '北路',
#  '店家',
#  '電話',
#  '營業時間',
#  '台南美食',
#  '旅遊',
#  '相關',
#  '連結',
#  '台南美食',
#  '整理',
#  '區',
#  '南部',
#  '旅遊',
#  '整理',
#  '區',
#  '肚子餓',
#  '嘰哩咕嚕',
#  '來到',
#  '安平',
#  '豆花',
#  '咧昭瑢',
#  '說裡面',
#  '賣',
#  '好吃',
#  '咧',
#  '哄',
#  '豆尼還',
#  '知道',
#  '發現',
#  '吃',
#  '豆花',
#  '數人',
#  '已經',
#  '點了',
#  '人潮',
#  '依然',
#  '強強',
#  '滾',
#  '先來',
#  '找',
#  '位置',
#  '坐',
#  '下來',
#  '小孩',
#  '餓',
#  '只',
#  '想',
#  '吃',
#  '冰牛奶',
#  '雪花',
#  '冰雪',
#  '花冰',
#  '選種',
#  '配料',
#  '小朱',
#  '朱',
#  '草莓',
#  '煉乳',
#  '家',
#  '隻',
#  '小鬼',
#  '珍珠',
#  '煉乳',
#  '大人',
#  '不約而同',
#  '選擇',
#  '珍珠',
#  '豆花',
#  '媽',
#  '喜歡',
#  '口感',
#  '小',
#  '珍珠',
#  '安平',
#  '豆花',
#  '旁松霖',
#  '茶坊',
#  '賣',
#  '飲料',
#  '這家',
#  '安平',
#  '豆花',
#  '老闆',
#  '小孩',
#  '開吃',
#  '豆花',
#  '吃',
#  '飽飽',
#  '好多',
#  '鍋',
#  '一起',
#  '煮',
#  '大碗',
#  '記得',
#  '好像',
#  '元料',
#  '好多',
#  '感覺',
#  '超',
#  '便宜',
#  '鍋燒',
#  '烏龍',
#  '裡',
#  '面料',
#  '有蛋',
#  '蛤蜊',
#  '菜',
#  '蟹肉',
#  '棒',
#  '火腿',
#  '片',
#  '值得',
#  '推薦',
#  '肉',
#  '感覺',
#  '加',
#  '黑胡椒',
#  '醃過',
#  '肉',
#  '吃',
#  '嫩',
#  '淡淡的',
#  '胡椒',
#  '味',
#  '口味',
#  '超',
#  '特別',
#  '湯頭',
#  '超',
#  '好喝',
#  '下',
#  '一次',
#  '安平',
#  '豆花',
#  '一種',
#  '選擇',
#  '台南市',
#  '安平',
#  '區安',
#  '北路',
#  '營業時間',
#  '安',
#  '平安',
#  '平總有',
#  '一種',
#  '糾結',
#  '感',
#  '有限',
#  '胃囊裡',
#  '抉擇',
#  '周記',
#  '蝦捲',
#  '吃',
#  '布丁',
#  '豆花',
#  '最具',
#  '代表',
#  '老店',
#  '這次',
#  '特別',
#  '來到',
#  '比較',
#  '偏僻',
#  '總店',
#  '吃點',
#  '多來',
#  '沒什麼',
#  '人',
#  '位置',
#  '超',
#  '多點',
#  '一個',
#  '豆花',
#  '元',
#  '創辦人',
#  '故事',
#  '贅述',
#  '這面',
#  '牆',
#  '知道',
#  '晚近',
#  '報導',
#  '已經',
#  '根本',
#  '傳統',
#  '豆花',
#  '金黃',
#  '糖水',
#  '糖水',
#  '味道',
#  '寧夏',
#  '豆花',
#  '莊',
#  '加冰',
#  '偏甜',
#  '南部',
#  '豆花',
#  '豆',
#  '花香',
#  '豆花',
#  '超嫩',
#  '外',
#  '一種',
#  '綿感',
#  '扁桃腺',
#  '發言',
#  '一府',
#  '二鹿',
#  '艋',
#  '舺',
#  '府城',
#  '舊',
#  '街巷',
#  '年輕人',
#  '艋',
#  '舺',
#  '新',
#  '公園',
#  '老傢伙',
#  '故事',
#  '土溝村',
#  '幾米',
#  '早上',
#  '六點',
#  '出門',
#  '現在',
#  '餓渴',
#  '土溝村',
#  '食物',
#  '吸引',
#  '估狗',
#  '搜尋',
#  '只',
#  '找到',
#  '醬鴨',
#  '工廠',
#  '女兒',
#  '問啥',
#  '醬鴨',
#  '說',
#  '杭州',
#  '爸爸',
#  '點過',
#  '好吃',
#  '外地人',
#  '後',
#  '壁',
#  '找',
#  '不到',
#  '東西',
#  '吃',
#  '父女倆',
#  '打算',
#  '買',
#  '醬鴨',
#  '吞餓',
#  '堅持',
#  '吃',
#  '小',
#  '父女',
#  '派',
#  '說',
#  '台南',
#  '吃',
#  '小七是',
#  '膚淺',
#  '行為',
#  '兩派',
#  '相爭',
#  '小七吃',
#  '老街',
#  '飯店',
#  '下落',
#  '中午',
#  '開張',
#  '割稻',
#  '飯',
#  '還煮',
#  '割稻',
#  '飯後',
#  '壁',
#  '真的',
#  '需要',
#  '早',
#  '午餐',
#  '只好',
#  '新營',
#  '方向',
#  '邊找',
#  '路邊',
#  '找',
#  '吃',
#  '最後',
#  '新營',
#  '交流',
#  '道',
#  '前',
#  '知名',
#  '市場',
#  '吃',
#  '碗粿',
#  '肉',
#  '粽配',
#  '豬血',
#  '湯及',
#  '排骨',
#  '酥',
#  '兩方',
#  '皆大歡喜',
#  '重點',
#  '是點',
#  '五樣',
#  '超過',
#  '一百',
#  '台南',
#  '物價',
#  '有夠',
#  '便宜',
#  '高速公路',
#  '沒多久',
#  '一下',
#  '看到',
#  '麻豆',
#  '交流',
#  '道',
#  '堅持',
#  '再補',
#  '一碗',
#  '正宗',
#  '麻豆',
#  '碗粿',
#  '如上圖',
#  '點了',
#  '兩碗',
#  '碗粿',
#  '蘭加',
#  '虱目',
#  '魚丸湯',
#  '甘願',
#  '魚丸湯',
#  '菜',
#  '嫌',
#  '虱目',
#  '魚',
#  '體味',
#  '太重',
#  '一個',
#  '早餐',
#  '吃',
#  '兩碗',
#  '也夠',
#  '晚餐',
#  '同事',
#  '說',
#  '台南',
#  '發現',
#  '胃',
#  '不夠',
#  '真的',
#  '台南小吃',
#  '卻',
#  '碗粿',
#  '餵',
#  '撐',
#  '何以',
#  '前',
#  '吃',
#  '阿蘭',
#  '碗粿',
#  '卻',
#  '變成',
#  '碗粿',
#  '蘭',
#  '一部',
#  '南部',
#  '人',
#  '愛看',
#  '世間',
#  '情',
#  '劇情',
#  '細查',
#  '碗粿',
#  '蘭',
#  '附近',
#  '很多賣',
#  '白柚',
#  '水果攤',
#  '心動',
#  '旅途',
#  '總塞爆',
#  '後',
#  '車箱',
#  '碗粿',
#  '蘭',
#  '停車場',
#  '附近',
#  '飲料店',
#  '外帶',
#  '飲料',
#  '解膩',
#  '決明',
#  '茶',
#  '吸睛夠',
#  '特別',
#  '至少',
#  '別處',
#  '看過',
#  '解了',
#  '肚子餓',
#  '文化',
#  '之旅',
#  '第一站',
#  '黑',
#  '橋牌',
#  '香腸',
#  '博物館',
#  '這是',
#  '哪門子',
#  '文化',
#  '吃',
#  '文化',
#  '點',
#  '普通',
#  '時間',
#  '不多',
#  '跳過',
#  '台南',
#  '籍',
#  '同事',
#  '聽',
#  '笑',
#  '傻',
#  '台南小吃',
#  '眾多',
#  '黑',
#  '橋牌',
#  '找',
#  '吃',
#  '約',
#  '同學',
#  '安平',
#  '樹',
#  '屋前',
#  '碰面',
#  '心頭',
#  '好',
#  '兩家',
#  '人',
#  '相約',
#  '敘舊',
#  '同學',
#  '三歲',
#  '小女孩',
#  '愛吃',
#  '粉圓',
#  '人來瘋',
#  '看著',
#  '粉圓',
#  '吃進',
#  '嘴裡',
#  '再',
#  '一顆顆',
#  '吐出來',
#  ...]

# %% [markdown]
# # 6. 把gensim, Doc2Vec的套件匯入

# %%
import gensim
Lsent = gensim.models.doc2vec.LabeledSentence
def labelizeNews(food, label_type):
    labelized = []
    #enumertate include index
    for i, v in enumerate(food):
        label = '%s_%s' %(label_type,i)
        labelized.append(Lsent(v, [label]))
    return labelized


# for i,v in enumerate()
# i為流水號，1  2  3
# v為每篇文章的，第1個字全部  第2個字全部  第3個字全部
# label_type為type標籤
# labelized = []
# for i,v in enumerate(Food_List):
#     label = '%s_%s' %('Food',i)
#     labelized.append(Lsent(v, [label]))

# 將第一篇的文字全部上Food_1的標籤
# 將第二篇的文字全部上Food_2的標籤
# 以此類推
# Out:
# D:\Anaconda3\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.

# %% [markdown]
# # 7. 將每個的文章給一個標籤，方便分析完對應

# %%
Train_Food = labelizeNews(Food_List,'Food')

# %%
print(type(Train_Food))
print(type(Train_Food[1]))
Train_Food[0]#為上完標籤的gensimlabel＿
# Out:
# <class 'list'>
# <class 'gensim.models.doc2vec.LabeledSentence'>
# LabeledSentence(words=['同記', '安平', '豆花', '安平', '總店', ' ', '簡單', '傳統', '安平', '豆花', '純白', '豆花', '特別', '挑逗', '胃口', '安平', '兼具', '台南', '傳統', '現代', '一個', '區域', '而作', '安平', '代表', '傳統', '美食', '一如', '所知', '安平', '豆花', '周氏', '蝦捲', '今天', '帶點', '炎熱', '天氣', '來點', '清涼', '降火', '冰品', '好日子', '喊', '豆花', '消暑', '吃', '安平', '豆花', '最', '著名', '光是在', '安平', '兩個', '店面', '相距', '公里', '左右', '今天', '來到', '總店', '平日', '下午', '但店', '一副', '忙碌', '景象', '剛有', '客人', '離開', '趕緊', '搶佔', '一桌', '店內用', '原木', '大張', '長桌', '長椅', '古風', '牆上', '擺', '年', '來到', '安平', '豆花', '名人', '真的', '安平', '已經', '四十多年', '歷史', '取名', '記是', '最早', '創始人', '黃', '慶同', '名字', '中有個', '同字', '推車', '一路', '叫賣', '現在', '成為', '台南', '十大', '傳統', '名產', '艱辛', '不足', '外人道', '知道', '跳', '過年', '成立', '店面', '後', '原本', '稱呼', '安平', '豆花', '正式', '掛上', '同記', '前綴', '安平', '區的', '豆花', '店逐', '漸變', '只', '要說', '安平', '豆花', '知道', '指說', '快快', '來點', '豆花', '種類', '道', '道', '經典', '選', '最', '正宗', '最', '傳統', '紅豆', '豆花', '綠豆', '豆花', '一碗', '古法', '精製', '非', '基因', '改造', '有機', '黃豆', '製作', '光看', '成色', '令人', '心動', '紅豆', '部', '分則', '來自', '屏東', '萬丹', '極品', '紅豆', '數', '小時', '熬', '煮', '後', '最佳', '紅豆', '香氣', '呈現', '眼前', '好吃', '加點', '一碗', '紅豆', '豆花', '每顆', '紅豆', '保持', '完整', '外觀', '入口', '口感', '說', '一口', '豆花', '口感', '軟嫩', '細緻', '入口', '傳統', '黃豆', '香氣', '手工', '製作', '洋菜', '粉', '勾芡', '口感', '綠豆', '豆花', '軟', '透心', '綠豆', '外', '搭', '著嫩', '豆花', '微甜', '甘蔗', '糖水', '一起', '入口', '高雅', '芬芳', '猶如', '咖啡館', '享用', '下午茶', '好吃', '豆花', '來到', '安平', '錯過', '老街', '逛累', '順便來', '碗', '冰涼', '透心', '豆花', '真是', '享受', '總店', '台南市', '安平', '區安', '北路', '來到', '台南', '試試', '這家', '老字號', '豆花', '店古', '早味', '有名', '一家', '店裡面', '人', '懂', '覺得', '吃店', '差別', '拉', '舌頭', '頓', '老字號', '自然', '歷史悠久', '牆上', '掛滿', '名', '料配', '豆', '花點', '紅豆', '小', '珍珠', '綠豆', '豆花', '很軟', '入口', '即化', '湯', '特別', '甜', '這家', '地人', '推薦', '安平', '豆花', '喔', '老字號', '豆花', '要來', '嘗試', '下', '炎熱', '天氣', '裡最', '需要', '碗', '甜品', '這天', '平日', '暑假', '店裡', '人來', '朝聖', '牆上', '滿滿的', '照片', '多名', '人', '電視', '專訪', '喔', '這間', '真的', '夯', '喔', '這是', '吃', '珍珠', '豆花', '珍珠', '超級', '無敵', '小顆', '外面', '飲料', '小', '珍珠', '還小顆', '吃', '沒什麼', '口感', '有點', '可惜', '豆花', '吃', '滑', '嫩', '豆味', '滿香', '整體', '吃還', '不錯', '這間', '電視', '好', '幾次', '周記', '安平', '豆花', '老婆', '台南', '唸書', '時吃過', '好', '幾次', '第一次', '造訪', '充滿', '人潮', '人氣', '豆花', '店', '酷熱', '吃', '一點', '豆花', '好', '消暑', '左豪痞', '客邦', '吃吃喝喝', '左豪', '粉絲團', '歡樂', '台南美食', '整理', '區', '南部', '旅遊', '整理', '區分', '內用區', '外帶', '區', '豆花', '主要', '原味', '紅豆', '綠豆', '珍珠', '檸檬', '豆花', '賣', '豆花', '賣', '二樓', '真的', '生意', '驚人', '好還', '下午', '高朋滿座', '牆上', '好多', '名人', '合照', '店裡面', '人太多', '沒靠', '過去', '冷氣', '二樓', '建議', '有點', '麵', '食者', '坐', '一樓', '方便', '麵', '二樓', '坐位', '區', '豆花', '圖片', '有分', '黃豆', '黑豆', '兩種', '豆花', '一律', '元', '統一價', '賣', '鮮奶', '豆花', '則賣元', '外帶', '區也', '一杯', '一杯', '賣點', '三種', '豆花', '解解', '酷熱', '珍珠', '豆花', '紅豆', '豆花', '珍珠', '豆花', '元', '豆花', '又稱', '作', '豆腐腦', '豆漿', '凝固', '成果', '凍狀', '珍珠', '波霸', '珍珠粉', '圓', '那種', '小巧', '可愛', '珍珠', '豆花', '吃', '比較', '細膩', '不像', '吃', '比較', '粗澀', '粉圓', '覺得', '再給', '多一點', '紅豆', '豆花', '元', '紅豆', '香甜', '燉', '軟爛', '紅豆', '還蠻', '愛的', '糖水', '不會太甜', '人氣', '小吃', '同記', '豆花', '吃', '淡淡的', '黃豆', '味', '兩種', '豆花', '覺得', '紅豆', '表現', '比珠珍', '香氣', '感覺', '檸檬', '豆花', '人', '吃', '來到', '安平', '吃', '豆花', '歇腳', '一下', '店家', '名稱', '安平', '總店', '店家', '地址', '臺南市', '安平', '區安', '北路', '店家', '電話', '營業時間', '台南美食', '旅遊', '相關', '連結', '台南美食', '整理', '區', '南部', '旅遊', '整理', '區', '肚子餓', '嘰哩咕嚕', '來到', '安平', '豆花', '咧昭瑢', '說裡面', '賣', '好吃', '咧', '哄', '豆尼還', '知道', '發現', '吃', '豆花', '數人', '已經', '點了', '人潮', '依然', '強強', '滾', '先來', '找', '位置', '坐', '下來', '小孩', '餓', '只', '想', '吃', '冰牛奶', '雪花', '冰雪', '花冰', '選種', '配料', '小朱', '朱', '草莓', '煉乳', '家', '隻', '小鬼', '珍珠', '煉乳', '大人', '不約而同', '選擇', '珍珠', '豆花', '媽', '喜歡', '口感', '小', '珍珠', '安平', '豆花', '旁松霖', '茶坊', '賣', '飲料', '這家', '安平', '豆花', '老闆', '小孩', '開吃', '豆花', '吃', '飽飽', '好多', '鍋', '一起', '煮', '大碗', '記得', '好像', '元料', '好多', '感覺', '超', '便宜', '鍋燒', '烏龍', '裡', '面料', '有蛋', '蛤蜊', '菜', '蟹肉', '棒', '火腿', '片', '值得', '推薦', '肉', '感覺', '加', '黑胡椒', '醃過', '肉', '吃', '嫩', '淡淡的', '胡椒', '味', '口味', '超', '特別', '湯頭', '超', '好喝', '下', '一次', '安平', '豆花', ' ...

# %% [markdown]
# # 設定Doc2Vec參數 (使用seed or save model 來排除訓練的隨機成分，如果需要每次的向量結果相同 每一個Corpus產出400維的向量，預設使用3個核心做運算

# %%
size = 400   
model_dm = gensim.models.Doc2Vec(min_count=1, window=10, size=size, sample=1e-3, negative=5, workers=3)
model_dbow = gensim.models.Doc2Vec(min_count=1, window=10, size=size, sample=1e-3, negative=5,dm=0, workers=3)

# %% [markdown]
# # 由有順序的句子建立model詞彙(讓model讀懂用的) 輸入的資料必須是((文章的有順序斷詞list)的list)

# %%
model_dm.build_vocab(Train_Food)
model_dbow.build_vocab(Train_Food)

# %% [markdown]
# # 訓練十次，每次隨機交換文章順序 (由於是隨機, 要每次結果完全相同也可以固定訓練次序)

# %%
for epoch in range(10):
    
    #總共幾篇文章(假設225) 對1~225做隨機排序的array
    perm = np.random.permutation(len(Train_Food))
    
    #將所有的文章隨機順序丟進去訓練 並告知model 共有225個example  5種時?
    model_dm.train([Train_Food[x] for x in perm],total_examples=model_dm.corpus_count,epochs=model_dm.iter)
    model_dbow.train([Train_Food[x] for x in perm],total_examples=model_dbow.corpus_count,epochs=model_dbow.iter)

# %%
perm
# Out:
# array([ 865, 5473, 4091, ..., 1530, 1063, 2479])

# %% [markdown]
# # 可以把模型存起來，下次直接取回向量

# %%
model_dm.save('D:/Data/doc2verData/model_dm')
model_dbow.save('D:/Data/doc2verData/model_dbow')

# %% [markdown]
# # 取出文章向量

# %%
def getVecs(model, corpus, size):
    #取出每一個tag(Eat_1.Eat_2...Ser_1.Ser_2....)的向量(docvecs)，並將向量長度全都變成400size
    vecs = [model.docvecs[z.tags[0]].reshape((1, size)) for z in corpus]
    
    return np.concatenate(vecs)

# %%
np.concatenate(model_dm.docvecs['Food_3'].reshape((1, 400)))
# Out:
# array([-1.36936986,  1.21071887, -2.79744244, -1.17583144,  0.06174225,
#        -3.58881712, -0.30412006, -2.40377307, -2.97899199,  0.22537233,
#        -0.76932871,  1.30588984,  0.43718785, -3.53362727,  0.6061371 ,
#         2.77494693,  0.23301212, -2.40291691, -0.50604594, -2.90309072,
#         2.55313897,  1.45795596, -1.70637155,  1.45439768, -1.3176595 ,
#         1.5020802 ,  1.08689511,  0.27795577,  0.91587639, -1.42461026,
#         2.27755046,  0.77033442, -0.94729716, -0.1718314 , -0.21482758,
#         1.37798035,  0.84041649,  1.00662208,  0.4704968 , -0.49571225,
#        -2.08479071,  0.41615668, -3.33387303, -2.87516046,  0.24340761,
#         0.90924042, -2.53633308, -1.42697167, -0.98602611, -3.38001132,
#        -1.55762553,  0.0620967 ,  1.11536729, -2.54848981, -0.78111506,
#        -2.36069012,  1.1318208 ,  0.46683952, -2.5760119 ,  2.93741846,
#         0.3870919 , -0.61699045, -0.43639132, -1.19125652,  0.86630362,
#         0.26677638, -1.08914888, -0.36378962,  3.02378249,  1.97889447,
#         0.9816221 ,  2.00497746, -3.46601868,  4.21190929,  2.21358585,
#         0.38312683,  0.81654668, -0.26444024,  1.78178847, -2.0771699 ,
#         1.32046509, -0.30566666,  2.14813519,  1.7071209 ,  0.25476819,
#         1.74577773,  1.32933176,  1.84898269, -0.07952542,  1.17561424,
#         1.00132012,  0.87576842, -0.24743243, -1.89912915, -2.26227832,
#         1.90982413, -0.92754829,  1.76579595, -0.15514192, -1.04858434,
#         2.12490559,  0.98629081,  3.07389021, -0.01693981, -1.25718904,
#         0.79469049,  0.87593275,  0.74233502, -1.3357389 ,  2.48274851,
#         1.20049024,  2.41286254, -2.4580617 ,  0.49093923,  3.15331197,
#         1.55455184,  1.17413116,  0.28099707,  3.15372348, -0.90537721,
#         1.17219126, -1.57463658,  0.11500845,  0.34617823, -1.60465908,
#        -3.38357663,  1.97892451,  2.23471713, -0.22680287,  0.20664431,
#         2.21099925,  0.37085709, -1.08604431, -1.36445069, -1.07406044,
#        -2.36745954, -1.43552017,  1.73810434,  0.15753773, -2.68612623,
#         0.99804974, -0.31017122, -1.86316347, -0.73917848, -1.03657019,
#         2.35516691,  2.12952876, -0.25661588,  1.75633812, -0.62986475,
#         0.29541937,  0.82854319, -0.99164319,  1.05067861,  0.72975749,
#         3.31384277, -1.54621601, -0.33984271,  2.77633548, -1.53588665,
#         0.76361912,  2.99946356, -1.93540955,  2.1631608 ,  0.73739594,
#         1.73012817,  2.70598841, -2.56433177, -1.17997015,  1.79124331,
#        -1.19114256, -1.14378643,  0.92700851,  0.63489425, -0.79735905,
#         0.63716346,  0.53339118,  0.62196791,  1.81724298, -2.01597238,
#        -2.45521235, -0.25934303,  0.8015666 , -2.6435585 , -0.73771518,
#         1.10842812, -1.48832715,  0.88107777,  1.93279088,  0.10955334,
#        -0.77770805,  3.23066664, -2.16878629,  0.89953065,  1.46525085], dtype=float32)

# %% [markdown]
# # 取出兩個模型 dm, dbow 取得其兩個模型的向量

# %%
Train_Food_vecs_dm = getVecs(model_dm, Train_Food, size)
Train_Food_vecs_dbow = getVecs(model_dbow, Train_Food, size)
#將兩種模型的vec上下疊加
Food_train_vecs = np.hstack((Train_Food_vecs_dm, Train_Food_vecs_dbow))

# %% [markdown]
# # 載入scikit learn 套件 kmeans; 並將Doc2Vec的向量做分群 將所有食記嘗試分50群，並人工對群體做觀察

# %%
from sklearn.cluster import KMeans
Ngroup=50
#固定random state 隨機初始值 fixed the seed
Food_kmeans = KMeans(n_clusters=Ngroup, random_state=0).fit(Food_train_vecs)

# %%
#清一下記憶體
import gc
gc.collect()
# Out:
# 22

# %% [markdown]
# # 將分群結果塞回DataFrame

# %%
# Food_df
# Food_List

#移除,的方法
Food_df['name']=Food_df['name'].apply(lambda y:y.replace(',',""))
Food_df['name']=Food_df['name'].apply(lambda y:y.replace('\n',""))

# %%
Food_df['Cluster'] = Food_kmeans.labels_

# %%
Food_df.to_excel('D:/Data/doc2verData/Food_'+str(Ngroup)+'gp.xlsx')
Food_df.to_csv('D:/Data/doc2verData/Food_'+str(Ngroup)+'gp.csv')

# %%
gc.collect()
# Out:
# 22

# %%
WC_Str=''
for i, x in enumerate(Food_kmeans.labels_):
    if x == 2:
        WC_Str += ' '.join(Food_List[i])

ww = WordCloud(max_font_size=100, relative_scaling=1,max_words=40,width=800, height=600,background_color='white',random_state=0,\
               stopwords=["臺南","菜色","味道","真的","店家","這道","感覺","比較","用餐","搭配",
         "料理","空間","一個","地方","台南市","台南","口味","店員",'一起','一段',
         '部分','餐點','地方','覺得','廁所','二樓',"看到","市場","地址","三段","一段",
         '兩段','中西區','海安','一盒','會館','座位','選擇','下午','提供','制式','使用',
         '北區','營業時間','電話','美食','一份','朋友','東西','一下','來到','一些','二段',
         '有點','應該','老闆','推薦','這家','一直','菜單','想法','平路','府連',
         '喜歡','東區','整個','時間','店內','國華','台北','聽說','升級','套餐',
         '餐廳','相當','店內','裡面','一點','一口','知道','已經','這是','客人'])\
               .generate(WC_Str)
ww.font_path = 'C:\Windows\Fonts\msjhbd' #微軟正黑體的路徑；字體可以自己設定，預設是英文的遇到中文會讀不出來
ww.to_image()
#ww.to_file('./pic/50gp_5.jpg') 可輸出圖檔
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x59993198>

# %%
with open('D:/Data/doc2verData/Food_'+str(Ngroup)+'gp.csv') as f:
    x=f.readlines()

# %% [markdown]
# # 發現有些群體過小 將它們合併為一個，並將超少評論或無評的文章群做標記

# %%
kfood=[dien.replace('\n',"").split(',')[2:] for dien in x[1:]]

# %%
groups={}
for dien in kfood:
    if dien[1] not in groups:
        groups[dien[1]]=set()
    groups[dien[1]].add(dien[0])

# %%
groups.keys()
# Out:
# dict_keys(['12', '43', '1', '30', '47', '31', '35', '34', '21', '25', '6', '37', '16', '29', '22', '38', '33', '8', '48', '41', '26', '39', '18', '36', '42', '2', '7', '20', '40', '11', '19', '9', '44', '24', '45', '13', '27', '4', '49', '3', '10', '5', '15', '14', '46', '17', '32', '28', '0', '23'])

# %%
groups['50']=set()
willdel=set()
for group in groups:
    if len(groups[group])<40:
        groups['50'].update(groups[group])
        willdel.add(group)

# %%
for group in willdel:
    del groups[group]

# %%
g=0
newgroups={}
for i in groups:
    if i =="0":
        newgroups['無評']=list(groups[i])
    elif i =="50":
        newgroups['無分類']=list(groups[i])
    else:
        g+=1
        newgroups[str(g)]=list(groups[i])

# %%
print(len(newgroups))
print([len(newgroups[i]) for i in newgroups])
#為了存成json 轉格式
# x=[dict({i:newgroups[i]}) for i in newgroups]
# Out:
# 21
# [178, 291, 304, 218, 332, 145, 203, 45, 141, 240, 216, 148, 164, 422, 107, 91, 107, 41, 1387, 926, 62]

# %%
import json
with open('D:/Data/doc2verData/Food_kmeans.json','w') as f:
    json.dump(newgroups,f)
