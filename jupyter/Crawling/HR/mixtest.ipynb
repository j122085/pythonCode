# %%
import json
import os
from collections import Counter
import pandas as pd
import numpy  as np 
from  ggplot  import * 
from pylab import *
datadir='D:/HumanResourceData/json/'
datas={}
for filename in os.listdir(datadir):
    with open(datadir+filename) as data:
        jdata=json.load(data)
        datas[filename.replace(".json","")]=jdata
x=datas["Yes123"]
# print(x)

co=dict(sorted(x.items(), key=lambda d: d[1], reverse=True)[0:30])
nco=[]
for i in co.keys():
    nco.append(i.lower())
alldata=[]

for i in datas:
    x={}
    for j in datas[i]:
        if j.lower() in nco:
#             print(j.lower)
            x["net"]=i
            x[j.lower()]=datas[i][j]
    alldata.append(x)
     
alldata



# import pandas as pd
# df=pd.DataFrame(alldata)
# x = df.groupby('net')
# df.
# Out:
# [{'ajax': 534,
#   'android': 515,
#   'asp': 452,
#   'asp.net': 968,
#   'c': 2256,
#   'c#': 1685,
#   'c++': 2798,
#   'delphi': 90,
#   'excel': 2011,
#   'html': 1197,
#   'ios': 213,
#   'java': 1709,
#   'jquery': 849,
#   'jsp': 204,
#   'linux': 1503,
#   'mysql': 1589,
#   'net': '104',
#   'oracle': 774,
#   'outlook': 1493,
#   'php': 832,
#   'pl/sql': 50,
#   'powerpoint': 1897,
#   'python': 489,
#   'spring': 184,
#   'windows': 2597,
#   'word': 2002},
#  {'ajax': 111,
#   'android': 111,
#   'asp': 63,
#   'asp.net': 275,
#   'c#.net': 289,
#   'c++': 102,
#   'delphi': 31,
#   'excel': 255,
#   'html': 259,
#   'ios': 73,
#   'java': 400,
#   'jquery': 176,
#   'jsp': 73,
#   'linux': 189,
#   'mysql': 239,
#   'net': '1111',
#   'oracle': 6,
#   'outlook': 153,
#   'php': 182,
#   'pl/sql': 69,
#   'powerpoint': 208,
#   'python': 64,
#   'windows': 12,
#   'word': 239},
#  {'ajax': 116,
#   'android': 46,
#   'asp': 74,
#   'asp.net': 150,
#   'c': 18,
# ...

# %%
import json
import os
from collections import Counter
import pandas as pd
from  ggplot  import * 
datadir='D:/HumanResourceData/json/'
datas={}
for filename in os.listdir(datadir):
    with open(datadir+filename) as data:
        jdata=json.load(data)
        datas[filename.replace(".json","")]=jdata
x=datas["104"]
# print(x)

# x['SQL']=x['MySQL']+x['SQL']+x['PostgreSQL']
# x['C++']=x['C++']+x['C++.Net']
# x['ASP']=x['ASP']+x['ASP.NET']


# de=['Visual', 'Excel', 'Word', 'PowerPoint', 'Outlook', '中文打字20~50', '英文打字20~50', '98',\
#     '2000', 'NT', '<ITEM/>', '<ITEM', 'Web', '"/>','Systems', 'Photoshop', 'Access', 'PCSKILL_ALL_DESC="', 'Server'\
#    , 'services', 'XP','MySQL','PostgreSQL','C++.Net','ASP.NET']
# for i in de:
#     if i in x:
#         del x[i]
co = Counter() 
for k,v in x.items():
    co[k] =v

ignore=['Visual', 'Excel', 'Word', 'PowerPoint', 'Outlook', '中文打字20~50', '英文打字20~50', '98',\
    '2000', 'NT', '<ITEM/>', '<ITEM', 'Web', '"/>','Systems', 'Photoshop', 'Access', 'PCSKILL_ALL_DESC="', 'Server'\
   , 'services', 'XP','MySQL','PostgreSQL','C++.Net','ASP.NET']
for word in list(co):
    if word in ignore:
        del co[word]
co.most_common(20)
# co=sorted(x.items(), key=lambda d: d[1], reverse=True)

# co.keys()

# x['C++']=x['C++']+x['Visual C++']
# x['C#']=x['C#']+x['C#.NET']+x['C#.NET']
# x['C']=x['C']+x['Objective-C']
# x=['word']
# del x['Word']
# del x['Excel']
# del x['PowerPoint']
# del x['Outlook']
# del x['Visual C++']
# del x['C#.NET']
# del x['Objective-C']
# del x['WINDOWS']
# del x['Windows 2000']
# del x['Windows NT']
# del x['Windows NT']
# print(x)

# co
# co
# for i in co.keys():
#     nco.append(i.lower())
# alldata=[]

# for i in datas:
#     x={}
#     for j in datas[i]:
#         if j.lower() in nco:
# #             print(j.lower)
#             x["netname"]=i
#             x[j.lower()]=datas[i][j]
#     alldata.append(x)
# alldata

# import pandas as pd
# df=pd.DataFrame(alldata)
# df.groupby('net').mean()
# Out:
# [('C++', 2798),
#  ('Windows', 2597),
#  ('C', 2256),
#  ('Java', 1709),
#  ('C#', 1685),
#  ('SQL', 1652),
#  ('MS', 1565),
#  ('Linux', 1503),
#  ('Basic', 1238),
#  ('HTML', 1197),
#  ('JavaScript', 1131),
#  ('jQuery', 849),
#  ('PHP', 832),
#  ('Oracle', 774),
#  ('AJAX', 534),
#  ('Android', 515),
#  ('Python', 489),
#  ('.net', 476),
#  ('Studio', 458),
#  ('ASP', 452)]
