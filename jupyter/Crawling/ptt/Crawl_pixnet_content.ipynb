# %%
import requests
from bs4 import BeautifulSoup

# %%
res=requests.get('http://leafphoto.pixnet.net/blog/post/117488062')
res.encoding='utf-8'
soup=BeautifulSoup(res.text,'lxml')

print(soup)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html itemscope="" itemtype="http://schema.org/Blog" lang="zh-TW">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="葉影瓶像 婚禮紀錄" property="og:site_name"/>
# <meta content="zh_TW" property="og:locale"/>
# <meta content="http://leafphoto.pixnet.net/blog/post/117488062" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="【台北】IM 雨焰商行 x 阿波伯楊桃。楊桃汁、鳳梨冰這種東西，竟然藏在文青咖啡館中！/大稻埕阿波伯楊桃汁/西門町冰品楊桃汁 @ 葉影瓶像 婚禮紀錄 :: 痞客邦 PIXNET ::" property="og:title"/>
# <meta content="西門町外圍，西寧南路這帶算是我平常較少過來的區域，這天跟幾個朋友找了家店喝午茶，離開時朋友說這附近有家楊桃汁她很推要不要順便試試！我原本以為是指全台北沒人不知道的「成都楊桃冰」，沒想到並不是！！是一家" property="og:description"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %%
title=soup.select('.title h2 a')[0].text
print(title)
print('-----'*20)


conn=[i.text for i in soup.select('.article-content-inner > p') if 'CDATA' not in i.text]

"\n".join(conn)
##article-content-inner > p:nth-child(18)
# with open('pixnet_content_test.doc', 'w', encoding='utf8') as f:
#     f.write(title)
#     f.write(con)
# Out:
# 【台北】IM 雨焰商行 x 阿波伯楊桃。楊桃汁、鳳梨冰這種東西，竟然藏在文青咖啡館中！/大稻埕阿波伯楊桃汁/西門町冰品楊桃汁
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# with open("pixnet_content_test.txt", 'w') as f:
#     w.write(a)
#     w.write(b)
# Out:
# '【台北】IM 雨焰商行 x 阿波伯楊桃。楊桃汁、鳳梨冰這種東西，竟然藏在文青咖啡館中！/大稻埕阿波伯楊桃汁/西門町冰品楊桃汁'
