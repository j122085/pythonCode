# %%
import pymongo
clinet=pymongo.MongoClient("mongodb://10.120.27.23:27017/")
db=clinet['project']
bigtable = list(db.FinishTainanBigTable.find({}))
clinet.close()
bigtable[0]
# Out:
# {'Ncomment': 26,
#  'TF_IDF': {'一下': 0.0005058619310472912,
#   '一個': 0.0006763427417325443,
#   '一口': 0.000902388368012658,
#   '一家': 0.0008383533159246719,
#   '一張': 0.0009772699783033602,
#   '一杯': 0.0007763227846572202,
#   '一次': 0.0007700843326304692,
#   '一碗': 0.0031732457338551666,
#   '一種': 0.0006668078310359679,
#   '一起': 0.0008712465982758182,
#   '一間': 0.0008375586857847692,
#   '一點': 0.0010014197611782284,
#   '三種': 0.0007760097055008344,
#   '上次': 0.0021988574511825607,
#   '上面': 0.000604514746360345,
#   '下': 0.00012088803629924028,
#   '下次': 0.0006209773348036758,
#   '不到': 0.0004732557107079696,
#   '不用': 0.0006399935237685169,
#   '不錯': 0.0003006029692292721,
#   '中午': 0.0007751981504600589,
#   '之後': 0.0007806238562467455,
#   '二樓': 0.0011710565380702723,
#   '享用': 0.0006151714242347759,
#   '人': 0.0009087926521433939,
#   '人潮': 0.0024724144797953255,
#   '今天': 0.00044843015836489036,
#   '介紹': 0.000613901062466487,
#   '以上': 0.0007279636511091276,
#   '以前': 0.0009350987128488293,
#   '位置': 0.0010154508997988877,
#   '來到': 0.0031730323165603804,
#   '便宜': 0.0004620164324086564,
#   '停車場': 0.0014437951933958353,
#   '傳統': 0.005952277443994108,
#   '價格': 0.0005268780599594217,
#   '價錢': 0.0009232666092113548,
#   '元': 0.0012229959543214762,
#   '入口': 0.0006339885880045137,
#   '入口即化': 0.0010030465751322824,
#   '兩個': 0.0005774823343672711,
#   '兩種': 0.002461150189110263,
#   '再': 0.00045739207700648733,
#   '再來': 0.0010903840050139704,
#   '冰': 0.002948198930306395,
#   '冰品': 0.0011475169836139866,
#   '分享': 0.00043720628377120834,
#   '分店': 0.001662034924833849,
#   '分類': 0.0019350626043513372,
#   '前': 0.0002944570015209515,
#   '加': 0.0006456346115859259,
#   '勁': 0.0007331947193424405,
#   '動力': 0.0013051014176470557,
#   '北路': 0.006875963707633245,
#   '區': 0.0004307178524642796,
#   '區安': 0.006933980374185343,
#   '南部': 0.0011999350682581488,
#   '卻': 0.0005954483558104234,
#   '原味': 0.0010147904348476555,
#   '原本': 0.0006769672665325918,
#   '口味': 0.0009272231015038364,
#   '口感': 0.0021616137196680276,
#   '只': 0.0004410784598771024,
#   '可惜': 0.0005336343485001274,
#   '可愛': 0.0008627876282319022,
#   '台': 0.00015185700677647343,
#   '台南': 0.0027805816378474956,
#   '台南市': 0.0005130639012666589,
#   '台南美食': 0.000990342579465192,
#   '台灣': 0.0009103887879917619,
#   '吃': 0.003421668452832174,
#   '吃過': 0.0005512643817978281,
#   '同事': 0.0009314668242681137,
#   '同學': 0.002764471172159734,
#   '同記': 0.006779607081152586,
#   '同記安平豆花': 0.026549680774741513,
#   '名人': 0.001763857992097767,
#   '名字': 0.0007726185026175407,
#   '吸引': 0.0005361782058236201,
#   '周氏': 0.001415015627987058,
#   '味': 0.00019720016622201767,
#   '味道': 0.0008127347703912137,
#   '哈哈哈': 0.002308697688061256,
#   '唷': 0.0015798790653047718,
#   '喔': 0.0013775013409456018,
#   '喜歡': 0.00109736782066873,
#   '囉': 0.0006048715250612551,
#   '回': 0.0003885672310496036,
#   '地址': 0.0009855234013410733,
#   '坐': 0.0004282064380305598,
#   '外': 0.00026443351155839017,
#   '外帶': 0.0011953800955213402,
#   '多一點': 0.0014899080524164439,
#   '天氣': 0.0019329927853901933,
#   '太': 0.00048734944299254985,
#   '好': 0.0006338140839139034,
#   '好久沒': 0.0015821699405168927,
#   '好像': 0.0007671913602848401,
#   '好吃': 0.001422252058763794,
#   '好多': 0.0012554302854541595,
#   '姊': 0.0016055790092057336,
#   '嫩': 0.0005957386720899929,
#   '安平': 0.018637383249754436,
#   '安平古堡': 0.0019422893785507626,
#   '客人': 0.0004731161704926497,
#   '家': 0.0002929824625799546,
#   '實在': 0.0006579684394422844,
#   '專頁': 0.0008194240494401097,
#   '對面': 0.0007585670156519513,
#   '導覽': 0.002380446609663194,
#   '小': 0.000550442339200311,
#   '小孩': 0.0008131818715839863,
#   '小顆': 0.0017744735041982098,
#   '少': 0.000392799935896242,
#   '左右': 0.0008797273191732098,
#   '已經': 0.0009569041498076532,
#   '市場': 0.0007380252030520506,
#   '布丁': 0.0015460821278781125,
#   '帶有': 0.0009420574276919628,
#   '幫': 0.0005348714114147416,
#   '平日': 0.001482348757301435,
#   '年': 0.0004104777479380629,
#   '幸福': 0.0010192711583823413,
#   '店': 0.0008426205966920252,
#   '店內': 0.0010347676316226748,
#   '店家': 0.001498635491317673,
#   '店裡': 0.0012263662530168581,
#   '店面': 0.001057175343254332,
#   '府城': 0.001713157125928414,
#   '座位': 0.000963617615162718,
#   '引述': 0.002754619127386893,
#   '很好吃': 0.0007439728170433304,
#   '後': 0.0003111835019300741,
#   '必吃': 0.001837806598167112,
#   '想': 0.00043352957683676546,
#   '愛': 0.00023683068438262457,
#   '感': 0.00013260411463174044,
#   '感覺': 0.0014068722699664873,
#   '應該': 0.0003885481659419724,
#   '找': 0.0013214596663630625,
#   '抹茶': 0.0015138974953711076,
#   '拍': 0.00040989342310808073,
#   '排隊': 0.003936134416277603,
#   '推': 0.00044222801562436256,
#   '推薦': 0.00038492666816962315,
#   '提供': 0.0009233591206175222,
#   '搭配': 0.0019222099966054377,
#   '故事': 0.0013059763079311954,
#   '整個': 0.0006585975749492772,
#   '整理': 0.0011991966050819225,
#   '整體': 0.0004436536431799306,
#   '文章': 0.0011146285905362853,
#   '料': 0.00035698532956111964,
#   '新': 0.00025742815980275455,
#   '旅遊': 0.0011781834372939137,
#   '早味': 0.0017534152372964927,
#   '是點': 0.0011785264891816412,
#   '時': 0.00016216659335076066,
#   '時間': 0.0002509182440983425,
#   '晚餐': 0.0006409225444007158,
#   '景點': 0.0015991305557329933,
#   '最': 0.00037982638885890134,
#   '最大': 0.0013669023366156073,
#   '最後': 0.0008241519984759781,
#   '有名': 0.0014050500202043247,
#   '有點': 0.0007210658265700194,
#   '朋友': 0.0003587989066086934,
#   '木頭': 0.0016085967257649298,
#   '東西': 0.0006645997628984972,
#   '松霖': 0.0056212574588051165,
#   '果凍': 0.006042306221059862,
#   '檸檬': 0.0064070024612477025,
#   '歷史': 0.0009308744909556089,
#   '每次': 0.0010412486162473054,
#   '比較': 0.0019450878234168398,
#   '消暑': 0.0010908782189924717,
#   '淋上': 0.0011289786674004228,
#   '淡淡的': 0.0007017981390193799,
#   '滿滿的': 0.0016070049867997573,
#   '濃郁': 0.0006295224413145338,
#   '無敵': 0.0009422588245336966,
#   '照片': 0.0009003803871627448,
#   '煮': 0.0012953203524272356,
#   '熬': 0.0006791140228509695,
#   '熱': 0.0003245454804385819,
#   '營業時間': 0.0009719456328243847,
#   '牆上': 0.0019504070007372583,
#   '牛奶': 0.0015685706638415393,
#   '特別': 0.0009364522446704451,
#   '玩': 0.0013209457896641021,
#   '珍珠': 0.01960106773588351,
#   '現在': 0.0006065569146868583,
#   '瑋': 0.006124668718623349,
#   '甜': 0.0004931241322983393,
#   '甜品': 0.0011281272847174237,
#   '甜度': 0.0009649723553551145,
#   '甜點': 0.0008685301252610629,
#   '生意': 0.001324942297773675,
#   '發現': 0.0004694309188111647,
#   '白河': 0.002225521991599388,
#   '相當': 0.0007432710781030609,
#   '相關': 0.0007991181326208868,
#   '看到': 0.00041231252719604747,
#   '真的': 0.001151074413497412,
#   '知道': 0.0006711669206074911,
#   '碗粿': 0.0032115235188550717,
#   '竹炭': 0.008470750783408955,
#   '第一次': 0.0004734788045758403,
#   '粉圓': 0.011414401363492853,
#   '粉絲': 0.0005377983812488566,
#   '粉絲團': 0.0007172895392726536,
#   '精製': 0.002450158572735264,
#   '糖水': 0.011228160422783661,
#   '紀念章': 0.0034268643540838663,
#   '紅豆': 0.013818462635480946,
#   '索引': 0.0034268643540838663,
#   '細緻': 0.00219014557692395,
#   '綠豆': 0.006532910453177864,
#   '綿密': 0.0020171434991668583,
#   '總店': 0.004339768275533544,
#   '美食': 0.0011955429752255858,
#   '老公': 0.001418897433567666,
#   '老字號': 0.001782772246426848,
#   '老店': 0.0010928989404856019,
#   '老街': 0.0017908540787196084,
#   '耶': 0.0013857046863114716,
#   '肉': 0.00018964808270973194,
#   '臺南市': 0.0017498641745168021,
#   '花': 0.0012576947311380236,
#   '花瓶': 0.0035408352012197067,
#   '花香': 0.0018195159665190808,
#   '茶坊': 0.004924175613839134,
#   '草莓': 0.0018664966553907532,
#   '蓮花': 0.0024808906135599116,
#   '虱目': 0.001027858277457604,
#   '蝦捲': 0.0020793814421919093,
#   '蝦餅': 0.002323143641117685,
#   '裡面': 0.0004367702118972437,
#   '製作': 0.0007509546924569702,
#   '要來': 0.000760027551377069,
#   '覺得': 0.0010010297141517487,
#   '言': 0.0014587086560060077,
#   '許多': 0.0008090955368974081,
#   '試試': 0.0004886732311529113,
#   '說': 0.0007630609384339677,
#   '謝謝': 0.0007404704075152697,
#   '讚': 0.0008378727375643414,
#   '豆': 0.0007111196377798823,
#   '豆漿': 0.0026436850863040856,
#   '豆花': 0.08761452874606844,
#   '買': 0.0006538484695382005,
#   '賣': 0.0011363015327048778,
#   '超': 0.0006478548992897569,
#   '超愛': 0.0013062180091921636,
#   '路邊': 0.0013185693276122753,
#   '軟': 0.0002964319246386529,
#   '這家': 0.0019381117194683778,
#   '這是': 0.0006996788507562209,
#   '這次': 0.0014909644524334401,
#   '這種': 0.0007307463641510232,
#   '這間': 0.0018382928712053132,
#   '遊客': 0.001631751558285196,
#   '道': 0.00033306742101930074,
#   '選': 0.0005190221495670851,
#   '選擇': 0.0014901317719060866,
#   '還不錯': 0.0009301499830295313,
#   '還好': 0.0009961500796011168,
#   '還沒': 0.0006631276409651666,
#   '還蠻': 0.0009160557703469682,
#   '那種': 0.0005137656230419869,
#   '部分': 0.000991279311657786,
#   '配': 0.0002846801735458431,
#   '配料': 0.0029518434424300423,
#   '酸酸甜甜': 0.0014735825813045327,
#   '醬鴨': 0.0024978775318846565,
#   '錯過': 0.001698512815532721,
#   '鍋燒': 0.001082623925596239,
#   '鍋燒意麵': 0.005191332886028057,
#   '鍋燒麵': 0.003025987775573494,
#   '開心': 0.0008545633925342878,
#   '附近': 0.0006617508732459073,
#   '隨便': 0.001231765675369444,
#   '雪花': 0.007369660585120349,
#   '電話': 0.0007288833723914274,
#   '靡': 0.005332969364038064,
#   '飲料': 0.00040566020436288514,
#   '餐廳': 0.00048148829125123767,
#   '餓': 0.0008823892494099566,
#   '香': 0.00035567191751661114,
#   '香氣': 0.0014337505349367359,
#   '香濃': 0.001301188379134636,
#   '香甜': 0.0008036088925737983,
#   '高朋滿座': 0.0016126522381882246,
#   '魚': 0.0010059731881986531,
#   '鮮奶': 0.006449061090613978,
#   '黃': 0.0004913996269501682,
#   '黃豆': 0.004286962634544435,
#   '黑豆': 0.008984914021602461,
#   '點': 0.00013576123150985776,
#   '點了': 0.00132795997908812},
#  '_id': ObjectId('59c9c720aadaed1be0ff844c'),
#  'address': '台南市安南區安北路433號',
#  'closetime': '23:00',
#  'contentcut': '簡單 傳統 安平 豆花 純白 豆花 特別 挑逗 胃口 安平 兼具 台南 傳統 現代 一個 區域 而作 安平 代表 傳統 美食 一如 所知 安平 豆花 周氏 蝦捲 今天 帶點 炎熱 天氣 來點 清涼 降火 冰品 好日子 喊 豆花 消暑 吃 安平 豆花 最 著名 同記安平豆花 同記安平豆花 光是在 安平 兩個 店面 相距 公里 左右 今天 來到 總店 平日 下午 但店 一副 忙碌 景象 剛有 客人 離開 趕緊 搶佔 一桌 店內用 原木 大張 長桌 長椅 古風 牆上 擺 這些年來 到過 安平 豆花 名人 真的 同記安平豆花 安平 已經 四十多年 歷史 取名 記是 最早 創始人 黃 慶同 名字 中有個 同字 推車 一路 叫賣 現在 成為 台南 十大 傳統 名產 艱辛 不足 外人道 知道 跳過 年 成立 店面 後 原本 稱呼 安平 豆花 正式 掛上 同記 前綴 安平 區的 豆花 店逐 漸變 只 要說 安平 豆花 知道 指 同記安平豆花 說 快快 來點 豆花 種類 道 道 經典 選 最 正宗 最 傳統 紅豆 豆花 綠豆 豆花 一碗 古法 精製 非 基因 改造 有機 黃豆 製作 光看 成色 令人 心動 紅豆 部分 則是 來自 屏東 萬丹 極品 紅豆 數 小時 熬 煮 後 最佳 紅豆 香氣 呈現 眼前 好吃 加點 一碗 紅豆 豆花 每顆 紅豆 保持 完整 外觀 入口 口感 說 一口 豆花 口感 軟嫩 細緻 入口 傳統 黃豆 香氣 手工 製作 洋菜 粉 勾芡 口感 綠豆 豆花 軟 透心 綠豆 外 搭著 嫩 豆花 微甜 甘蔗 糖水 一起 入口 高雅 芬芳 猶如 咖啡館 享用 下午茶 好吃 豆花 來到 安平 錯過 老街 逛累 順便來 碗 冰涼 透心 豆花 真是 享受 同記安平豆花 總店 台南市 安平 區安 北路 來到 台南 試試 這家 老字號 豆花 店古 早味 有名 一家 店裡面 人 懂 覺得 吃 店 差別 拉 舌頭 頓 老字號 自然 歷史悠久 牆上 掛滿 名人 家 料配 豆花 點了 紅豆 小 珍珠 綠豆 豆花 很軟 入口即化 湯 特別 甜 這家 地人 推薦 安平 豆花 喔 老字號 豆花 要來 嘗試 下 炎熱 天氣 裡最 需要 碗 甜品 這天 平日 暑假 店裡 人來 朝聖 牆上 滿滿的 照片 多名 人 電視 專訪 喔 這間 真的 夯 喔 這是 吃 珍珠 豆花 珍珠 超級 無敵 小顆 外面 飲料 小 珍珠 還小顆 吃 沒什麼 口感 有點 可惜 豆花 吃 滑 嫩 豆味 滿香 整體 吃 還不錯 這間 電視 好 幾次 周記 安平 豆花 老婆 台南 唸書 時 吃 過好 幾次 第一次 造訪 充滿 人潮 人氣 豆花 店 酷熱 吃 一點 豆花 好 消暑 左豪 痞客 邦 吃吃喝喝 左豪 粉絲團 歡樂 台南美食 整理 區 南部 旅遊 整理 區 分內 用區 外帶 區 豆花 主要 原味 紅豆 綠豆 珍珠 檸檬 豆花 賣 豆花 賣到 二樓 真的 生意 驚人 好 還沒 下午 高朋滿座 牆上 好多 名人 合照 店裡 面人 太多了 沒靠 過去 冷氣 二樓 建議 有點 麵 食者 坐 一樓 方便 麵 二樓 坐位 區 豆花 圖片 有分 黃豆 黑豆 兩種 豆花 一律 元 統一價 賣 鮮奶 豆花 則賣 元 外帶 區也 一杯 一杯 賣 點了 三種 豆花 解解 酷熱 珍珠 豆花 紅豆 豆花 珍珠 豆花 元 豆花 又稱 作 豆腐腦 豆漿 凝固 成果 凍狀 珍珠 波霸 珍珠 粉圓 那種 小巧 可愛 珍珠 豆花 吃 比較 細膩 不像 吃 比較 粗澀 粉圓 覺得 再給 多一點 紅豆 豆花 元 紅豆 香甜 燉 軟爛 紅豆 還蠻 愛的 糖水 不會太甜 人氣 小吃 同記 豆花 吃 淡淡的 黃豆 味 兩種 豆花 覺得 紅豆 表現 比珠珍 香氣 感覺 檸檬 豆花 人 吃 來到 安平 吃 豆花 歇腳 一下 店家 名稱 同記安平豆花 安平 總店 店家 地址 臺南市 安平 區安 北路 店家 電話 營業時間 台南美食 旅遊 相關 連結 台南美食 整理 區 南部 旅遊 整理 區 肚子餓 嘰哩咕嚕 來到 安平 豆花 咧 昭瑢 說 裡面 賣 鍋燒麵 好吃 咧 哄豆尼 還不 知道 發現 吃 鍋燒麵 豆花 數人 已經 點了 人潮 依然 強強 滾 先來 找 位置 坐 下來 小孩 餓 只 想 吃 冰 牛奶 雪花 冰 雪花 冰 選 種 配料 小朱 朱 草莓 煉乳 家 隻 小鬼 珍珠 煉乳 大人 不約而同 選擇 珍珠 豆花 媽 喜歡 口感 小 珍珠 安平 豆花 旁 松霖 茶坊 賣 飲料 鍋燒麵 這家 安平 豆花 老闆 小孩 開 吃 豆花 吃 飽飽 好多 鍋 鍋燒麵 一起 煮 鍋燒意麵 大碗 鍋燒意麵 記得 好像 元 料 好多 感覺 超 便宜 鍋燒 烏龍 鍋燒麵 裡面 料 有蛋 蛤蜊 菜 蟹肉 棒 火腿 片 值得 推薦 肉 感覺 加 黑胡椒 醃過 肉 吃 很嫩 淡淡的 胡椒 味 口味 超 特別 湯頭 超 好喝 下 一次 安平 豆花 一種 選擇 同記安平豆花 台南市 安平 區安 北路 營業時間 安平 同記安平豆花 安平 總有 一種 糾結 感 有限 胃囊裡 抉擇 周記 蝦捲 陳家蚵捲 吃 布丁 豆花 同記安平豆花 最具 代表 老店 這次 特別 來到 比較 偏僻 總店 吃 點多來 沒什麼 人 位置 超多 點了 一個 豆花 元 創辦人 故事 贅述 這面 牆 知道 晚近 報導 已經 根本 傳統 豆花 金黃 糖水 糖水 味道 寧夏 豆花 莊 加冰 偏甜 南部 豆花 豆 花香 豆花 超嫩 外 一種 綿感 扁桃腺 發言 一府 二鹿 艋 舺 府城 舊 街巷 年輕人 艋 舺 新 公園 老傢伙 故事 土溝村 幾米 早上 六點 出門 現在 餓 渴 土溝村 食物 吸引 估狗 搜尋 只 找到 醬鴨 工廠 女兒 問啥 醬鴨 說 杭州 爸爸 點過 不好吃 外地人 後壁 找 不到 東西 吃 父女倆 打算 買 醬鴨 吞 餓 堅持 吃 小 父女 派 說 台南 吃 小七是 膚淺 行為 兩派 相爭 小七 吃 老街 飯店 下落 中午 開張 割稻 飯還 煮 割稻 飯 後壁 真的 需要 早午餐 只好 新營 方向 邊找 路邊 找 吃 最後 新營 交流 道 前 知名 市場 吃 碗粿 肉粽 配 豬血 湯及 排骨 酥 兩方 皆大歡喜 重點 是點 五樣 超過 一百 台南 物價 有夠便宜 高速公路 沒多久 一下 看到 麻豆 交流 道 堅持 再補 一碗 正宗 麻豆 碗粿 如上圖 點了 兩碗 碗粿 蘭加 虱目 魚丸湯 甘願 魚丸湯 菜 嫌 虱目 魚 體味 太重 一個 早餐 吃 兩碗 也夠 晚餐 同事 說 台南 發現 胃 不夠 真的 台南小吃 卻 碗粿 餵 撐 何以 前 吃 阿蘭 碗粿 卻 變成 碗粿 蘭 一部 南部 人 愛看 世間 情 劇情 細查 碗粿 蘭 附近 很多賣 白柚 水果攤 心動 旅途 總 塞爆 後 車箱 碗粿 蘭 停車場 附近 飲料店 外帶 飲料 解膩 決明 茶 吸睛 夠 特別 至少 別處 看過 解了 肚子 餓 文化 之旅 第一站 黑 橋牌 香腸 博物館 這是 哪門子 文化 吃 文化 點 普通 時間 不多 跳過 台南 籍 同事 聽 笑 傻 台南小吃 眾多 黑 橋牌 找 吃 約 同學 安平 樹 屋前 碰面 同記安平豆花 心頭 好 兩家 人 相約 敘舊 同學 三歲 小女孩 愛吃 粉圓 人來瘋 看著 粉圓 吃進 嘴裡 再 一顆顆 吐出來 表演 秀 哈哈哈 台南 天氣 熱 蚊子 特多 店東 不用 特別 趕人 店 蚊子 咬到 受不了 自動 離座 一出 店門 隔壁 蝦餅 攤請 人 試吃 試吃 打算 買 奧客 小女孩 有樣學樣 爸爸 掏錢 說 遊客 伴 手禮 本地人 瞎 買 買來 送 真是 不好意思 實在 太 好吃 伴手 禮還 沒到 家 已經 掉 半包 踩 街 助消化 安平 變 特殊 景觀 墓 仔埔 不見 老街 人潮 依舊 老外 遊客 短短 百 公尺 陳氏蚵捲 熱情 台 同學 走進 消費 同學 小孩 可愛 老李 特地 買 冰淇淋 討 開心 這種 拐杖 冰淇淋 地方 沒見過 小女孩 拿到 一臉 開心 同學 又點 滿桌 招牌菜 小吃 說 實在 胃 撐得 誇張 但管 蚵捲 蝦捲 蚵仔煎 烤生 蠔 外加 我點 一碗 肉燥飯 通通 不留 吃 光光 好吃嗎 聽說 名列 最新 餿油 店家 這次 逃過 午餐 吃 撐 之後 回 飯店 休息 準備 晚餐 再戰 晚餐 約 夏林 海鮮 炭烤 另一名 同學 已 預訂 招牌菜 魠 魚 粥 螺 肉湯 吃 撐 聊到 忘記 味覺 一頓飯 飯後 小 西門 散步 咖啡 甜點 通 通來 老李 回贈 德國 小 西點 同學 另一名 同學 不甘示弱 幫 買盒 蛋糕 互送 整個 滿載 郭 一整天 吃 不停 特地 黃色 標示 證明 這是 一趟 神豬 旅 原本 鬆 掉 褲子 變緊 蹦 很久沒 發文 這篇 照片 不足 誠意十足 上次 安平 豆花 店 整個 傻眼 人 好多 實在 懶得 排隊 這次 想 飛 套票 換餐 囉 依舊 人潮 擠擠 上次 好 蠻想 試試看 竹炭 黑豆 花 香濃 鮮奶 位花 想 試試看 雪花 冰 價位 小林 木瓜 可愛 許多 人 去過 一店 人 應該 好像 安平古堡 已經 賣 久 歷史 餒 店內 古色古香 桌具 整間 店面 變得 菜單 詳細 版 沒想到 還賣 咖啡 一碗 好滿 好 糖水 檸檬水 原味 豆花 選擇 兩種 配料 選擇 珍珠 姊 選擇 檸檬 家 再 一起 好吃 唷 想 上面 豆花 喳喳 喀嚓 掉 豆花 口感 覺得 崇德 市場 崇德 市場 黃 氏 薏仁 專賣店 價位 比較 可愛 一個 銅板 元 餒 店內 許多 古物 想 扛 回家 耶 覺得 一個 櫥窗 台要 再 堅硬 些  ...
#  'coordinate': {'lat': 22.9999252, 'lng': 120.1534308},
#  'featurescores': {'份量大': 0.13,
#   '偏甜': 0.24,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.19,
#   '划算': 0.19,
#   '口味清淡': 0.07,
#   '服務好': -0.15,
#   '環境好': 0.14,
#   '食物很香': 0.22,
#   '食物精緻漂亮': 0.19,
#   '食物美味': 0.37},
#  'introduction': '同記安平豆花(安平總店)是一個有台南小吃、豆花、安平美食的剉冰、豆花，網友認為值得推薦的有：珍珠豆花、紅豆豆花、檸檬豆花、珍珠檸檬豆花、原味豆花',
#  'name': '同記安平豆花(安平總店)',
#  'opentime': '09:00',
#  'pinCountMaxper5': {'': 182,
#   '不好吃': 1,
#   '不會太重': 1,
#   '不會過甜': 1,
#   '不用擔心': 1,
#   '不膩口': 1,
#   '也不錯': 2,
#   '享受': 2,
#   '份量不少': 2,
#   '便宜': 4,
#   '偏甜': 1,
#   '偏酸': 1,
#   '健康': 1,
#   '充數': 1,
#   '入口即化': 3,
#   '划算': 2,
#   '古色古香': 3,
#   '可愛': 5,
#   '吃飽': 1,
#   '喜歡': 18,
#   '大碗': 1,
#   '天然': 1,
#   '太多了': 2,
#   '太甜': 3,
#   '好吃': 31,
#   '好喝': 1,
#   '好好吃': 3,
#   '好香': 1,
#   '寬敞': 1,
#   '小巧': 1,
#   '平價': 1,
#   '很不錯': 3,
#   '很划算': 2,
#   '很喜歡': 2,
#   '很好吃': 5,
#   '很嫩': 2,
#   '很貴': 1,
#   '挺不賴': 2,
#   '新鮮': 2,
#   '有夠便宜': 1,
#   '有彈性': 1,
#   '有點小': 1,
#   '柔軟': 2,
#   '浪漫': 1,
#   '清潔': 1,
#   '清爽': 1,
#   '漂亮': 2,
#   '濃郁': 4,
#   '熱情': 2,
#   '爽口': 1,
#   '特別': 10,
#   '綿密': 8,
#   '綿綿的': 2,
#   '美味': 3,
#   '膩口': 2,
#   '裝潢': 1,
#   '親民': 1,
#   '誠意': 1,
#   '誠意十足': 1,
#   '貴': 3,
#   '超好吃': 2,
#   '超愛': 5,
#   '超開心': 1,
#   '軟嫩': 2,
#   '過甜': 1,
#   '過癮': 2,
#   '還不錯': 6,
#   '還沒出': 2,
#   '開心': 5,
#   '難吃': 3,
#   '飽足感': 1,
#   '養生': 1,
#   '香氣': 11},
#  'score': 6.215384615384615,
#  'style': '甜點(合併飲品)',
#  'tags': ['豆花', '珍珠', '同記安平豆花', '服務較差', '紅豆', '安平', '剉冰、豆花'],
#  'tel': '063915385',
#  'wordCount': [['豆花', 253],
#   ['吃', 113],
#   ['安平', 80],
#   ['台南', 66],
#   ['紅豆', 50],
#   ['珍珠', 47],
#   ['同記安平豆花', 42],
#   ['口感', 29],
#   ['檸檬', 29],
#   ['傳統', 28],
#   ['冰', 27],
#   ['人', 26],
#   ['好吃', 25],
#   ['店', 25],
#   ['鮮奶', 25],
#   ['糖水', 24],
#   ['粉圓', 24],
#   ['比較', 24],
#   ['好', 21],
#   ['店家', 20],
#   ['喔', 19],
#   ['來到', 18],
#   ['真的', 18],
#   ['感覺', 18],
#   ['一碗', 17],
#   ['這家', 17],
#   ['黑豆', 17],
#   ['元', 17],
#   ['雪花', 17],
#   ['說', 16],
#   ['綠豆', 16],
#   ['喜歡', 16],
#   ['排隊', 16],
#   ['搭配', 16],
#   ['北路', 15],
#   ['這間', 15],
#   ['花', 15],
#   ['小', 14],
#   ['選擇', 14],
#   ['同記', 13],
#   ['區安', 13],
#   ['覺得', 13],
#   ['賣', 13],
#   ['地址', 13],
#   ['配料', 13],
#   ['鍋燒意麵', 13],
#   ['美食', 12],
#   ['找', 12],
#   ['口味', 12],
#   ['竹炭', 12],
#   ['唷', 12],
#   ['果凍', 12],
#   ['總店', 11],
#   ['香氣', 11],
#   ['人潮', 11],
#   ['兩種', 11],
#   ['營業時間', 11],
#   ['加', 11],
#   ['這次', 11],
#   ['味道', 11],
#   ['耶', 11],
#   ['特別', 10],
#   ['煮', 10],
#   ['一點', 10],
#   ['電話', 10],
#   ['台南市', 9],
#   ['滿滿的', 9],
#   ['想', 9],
#   ['松霖', 9],
#   ['茶坊', 9],
#   ['超', 9],
#   ['魚', 9],
#   ['上次', 9],
#   ['玩', 9],
#   ['一個', 8],
#   ['天氣', 8],
#   ['牆上', 8],
#   ['已經', 8],
#   ['黃豆', 8],
#   ['家', 8],
#   ['點了', 8],
#   ['甜', 8],
#   ['有點', 8],
#   ['區', 8],
#   ['碗粿', 8],
#   ['同學', 8],
#   ['哈哈哈', 8],
#   ['太', 8],
#   ['店內', 8],
#   ['讚', 8],
#   ['綿密', 8],
#   ['瑋', 8],
#   ['文章', 8],
#   ['靡', 8],
#   ['引述', 8],
#   ['言', 8],
#   ['最', 7],
#   ['知道', 7],
#   ['道', 7],
#   ['選', 7],
#   ['一口', 7],
#   ['細緻', 7],
#   ['一起', 7],
#   ['錯過', 7],
#   ['店裡', 7],
#   ['生意', 7],
#   ['牛奶', 7],
#   ['料', 7],
#   ['一次', 7],
#   ['豆', 7],
#   ['再', 7],
#   ['推', 7],
#   ['香', 7],
#   ['提供', 7],
#   ['店面', 6],
#   ['平日', 6],
#   ['後', 6],
#   ['部分', 6],
#   ['早味', 6],
#   ['有名', 6],
#   ['一家', 6],
#   ['照片', 6],
#   ['這是', 6],
#   ['還不錯', 6],
#   ['外帶', 6],
#   ['好多', 6],
#   ['豆漿', 6],
#   ['味', 6],
#   ['一下', 6],
#   ['位置', 6],
#   ['草莓', 6],
#   ['好像', 6],
#   ['布丁', 6],
#   ['府城', 6],
#   ['買', 6],
#   ['最後', 6],
#   ['囉', 6],
#   ['分店', 6],
#   ['座位', 6],
#   ['再來', 6],
#   ['介紹', 6],
#   ['景點', 6],
#   ['一間', 6],
#   ['每次', 6],
#   ['蝦捲', 5],
#   ['現在', 5],
#   ['年', 5],
#   ['只', 5],
#   ['外', 5],
#   ['嫩', 5],
#   ['老街', 5],
#   ['旅遊', 5],
#   ['原味', 5],
#   ['可愛', 5],
#   ['還蠻', 5],
#   ['鍋燒麵', 5],
#   ['東西', 5],
#   ['路邊', 5],
#   ['前', 5],
#   ['看到', 5],
#   ['卻', 5],
#   ['附近', 5],
#   ['停車場', 5],
#   ['蝦餅', 5],
#   ['實在', 5],
#   ['這種', 5],
#   ['之後', 5],
#   ['回', 5],
#   ['甜點', 5],
#   ['幫', 5],
#   ['整個', 5],
#   ['香濃', 5],
#   ['許多', 5],
#   ['姊', 5],
#   ['最大', 5],
#   ['還好', 5],
#   ['以前', 5],
#   ['很好吃', 5],
#   ['必吃', 5],
#   ['台灣', 5],
#   ['淋上', 5],
#   ['抹茶', 5],
#   ['酸酸甜甜', 5],
#   ['幸福', 5],
#   ['謝謝', 5],
#   ['相當', 5],
#   ['超愛', 5],
#   ['今天', 4],
#   ['冰品', 4],
#   ['左右', 4],
#   ['客人', 4],
#   ['黃', 4],
#   ['原本', 4],
#   ['製作', 4],
#   ['入口', 4],
#   ['老字號', 4],
#   ['推薦', 4],
#   ['要來', 4],
#   ['時', 4],
#   ['粉絲團', 4],
#   ['台南美食', 4],
#   ['整理', 4],
#   ['南部', 4],
#   ['二樓', 4],
#   ['一杯', 4],
#   ['多一點', 4],
#   ['臺南市', 4],
#   ['裡面', 4],
#   ['發現', 4],
#   ['餓', 4],
#   ['一種', 4],
#   ['老店', 4],
#   ['故事', 4],
#   ['新', 4],
#   ['中午', 4],
#   ['配', 4],
#   ['點', 4],
#   ['時間', 4],
#   ['熱', 4],
#   ['不用', 4],
#   ['遊客', 4],
#   ['台', 4],
#   ['開心', 4],
#   ['應該', 4],
#   ['安平古堡', 4],
#   ['上面', 4],
#   ['花瓶', 4],
#   ['動力', 4],
#   ['下次', 4],
#   ['少', 4],
#   ['拍', 4],
#   ['價格', 4],
#   ['木頭', 4],
#   ['帶有', 4],
#   ['甜度', 4],
#   ['濃郁', 4],
#   ['勁', 4],
#   ['一張', 4],
#   ['以上', 4],
#   ['對面', 4],
#   ['紀念章', 4],
#   ['吃過', 4],
#   ['朋友', 4],
#   ['愛', 4],
#   ['餐廳', 4],
#   ['分享', 4],
#   ['隨便', 4],
#   ['老公', 4],
#   ['白河', 4],
#   ['蓮花', 4],
#   ['分類', 4],
#   ['索引', 4],
#   ['導覽', 4],
#   ['粉絲', 4],
#   ['專頁', 4],
#   ['價錢', 4],
#   ['不錯', 4],
#   ['好久沒', 4],
#   ['周氏', 3],
#   ['消暑', 3],
#   ['兩個', 3],
#   ['名人', 3],
#   ['歷史', 3],
#   ['名字', 3],
#   ['精製', 3],
#   ['熬', 3],
#   ['軟', 3],
#   ['享用', 3],
#   ['試試', 3],
#   ['入口即化', 3],
#   ['下', 3],
#   ['甜品', 3],
#   ['無敵', 3],
#   ['小顆', 3],
#   ['飲料', 3],
#   ['可惜', 3],
#   ['整體', 3],
#   ['第一次', 3],
#   ['還沒', 3],
#   ['高朋滿座', 3],
#   ['坐', 3],
#   ['三種', 3],
#   ['那種', 3],
#   ['香甜', 3],
#   ['淡淡的', 3],
#   ['相關', 3],
#   ['小孩', 3],
#   ['便宜', 3],
#   ['鍋燒', 3],
#   ['肉', 3],
#   ['感', 3],
#   ['花香', 3],
#   ['吸引', 3],
#   ['醬鴨', 3],
#   ['不到', 3],
#   ['市場', 3],
#   ['是點', 3],
#   ['虱目', 3],
#   ['晚餐', 3],
#   ['同事', 3]]}

# %%
# [dien['style'] for dien in bigtable]

# %%
#經緯度換算公尺
def transDoToM(doo):
    return doo*101751.561277

# %%
# import json
# with open('D:/Data/JsonData/TainanFood/FinishTainanBigTable.json') as f:
#     bigtable=json.load(f)

# %%
TainanStationLoc=(22.997183,120.212577)
RedCutBuild=(22.997478,120.202543)
GodRoad=(22.997295,120.197187)

# %%
bigtable[0].keys()
# Out:
# dict_keys(['_id', 'name', 'style', 'Ncomment', 'contentcut', 'wordCount', 'TF_IDF', 'pinCountMaxper5', 'score', 'featurescores', 'tags', 'introduction', 'coordinate', 'opentime', 'closetime', 'address', 'tel'])

# %%
bigtable[0]['coordinate'].keys()
# Out:
# dict_keys(['lat', 'lng'])

# %%
from collections import Counter

# %%
TainanStationDien500={}
for dien in bigtable:
    if dien['style']=="異國料理":
        if dien['coordinate']!=None:
            if (((dien['coordinate']['lat']-TainanStationLoc[0])**2+
                 (dien['coordinate']['lng']-TainanStationLoc[1])**2)**(1/2))*101751.561277<500 and dien['Ncomment']>7:
                TainanStationDien500[dien['name']]=dien['score']
print(len(TainanStationDien500))
TainanStationDien500_5=dict(Counter(TainanStationDien500).most_common(7))
# Out:
# 18

# %%
RedCutBuildDien500={}
for dien in bigtable:
    if dien['style']=="甜點(合併飲品)":
        if dien['coordinate']!=None:
            if (((dien['coordinate']['lat']-RedCutBuild[0])**2+
                 (dien['coordinate']['lng']-RedCutBuild[1])**2)**(1/2))*101751.561277<500 and dien['Ncomment']>7:
                RedCutBuildDien500[dien['name']]=dien['score']
print(len(RedCutBuildDien500))
RedCutBuildDien500_5=dict(Counter(RedCutBuildDien500).most_common(7))
# Out:
# 19

# %%
GodRoadDien500={}
for dien in bigtable:
    if dien['style']=="小吃":
        if dien['coordinate']!=None:
            if (((dien['coordinate']['lat']-GodRoad[0])**2+
                 (dien['coordinate']['lng']-GodRoad[1])**2)**(1/2))*101751.561277<500 and dien['Ncomment']>7:
                GodRoadDien500[dien['name']]=dien['score']
print(len(GodRoadDien500))
GodRoadDien500_5=dict(Counter(GodRoadDien500).most_common(7))
# Out:
# 64

# %%
dienVec={dien['name']:dien['featurescores'] for dien in bigtable}
dienVec
# Out:
# {'同記安平豆花(安平總店)': {'份量大': 0.13,
#   '偏甜': 0.24,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.19,
#   '划算': 0.19,
#   '口味清淡': 0.07,
#   '服務好': -0.15,
#   '環境好': 0.14,
#   '食物很香': 0.22,
#   '食物精緻漂亮': 0.19,
#   '食物美味': 0.37},
#  '深藍咖啡館': {'份量大': 0.04,
#   '偏甜': 0.33,
#   '其他正面情緒': 0.21,
#   '划算': -0.8,
#   '小份量': 0.05,
#   '服務好': 0.13,
#   '環境好': 0.25,
#   '重口味': 0.06,
#   '食物很香': 0.29,
#   '食物精緻漂亮': 0.3,
#   '食物美味': 0.61},
#  '阿堂鹹粥': {'份量大': 0.48,
#   '偏甜': 0.12,
#   '偏辣': 0.02,
#   '其他正面情緒': 0.24,
#   '划算': -0.23,
#   '口味清淡': 0.02,
#   '服務好': 0.09,
#   '環境好': 0.04,
#   '重口味': 0.08,
#   '食物很香': 0.1,
#   '食物精緻漂亮': 0.23,
#   '食物美味': 0.61},
#  '富盛號碗粿': {'份量大': 0.4,
#   '偏甜': 0.41,
#   '偏辣': 0.09,
#   '其他正面情緒': 0.24,
#   '划算': 0.18,
#   '口味清淡': 0.04,
#   '小份量': 0.03,
#   '服務好': 0.11,
#   '環境好': 0.29,
#   '重口味': 0.14,
#   '食物很香': 0.12,
#   '食物精緻漂亮': 0.24,
#   '食物美味': 0.58},
#  '依蕾特布丁奶酪(安平門市)': {'份量大': 0.08,
#   '偏甜': 0.29,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.15,
#   '划算': 0.06,
#   '口味清淡': 0.07,
#   '小份量': 0.05,
#   '環境好': 0.08,
#   '食物很香': 0.29,
#   '食物精緻漂亮': 0.1,
#   '食物美味': 0.55},
#  '食下有約 想法廚房': {'份量大': 0.54,
#   '偏甜': 0.28,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.66,
#   '划算': 0.18,
#   '口味清淡': 0.07,
#   '小份量': 0.21,
#   '服務好': 0.15,
#   '環境好': 0.97,
#   '重口味': 0.18,
#   '食物很香': 0.82,
#   '食物精緻漂亮': 0.97,
#   '食物美味': 1.36},
#  '飛饗創意西式料理': {'份量大': 0.65,
#   '偏甜': 0.47,
#   '偏辣': 0.12,
#   '偏酸': 0.8,
#   '其他正面情緒': 0.85,
#   '划算': 0.31,
#   '口味清淡': 0.36,
#   '小份量': 0.16,
#   '服務好': 0.51,
#   '環境好': 1.06,
#   '重口味': 0.31,
#   '食物很香': 0.69,
#   '食物精緻漂亮': 1.28,
#   '食物美味': 1.33},
#  '莉莉水果店': {'份量大': 0.28,
#   '偏甜': 0.35,
#   '偏辣': 0.02,
#   '偏酸': 0.05,
#   '其他正面情緒': 0.34,
#   '划算': -0.11,
#   '服務好': 0.22,
#   '環境好': 0.19,
#   '重口味': 0.11,
#   '食物很香': 0.08,
#   '食物精緻漂亮': 0.34,
#   '食物美味': 0.53},
#  '連得堂餅舖': {'份量大': 0.04,
#   '偏甜': 0.07,
#   '其他正面情緒': 0.08,
#   '划算': -0.01,
#   '服務好': 0.0,
#   '環境好': 0.1,
#   '重口味': 0.09,
#   '食物很香': 0.28,
#   '食物精緻漂亮': 0.28,
#   '食物美味': 0.3},
#  '矮仔成蝦仁飯': {'份量大': 0.23,
#   '偏甜': 0.16,
#   '偏辣': 0.12,
#   '其他正面情緒': 0.13,
#   '划算': -0.02,
#   '口味清淡': 0.02,
#   '小份量': 0.01,
#   '服務好': 0.09,
#   '環境好': 0.25,
#   '重口味': 0.18,
#   '食物很香': 0.23,
#   '食物精緻漂亮': 0.2,
#   '食物美味': 0.55},
#  '泰成水果店': {'份量大': 0.24,
#   '偏甜': 0.44,
#   '偏辣': 0.08,
#   '偏酸': 0.05,
#   '其他正面情緒': 0.32,
#   '划算': -0.15,
#   '口味清淡': 0.02,
#   '小份量': 0.01,
#   '服務好': 0.2,
#   '環境好': 0.33,
#   '重口味': 0.05,
#   '食物很香': 0.2,
#   '食物精緻漂亮': 0.51,
#   '食物美味': 0.58},
#  '騷烤家(前鋒總店)': {'份量大': 0.34,
#   '偏甜': 0.05,
#   '偏辣': 0.18,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.53,
#   '划算': 0.23,
#   '口味清淡': 0.36,
#   '小份量': 0.05,
#   '服務好': 0.22,
#   '環境好': 0.32,
#   '重口味': 0.49,
#   '食物很香': 0.64,
#   '食物精緻漂亮': 0.5,
#   '食物美味': 1.29},
#  '阿松割包': {'份量大': 0.29,
#   '偏甜': 0.21,
#   '偏辣': 0.03,
#   '其他正面情緒': 0.17,
#   '划算': -0.03,
#   '口味清淡': 0.02,
#   '小份量': 0.01,
#   '服務好': 0.11,
#   '環境好': 0.23,
#   '重口味': 0.06,
#   '食物很香': 0.21,
#   '食物精緻漂亮': 0.32,
#   '食物美味': 0.63},
#  '秉醇烘焙坊': {'份量大': 0.16,
#   '偏甜': 0.54,
#   '其他正面情緒': 0.66,
#   '划算': 0.28,
#   '小份量': 0.07,
#   '環境好': 0.1,
#   '重口味': 0.15,
#   '食物很香': 1.04,
#   '食物精緻漂亮': 0.73,
#   '食物美味': 0.86},
#  '冰鄉': {'份量大': 0.47,
#   '偏甜': 0.16,
#   '偏辣': 0.06,
#   '偏酸': 0.1,
#   '其他正面情緒': 0.23,
#   '划算': 0.37,
#   '服務好': 0.22,
#   '環境好': 0.17,
#   '重口味': 0.09,
#   '食物很香': 0.21,
#   '食物精緻漂亮': 0.18,
#   '食物美味': 0.42},
#  '小銅鍋義式餐廳(德安誠品店)': {'份量大': 0.65,
#   '偏甜': 0.11,
#   '偏辣': 0.26,
#   '偏酸': 0.65,
#   '其他正面情緒': 0.62,
#   '划算': 0.18,
#   '口味清淡': 0.24,
#   '小份量': 0.17,
#   '服務好': 0.31,
#   '環境好': 1.13,
#   '重口味': 0.45,
#   '食物很香': 0.99,
#   '食物精緻漂亮': 0.71,
#   '食物美味': 1.7},
#  '周氏蝦捲(總店)': {'份量大': 0.23,
#   '偏甜': 0.21,
#   '其他正面情緒': 0.13,
#   '划算': -0.1,
#   '小份量': 0.04,
#   '環境好': 0.12,
#   '重口味': 0.09,
#   '食物很香': 0.1,
#   '食物精緻漂亮': 0.23,
#   '食物美味': 0.63},
#  '大菜市純薏仁': {'份量大': 0.08,
#   '偏甜': 0.61,
#   '其他正面情緒': 0.3,
#   '划算': 0.06,
#   '小份量': 0.16,
#   '服務好': 0.07,
#   '環境好': 0.36,
#   '食物很香': 0.13,
#   '食物精緻漂亮': 0.44,
#   '食物美味': 0.48},
#  '聯盈發點心專門店': {'份量大': 0.27,
#   '偏甜': 0.56,
#   '其他正面情緒': 0.26,
#   '划算': 0.4,
#   '口味清淡': 0.05,
#   '小份量': 0.12,
#   '服務好': 0.11,
#   '環境好': 0.07,
#   '重口味': 0.18,
#   '食物很香': 0.27,
#   '食物精緻漂亮': 0.48,
#   '食物美味': 0.8},
#  'OMAYA春川炒雞(台南永華店)': {'份量大': 0.69,
#   '偏甜': 0.35,
#   '偏辣': 0.34,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.49,
#   '划算': 0.34,
#   '口味清淡': 0.31,
#   '服務好': 0.55,
#   '環境好': 0.74,
#   '重口味': 0.32,
#   '食物很香': 0.74,
#   '食物精緻漂亮': 0.42,
#   '食物美味': 1.16},
#  '西井村蜂蜜滷味(安平店)': {'份量大': 0.16,
#   '偏甜': 0.12,
#   '其他正面情緒': 0.28,
#   '划算': 0.1,
#   '口味清淡': 0.18,
#   '小份量': 1.65,
#   '服務好': 0.25,
#   '環境好': 0.24,
#   '重口味': 0.8,
#   '食物很香': 0.4,
#   '食物精緻漂亮': 0.45,
#   '食物美味': 0.85},
#  '瑞益行': {'份量大': 0.12,
#   '偏甜': 0.71,
#   '其他正面情緒': 0.92,
#   '划算': 0.02,
#   '小份量': 0.07,
#   '服務好': 0.0,
#   '環境好': 0.18,
#   '重口味': 0.08,
#   '食物很香': 1.11,
#   '食物精緻漂亮': 0.64,
#   '食物美味': 0.76},
#  '六千牛肉湯': {'份量大': 0.48,
#   '偏甜': 0.06,
#   '偏辣': 0.02,
#   '其他正面情緒': 0.14,
#   '划算': 0.02,
#   '口味清淡': 0.09,
#   '小份量': 0.01,
#   '服務好': 0.07,
#   '環境好': 0.15,
#   '重口味': 0.23,
#   '食物很香': 0.13,
#   '食物精緻漂亮': 0.16,
#   '食物美味': 0.68},
#  '文章牛肉湯': {'份量大': 0.26,
#   '偏甜': 0.11,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.19,
#   '划算': 0.17,
#   '口味清淡': 0.05,
#   '服務好': 0.04,
#   '環境好': 0.15,
#   '重口味': 0.17,
#   '食物很香': 0.23,
#   '食物精緻漂亮': 0.26,
#   '食物美味': 0.58},
#  '拿滋派瑞 Nuts Pirates': {'份量大': 0.03,
#   '偏甜': 0.33,
#   '偏辣': 0.22,
#   '其他正面情緒': 0.64,
#   '划算': 0.16,
#   '口味清淡': 0.09,
#   '服務好': 0.33,
#   '環境好': 0.17,
#   '重口味': 0.22,
#   '食物很香': 0.57,
#   '食物精緻漂亮': 1.23,
#   '食物美味': 0.83},
#  '陳家蚵捲': {'份量大': 0.1,
#   '偏甜': 0.16,
#   '偏辣': 0.15,
#   '其他正面情緒': 0.13,
#   '划算': -0.09,
#   '口味清淡': 0.04,
#   '小份量': 0.03,
#   '環境好': 0.19,
#   '重口味': 0.11,
#   '食物很香': 0.05,
#   '食物精緻漂亮': 0.17,
#   '食物美味': 0.58},
#  'EVA伊娃日式泡芙專賣店': {'份量大': 0.22,
#   '偏甜': 0.38,
#   '其他正面情緒': 0.19,
#   '划算': -0.12,
#   '口味清淡': 0.16,
#   '服務好': 0.09,
#   '環境好': 0.26,
#   '重口味': 0.15,
#   '食物很香': 0.04,
#   '食物精緻漂亮': 0.44,
#   '食物美味': 0.54},
#  'A WEEK PANCAKE&COFFEE': {'份量大': 0.31,
#   '偏甜': 0.54,
#   '偏酸': 0.25,
#   '其他正面情緒': 0.41,
#   '划算': 0.09,
#   '口味清淡': 0.09,
#   '小份量': 0.19,
#   '服務好': 0.51,
#   '環境好': 0.86,
#   '重口味': 0.15,
#   '食物很香': 0.48,
#   '食物精緻漂亮': 0.73,
#   '食物美味': 0.95},
#  '邱家小卷米粉': {'份量大': 0.28,
#   '偏甜': 0.4,
#   '偏辣': 0.05,
#   '其他正面情緒': 0.18,
#   '划算': -0.14,
#   '口味清淡': 0.02,
#   '小份量': 0.05,
#   '服務好': 0.04,
#   '環境好': 0.12,
#   '重口味': 0.06,
#   '食物很香': 0.12,
#   '食物精緻漂亮': 0.24,
#   '食物美味': 0.49},
#  '阿裕現宰牛肉涮涮鍋': {'份量大': 0.18,
#   '偏甜': 0.14,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.23,
#   '划算': -0.08,
#   '服務好': 0.07,
#   '環境好': 0.03,
#   '重口味': 0.06,
#   '食物很香': 0.24,
#   '食物精緻漂亮': 0.31,
#   '食物美味': 0.83},
#  '山根壽司': {'份量大': 0.44,
#   '偏甜': 0.25,
#   '偏辣': 0.26,
#   '偏酸': 0.1,
#   '其他正面情緒': 0.33,
#   '划算': 0.74,
#   '小份量': 0.03,
#   '服務好': 0.42,
#   '環境好': 0.36,
#   '重口味': 0.09,
#   '食物很香': 0.09,
#   '食物精緻漂亮': 0.48,
#   '食物美味': 0.67},
#  '金得春捲': {'份量大': 0.37,
#   '偏甜': 0.38,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.23,
#   '划算': 0.18,
#   '小份量': 0.01,
#   '服務好': 0.07,
#   '環境好': 0.17,
#   '重口味': 0.03,
#   '食物很香': 0.21,
#   '食物精緻漂亮': 0.27,
#   '食物美味': 0.62},
#  '克林台包': {'偏甜': 0.22,
#   '其他正面情緒': 0.21,
#   '划算': -0.17,
#   '環境好': 0.07,
#   '食物很香': 0.26,
#   '食物精緻漂亮': 0.19,
#   '食物美味': 0.42},
#  'Doga香酥脆椒': {'份量大': 0.05,
#   '偏甜': 0.05,
#   '偏辣': 0.92,
#   '其他正面情緒': 0.1,
#   '划算': 0.04,
#   '小份量': 0.05,
#   '環境好': 0.14,
#   '重口味': 0.68,
#   '食物很香': 0.1,
#   '食物精緻漂亮': 0.4,
#   '食物美味': 0.43},
#  '懷舊小棧': {'份量大': 0.21,
#   '偏甜': 0.22,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.2,
#   '划算': 0.15,
#   '口味清淡': 0.07,
#   '服務好': 0.07,
#   '環境好': 0.14,
#   '重口味': 0.06,
#   '食物很香': 0.3,
#   '食物精緻漂亮': 0.19,
#   '食物美味': 0.42},
#  'FUN Tower日式可麗餅': {'份量大': 0.26,
#   '偏甜': 0.47,
#   '偏酸': 1.6,
#   '其他正面情緒': 0.48,
#   '划算': 0.08,
#   '小份量': 0.05,
#   '服務好': 0.87,
#   '環境好': 0.5,
#   '重口味': 0.12,
#   '食物很香': 0.3,
#   '食物精緻漂亮': 0.55,
#   '食物美味': 0.91},
#  '阿憨鹹粥': {'份量大': 0.31,
#   '偏甜': 0.16,
#   '其他正面情緒': 0.21,
#   '划算': -0.07,
#   '服務好': 0.07,
#   '環境好': 0.15,
#   '重口味': 0.02,
#   '食物很香': 0.11,
#   '食物精緻漂亮': 0.19,
#   '食物美味': 0.52},
#  '花見宇治抹茶甘味処': {'份量大': 0.13,
#   '偏甜': 0.53,
#   '其他正面情緒': 0.23,
#   '划算': 0.37,
#   '服務好': 0.36,
#   '環境好': 0.48,
#   '重口味': 0.06,
#   '食物很香': 0.2,
#   '食物精緻漂亮': 0.5,
#   '食物美味': 0.81},
#  '鹿早茶屋': {'份量大': 0.52,
#   '偏甜': 0.31,
#   '偏辣': 0.08,
#   '偏酸': 0.25,
#   '其他正面情緒': 0.47,
#   '划算': 0.19,
#   '口味清淡': 0.09,
#   '小份量': 0.19,
#   '服務好': 0.29,
#   '環境好': 0.57,
#   '重口味': 0.03,
#   '食物很香': 0.43,
#   '食物精緻漂亮': 0.88,
#   '食物美味': 0.65},
#  '窩吧': {'份量大': 0.35,
#   '偏甜': 0.19,
#   '偏酸': 0.6,
#   '其他正面情緒': 0.51,
#   '划算': 0.21,
#   '小份量': 1.03,
#   '服務好': 0.15,
#   '環境好': 1.11,
#   '重口味': 0.25,
#   '食物很香': 0.35,
#   '食物精緻漂亮': 0.79,
#   '食物美味': 0.67},
#  'Kadoya喫茶店': {'份量大': 0.02,
#   '偏甜': 0.49,
#   '偏酸': 0.15,
#   '其他正面情緒': 0.21,
#   '划算': 0.03,
#   '小份量': 0.08,
#   '服務好': 0.22,
#   '環境好': 0.39,
#   '重口味': 0.23,
#   '食物很香': 0.3,
#   '食物精緻漂亮': 0.58,
#   '食物美味': 0.67},
#  '王西勢食品行': {'份量大': 0.08,
#   '偏甜': 0.19,
#   '其他正面情緒': 0.48,
#   '划算': 0.04,
#   '小份量': 0.05,
#   '服務好': 0.07,
#   '環境好': 0.17,
#   '重口味': 0.06,
#   '食物很香': 0.32,
#   '食物精緻漂亮': 0.74,
#   '食物美味': 0.38},
#  '窄門咖啡': {'份量大': 0.1,
#   '偏甜': 0.12,
#   '偏辣': 0.03,
#   '偏酸': 0.1,
#   '其他正面情緒': 0.28,
#   '划算': -0.09,
#   '小份量': 0.11,
#   '服務好': 0.0,
#   '環境好': 0.43,
#   '重口味': 0.03,
#   '食物很香': 0.1,
#   '食物精緻漂亮': 0.29,
#   '食物美味': 0.17},
#  '秀治咖啡簡餐(臨安店)': {'份量大': 0.53,
#   '偏甜': 0.22,
#   '偏辣': 0.22,
#   '其他正面情緒': 0.77,
#   '划算': 0.33,
#   '口味清淡': 0.72,
#   '服務好': 0.59,
#   '環境好': 0.51,
#   '重口味': 0.29,
#   '食物很香': 0.16,
#   '食物精緻漂亮': 0.51,
#   '食物美味': 0.67},
#  '橋北屋日本家庭料理(永福店)': {'份量大': 0.17,
#   '偏甜': 0.05,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.17,
#   '划算': 0.31,
#   '口味清淡': 0.24,
#   '服務好': 0.07,
#   '環境好': 0.29,
#   '重口味': 0.12,
#   '食物很香': 0.17,
#   '食物精緻漂亮': 0.13,
#   '食物美味': 0.64},
#  '歐加里(台南大學店)': {'份量大': 0.34,
#   '偏甜': 0.33,
#   '偏辣': 0.12,
#   '偏酸': 0.6,
#   '其他正面情緒': 0.65,
#   '划算': 0.78,
#   '口味清淡': 0.15,
#   '小份量': 0.27,
#   '服務好': 1.16,
#   '環境好': 0.73,
#   '重口味': 0.37,
#   '食物很香': 0.72,
#   '食物精緻漂亮': 1.45,
#   '食物美味': 1.51},
#  '華侖婷娜': {'偏甜': 0.75,
#   '偏辣': 0.35,
#   '其他正面情緒': 0.51,
#   '划算': 0.14,
#   '口味清淡': 0.25,
#   '小份量': 0.24,
#   '服務好': 0.65,
#   '環境好': 0.69,
#   '重口味': 0.29,
#   '食物很香': 0.65,
#   '食物精緻漂亮': 1.67,
#   '食物美味': 0.42},
#  '阿明豬心': {'份量大': 0.22,
#   '偏甜': 0.11,
#   '偏辣': 0.05,
#   '其他正面情緒': 0.23,
#   '划算': -0.03,
#   '口味清淡': 0.13,
#   '小份量': 0.01,
#   '服務好': 0.29,
#   '環境好': 0.06,
#   '重口味': 0.32,
#   '食物很香': 0.07,
#   '食物精緻漂亮': 0.24,
#   '食物美味': 0.72},
#  '旗哥牛肉湯': {'份量大': 0.25,
#   '偏甜': 0.06,
#   '偏辣': 0.03,
#   '偏酸': 0.1,
#   '其他正面情緒': 0.16,
#   '划算': -0.1,
#   '口味清淡': 0.05,
#   '服務好': 0.07,
#   '環境好': 0.04,
#   '重口味': 0.26,
#   '食物很香': 0.14,
#   '食物精緻漂亮': 0.16,
#   '食物美味': 0.55},
#  '裕成水果店': {'份量大': 0.25,
#   '偏甜': 0.21,
#   '其他正面情緒': 0.2,
#   '划算': -0.32,
#   '小份量': 0.03,
#   '環境好': 0.13,
#   '食物很香': 0.13,
#   '食物精緻漂亮': 0.25,
#   '食物美味': 0.39},
#  '太陽牌冰品': {'份量大': 0.14,
#   '偏甜': 0.39,
#   '偏酸': 0.1,
#   '其他正面情緒': 0.2,
#   '划算': 0.0,
#   '服務好': 0.11,
#   '環境好': 0.21,
#   '重口味': 0.06,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 0.28,
#   '食物美味': 0.59},
#  '赤崁棺材板': {'份量大': 0.4,
#   '偏甜': 0.19,
#   '偏辣': 0.05,
#   '其他正面情緒': 0.18,
#   '划算': -0.01,
#   '服務好': 0.09,
#   '環境好': 0.19,
#   '重口味': 0.17,
#   '食物很香': 0.17,
#   '食物精緻漂亮': 0.23,
#   '食物美味': 0.7},
#  '保哥黑輪': {'份量大': 0.17,
#   '偏甜': 0.02,
#   '偏辣': 0.03,
#   '其他正面情緒': 0.12,
#   '划算': 0.14,
#   '口味清淡': 0.04,
#   '小份量': 0.03,
#   '服務好': 0.15,
#   '環境好': 0.19,
#   '重口味': 0.09,
#   '食物很香': 0.22,
#   '食物精緻漂亮': 0.24,
#   '食物美味': 0.35},
#  'KAFFE @ HOME': {'份量大': 0.78,
#   '偏甜': 0.29,
#   '偏辣': 0.06,
#   '偏酸': 0.35,
#   '其他正面情緒': 0.51,
#   '划算': 0.37,
#   '口味清淡': 0.07,
#   '小份量': 1.48,
#   '服務好': 0.27,
#   '環境好': 0.96,
#   '重口味': 0.45,
#   '食物很香': 0.49,
#   '食物精緻漂亮': 0.36,
#   '食物美味': 1.03},
#  '福記肉圓(總店)': {'份量大': 0.15,
#   '偏甜': 0.32,
#   '其他正面情緒': 0.25,
#   '划算': 0.09,
#   '環境好': 0.06,
#   '重口味': 0.12,
#   '食物很香': 0.04,
#   '食物精緻漂亮': 0.14,
#   '食物美味': 0.5},
#  '益生堂凡吉力樂園': {'份量大': 0.03,
#   '偏甜': 0.4,
#   '偏辣': 0.08,
#   '偏酸': 0.25,
#   '其他正面情緒': 0.58,
#   '划算': 0.05,
#   '口味清淡': 0.18,
#   '小份量': 0.07,
#   '服務好': 0.09,
#   '環境好': 0.12,
#   '重口味': 0.23,
#   '食物很香': 0.57,
#   '食物精緻漂亮': 0.73,
#   '食物美味': 0.45},
#  '府城騷烤家': {'份量大': 0.29,
#   '偏甜': 0.13,
#   '偏辣': 0.11,
#   '其他正面情緒': 0.45,
#   '划算': 0.45,
#   '口味清淡': 0.07,
#   '服務好': 0.22,
#   '環境好': 0.27,
#   '重口味': 0.38,
#   '食物很香': 0.76,
#   '食物精緻漂亮': 0.28,
#   '食物美味': 1.13},
#  '修安扁擔豆花': {'份量大': 0.08,
#   '偏甜': 0.62,
#   '偏辣': 0.15,
#   '其他正面情緒': 0.15,
#   '划算': -0.12,
#   '小份量': 0.03,
#   '服務好': 0.27,
#   '環境好': 0.18,
#   '重口味': 0.08,
#   '食物很香': 0.28,
#   '食物精緻漂亮': 0.32,
#   '食物美味': 0.41},
#  '無聊郎-懷舊冰品冷飲': {'份量大': 0.03,
#   '偏甜': 1.39,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.27,
#   '划算': -0.02,
#   '口味清淡': 0.07,
#   '服務好': 0.2,
#   '環境好': 0.16,
#   '重口味': 0.06,
#   '食物很香': 0.32,
#   '食物精緻漂亮': 1.65,
#   '食物美味': 0.54},
#  '食香客雞會站雞排專賣(北門總店)': {'份量大': 0.55,
#   '偏甜': 0.49,
#   '偏辣': 0.08,
#   '其他正面情緒': 0.27,
#   '划算': 0.27,
#   '口味清淡': 0.25,
#   '服務好': 0.16,
#   '環境好': 0.27,
#   '重口味': 0.35,
#   '食物很香': 0.68,
#   '食物精緻漂亮': 0.53,
#   '食物美味': 0.94},
#  '轉角餐廳': {'份量大': 0.33,
#   '偏甜': 0.28,
#   '偏辣': 0.23,
#   '偏酸': 0.3,
#   '其他正面情緒': 0.65,
#   '划算': -0.1,
#   '口味清淡': 0.16,
#   '小份量': 0.2,
#   '服務好': 0.6,
#   '環境好': 1.01,
#   '重口味': 0.55,
#   '食物很香': 1.0,
#   '食物精緻漂亮': 0.82,
#   '食物美味': 1.33},
#  '綣綣屋 霜淇淋專賣': {'份量大': 0.05,
#   '偏甜': 0.28,
#   '偏辣': 0.12,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.27,
#   '划算': 0.1,
#   '服務好': 0.31,
#   '環境好': 0.21,
#   '重口味': 0.06,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 0.4,
#   '食物美味': 0.65},
#  '葉家小卷米粉': {'份量大': 0.23,
#   '偏甜': 0.28,
#   '偏辣': 0.12,
#   '其他正面情緒': 0.18,
#   '划算': -0.08,
#   '小份量': 0.03,
#   '服務好': 0.33,
#   '環境好': 0.24,
#   '重口味': 0.18,
#   '食物很香': 0.2,
#   '食物精緻漂亮': 0.33,
#   '食物美味': 0.66},
#  "台南晶英酒店-ROBIN'S": {'份量大': 0.41,
#   '偏甜': 0.36,
#   '偏辣': 0.12,
#   '偏酸': 0.4,
#   '其他正面情緒': 0.53,
#   '划算': -0.11,
#   '小份量': 0.16,
#   '服務好': -0.07,
#   '環境好': 0.42,
#   '重口味': 0.25,
#   '食物很香': 0.33,
#   '食物精緻漂亮': 0.7,
#   '食物美味': 0.91},
#  '碳佐麻里日式燒肉(台南府前店)': {'份量大': 0.36,
#   '偏甜': 0.34,
#   '偏辣': 0.14,
#   '偏酸': 0.5,
#   '其他正面情緒': 0.48,
#   '划算': 0.31,
#   '小份量': 0.13,
#   '環境好': 0.52,
#   '重口味': 0.35,
#   '食物很香': 0.15,
#   '食物精緻漂亮': 0.55,
#   '食物美味': 1.18},
#  '1010湘(台南三越西門店)': {'份量大': 0.25,
#   '偏甜': 0.38,
#   '偏辣': 0.92,
#   '偏酸': 0.45,
#   '其他正面情緒': 0.34,
#   '划算': -0.13,
#   '口味清淡': 0.18,
#   '服務好': 0.69,
#   '環境好': 0.31,
#   '重口味': 1.28,
#   '食物很香': 0.44,
#   '食物精緻漂亮': 0.61,
#   '食物美味': 1.07},
#  'a Room 房間': {'份量大': 0.06,
#   '偏甜': 0.06,
#   '其他正面情緒': 0.34,
#   '划算': 0.04,
#   '小份量': 0.44,
#   '服務好': 0.25,
#   '環境好': 0.43,
#   '食物很香': 0.27,
#   '食物精緻漂亮': 0.36,
#   '食物美味': 0.3},
#  '永樂燒肉飯': {'份量大': 0.38,
#   '偏甜': 0.28,
#   '偏辣': 0.08,
#   '其他正面情緒': 0.21,
#   '划算': 0.13,
#   '口味清淡': 0.04,
#   '小份量': 0.03,
#   '服務好': 0.09,
#   '環境好': 0.19,
#   '重口味': 0.09,
#   '食物很香': 0.19,
#   '食物精緻漂亮': 0.23,
#   '食物美味': 0.39},
#  '紙上城市(安平店)': {'份量大': 0.23,
#   '偏辣': 0.29,
#   '偏酸': 0.93,
#   '其他正面情緒': 0.18,
#   '划算': 0.37,
#   '口味清淡': 0.28,
#   '小份量': 0.24,
#   '服務好': 0.33,
#   '環境好': 0.27,
#   '重口味': 0.74,
#   '食物很香': 0.35,
#   '食物精緻漂亮': 0.56,
#   '食物美味': 0.76},
#  'L+B coffee 綠色咖啡館': {'份量大': 0.59,
#   '偏甜': 0.52,
#   '偏辣': 0.15,
#   '偏酸': 0.25,
#   '其他正面情緒': 0.74,
#   '划算': 0.42,
#   '口味清淡': 0.09,
#   '小份量': 0.83,
#   '服務好': 0.62,
#   '環境好': 0.95,
#   '重口味': 0.08,
#   '食物很香': 0.2,
#   '食物精緻漂亮': 0.92,
#   '食物美味': 0.92},
#  '台南商務會館-港式飲茶': {'份量大': 0.59,
#   '偏甜': 0.19,
#   '其他正面情緒': 0.37,
#   '划算': 0.29,
#   '口味清淡': 0.22,
#   '小份量': 0.05,
#   '服務好': 0.45,
#   '環境好': 0.68,
#   '重口味': 0.92,
#   '食物很香': 0.33,
#   '食物精緻漂亮': 0.42,
#   '食物美味': 0.96},
#  '牛軋本舖': {'份量大': 0.03,
#   '偏甜': 0.24,
#   '其他正面情緒': 0.45,
#   '划算': 0.26,
#   '服務好': 0.09,
#   '環境好': 0.21,
#   '重口味': 0.08,
#   '食物很香': 0.66,
#   '食物精緻漂亮': 0.43,
#   '食物美味': 0.72},
#  '碗稞蘭': {'份量大': 0.1,
#   '偏辣': 0.08,
#   '其他正面情緒': 0.08,
#   '划算': 0.27,
#   '環境好': 0.07,
#   '重口味': 0.08,
#   '食物很香': 0.13,
#   '食物精緻漂亮': 0.11,
#   '食物美味': 0.43},
#  '葡吉麵包店': {'份量大': 0.3,
#   '偏甜': 0.2,
#   '其他正面情緒': 0.52,
#   '划算': -0.11,
#   '小份量': 0.11,
#   '服務好': 0.07,
#   '環境好': 0.25,
#   '食物很香': 0.52,
#   '食物精緻漂亮': 0.5,
#   '食物美味': 0.69},
#  'WIRE破屋': {'份量大': 0.03,
#   '偏甜': 0.06,
#   '其他正面情緒': 0.24,
#   '划算': 0.23,
#   '口味清淡': 0.09,
#   '小份量': 0.13,
#   '服務好': 0.18,
#   '環境好': 0.29,
#   '重口味': 0.08,
#   '食物很香': 0.2,
#   '食物精緻漂亮': 0.32,
#   '食物美味': 0.3},
#  '周氏蝦捲(老店)': {'份量大': 0.21,
#   '偏甜': 0.05,
#   '偏辣': 0.12,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.12,
#   '划算': 0.03,
#   '環境好': 0.25,
#   '重口味': 0.06,
#   '食物很香': 0.06,
#   '食物精緻漂亮': 0.15,
#   '食物美味': 0.55},
#  '義豐冬瓜茶': {'份量大': 0.34,
#   '偏甜': 0.52,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.21,
#   '划算': 0.12,
#   '小份量': 0.01,
#   '服務好': 0.18,
#   '環境好': 0.23,
#   '重口味': 0.05,
#   '食物很香': 0.19,
#   '食物精緻漂亮': 0.23,
#   '食物美味': 0.57},
#  '黑工號嫩仙草': {'份量大': 0.64,
#   '偏甜': 0.59,
#   '其他正面情緒': 0.41,
#   '划算': 0.18,
#   '口味清淡': 0.07,
#   '小份量': 0.05,
#   '服務好': 0.44,
#   '環境好': 0.37,
#   '重口味': 0.06,
#   '食物很香': 0.35,
#   '食物精緻漂亮': 0.33,
#   '食物美味': 0.77},
#  '武廟肉圓': {'份量大': 0.12,
#   '偏甜': 0.25,
#   '偏辣': 0.15,
#   '其他正面情緒': 0.2,
#   '划算': -0.2,
#   '口味清淡': 0.04,
#   '小份量': 0.01,
#   '服務好': 0.04,
#   '環境好': 0.11,
#   '重口味': 0.29,
#   '食物很香': 0.1,
#   '食物精緻漂亮': 0.2,
#   '食物美味': 0.58},
#  '安平貓小巴': {'份量大': 0.04,
#   '偏甜': 0.04,
#   '其他正面情緒': 0.16,
#   '划算': -0.12,
#   '服務好': 0.11,
#   '環境好': 0.19,
#   '食物很香': 0.07,
#   '食物精緻漂亮': 0.91,
#   '食物美味': 0.19},
#  '勝利早點': {'份量大': 0.45,
#   '偏甜': 0.36,
#   '偏辣': 0.11,
#   '其他正面情緒': 0.28,
#   '划算': 0.34,
#   '口味清淡': 0.04,
#   '小份量': 0.03,
#   '服務好': -0.29,
#   '環境好': 0.01,
#   '重口味': 0.12,
#   '食物很香': 0.1,
#   '食物精緻漂亮': 0.21,
#   '食物美味': 0.55},
#  "瑪莉洋房 Marie's House": {'份量大': 0.15,
#   '偏甜': 0.14,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.89,
#   '划算': -0.32,
#   '口味清淡': 0.07,
#   '小份量': 0.17,
#   '服務好': 1.02,
#   '環境好': 1.49,
#   '重口味': 0.38,
#   '食物很香': 0.95,
#   '食物精緻漂亮': 0.91,
#   '食物美味': 1.77},
#  '集品蝦仁飯': {'份量大': 0.25,
#   '偏甜': 0.19,
#   '偏辣': 0.03,
#   '偏酸': 0.1,
#   '其他正面情緒': 0.2,
#   '划算': -0.03,
#   '小份量': 0.03,
#   '服務好': 0.09,
#   '環境好': 0.11,
#   '重口味': 0.28,
#   '食物很香': 0.22,
#   '食物精緻漂亮': 0.15,
#   '食物美味': 0.47},
#  '雙全紅茶': {'份量大': 0.3,
#   '偏甜': 0.35,
#   '偏辣': 0.25,
#   '其他正面情緒': 0.29,
#   '划算': -0.25,
#   '口味清淡': 0.04,
#   '小份量': 0.05,
#   '服務好': 0.18,
#   '環境好': 0.31,
#   '重口味': 0.12,
#   '食物很香': 0.24,
#   '食物精緻漂亮': 0.36,
#   '食物美味': 0.52},
#  '義豐阿川冬瓜茶': {'份量大': 0.2,
#   '偏甜': 0.41,
#   '偏辣': 0.22,
#   '其他正面情緒': 0.23,
#   '划算': 0.05,
#   '口味清淡': 0.11,
#   '小份量': 0.04,
#   '服務好': 0.35,
#   '環境好': 0.28,
#   '重口味': 0.14,
#   '食物很香': 0.24,
#   '食物精緻漂亮': 0.25,
#   '食物美味': 0.5},
#  '咩 灣裡羊肉(總店)': {'份量大': 0.06,
#   '偏甜': 0.06,
#   '偏辣': 0.08,
#   '其他正面情緒': 0.4,
#   '划算': 0.18,
#   '口味清淡': 0.47,
#   '服務好': 0.76,
#   '環境好': 0.6,
#   '重口味': 0.48,
#   '食物很香': 0.48,
#   '食物精緻漂亮': 0.54,
#   '食物美味': 1.05},
#  '鬍扯瓦夫': {'份量大': 0.19,
#   '偏甜': 0.45,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.54,
#   '划算': 0.57,
#   '服務好': 0.38,
#   '環境好': 0.26,
#   '重口味': 0.58,
#   '食物很香': 0.23,
#   '食物精緻漂亮': 1.15,
#   '食物美味': 0.7},
#  '禾記嫩骨飯HoChe(南門旗艦店)': {'份量大': 0.47,
#   '偏甜': 0.37,
#   '偏辣': 0.38,
#   '偏酸': 0.48,
#   '其他正面情緒': 0.25,
#   '划算': 0.04,
#   '服務好': 0.1,
#   '環境好': 0.71,
#   '重口味': 0.13,
#   '食物很香': 0.48,
#   '食物精緻漂亮': 0.45,
#   '食物美味': 0.77},
#  '毛丼 丼飯專門店': {'份量大': 0.23,
#   '偏甜': 0.34,
#   '偏辣': 0.26,
#   '其他正面情緒': 0.25,
#   '划算': 0.16,
#   '服務好': 0.29,
#   '環境好': 0.28,
#   '重口味': 0.18,
#   '食物很香': 0.16,
#   '食物精緻漂亮': 0.38,
#   '食物美味': 0.82},
#  '江水號': {'份量大': 0.25,
#   '偏甜': 0.21,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.23,
#   '划算': 0.12,
#   '小份量': 0.03,
#   '服務好': 0.33,
#   '環境好': 0.26,
#   '重口味': 0.02,
#   '食物很香': 0.15,
#   '食物精緻漂亮': 0.29,
#   '食物美味': 0.59},
#  '進來涼冬瓜茶(兩角銀)(安平總店)': {'份量大': 0.09,
#   '偏甜': 0.75,
#   '其他正面情緒': 0.2,
#   '划算': -0.09,
#   '服務好': 0.25,
#   '環境好': 0.18,
#   '食物很香': 0.37,
#   '食物精緻漂亮': 0.39,
#   '食物美味': 0.38},
#  '阿霞飯店': {'份量大': 0.41,
#   '偏甜': 0.42,
#   '偏辣': 0.08,
#   '偏酸': 0.25,
#   '其他正面情緒': 0.36,
#   '划算': -0.08,
#   '口味清淡': 0.04,
#   '小份量': 0.11,
#   '服務好': 0.13,
#   '環境好': 0.25,
#   '重口味': 0.28,
#   '食物很香': 0.38,
#   '食物精緻漂亮': 0.37,
#   '食物美味': 0.68},
#  '小豪洲沙茶爐': {'份量大': 0.25,
#   '偏甜': 0.16,
#   '偏辣': 0.14,
#   '偏酸': 0.1,
#   '其他正面情緒': 0.33,
#   '划算': 0.23,
#   '口味清淡': 0.11,
#   '小份量': 0.03,
#   '服務好': 0.09,
#   '環境好': 0.44,
#   '重口味': 0.4,
#   '食物很香': 0.22,
#   '食物精緻漂亮': 0.46,
#   '食物美味': 0.67},
#  "貓門咖啡 Cafe' Moment": {'份量大': 0.18,
#   '偏甜': 0.05,
#   '其他正面情緒': 0.31,
#   '划算': 0.05,
#   '小份量': 0.56,
#   '服務好': 0.07,
#   '環境好': 0.22,
#   '食物很香': 0.23,
#   '食物精緻漂亮': 1.19,
#   '食物美味': 0.49},
#  '椰庭景觀餐廳': {'份量大': 0.57,
#   '偏甜': 0.14,
#   '其他正面情緒': 0.74,
#   '划算': 0.18,
#   '小份量': 0.08,
#   '服務好': 1.07,
#   '環境好': 0.7,
#   '重口味': 0.46,
#   '食物很香': 0.34,
#   '食物精緻漂亮': 0.82,
#   '食物美味': 0.77},
#  '再發號百年八寶肉粽(總店)': {'份量大': 0.19,
#   '其他正面情緒': 0.13,
#   '划算': -0.49,
#   '小份量': 0.07,
#   '服務好': 0.09,
#   '環境好': 0.05,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 0.16,
#   '食物美味': 0.4},
#  '上海好味道小籠湯包': {'份量大': 0.19,
#   '偏甜': 0.07,
#   '偏辣': 0.28,
#   '偏酸': 0.1,
#   '其他正面情緒': 0.2,
#   '划算': -0.67,
#   '口味清淡': 0.11,
#   '服務好': 0.18,
#   '環境好': 0.4,
#   '重口味': 0.18,
#   '食物很香': 0.13,
#   '食物精緻漂亮': 0.17,
#   '食物美味': 0.65},
#  '尼法咖啡': {'份量大': 0.13,
#   '偏甜': 0.28,
#   '其他正面情緒': 0.41,
#   '划算': 0.29,
#   '口味清淡': 0.07,
#   '小份量': 0.05,
#   '服務好': 0.65,
#   '環境好': 0.69,
#   '重口味': 0.25,
#   '食物很香': 0.61,
#   '食物精緻漂亮': 0.75,
#   '食物美味': 0.93},
#  'Mumu小客廳': {'份量大': 0.46,
#   '偏甜': 0.28,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.45,
#   '划算': 0.01,
#   '口味清淡': 0.29,
#   '小份量': 0.61,
#   '服務好': 0.29,
#   '環境好': 0.53,
#   '重口味': 0.18,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 0.81,
#   '食物美味': 0.86},
#  '小豆豆鍋燒意麵': {'份量大': 0.24,
#   '偏甜': 0.05,
#   '其他正面情緒': 0.1,
#   '划算': 0.02,
#   '環境好': 0.13,
#   '重口味': 0.17,
#   '食物很香': 0.16,
#   '食物精緻漂亮': 0.25,
#   '食物美味': 0.67},
#  '珍杏擱牛奶鍋物': {'份量大': 0.81,
#   '偏甜': 0.06,
#   '偏辣': 0.32,
#   '偏酸': 0.75,
#   '其他正面情緒': 0.85,
#   '划算': 0.86,
#   '口味清淡': 0.24,
#   '服務好': 0.24,
#   '環境好': 1.21,
#   '重口味': 0.77,
#   '食物很香': 0.6,
#   '食物精緻漂亮': 0.74,
#   '食物美味': 1.13},
#  '名坂奇': {'份量大': 0.13,
#   '偏甜': 0.38,
#   '其他正面情緒': 0.2,
#   '划算': 0.14,
#   '口味清淡': 0.09,
#   '環境好': 0.23,
#   '食物很香': 0.8,
#   '食物精緻漂亮': 0.44,
#   '食物美味': 0.72},
#  '韓金婆婆豆腐酪(安平店)': {'份量大': 0.06,
#   '偏甜': 0.44,
#   '其他正面情緒': 1.07,
#   '划算': 0.02,
#   '口味清淡': 0.09,
#   '服務好': 0.67,
#   '環境好': 0.25,
#   '重口味': 0.23,
#   '食物很香': 0.76,
#   '食物精緻漂亮': 0.44,
#   '食物美味': 0.9},
#  '扣扣魔坊': {'其他正面情緒': 0.15,
#   '划算': -0.05,
#   '服務好': 0.17,
#   '環境好': 0.17,
#   '食物很香': 0.25,
#   '食物精緻漂亮': 0.2,
#   '食物美味': 0.2},
#  'Genki Juice 元氣果汁': {'份量大': 0.08,
#   '偏甜': 0.05,
#   '偏酸': 0.4,
#   '其他正面情緒': 0.22,
#   '划算': 0.0,
#   '環境好': 0.11,
#   '食物很香': 0.13,
#   '食物精緻漂亮': 0.45,
#   '食物美味': 0.32},
#  'Mascot Bar  哥德式教堂': {'份量大': 0.27,
#   '偏甜': 0.85,
#   '偏辣': 0.31,
#   '其他正面情緒': 0.21,
#   '划算': -0.12,
#   '小份量': 0.24,
#   '服務好': 0.22,
#   '環境好': 0.53,
#   '重口味': 0.11,
#   '食物很香': 0.47,
#   '食物精緻漂亮': 1.1,
#   '食物美味': 0.88},
#  '吐司吐司早餐店': {'份量大': 1.52,
#   '偏甜': 0.21,
#   '其他正面情緒': 0.54,
#   '划算': 0.38,
#   '小份量': 0.16,
#   '服務好': -0.11,
#   '環境好': 0.04,
#   '重口味': 0.28,
#   '食物很香': 0.25,
#   '食物精緻漂亮': 0.2,
#   '食物美味': 0.71},
#  '庫肯花園': {'份量大': 0.17,
#   '偏甜': 0.18,
#   '偏辣': 0.03,
#   '其他正面情緒': 0.2,
#   '划算': 0.04,
#   '口味清淡': 0.07,
#   '小份量': 0.03,
#   '服務好': 0.2,
#   '環境好': 0.34,
#   '重口味': 0.43,
#   '食物很香': 0.13,
#   '食物精緻漂亮': 0.28,
#   '食物美味': 0.56},
#  '五條港府城伴手禮': {'份量大': 0.19,
#   '偏甜': 0.86,
#   '其他正面情緒': 0.53,
#   '划算': 0.14,
#   '小份量': 0.07,
#   '環境好': 0.18,
#   '食物很香': 0.59,
#   '食物精緻漂亮': 0.28,
#   '食物美味': 0.62},
#  '林永泰興蜜餞行': {'份量大': 0.1,
#   '偏甜': 0.21,
#   '其他正面情緒': 0.19,
#   '划算': 0.07,
#   '口味清淡': 0.07,
#   '服務好': 0.0,
#   '環境好': 0.01,
#   '重口味': 0.11,
#   '食物很香': 0.05,
#   '食物精緻漂亮': 0.11,
#   '食物美味': 0.35},
#  '甘單咖啡館': {'份量大': 0.08,
#   '偏甜': 0.04,
#   '偏酸': 0.3,
#   '其他正面情緒': 0.21,
#   '划算': -0.01,
#   '口味清淡': 0.16,
#   '小份量': 0.04,
#   '服務好': 0.44,
#   '環境好': 0.26,
#   '重口味': 0.09,
#   '食物很香': 0.27,
#   '食物精緻漂亮': 0.44,
#   '食物美味': 0.33},
#  '采田壽司': {'份量大': 0.53,
#   '偏甜': 0.41,
#   '偏辣': 0.15,
#   '其他正面情緒': 0.23,
#   '划算': 1.0,
#   '口味清淡': 0.05,
#   '服務好': 0.11,
#   '環境好': 0.18,
#   '重口味': 0.14,
#   '食物很香': 0.29,
#   '食物精緻漂亮': 0.17,
#   '食物美味': 0.72},
#  '順風號': {'份量大': 0.12,
#   '偏甜': 0.33,
#   '偏辣': 0.05,
#   '偏酸': 0.15,
#   '其他正面情緒': 0.27,
#   '划算': -0.05,
#   '小份量': 0.45,
#   '服務好': 0.05,
#   '環境好': 0.23,
#   '重口味': 0.09,
#   '食物很香': 0.23,
#   '食物精緻漂亮': 0.59,
#   '食物美味': 0.55},
#  '44 Bit 拍拍咖啡 Cafe Lab(原：44 bit 拍拍 beverage)': {'份量大': 0.19,
#   '偏甜': 0.14,
#   '其他正面情緒': 0.29,
#   '划算': 0.09,
#   '口味清淡': 0.22,
#   '小份量': 0.16,
#   '服務好': 0.22,
#   '環境好': 0.49,
#   '重口味': 0.37,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 0.6,
#   '食物美味': 0.68},
#  '台南安平黃家鮮蝦餅': {'份量大': 0.1,
#   '偏辣': 0.89,
#   '其他正面情緒': 0.47,
#   '划算': 0.26,
#   '口味清淡': 0.18,
#   '服務好': 0.18,
#   '重口味': 0.89,
#   '食物很香': 0.48,
#   '食物精緻漂亮': 0.13,
#   '食物美味': 0.49},
#  '綠橄欖義大利麵': {'份量大': 0.78,
#   '偏甜': 0.2,
#   '偏辣': 0.14,
#   '偏酸': 1.1,
#   '其他正面情緒': 0.48,
#   '划算': 0.11,
#   '口味清淡': 0.07,
#   '小份量': 0.12,
#   '服務好': 0.87,
#   '環境好': 0.48,
#   '重口味': 0.18,
#   '食物很香': 0.45,
#   '食物精緻漂亮': 0.48,
#   '食物美味': 0.96},
#  '舟鶴家嫩骨飯(文賢店)': {'份量大': 0.68,
#   '偏辣': 0.08,
#   '其他正面情緒': 0.6,
#   '划算': 0.63,
#   '小份量': 0.07,
#   '服務好': 0.2,
#   '環境好': 0.98,
#   '重口味': 0.46,
#   '食物很香': 0.46,
#   '食物精緻漂亮': 0.16,
#   '食物美味': 1.07},
#  '王氏魚皮': {'份量大': 0.5,
#   '偏甜': 0.16,
#   '其他正面情緒': 0.18,
#   '划算': 0.2,
#   '口味清淡': 0.11,
#   '小份量': 0.03,
#   '服務好': 0.04,
#   '環境好': 0.14,
#   '重口味': 0.22,
#   '食物很香': 0.1,
#   '食物精緻漂亮': 0.08,
#   '食物美味': 0.74},
#  '阿布丁丁專賣店': {'份量大': 0.09,
#   '偏甜': 0.49,
#   '其他正面情緒': 0.2,
#   '划算': -0.02,
#   '服務好': 0.18,
#   '環境好': 0.03,
#   '食物很香': 0.11,
#   '食物精緻漂亮': 0.41,
#   '食物美味': 0.36},
#  '魚之家': {'份量大': 0.06,
#   '偏甜': 0.06,
#   '其他正面情緒': 0.8,
#   '划算': 0.23,
#   '口味清淡': 0.09,
#   '環境好': 0.06,
#   '重口味': 0.08,
#   '食物很香': 0.22,
#   '食物精緻漂亮': 0.11,
#   '食物美味': 0.45},
#  '民族鍋燒老店': {'份量大': 0.15,
#   '偏甜': 0.05,
#   '其他正面情緒': 0.12,
#   '划算': -0.23,
#   '小份量': 0.05,
#   '服務好': 0.49,
#   '環境好': 0.15,
#   '重口味': 0.06,
#   '食物很香': 0.09,
#   '食物精緻漂亮': 0.23,
#   '食物美味': 0.46},
#  '井選日式定食': {'份量大': 0.31,
#   '偏甜': 0.09,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.38,
#   '划算': 0.31,
#   '口味清淡': 0.07,
#   '小份量': 0.15,
#   '服務好': 0.35,
#   '環境好': 0.59,
#   '重口味': 0.18,
#   '食物很香': 0.37,
#   '食物精緻漂亮': 0.51,
#   '食物美味': 1.01},
#  '劉家肉粽菜粽專賣(西門店)': {'份量大': 0.13,
#   '偏甜': 0.22,
#   '其他正面情緒': 0.14,
#   '划算': 0.34,
#   '口味清淡': 0.07,
#   '環境好': 0.07,
#   '重口味': 0.12,
#   '食物很香': 0.33,
#   '食物精緻漂亮': 0.18,
#   '食物美味': 0.5},
#  '阿鳳浮水虱目魚焿': {'份量大': 0.39,
#   '偏甜': 0.56,
#   '其他正面情緒': 0.16,
#   '划算': -0.1,
#   '口味清淡': 0.05,
#   '服務好': 0.16,
#   '環境好': 0.01,
#   '食物很香': 0.15,
#   '食物精緻漂亮': 0.18,
#   '食物美味': 0.55},
#  '你我他之家': {'偏甜': 0.05,
#   '其他正面情緒': 0.1,
#   '划算': -0.34,
#   '服務好': 0.0,
#   '環境好': 0.06,
#   '重口味': 0.12,
#   '食物很香': 0.09,
#   '食物精緻漂亮': 0.22,
#   '食物美味': 0.47},
#  '阿龍意麵': {'份量大': 0.32,
#   '偏辣': 0.05,
#   '其他正面情緒': 0.21,
#   '划算': -0.41,
#   '服務好': 0.07,
#   '環境好': 0.01,
#   '重口味': 0.2,
#   '食物很香': 0.3,
#   '食物精緻漂亮': 0.21,
#   '食物美味': 0.43},
#  'Brick磚塊': {'份量大': 0.48,
#   '偏甜': 0.44,
#   '偏辣': 0.18,
#   '偏酸': 0.6,
#   '其他正面情緒': 0.85,
#   '划算': -0.14,
#   '口味清淡': 0.07,
#   '小份量': 0.44,
#   '服務好': 0.15,
#   '環境好': 0.9,
#   '重口味': 0.31,
#   '食物很香': 0.73,
#   '食物精緻漂亮': 0.53,
#   '食物美味': 1.16},
#  '吳萬春蜜餞(武廟店)': {'份量大': 0.22,
#   '偏甜': 0.16,
#   '其他正面情緒': 1.22,
#   '划算': 0.12,
#   '小份量': 0.07,
#   '服務好': 0.42,
#   '環境好': 0.27,
#   '食物很香': 0.67,
#   '食物精緻漂亮': 0.49,
#   '食物美味': 0.71},
#  '吉樂菓義式冰淇淋雪糕': {'份量大': 0.15,
#   '偏甜': 0.42,
#   '其他正面情緒': 0.6,
#   '划算': 0.11,
#   '口味清淡': 0.09,
#   '服務好': 0.16,
#   '環境好': 0.43,
#   '食物很香': 0.48,
#   '食物精緻漂亮': 0.59,
#   '食物美味': 0.7},
#  '鴻源金好吃牛肉麵(原：上好吃牛肉麵)': {'份量大': 0.61,
#   '偏甜': 0.38,
#   '偏酸': 0.47,
#   '其他正面情緒': 0.16,
#   '划算': -0.11,
#   '口味清淡': 0.56,
#   '服務好': 0.0,
#   '環境好': 0.39,
#   '重口味': 1.2,
#   '食物很香': 1.24,
#   '食物精緻漂亮': 0.28,
#   '食物美味': 1.16},
#  'Dessert Tree 甜點樹鬆餅甜點坊': {'份量大': 0.62,
#   '偏甜': 0.6,
#   '偏辣': 0.56,
#   '其他正面情緒': 1.08,
#   '划算': 0.25,
#   '小份量': 0.2,
#   '服務好': 0.55,
#   '環境好': 1.26,
#   '食物很香': 1.23,
#   '食物精緻漂亮': 1.15,
#   '食物美味': 1.1},
#  '食蔬茶齋 蔬果料理': {'份量大': 0.47,
#   '偏甜': 0.18,
#   '偏辣': 0.22,
#   '偏酸': 0.25,
#   '其他正面情緒': 1.78,
#   '划算': -0.38,
#   '口味清淡': 0.09,
#   '小份量': 0.13,
#   '服務好': 0.27,
#   '環境好': 0.66,
#   '重口味': 0.58,
#   '食物很香': 0.93,
#   '食物精緻漂亮': 1.41,
#   '食物美味': 1.38},
#  'Relax.brunch 輕鬆點早午餐': {'份量大': 0.49,
#   '偏甜': 0.13,
#   '偏辣': 0.73,
#   '其他正面情緒': 0.52,
#   '划算': 0.16,
#   '口味清淡': 0.56,
#   '小份量': 0.39,
#   '服務好': 0.12,
#   '環境好': 0.54,
#   '重口味': 0.32,
#   '食物很香': 1.51,
#   '食物精緻漂亮': 1.54,
#   '食物美味': 1.25},
#  '阿江炒鱔魚意麵': {'份量大': 0.03,
#   '偏甜': 0.14,
#   '偏辣': 0.18,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.08,
#   '划算': 0.13,
#   '小份量': 0.05,
#   '環境好': 0.08,
#   '重口味': 0.25,
#   '食物很香': 0.37,
#   '食物精緻漂亮': 0.05,
#   '食物美味': 0.47},
#  '卓家汕頭魚麵(民生老店)': {'份量大': 0.48,
#   '偏甜': 0.05,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.12,
#   '划算': -0.07,
#   '服務好': 0.42,
#   '環境好': 0.09,
#   '食物很香': 0.28,
#   '食物精緻漂亮': 0.35,
#   '食物美味': 0.45},
#  '碳佐麻里日式燒肉(台南中華店)': {'份量大': 0.33,
#   '偏甜': 0.27,
#   '偏辣': 0.28,
#   '其他正面情緒': 0.54,
#   '划算': 0.28,
#   '口味清淡': 0.09,
#   '服務好': 0.42,
#   '環境好': 0.42,
#   '重口味': 0.08,
#   '食物很香': 0.41,
#   '食物精緻漂亮': 0.76,
#   '食物美味': 1.16},
#  '進福炒鱔魚專家': {'份量大': 0.25,
#   '偏甜': 0.4,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.11,
#   '划算': 0.27,
#   '小份量': 0.05,
#   '環境好': 0.15,
#   '重口味': 0.17,
#   '食物很香': 0.09,
#   '食物精緻漂亮': 0.16,
#   '食物美味': 0.48},
#  'Lady MaMa 私房點心': {'份量大': 0.06,
#   '偏甜': 0.28,
#   '其他正面情緒': 0.31,
#   '划算': -0.06,
#   '小份量': 0.12,
#   '環境好': 0.1,
#   '重口味': 0.08,
#   '食物很香': 0.39,
#   '食物精緻漂亮': 0.52,
#   '食物美味': 0.61},
#  '籃記東山鴨頭': {'份量大': 0.04,
#   '偏甜': 0.65,
#   '偏辣': 0.03,
#   '其他正面情緒': 0.16,
#   '划算': 0.11,
#   '服務好': 0.04,
#   '環境好': 0.01,
#   '重口味': 0.14,
#   '食物很香': 0.32,
#   '食物精緻漂亮': 0.16,
#   '食物美味': 0.53},
#  '有間冰舖': {'份量大': 0.34,
#   '偏甜': 0.18,
#   '偏酸': 0.15,
#   '其他正面情緒': 0.2,
#   '划算': 0.09,
#   '服務好': -0.05,
#   '環境好': 0.04,
#   '食物很香': 0.15,
#   '食物精緻漂亮': 0.2,
#   '食物美味': 0.44},
#  "Willy's Grill葳苙二壘": {'份量大': 0.47,
#   '偏甜': 0.09,
#   '偏辣': 0.2,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.81,
#   '划算': 0.21,
#   '口味清淡': 0.15,
#   '小份量': 0.05,
#   '服務好': 0.24,
#   '環境好': 0.28,
#   '重口味': 0.86,
#   '食物很香': 0.25,
#   '食物精緻漂亮': 0.3,
#   '食物美味': 0.94},
#  'M&M 音樂廚房': {'份量大': 0.49,
#   '偏甜': 0.14,
#   '其他正面情緒': 0.6,
#   '划算': 0.03,
#   '口味清淡': 0.15,
#   '服務好': 0.07,
#   '環境好': 0.57,
#   '重口味': 0.46,
#   '食物很香': 0.6,
#   '食物精緻漂亮': 0.91,
#   '食物美味': 1.07},
#  '熱點義式餐館': {'份量大': 0.43,
#   '其他正面情緒': 0.24,
#   '划算': 0.05,
#   '口味清淡': 0.32,
#   '服務好': 0.27,
#   '環境好': 0.61,
#   '重口味': 0.12,
#   '食物很香': 0.87,
#   '食物精緻漂亮': 1.0,
#   '食物美味': 0.7},
#  '派初所鮮火鍋': {'份量大': 0.19,
#   '偏甜': 0.07,
#   '偏辣': 0.09,
#   '其他正面情緒': 0.22,
#   '划算': 0.3,
#   '服務好': 0.91,
#   '環境好': 1.23,
#   '重口味': 0.28,
#   '食物很香': 0.09,
#   '食物精緻漂亮': 0.39,
#   '食物美味': 0.88},
#  'ORO咖啡屋': {'份量大': 0.15,
#   '偏甜': 0.06,
#   '其他正面情緒': 0.38,
#   '划算': 0.12,
#   '小份量': 0.32,
#   '服務好': 0.09,
#   '環境好': 0.63,
#   '食物很香': 0.3,
#   '食物精緻漂亮': 0.37,
#   '食物美味': 0.36},
#  '牡丹庭 漢風料理': {'份量大': 0.52,
#   '偏甜': 0.46,
#   '偏辣': 0.62,
#   '偏酸': 0.4,
#   '其他正面情緒': 0.51,
#   '划算': -0.08,
#   '口味清淡': 0.25,
#   '服務好': 0.17,
#   '環境好': 0.68,
#   '重口味': 0.74,
#   '食物很香': 1.14,
#   '食物精緻漂亮': 0.83,
#   '食物美味': 1.56},
#  "帕里諾咖啡 PANINO CAFE'": {'份量大': 0.21,
#   '偏甜': 0.11,
#   '偏辣': 0.14,
#   '其他正面情緒': 0.18,
#   '划算': 0.45,
#   '小份量': 0.43,
#   '服務好': 0.09,
#   '環境好': 0.19,
#   '重口味': 0.14,
#   '食物很香': 0.3,
#   '食物精緻漂亮': 0.4,
#   '食物美味': 0.59},
#  "Coffee Cafe' 咖啡珈琲": {'份量大': 0.46,
#   '偏甜': 0.22,
#   '偏辣': 0.22,
#   '偏酸': 0.45,
#   '其他正面情緒': 0.73,
#   '划算': 0.2,
#   '小份量': 0.19,
#   '服務好': 0.09,
#   '環境好': 1.21,
#   '重口味': 0.15,
#   '食物很香': 1.16,
#   '食物精緻漂亮': 1.18,
#   '食物美味': 1.17},
#  'Mr.wheat 小麥先生創意料理(台南金華店)': {'份量大': 0.58,
#   '偏甜': 0.35,
#   '偏辣': 0.2,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.48,
#   '划算': 0.25,
#   '口味清淡': 0.24,
#   '小份量': 0.23,
#   '服務好': 0.38,
#   '環境好': 1.0,
#   '重口味': 0.34,
#   '食物很香': 0.29,
#   '食物精緻漂亮': 0.52,
#   '食物美味': 0.94},
#  '信燒烤': {'份量大': 0.25,
#   '偏甜': 0.35,
#   '偏辣': 0.74,
#   '其他正面情緒': 0.48,
#   '划算': 0.81,
#   '口味清淡': 0.05,
#   '小份量': 0.04,
#   '服務好': 0.25,
#   '環境好': 0.18,
#   '重口味': 0.75,
#   '食物很香': 0.51,
#   '食物精緻漂亮': 0.46,
#   '食物美味': 1.25},
#  '紅磚布丁': {'份量大': 0.15,
#   '偏甜': 0.33,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.2,
#   '划算': 0.09,
#   '小份量': 0.05,
#   '服務好': 0.0,
#   '環境好': 0.2,
#   '重口味': 0.06,
#   '食物很香': 0.25,
#   '食物精緻漂亮': 0.4,
#   '食物美味': 0.63},
#  '歐培拉(台南店)': {'份量大': 0.1,
#   '偏甜': 0.31,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.28,
#   '划算': 0.11,
#   '小份量': 0.05,
#   '服務好': 0.38,
#   '環境好': 0.27,
#   '重口味': 0.12,
#   '食物很香': 0.32,
#   '食物精緻漂亮': 0.35,
#   '食物美味': 0.63},
#  'Picturesque 塗鴉空間書店': {'份量大': 0.32,
#   '偏甜': 0.45,
#   '其他正面情緒': 0.62,
#   '划算': -0.13,
#   '口味清淡': 0.09,
#   '小份量': 0.19,
#   '服務好': 0.42,
#   '環境好': 0.71,
#   '重口味': 0.15,
#   '食物很香': 0.56,
#   '食物精緻漂亮': 0.52,
#   '食物美味': 0.69},
#  '鮮果診所   Juice Clinic': {'份量大': 0.37,
#   '偏甜': 0.45,
#   '偏酸': 0.5,
#   '其他正面情緒': 0.64,
#   '划算': 0.0,
#   '口味清淡': 0.18,
#   '小份量': 0.69,
#   '服務好': 0.25,
#   '環境好': 0.65,
#   '重口味': 0.23,
#   '食物很香': 0.3,
#   '食物精緻漂亮': 0.6,
#   '食物美味': 0.72},
#  'Queen House法式手工甜點': {'份量大': 0.05,
#   '偏甜': 0.29,
#   '偏辣': 0.06,
#   '偏酸': 1.85,
#   '其他正面情緒': 0.57,
#   '划算': 0.03,
#   '口味清淡': 0.15,
#   '小份量': 0.11,
#   '環境好': 0.31,
#   '重口味': 0.12,
#   '食物很香': 0.61,
#   '食物精緻漂亮': 0.54,
#   '食物美味': 0.91},
#  '勁辣旋風麻辣鴛鴦鍋(永康旗艦店)': {'份量大': 0.37,
#   '偏甜': 0.28,
#   '偏辣': 0.6,
#   '偏酸': 0.25,
#   '其他正面情緒': 0.74,
#   '划算': 0.96,
#   '口味清淡': 0.09,
#   '小份量': 0.13,
#   '服務好': 0.53,
#   '環境好': 0.62,
#   '重口味': 0.51,
#   '食物很香': 0.21,
#   '食物精緻漂亮': 0.61,
#   '食物美味': 1.17},
#  '薄多義': {'份量大': 0.15,
#   '偏甜': 0.21,
#   '偏辣': 0.05,
#   '其他正面情緒': 0.18,
#   '划算': 0.26,
#   '小份量': 0.04,
#   '服務好': 0.25,
#   '環境好': 0.56,
#   '重口味': 0.31,
#   '食物很香': 0.27,
#   '食物精緻漂亮': 0.26,
#   '食物美味': 0.71},
#  '築地壽司': {'份量大': 0.3,
#   '偏甜': 0.11,
#   '偏辣': 0.12,
#   '其他正面情緒': 0.26,
#   '划算': 0.03,
#   '口味清淡': 0.05,
#   '小份量': 0.04,
#   '服務好': 0.16,
#   '環境好': 0.24,
#   '重口味': 0.38,
#   '食物很香': 0.12,
#   '食物精緻漂亮': 0.16,
#   '食物美味': 0.76},
#  'kokoni cafe': {'份量大': 0.34,
#   '偏甜': 0.44,
#   '其他正面情緒': 0.4,
#   '划算': 0.03,
#   '小份量': 0.28,
#   '服務好': 0.29,
#   '環境好': 0.68,
#   '重口味': 0.34,
#   '食物很香': 0.3,
#   '食物精緻漂亮': 0.77,
#   '食物美味': 0.82},
#  'PIANO PIANO慢慢咖啡': {'份量大': 0.11,
#   '偏甜': 0.07,
#   '其他正面情緒': 0.25,
#   '划算': -0.11,
#   '小份量': 0.37,
#   '服務好': 0.09,
#   '環境好': 0.52,
#   '重口味': 0.09,
#   '食物很香': 0.27,
#   '食物精緻漂亮': 0.8,
#   '食物美味': 0.4},
#  '馬修嚴選(台南門市)': {'份量大': 0.09,
#   '偏甜': 0.27,
#   '偏酸': 0.45,
#   '其他正面情緒': 1.04,
#   '划算': -0.04,
#   '口味清淡': 0.09,
#   '小份量': 0.19,
#   '環境好': 0.14,
#   '重口味': 0.22,
#   '食物很香': 0.35,
#   '食物精緻漂亮': 0.2,
#   '食物美味': 0.64},
#  '鰻丼作': {'份量大': 0.26,
#   '偏甜': 0.29,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.2,
#   '划算': 0.28,
#   '服務好': 0.15,
#   '環境好': 0.11,
#   '重口味': 0.18,
#   '食物很香': 0.16,
#   '食物精緻漂亮': 0.32,
#   '食物美味': 0.88},
#  '正義餃子': {'份量大': 0.28,
#   '偏甜': 0.07,
#   '偏辣': 0.26,
#   '偏酸': 0.3,
#   '其他正面情緒': 0.24,
#   '划算': 0.1,
#   '服務好': 0.11,
#   '環境好': 0.02,
#   '重口味': 0.52,
#   '食物很香': 0.19,
#   '食物精緻漂亮': 0.38,
#   '食物美味': 0.54},
#  '銀波布丁(府前老店)': {'份量大': 0.08,
#   '偏甜': 0.47,
#   '其他正面情緒': 0.11,
#   '划算': 0.02,
#   '服務好': 0.07,
#   '環境好': 0.03,
#   '重口味': 0.06,
#   '食物很香': 0.15,
#   '食物精緻漂亮': 0.21,
#   '食物美味': 0.63},
#  '性格せいかく 早午餐': {'份量大': 0.57,
#   '偏甜': 0.41,
#   '偏辣': 0.22,
#   '其他正面情緒': 0.35,
#   '划算': 0.44,
#   '小份量': 0.32,
#   '服務好': 1.05,
#   '環境好': 0.38,
#   '重口味': 0.08,
#   '食物很香': 0.09,
#   '食物精緻漂亮': 1.21,
#   '食物美味': 0.67},
#  '陶板屋和風創作料理(忠義店)': {'份量大': 0.21,
#   '偏甜': 0.54,
#   '偏辣': 0.26,
#   '其他正面情緒': 0.41,
#   '划算': 0.12,
#   '口味清淡': 0.07,
#   '小份量': 0.05,
#   '服務好': 0.36,
#   '環境好': 0.2,
#   '重口味': 0.25,
#   '食物很香': 0.12,
#   '食物精緻漂亮': 0.44,
#   '食物美味': 0.97},
#  '旭屋牛丼專賣': {'份量大': 0.13,
#   '偏甜': 0.12,
#   '偏辣': 0.69,
#   '偏酸': 0.25,
#   '其他正面情緒': 0.1,
#   '划算': 0.12,
#   '口味清淡': 0.18,
#   '環境好': 0.18,
#   '重口味': 0.77,
#   '食物很香': 0.26,
#   '食物精緻漂亮': 0.12,
#   '食物美味': 0.55},
#  'MissBanana巴娜娜的早午茶趣': {'份量大': 0.4,
#   '偏甜': 0.12,
#   '其他正面情緒': 0.62,
#   '划算': 0.18,
#   '口味清淡': 0.4,
#   '小份量': 0.07,
#   '服務好': 0.56,
#   '環境好': 1.09,
#   '重口味': 0.17,
#   '食物很香': 0.28,
#   '食物精緻漂亮': 0.72,
#   '食物美味': 0.83},
#  '格那修ganache手作蛋糕': {'份量大': 0.1,
#   '偏甜': 1.06,
#   '其他正面情緒': 0.48,
#   '划算': 0.23,
#   '口味清淡': 0.25,
#   '小份量': 0.13,
#   '服務好': 0.09,
#   '環境好': 0.72,
#   '食物很香': 0.46,
#   '食物精緻漂亮': 0.86,
#   '食物美味': 0.72},
#  '慕紅豆': {'份量大': 0.12,
#   '偏甜': 0.33,
#   '其他正面情緒': 0.18,
#   '划算': 0.2,
#   '小份量': 0.04,
#   '服務好': 0.0,
#   '環境好': 0.34,
#   '食物很香': 0.12,
#   '食物精緻漂亮': 0.22,
#   '食物美味': 0.34},
#  '愛夏子あいさつ': {'份量大': 0.47,
#   '偏甜': 0.19,
#   '偏辣': 0.18,
#   '其他正面情緒': 0.41,
#   '划算': 0.04,
#   '口味清淡': 0.22,
#   '服務好': 0.62,
#   '環境好': 0.49,
#   '重口味': 0.95,
#   '食物很香': 0.34,
#   '食物精緻漂亮': 0.86,
#   '食物美味': 0.67},
#  'ChuChu Pâtisserie 法式甜點': {'份量大': 0.35,
#   '偏甜': 0.78,
#   '偏酸': 0.4,
#   '其他正面情緒': 0.58,
#   '划算': -0.01,
#   '口味清淡': 0.22,
#   '小份量': 0.05,
#   '服務好': 0.84,
#   '環境好': 1.1,
#   '重口味': 0.06,
#   '食物很香': 0.83,
#   '食物精緻漂亮': 1.01,
#   '食物美味': 1.08},
#  '石精臼蚵仔煎': {'份量大': 0.5,
#   '偏甜': 0.4,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.19,
#   '划算': 0.06,
#   '服務好': 0.35,
#   '環境好': 0.13,
#   '重口味': 0.34,
#   '食物很香': 0.07,
#   '食物精緻漂亮': 0.28,
#   '食物美味': 0.56},
#  '木門朝午洋食 MOMENT': {'份量大': 0.59,
#   '偏甜': 0.15,
#   '其他正面情緒': 0.28,
#   '划算': -0.0,
#   '口味清淡': 0.25,
#   '小份量': 0.17,
#   '環境好': 0.49,
#   '重口味': 0.21,
#   '食物很香': 0.32,
#   '食物精緻漂亮': 0.39,
#   '食物美味': 0.56},
#  '來呷麵': {'份量大': 0.22, '划算': 0.19, '食物美味': 0.04},
#  'TWIN coffee 咖啡 云': {'份量大': 0.23,
#   '偏甜': 0.38,
#   '偏辣': 0.29,
#   '偏酸': 0.87,
#   '其他正面情緒': 0.36,
#   '划算': -0.08,
#   '小份量': 1.02,
#   '服務好': 0.12,
#   '環境好': 0.59,
#   '重口味': 0.2,
#   '食物很香': 1.22,
#   '食物精緻漂亮': 0.62,
#   '食物美味': 1.06},
#  'Dazzling Cafe(台南新光三越中山店)': {'份量大': 0.13,
#   '偏甜': 0.56,
#   '偏酸': 0.25,
#   '其他正面情緒': 0.16,
#   '划算': -0.02,
#   '小份量': 0.13,
#   '服務好': 0.0,
#   '環境好': 0.32,
#   '食物很香': 0.1,
#   '食物精緻漂亮': 0.27,
#   '食物美味': 0.57},
#  '新都巷日本料理': {'份量大': 0.82,
#   '偏甜': 0.25,
#   '偏辣': 0.15,
#   '其他正面情緒': 0.31,
#   '划算': 1.16,
#   '服務好': 0.29,
#   '環境好': 0.32,
#   '重口味': 0.15,
#   '食物很香': 0.15,
#   '食物精緻漂亮': 0.47,
#   '食物美味': 0.88},
#  '阿卿傳統飲品‧冰品': {'份量大': 0.44,
#   '偏甜': 0.4,
#   '偏辣': 0.22,
#   '其他正面情緒': 0.16,
#   '划算': 0.12,
#   '服務好': 0.64,
#   '環境好': 0.27,
#   '重口味': 0.11,
#   '食物很香': 0.25,
#   '食物精緻漂亮': 0.32,
#   '食物美味': 0.73},
#  'Sunny Pasta陽光義式廚坊': {'份量大': 0.47,
#   '偏甜': 0.32,
#   '偏辣': 0.34,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.48,
#   '划算': 1.19,
#   '口味清淡': 0.07,
#   '小份量': 0.17,
#   '服務好': 0.78,
#   '環境好': 1.1,
#   '重口味': 0.54,
#   '食物很香': 0.7,
#   '食物精緻漂亮': 0.87,
#   '食物美味': 1.31},
#  '樂禾田': {'份量大': 0.65,
#   '偏甜': 0.29,
#   '其他正面情緒': 0.41,
#   '划算': -0.05,
#   '小份量': 0.33,
#   '服務好': 0.18,
#   '環境好': 0.82,
#   '食物很香': 0.43,
#   '食物精緻漂亮': 0.6,
#   '食物美味': 0.94},
#  '尚禾黑糖粉圓冰': {'份量大': 0.27,
#   '偏甜': 0.34,
#   '偏辣': 0.05,
#   '其他正面情緒': 0.16,
#   '划算': 0.48,
#   '服務好': 0.24,
#   '環境好': 0.12,
#   '食物很香': 0.24,
#   '食物精緻漂亮': 0.16,
#   '食物美味': 0.46},
#  '方蘭川焦皮布丁': {'份量大': 0.13,
#   '偏甜': 0.46,
#   '其他正面情緒': 0.71,
#   '划算': 0.17,
#   '小份量': 0.13,
#   '環境好': 0.24,
#   '食物很香': 0.5,
#   '食物精緻漂亮': 0.27,
#   '食物美味': 0.58},
#  'Picturesque 塗鴉空間書店(長榮2店)': {'份量大': 0.27,
#   '偏甜': 0.25,
#   '偏辣': 0.08,
#   '其他正面情緒': 0.43,
#   '划算': 0.16,
#   '口味清淡': 0.2,
#   '小份量': 1.96,
#   '服務好': 0.38,
#   '環境好': 0.96,
#   '食物很香': 0.35,
#   '食物精緻漂亮': 0.56,
#   '食物美味': 0.7},
#  'Daylight光合箱子': {'份量大': 0.42,
#   '偏甜': 0.14,
#   '偏酸': 0.3,
#   '其他正面情緒': 0.41,
#   '划算': -0.23,
#   '服務好': 0.22,
#   '環境好': 0.59,
#   '重口味': 0.18,
#   '食物很香': 0.28,
#   '食物精緻漂亮': 0.32,
#   '食物美味': 0.67},
#  '德斯啤鮮釀啤酒餐廳': {'份量大': 0.28,
#   '偏甜': 0.05,
#   '偏辣': 0.45,
#   '其他正面情緒': 0.39,
#   '划算': 0.2,
#   '口味清淡': 0.15,
#   '小份量': 0.28,
#   '服務好': 0.15,
#   '環境好': 0.63,
#   '重口味': 1.15,
#   '食物很香': 0.85,
#   '食物精緻漂亮': 0.72,
#   '食物美味': 1.2},
#  '秋收碳烤': {'份量大': 0.13,
#   '偏甜': 0.06,
#   '其他正面情緒': 0.06,
#   '划算': 0.08,
#   '服務好': 0.09,
#   '環境好': 0.02,
#   '食物很香': 0.11,
#   '食物精緻漂亮': 0.27,
#   '食物美味': 0.36},
#  'Yellow Bee手創漢堡': {'份量大': 0.19,
#   '偏辣': 0.44,
#   '其他正面情緒': 0.16,
#   '划算': 0.08,
#   '口味清淡': 0.28,
#   '小份量': 0.32,
#   '服務好': -0.22,
#   '環境好': 0.02,
#   '重口味': 0.42,
#   '食物很香': 0.17,
#   '食物精緻漂亮': 0.77,
#   '食物美味': 0.59},
#  '1004 Brunch 早午餐': {'份量大': 0.63,
#   '偏甜': 0.12,
#   '其他正面情緒': 0.43,
#   '划算': 0.34,
#   '小份量': 0.13,
#   '服務好': 0.44,
#   '環境好': 0.83,
#   '重口味': 0.22,
#   '食物很香': 0.41,
#   '食物精緻漂亮': 0.57,
#   '食物美味': 1.0},
#  '半個鍋-個人火烤兩吃鍋物(永華店)': {'份量大': 0.29,
#   '偏甜': 0.24,
#   '偏辣': 0.31,
#   '其他正面情緒': 0.78,
#   '划算': 0.41,
#   '口味清淡': 0.09,
#   '服務好': 0.27,
#   '環境好': 0.96,
#   '重口味': 0.69,
#   '食物很香': 0.36,
#   '食物精緻漂亮': 0.17,
#   '食物美味': 0.74},
#  '虎山雷創意蛋塔': {'份量大': 0.31,
#   '偏甜': 0.61,
#   '其他正面情緒': 1.11,
#   '划算': 0.39,
#   '服務好': 0.51,
#   '環境好': 0.86,
#   '重口味': 0.18,
#   '食物很香': 0.74,
#   '食物精緻漂亮': 1.29,
#   '食物美味': 1.03},
#  '祿記肉包': {'份量大': 0.08,
#   '偏甜': 0.05,
#   '其他正面情緒': 0.04,
#   '划算': -0.12,
#   '服務好': -0.09,
#   '環境好': 0.06,
#   '食物很香': 0.17,
#   '食物精緻漂亮': 0.16,
#   '食物美味': 0.4},
#  'i.mita 愛米塔': {'份量大': 0.8,
#   '偏甜': 0.38,
#   '偏辣': 0.12,
#   '其他正面情緒': 0.41,
#   '划算': 0.59,
#   '小份量': 1.44,
#   '服務好': 0.73,
#   '環境好': 0.63,
#   '重口味': 0.31,
#   '食物很香': 0.23,
#   '食物精緻漂亮': 0.79,
#   '食物美味': 0.87},
#  '法羅烤箱 Often Oven': {'份量大': 0.26,
#   '偏甜': 0.07,
#   '其他正面情緒': 0.32,
#   '划算': 0.72,
#   '小份量': 0.44,
#   '服務好': 0.71,
#   '環境好': 0.68,
#   '重口味': 0.26,
#   '食物很香': 0.24,
#   '食物精緻漂亮': 0.8,
#   '食物美味': 0.71},
#  'WiWe 威葳義法餐廳': {'份量大': 0.28,
#   '偏甜': 0.09,
#   '其他正面情緒': 0.41,
#   '划算': 0.12,
#   '口味清淡': 0.07,
#   '小份量': 0.27,
#   '服務好': 0.6,
#   '環境好': 0.75,
#   '重口味': 0.25,
#   '食物很香': 0.41,
#   '食物精緻漂亮': 0.79,
#   '食物美味': 1.09},
#  '鐵木匠複合式餐廳': {'份量大': 0.52,
#   '偏甜': 0.09,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.52,
#   '划算': 0.08,
#   '口味清淡': 0.15,
#   '小份量': 0.11,
#   '服務好': 0.6,
#   '環境好': 0.99,
#   '重口味': 0.63,
#   '食物很香': 0.55,
#   '食物精緻漂亮': 0.96,
#   '食物美味': 1.12},
#  '大鋤花間': {'份量大': 0.07,
#   '偏甜': 0.04,
#   '其他正面情緒': 0.36,
#   '划算': 0.0,
#   '小份量': 0.04,
#   '服務好': 0.45,
#   '環境好': 0.23,
#   '重口味': 0.05,
#   '食物很香': 0.08,
#   '食物精緻漂亮': 0.34,
#   '食物美味': 0.24},
#  '諾亞方舟餐廳(台南店)': {'份量大': 0.17,
#   '偏甜': 0.32,
#   '其他正面情緒': 0.27,
#   '划算': -0.18,
#   '口味清淡': 0.18,
#   '小份量': 0.07,
#   '服務好': 0.29,
#   '環境好': 0.51,
#   '重口味': 0.08,
#   '食物很香': 0.25,
#   '食物精緻漂亮': 0.37,
#   '食物美味': 0.59},
#  '樹屋咖啡': {'份量大': 0.08,
#   '偏甜': 0.07,
#   '其他正面情緒': 0.18,
#   '划算': -0.06,
#   '小份量': 0.08,
#   '環境好': 0.15,
#   '重口味': 0.09,
#   '食物很香': 0.17,
#   '食物精緻漂亮': 0.28,
#   '食物美味': 0.29},
#  "棻園 Caf'e No.2": {'份量大': 0.66,
#   '偏甜': 0.92,
#   '其他正面情緒': 0.45,
#   '划算': -0.46,
#   '口味清淡': 0.18,
#   '小份量': 0.48,
#   '服務好': 1.11,
#   '環境好': 0.82,
#   '食物很香': 0.44,
#   '食物精緻漂亮': 1.14,
#   '食物美味': 0.99},
#  '小巷裡的拾壹號': {'份量大': 0.57,
#   '偏甜': 0.29,
#   '其他正面情緒': 0.43,
#   '划算': 0.23,
#   '口味清淡': 0.05,
#   '小份量': 0.59,
#   '服務好': 0.29,
#   '環境好': 0.68,
#   '重口味': 0.14,
#   '食物很香': 0.22,
#   '食物精緻漂亮': 0.77,
#   '食物美味': 0.72},
#  '小杉堡霜淇淋專賣店': {'份量大': 0.09,
#   '偏甜': 0.28,
#   '其他正面情緒': 0.59,
#   '划算': 0.46,
#   '口味清淡': 0.09,
#   '小份量': 0.07,
#   '服務好': 0.91,
#   '環境好': 0.63,
#   '重口味': 0.08,
#   '食物很香': 0.5,
#   '食物精緻漂亮': 0.46,
#   '食物美味': 0.68},
#  '晚起餐館': {'份量大': 0.54,
#   '偏甜': 0.14,
#   '偏辣': 0.06,
#   '其他正面情緒': 0.44,
#   '划算': 0.03,
#   '小份量': 0.11,
#   '服務好': 0.6,
#   '環境好': 0.47,
#   '重口味': 0.38,
#   '食物很香': 0.1,
#   '食物精緻漂亮': 0.35,
#   '食物美味': 0.58},
#  '惠比壽鯛魚燒': {'份量大': 0.03,
#   '偏甜': 0.18,
#   '偏辣': 0.15,
#   '其他正面情緒': 0.16,
#   '划算': 0.56,
#   '服務好': 0.09,
#   '環境好': 0.02,
#   '重口味': 0.08,
#   '食物很香': 0.19,
#   '食物精緻漂亮': 0.38,
#   '食物美味': 0.38},
#  '阿力海百匯自助餐廳(原：桂田酒店-心巴黎百匯餐廳)': {'份量大': 0.35,
#   '偏甜': 0.18,
#   '其他正面情緒': 0.49,
#   '划算': 0.07,
#   '口味清淡': 0.09,
#   '小份量': 0.07,
#   '服務好': -0.09,
#   '環境好': 0.36,
#   '重口味': 0.08,
#   '食物很香': 0.12,
#   '食物精緻漂亮': 0.18,
#   '食物美味': 0.45},
#  '一方日朝食X喫茶': {'份量大': 0.35,
#   '偏甜': 0.69,
#   '偏辣': 0.18,
#   '其他正面情緒': 0.54,
#   '划算': 0.03,
#   '小份量': 0.18,
#   '服務好': 1.03,
#   '環境好': 0.7,
#   '重口味': 0.35,
#   '食物很香': 0.27,
#   '食物精緻漂亮': 0.96,
#   '食物美味': 0.93},
#  '石精臼牛肉湯': {'份量大': 0.22,
#   '偏甜': 0.14,
#   '偏辣': 0.09,
#   '偏酸': 0.1,
#   '其他正面情緒': 0.25,
#   '划算': -0.05,
#   '口味清淡': 0.04,
#   '小份量': 0.03,
#   '服務好': 0.29,
#   '環境好': 0.19,
#   '重口味': 0.06,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 0.22,
#   '食物美味': 0.67},
#  '麥多古堡童話餐廳': {'份量大': 0.37,
#   '偏甜': 0.14,
#   '偏辣': 0.06,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.09,
#   '划算': 0.11,
#   '服務好': 0.84,
#   '環境好': 0.08,
#   '重口味': 0.06,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 1.26,
#   '食物美味': 0.49},
#  'MUMU白姆森林': {'份量大': 0.34,
#   '偏甜': 0.12,
#   '偏辣': 0.08,
#   '其他正面情緒': 0.34,
#   '划算': 0.41,
#   '小份量': 0.07,
#   '服務好': -0.11,
#   '環境好': 0.41,
#   '重口味': 0.48,
#   '食物很香': 0.3,
#   '食物精緻漂亮': 1.12,
#   '食物美味': 0.9},
#  '度小月擔仔麵(中正旗艦店)': {'份量大': 0.26,
#   '偏甜': 0.29,
#   '其他正面情緒': 0.08,
#   '划算': -0.16,
#   '服務好': 0.13,
#   '環境好': 0.23,
#   '重口味': 0.12,
#   '食物很香': 0.67,
#   '食物精緻漂亮': 0.44,
#   '食物美味': 0.3},
#  '安平東興蚵嗲': {'份量大': 0.03,
#   '偏甜': 0.06,
#   '偏辣': 0.08,
#   '其他正面情緒': 0.15,
#   '划算': 0.07,
#   '小份量': 0.07,
#   '環境好': 0.14,
#   '重口味': 0.31,
#   '食物很香': 0.17,
#   '食物精緻漂亮': 0.17,
#   '食物美味': 0.49},
#  '小象樹義式冰淇淋': {'份量大': 0.06,
#   '偏甜': 0.27,
#   '其他正面情緒': 0.47,
#   '划算': 0.18,
#   '口味清淡': 0.16,
#   '小份量': 0.09,
#   '服務好': 0.05,
#   '環境好': 0.39,
#   '重口味': 0.14,
#   '食物很香': 0.32,
#   '食物精緻漂亮': 0.93,
#   '食物美味': 0.81},
#  '南方米造秈稻碗粿': {'份量大': 0.27,
#   '偏甜': 1.32,
#   '其他正面情緒': 0.9,
#   '划算': 0.05,
#   '服務好': 0.32,
#   '環境好': 1.02,
#   '重口味': 0.39,
#   '食物很香': 0.81,
#   '食物精緻漂亮': 0.66,
#   '食物美味': 0.9},
#  '日光徐徐(台南永華店)': {'份量大': 0.84,
#   '偏辣': 0.18,
#   '偏酸': 0.53,
#   '其他正面情緒': 0.3,
#   '划算': 0.46,
#   '小份量': 0.45,
#   '服務好': 1.42,
#   '環境好': 1.14,
#   '重口味': 0.37,
#   '食物很香': 0.67,
#   '食物精緻漂亮': 0.96,
#   '食物美味': 1.05},
#  '米谷手作料理食堂': {'份量大': 0.26,
#   '偏甜': 0.06,
#   '偏辣': 0.46,
#   '其他正面情緒': 0.32,
#   '划算': 0.88,
#   '服務好': 0.18,
#   '環境好': 0.54,
#   '重口味': 0.46,
#   '食物很香': 0.29,
#   '食物精緻漂亮': 0.25,
#   '食物美味': 0.75},
#  '金蕉條雞蛋糕': {'份量大': 0.08,
#   '其他正面情緒': 0.08,
#   '划算': 0.13,
#   '環境好': 0.0,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 0.12,
#   '食物美味': 0.38},
#  '日日咖啡': {'份量大': 0.49,
#   '偏甜': 0.19,
#   '其他正面情緒': 0.27,
#   '划算': 0.27,
#   '口味清淡': 0.07,
#   '小份量': 1.44,
#   '服務好': 0.07,
#   '環境好': 0.63,
#   '食物很香': 0.23,
#   '食物精緻漂亮': 0.79,
#   '食物美味': 0.84},
#  '度小月擔仔麵(總店)': {'份量大': 0.39,
#   '偏甜': 0.09,
#   '其他正面情緒': 0.08,
#   '划算': -0.44,
#   '口味清淡': 0.07,
#   '服務好': 0.07,
#   '環境好': 0.16,
#   '重口味': 0.25,
#   '食物很香': 0.26,
#   '食物精緻漂亮': 0.19,
#   '食物美味': 0.23},
#  '鯨吞燒 地雞料理專門店(赤崁分店)': {'份量大': 0.15,
#   '偏甜': 0.07,
#   '偏辣': 0.82,
#   '偏酸': 0.3,
#   '其他正面情緒': 0.42,
#   '划算': 0.46,
#   '服務好': 0.11,
#   '環境好': 0.39,
#   '重口味': 0.55,
#   '食物很香': 0.59,
#   '食物精緻漂亮': 0.55,
#   '食物美味': 1.46},
#  '韓金婆婆豆腐酪(赤崁店)': {'份量大': 0.03,
#   '偏甜': 0.22,
#   '偏辣': 0.14,
#   '其他正面情緒': 0.21,
#   '划算': -0.02,
#   '口味清淡': 0.18,
#   '環境好': 0.14,
#   '重口味': 0.08,
#   '食物很香': 0.33,
#   '食物精緻漂亮': 0.18,
#   '食物美味': 0.43},
#  '茂記安平黑豆花': {'份量大': 0.11,
#   '偏甜': 0.36,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.15,
#   '划算': 0.17,
#   '口味清淡': 0.07,
#   '服務好': 0.0,
#   '環境好': 0.09,
#   '重口味': 0.06,
#   '食物很香': 0.08,
#   '食物精緻漂亮': 0.17,
#   '食物美味': 0.46},
#  '正興咖啡館': {'份量大': 0.15,
#   '偏甜': 0.04,
#   '其他正面情緒': 0.31,
#   '划算': -0.08,
#   '口味清淡': 0.05,
#   '小份量': 0.12,
#   '服務好': 0.22,
#   '環境好': 0.46,
#   '重口味': 0.05,
#   '食物很香': 0.13,
#   '食物精緻漂亮': 0.41,
#   '食物美味': 0.39},
#  '舊烘爐': {'份量大': 0.15,
#   '偏甜': 0.46,
#   '偏辣': 0.15,
#   '其他正面情緒': 0.38,
#   '划算': 0.02,
#   '小份量': 0.08,
#   '服務好': 0.08,
#   '環境好': 0.33,
#   '食物很香': 0.27,
#   '食物精緻漂亮': 0.42,
#   '食物美味': 0.36},
#  '波哥(台南誠品店)': {'份量大': 0.19,
#   '偏甜': 0.25,
#   '偏酸': 0.93,
#   '其他正面情緒': 0.26,
#   '划算': 0.02,
#   '環境好': 0.1,
#   '重口味': 0.11,
#   '食物很香': 0.76,
#   '食物精緻漂亮': 0.15,
#   '食物美味': 0.62},
#  '饗麻饗辣麻辣火鍋(台南中華店)': {'份量大': 0.71,
#   '偏甜': 0.29,
#   '偏辣': 0.15,
#   '其他正面情緒': 0.57,
#   '划算': 0.83,
#   '口味清淡': 0.09,
#   '服務好': 0.09,
#   '環境好': 0.34,
#   '重口味': 0.15,
#   '食物很香': 0.07,
#   '食物精緻漂亮': 0.38,
#   '食物美味': 1.1},
#  '上原UEHARA日式料理': {'份量大': 0.23,
#   '偏甜': 0.13,
#   '偏辣': 0.6,
#   '其他正面情緒': 0.18,
#   '划算': 0.14,
#   '小份量': 0.32,
#   '服務好': 0.0,
#   '環境好': 0.16,
#   '重口味': 0.52,
#   '食物很香': 0.52,
#   '食物精緻漂亮': 0.63,
#   '食物美味': 0.85},
#  '宇樂居酒屋': {'份量大': 0.3,
#   '偏甜': 0.12,
#   '偏辣': 0.4,
#   '其他正面情緒': 0.39,
#   '划算': 0.21,
#   '口味清淡': 0.29,
#   '小份量': 0.35,
#   '環境好': 0.47,
#   '重口味': 0.57,
#   '食物很香': 0.7,
#   '食物精緻漂亮': 1.35,
#   '食物美味': 1.14},
#  '山小屋 Yamagoya Taiwan(台南店)': {'份量大': 0.33,
#   '偏甜': 0.05,
#   '偏辣': 0.06,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.22,
#   '划算': 0.25,
#   '口味清淡': 0.07,
#   '服務好': 0.93,
#   '環境好': 0.63,
#   '重口味': 0.74,
#   '食物很香': 0.2,
#   '食物精緻漂亮': 0.45,
#   '食物美味': 1.01},
#  '阿公阿婆蛋餅': {'份量大': 1.35,
#   '偏甜': 0.05,
#   '其他正面情緒': 0.09,
#   '划算': 0.56,
#   '小份量': 0.05,
#   '服務好': 0.07,
#   '環境好': 0.01,
#   '重口味': 0.22,
#   '食物很香': 0.12,
#   '食物精緻漂亮': 0.07,
#   '食物美味': 0.43},
#  '勾勾鍋 鴛鴦火鍋': {'份量大': 0.69,
#   '偏甜': 0.09,
#   '偏辣': 0.37,
#   '其他正面情緒': 0.77,
#   '划算': 0.78,
#   '口味清淡': 0.56,
#   '小份量': 0.05,
#   '服務好': 0.15,
#   '環境好': 0.49,
#   '重口味': 0.12,
#   '食物很香': 0.31,
#   '食物精緻漂亮': 0.55,
#   '食物美味': 0.98},
#  '冰ㄉ• かき氷': {'份量大': 0.35,
#   '偏甜': 0.22,
#   '偏辣': 0.09,
#   '其他正面情緒': 0.18,
#   '划算': 0.27,
#   '口味清淡': 0.22,
#   '服務好': 0.45,
#   '環境好': 0.18,
#   '重口味': 0.29,
#   '食物很香': 0.48,
#   '食物精緻漂亮': 0.41,
#   '食物美味': 0.47},
#  'T&F 手作吐司': {'份量大': 0.51,
#   '偏甜': 1.19,
#   '偏辣': 0.4,
#   '偏酸': 0.25,
#   '其他正面情緒': 0.37,
#   '划算': 0.12,
#   '服務好': 0.18,
#   '環境好': 0.66,
#   '重口味': 0.82,
#   '食物很香': 0.65,
#   '食物精緻漂亮': 0.8,
#   '食物美味': 1.01},
#  '寶島菠蘿團(安平店)': {'份量大': 0.44,
#   '偏甜': 0.76,
#   '其他正面情緒': 0.23,
#   '划算': 0.19,
#   '服務好': 0.83,
#   '環境好': 0.43,
#   '食物很香': 0.62,
#   '食物精緻漂亮': 0.95,
#   '食物美味': 0.72},
#  '瑞比冰淇淋店': {'份量大': 0.03,
#   '偏甜': 0.35,
#   '其他正面情緒': 0.4,
#   '划算': 0.39,
#   '服務好': 0.09,
#   '環境好': 0.04,
#   '食物很香': 0.19,
#   '食物精緻漂亮': 0.4,
#   '食物美味': 0.42},
#  '蘇格蕾法式甜點 Le Sucré Pâtisserie': {'份量大': 0.14,
#   '偏甜': 0.56,
#   '偏酸': 2.07,
#   '其他正面情緒': 0.24,
#   '划算': 0.17,
#   '口味清淡': 0.32,
#   '小份量': 0.36,
#   '環境好': 0.6,
#   '食物很香': 1.74,
#   '食物精緻漂亮': 1.09,
#   '食物美味': 0.98},
#  '宇田家': {'份量大': 0.12,
#   '偏甜': 0.07,
#   '其他正面情緒': 0.27,
#   '划算': 0.26,
#   '小份量': 0.25,
#   '服務好': 0.35,
#   '環境好': 0.24,
#   '食物很香': 0.3,
#   '食物精緻漂亮': 0.65,
#   '食物美味': 0.63},
#  '肉伯火雞肉飯': {'份量大': 0.26,
#   '偏甜': 0.44,
#   '偏酸': 0.15,
#   '其他正面情緒': 0.19,
#   '划算': -0.38,
#   '口味清淡': 0.05,
#   '小份量': 0.04,
#   '服務好': -0.05,
#   '環境好': 0.08,
#   '重口味': 0.18,
#   '食物很香': 0.15,
#   '食物精緻漂亮': 0.15,
#   '食物美味': 0.57},
#  '赤崁擔仔麵(民族店)': {'份量大': 0.24,
#   '其他正面情緒': 0.13,
#   '划算': -0.07,
#   '小份量': 0.12,
#   '服務好': 0.25,
#   '環境好': 0.46,
#   '重口味': 0.08,
#   '食物很香': 0.13,
#   '食物精緻漂亮': 0.24,
#   '食物美味': 0.32},
#  '小南米糕': {'份量大': 0.38,
#   '偏甜': 0.18,
#   '偏辣': 0.15,
#   '其他正面情緒': 0.28,
#   '划算': 0.12,
#   '小份量': 0.07,
#   '服務好': 0.25,
#   '環境好': 0.58,
#   '重口味': 0.52,
#   '食物很香': 0.61,
#   '食物精緻漂亮': 0.34,
#   '食物美味': 0.7},
#  '小綿羊藥膳的鍋(健康店)': {'份量大': 0.55,
#   '偏甜': 0.27,
#   '偏辣': 1.11,
#   '其他正面情緒': 1.99,
#   '划算': 0.62,
#   '口味清淡': 0.8,
#   '服務好': 0.2,
#   '環境好': 0.75,
#   '重口味': 0.8,
#   '食物很香': 0.17,
#   '食物精緻漂亮': 0.89,
#   '食物美味': 0.92},
#  '台南碳味亭': {'份量大': 0.25,
#   '偏甜': 0.24,
#   '偏辣': 0.29,
#   '其他正面情緒': 0.64,
#   '划算': 0.42,
#   '口味清淡': 0.18,
#   '服務好': 0.25,
#   '環境好': 0.29,
#   '重口味': 0.29,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 0.81,
#   '食物美味': 0.8},
#  '禮物水果': {'份量大': 0.81,
#   '偏甜': 0.26,
#   '偏辣': 0.11,
#   '偏酸': 0.7,
#   '其他正面情緒': 0.42,
#   '划算': 0.15,
#   '口味清淡': 0.07,
#   '服務好': 0.35,
#   '環境好': 0.32,
#   '重口味': 0.12,
#   '食物很香': 0.25,
#   '食物精緻漂亮': 0.59,
#   '食物美味': 0.74},
#  'TASTy 西堤牛排(民族店)': {'份量大': 0.24,
#   '偏甜': 0.6,
#   '偏酸': 0.45,
#   '其他正面情緒': 0.33,
#   '划算': 0.08,
#   '服務好': 0.75,
#   '環境好': 0.37,
#   '重口味': 0.23,
#   '食物很香': 0.22,
#   '食物精緻漂亮': 0.47,
#   '食物美味': 1.47},
#  '喬義思窯烤手作廚房': {'份量大': 0.33,
#   '偏甜': 0.31,
#   '偏辣': 0.14,
#   '偏酸': 0.2,
#   '其他正面情緒': 0.25,
#   '划算': 0.29,
#   '口味清淡': 0.15,
#   '服務好': 0.07,
#   '環境好': 1.07,
#   '重口味': 0.68,
#   '食物很香': 0.37,
#   '食物精緻漂亮': 0.63,
#   '食物美味': 0.88},
#  'OMAYA春川炒雞(台南東門店)': {'份量大': 0.52,
#   '偏甜': 0.13,
#   '偏辣': 0.18,
#   '偏酸': 0.85,
#   '其他正面情緒': 0.36,
#   '划算': 0.06,
#   '口味清淡': 0.2,
#   '服務好': 0.82,
#   '環境好': 0.54,
#   '重口味': 0.18,
#   '食物很香': 0.45,
#   '食物精緻漂亮': 0.24,
#   '食物美味': 0.63},
#  '福米cafe': {'份量大': 0.19,
#   '偏甜': 0.15,
#   '其他正面情緒': 0.41,
#   '划算': 0.22,
#   '口味清淡': 0.32,
#   '小份量': 0.59,
#   '服務好': 0.83,
#   '環境好': 0.71,
#   '重口味': 0.25,
#   '食物很香': 1.38,
#   '食物精緻漂亮': 0.7,
#   '食物美味': 0.95},
#  '慶家食品行': {'份量大': 0.06,
#   '偏辣': 0.31,
#   '其他正面情緒': 0.29,
#   '划算': -0.14,
#   '口味清淡': 0.36,
#   '服務好': 0.09,
#   '環境好': 0.2,
#   '重口味': 0.38,
#   '食物很香': 0.11,
#   '食物精緻漂亮': 0.42,
#   '食物美味': 0.58},
#  '豪記臭豆腐(台南旗艦店)': {'份量大': 0.17,
#   '偏甜': 0.25,
#   '偏辣': 0.23,
#   '其他正面情緒': 0.12,
#   '划算': 0.07,
#   '口味清淡': 0.2,
#   '服務好': 0.18,
#   '環境好': 0.3,
#   '重口味': 0.08,
#   '食物很香': 0.28,
#   '食物精緻漂亮': 0.23,
#   '食物美味': 0.55},
#  '那個時代法式餐廳': {'份量大': 0.23,
#   '偏甜': 0.25,
#   '偏辣': 0.16,
#   '其他正面情緒': 0.49,
#   '划算': -0.08,
#   '口味清淡': 0.28,
#   '服務好': 1.12,
#   '環境好': 0.95,
#   '重口味': 0.62,
#   '食物很香': 1.23,
#   '食物精緻漂亮': 1.63,
# ...
#   '食物精緻漂亮': 0.12,
#   '食物美味': 0.53},
#  'ZiZA咖啡': {'份量大': 0.33,
#   '其他正面情緒': 0.42,
#   '划算': -0.02,
#   '小份量': 0.56,
#   '服務好': 0.18,
#   '環境好': 0.36,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 0.28,
#   '食物美味': 0.13},
#  '滿福亭 まんぷくてい': {'份量大': 0.13,
#   '偏甜': 0.08,
#   '其他正面情緒': 0.24,
#   '划算': 0.06,
#   '小份量': 0.08,
#   '環境好': 0.1,
#   '重口味': 0.08,
#   '食物很香': 0.05,
#   '食物精緻漂亮': 0.16,
#   '食物美味': 0.37},
#  '豆腐花 DofuWhat': {'份量大': 0.13,
#   '偏甜': 0.08,
#   '其他正面情緒': 0.12,
#   '划算': 0.02,
#   '環境好': 0.04,
#   '食物很香': 0.05,
#   '食物美味': 0.16},
#  'ICHIRO，ㄧ起囉！': {'份量大': 0.18,
#   '偏甜': 0.38,
#   '偏辣': 0.38,
#   '其他正面情緒': 0.25,
#   '划算': 0.07,
#   '服務好': 0.1,
#   '環境好': 0.41,
#   '食物很香': 1.08,
#   '食物精緻漂亮': 0.59,
#   '食物美味': 0.95},
#  'Do - Li  BAKERY CAFE 多麗咖啡烘焙美食': {'份量大': 0.31,
#   '偏甜': 0.43,
#   '偏酸': 0.56,
#   '其他正面情緒': 0.4,
#   '划算': 0.08,
#   '環境好': 0.39,
#   '食物很香': 0.23,
#   '食物精緻漂亮': 0.28,
#   '食物美味': 0.41},
#  '饕公麻辣燙': {'份量大': 0.41,
#   '偏辣': 0.17,
#   '其他正面情緒': 0.23,
#   '划算': 0.08,
#   '口味清淡': 0.27,
#   '環境好': 0.27,
#   '食物很香': 0.06,
#   '食物精緻漂亮': 0.03,
#   '食物美味': 0.55},
#  '福來伯臭豆腐': {'份量大': 0.92,
#   '偏酸': 0.48,
#   '其他正面情緒': 0.12,
#   '划算': 0.02,
#   '服務好': 0.1,
#   '環境好': 0.07,
#   '重口味': 0.13,
#   '食物很香': 0.61,
#   '食物精緻漂亮': 0.14,
#   '食物美味': 0.67},
#  '華味香鴨肉羹(第一店)': {'其他正面情緒': 0.09,
#   '划算': -0.1,
#   '環境好': -0.05,
#   '重口味': 0.18,
#   '食物精緻漂亮': 0.32,
#   '食物美味': 0.31},
#  '瑪西達': {'份量大': 0.81,
#   '偏甜': 0.34,
#   '偏辣': 0.17,
#   '其他正面情緒': 0.48,
#   '划算': 0.32,
#   '小份量': 0.09,
#   '服務好': 0.18,
#   '環境好': 0.76,
#   '重口味': 0.69,
#   '食物很香': 0.84,
#   '食物精緻漂亮': 0.53,
#   '食物美味': 1.23},
#  '打翻泡菜 김치 엎어': {'份量大': 0.09,
#   '其他正面情緒': 0.32,
#   '划算': 0.07,
#   '口味清淡': 0.3,
#   '服務好': 0.21,
#   '環境好': 0.13,
#   '重口味': 1.05,
#   '食物很香': 0.34,
#   '食物精緻漂亮': 0.42,
#   '食物美味': 0.91},
#  '許家芋粿': {'份量大': 0.55,
#   '偏甜': 0.41,
#   '偏辣': 0.23,
#   '其他正面情緒': 0.47,
#   '划算': 0.27,
#   '小份量': 0.07,
#   '服務好': 0.45,
#   '環境好': 0.5,
#   '重口味': 0.23,
#   '食物很香': 0.43,
#   '食物精緻漂亮': 0.4,
#   '食物美味': 0.8},
#  '比薩斜塔pizzastyle': {'份量大': 0.64,
#   '偏甜': 1.09,
#   '偏辣': 1.98,
#   '其他正面情緒': 0.63,
#   '划算': 0.38,
#   '口味清淡': 1.43,
#   '服務好': 0.23,
#   '環境好': 0.7,
#   '重口味': 1.49,
#   '食物很香': 1.01,
#   '食物精緻漂亮': 0.95,
#   '食物美味': 1.72},
#  '綠麥田': {'份量大': 1.16,
#   '偏甜': 0.45,
#   '偏辣': 0.22,
#   '其他正面情緒': 0.44,
#   '划算': 0.25,
#   '小份量': 1.55,
#   '服務好': 0.12,
#   '環境好': 1.1,
#   '食物很香': 1.0,
#   '食物精緻漂亮': 1.19,
#   '食物美味': 0.98},
#  '阿松臭豆腐': {'份量大': 0.15,
#   '偏酸': 0.47,
#   '其他正面情緒': 0.11,
#   '划算': 0.04,
#   '環境好': 0.02,
#   '重口味': 0.22,
#   '食物很香': 0.41,
#   '食物精緻漂亮': 0.09,
#   '食物美味': 0.46},
#  'Mo-Mo-Paradise': {'份量大': 0.37,
#   '偏甜': 0.18,
#   '其他正面情緒': 0.58,
#   '划算': 0.05,
#   '服務好': -0.1,
#   '環境好': 0.27,
#   '重口味': 0.91,
#   '食物精緻漂亮': 0.24,
#   '食物美味': 0.54},
#  '橘象泰早安(台南永康店)': {'份量大': 0.09,
#   '偏甜': 0.57,
#   '其他正面情緒': 0.32,
#   '划算': 0.0,
#   '小份量': 0.1,
#   '服務好': 0.31,
#   '環境好': 0.17,
#   '食物很香': 0.34,
#   '食物精緻漂亮': 0.24,
#   '食物美味': 0.5},
#  '小西腳青草茶': {'份量大': 0.32,
#   '偏甜': 0.89,
#   '偏辣': 0.31,
#   '其他正面情緒': 0.24,
#   '划算': 0.17,
#   '口味清淡': 0.28,
#   '小份量': 0.16,
#   '服務好': 0.12,
#   '環境好': 0.1,
#   '重口味': 0.22,
#   '食物很香': 0.12,
#   '食物精緻漂亮': 0.16,
#   '食物美味': 0.44},
#  '格樓主題餐廳-Grimm House': {'份量大': 0.91,
#   '偏甜': 0.18,
#   '其他正面情緒': 0.96,
#   '划算': 0.14,
#   '小份量': 0.1,
#   '服務好': 1.55,
#   '環境好': 1.37,
#   '重口味': 0.13,
#   '食物很香': 0.95,
#   '食物精緻漂亮': 2.01,
#   '食物美味': 1.6},
#  '府城藝術轉角': {'份量大': 0.85,
#   '其他正面情緒': 1.86,
#   '划算': 0.14,
#   '口味清淡': 0.35,
#   '小份量': 0.12,
#   '服務好': 0.36,
#   '環境好': 0.5,
#   '重口味': 0.31,
#   '食物很香': 0.39,
#   '食物精緻漂亮': 0.56,
#   '食物美味': 0.26},
#  '黃記鱔魚意麵': {'份量大': 0.46,
#   '偏甜': 1.32,
#   '其他正面情緒': 0.06,
#   '划算': 0.12,
#   '環境好': 0.07,
#   '重口味': 0.13,
#   '食物很香': 0.47,
#   '食物精緻漂亮': 0.07,
#   '食物美味': 0.48},
#  '餓魚咬冰': {'份量大': 0.21,
#   '偏甜': 0.43,
#   '其他正面情緒': 0.22,
#   '划算': 0.06,
#   '小份量': 0.12,
#   '服務好': 0.12,
#   '環境好': 0.16,
#   '食物很香': 0.46,
#   '食物精緻漂亮': 1.59,
#   '食物美味': 0.42},
#  '花川日本料理': {'份量大': 0.36,
#   '其他正面情緒': 0.13,
#   '划算': -0.05,
#   '口味清淡': 0.3,
#   '環境好': 0.24,
#   '食物很香': 0.21,
#   '食物精緻漂亮': 0.07,
#   '食物美味': 0.79},
#  '陳氏蚵捲': {'偏甜': 0.16,
#   '其他正面情緒': 0.0,
#   '划算': 0.0,
#   '環境好': 0.14,
#   '食物很香': 0.08,
#   '食物精緻漂亮': 0.2,
#   '食物美味': 0.4},
#  '橫須賀海軍咖哩': {'份量大': 0.16,
#   '其他正面情緒': 0.31,
#   '划算': 0.17,
#   '口味清淡': 0.56,
#   '服務好': 0.35,
#   '環境好': 0.45,
#   '食物很香': 0.68,
#   '食物精緻漂亮': 0.73,
#   '食物美味': 0.59},
#  '金門館': {'份量大': 0.65,
#   '偏甜': 0.2,
#   '其他正面情緒': 0.14,
#   '划算': -0.27,
#   '口味清淡': 0.2,
#   '服務好': 0.31,
#   '環境好': 0.44,
#   '重口味': 0.52,
#   '食物很香': 0.16,
#   '食物精緻漂亮': 0.26,
#   '食物美味': 0.57},
#  '羊城油雞': {'份量大': 0.27,
#   '偏甜': 0.24,
#   '偏辣': 0.29,
#   '其他正面情緒': 0.28,
#   '划算': 0.05,
#   '服務好': 0.57,
#   '環境好': 0.3,
#   '重口味': 0.52,
#   '食物很香': 0.23,
#   '食物精緻漂亮': 0.36,
#   '食物美味': 0.44},
#  '水鳥和洋創作料理-府城店': {'份量大': 0.25,
#   '偏甜': 0.52,
#   '偏辣': 0.26,
#   '其他正面情緒': 0.47,
#   '划算': -0.1,
#   '環境好': 0.46,
#   '食物很香': 0.54,
#   '食物精緻漂亮': 0.51,
#   '食物美味': 1.29},
#  '大億麗緻-風尚庭園咖啡下午茶': {'份量大': 0.18,
#   '偏甜': 0.58,
#   '偏酸': 0.48,
#   '其他正面情緒': 0.22,
#   '划算': 0.12,
#   '環境好': 0.34,
#   '重口味': 0.38,
#   '食物很香': 0.13,
#   '食物精緻漂亮': 0.31,
#   '食物美味': 0.64},
#  '奶控': {'份量大': 0.08,
#   '偏甜': 0.17,
#   '其他正面情緒': 0.43,
#   '划算': 0.17,
#   '服務好': 0.09,
#   '環境好': 0.48,
#   '食物很香': 1.14,
#   '食物精緻漂亮': 0.71,
#   '食物美味': 0.62},
#  '金帝元薑母鴨': {'份量大': 0.57,
#   '偏甜': 0.34,
#   '偏辣': 0.68,
#   '其他正面情緒': 0.39,
#   '划算': 0.17,
#   '環境好': 0.55,
#   '重口味': 0.35,
#   '食物很香': 1.02,
#   '食物精緻漂亮': 0.25,
#   '食物美味': 0.6},
#  '木銅咖啡屋': {'其他正面情緒': 0.2,
#   '划算': -0.03,
#   '環境好': 0.02,
#   '食物精緻漂亮': 0.18,
#   '食物美味': 0.12},
#  '王記好吃雞肉便當': {'份量大': 0.04,
#   '其他正面情緒': 0.04,
#   '划算': 0.06,
#   '重口味': 0.08,
#   '食物很香': 0.2,
#   '食物美味': 0.19},
#  'NO.17 Brunch table & More': {'份量大': 0.63,
#   '偏甜': 0.22,
#   '其他正面情緒': 0.33,
#   '划算': -0.06,
#   '小份量': 0.12,
#   '服務好': 0.24,
#   '環境好': 0.51,
#   '食物很香': 0.77,
#   '食物精緻漂亮': 0.36,
#   '食物美味': 1.23},
#  '小石子義式廚房': {'份量大': 0.09,
#   '偏甜': 0.18,
#   '其他正面情緒': 0.25,
#   '划算': 0.38,
#   '口味清淡': 0.3,
#   '環境好': 0.37,
#   '食物很香': 0.54,
#   '食物精緻漂亮': 0.1,
#   '食物美味': 0.58},
#  '狐狸小屋': {'份量大': 0.18,
#   '其他正面情緒': 0.35,
#   '划算': -0.02,
#   '口味清淡': 0.3,
#   '小份量': 0.32,
#   '服務好': 0.32,
#   '環境好': 0.27,
#   '食物很香': 0.34,
#   '食物精緻漂亮': 0.42,
#   '食物美味': 0.34},
#  '彩虹糖輕食義大利麵館': {'份量大': 0.25,
#   '偏辣': 0.77,
#   '偏酸': 0.68,
#   '其他正面情緒': 0.47,
#   '划算': 0.29,
#   '口味清淡': 0.42,
#   '小份量': 1.53,
#   '服務好': 0.83,
#   '環境好': 0.82,
#   '重口味': 0.36,
#   '食物很香': 0.9,
#   '食物精緻漂亮': 0.83,
#   '食物美味': 1.16},
#  '金站麻辣鍋': {'份量大': 0.65,
#   '偏辣': 0.68,
#   '其他正面情緒': 0.57,
#   '划算': 0.11,
#   '口味清淡': 0.82,
#   '服務好': 0.56,
#   '環境好': 0.48,
#   '重口味': 0.23,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 0.53,
#   '食物美味': 1.16},
#  '烹大師涮涮鍋': {'份量大': 0.75,
#   '其他正面情緒': 1.2,
#   '划算': 0.45,
#   '小份量': 0.14,
#   '服務好': 0.42,
#   '環境好': 0.42,
#   '重口味': 0.35,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 0.74,
#   '食物美味': 1.1},
#  '台南艾咖啡': {'份量大': 0.13,
#   '偏甜': 0.77,
#   '其他正面情緒': 0.34,
#   '划算': 0.03,
#   '服務好': 0.14,
#   '環境好': 0.09,
#   '食物很香': 0.36,
#   '食物精緻漂亮': 0.32,
#   '食物美味': 0.41},
#  '富士達人日本拉麵(東寧店)': {'偏辣': 0.26,
#   '偏酸': 0.68,
#   '其他正面情緒': 0.39,
#   '划算': 0.03,
#   '環境好': 0.14,
#   '食物很香': 0.09,
#   '食物精緻漂亮': 0.14,
#   '食物美味': 0.36},
#  'Dreaming cafe 綺飛 法式甜點': {'偏甜': 0.24,
#   '偏酸': 0.4,
#   '其他正面情緒': 0.12,
#   '划算': -0.1,
#   '小份量': 0.08,
#   '環境好': 0.15,
#   '重口味': 0.16,
#   '食物很香': 0.35,
#   '食物精緻漂亮': 0.21,
#   '食物美味': 0.29},
#  '蕎琪義大利麵': {'份量大': 0.42,
#   '偏甜': 0.15,
#   '偏辣': 0.18,
#   '其他正面情緒': 0.31,
#   '划算': 0.88,
#   '服務好': 0.13,
#   '環境好': 0.66,
#   '重口味': 0.38,
#   '食物很香': 0.5,
#   '食物精緻漂亮': 1.29,
#   '食物美味': 0.86},
#  '井煲仔沙茶爐': {'份量大': 0.63,
#   '其他正面情緒': 0.73,
#   '划算': 0.46,
#   '口味清淡': 0.35,
#   '小份量': 0.24,
#   '環境好': 1.53,
#   '重口味': 0.15,
#   '食物很香': 1.0,
#   '食物精緻漂亮': 1.15,
#   '食物美味': 1.55},
#  'Pizza Hut 必勝客(台南南科店)': {'份量大': 0.63,
#   '其他正面情緒': 0.11,
#   '划算': -0.08,
#   '小份量': 0.12,
#   '服務好': 0.23,
#   '環境好': -0.04,
#   '重口味': 0.29,
#   '食物很香': 0.08,
#   '食物精緻漂亮': 0.12,
#   '食物美味': 0.36},
#  'XM麻辣鍋(湖美旗艦店)': {'份量大': 0.32,
#   '偏甜': 0.22,
#   '偏辣': 0.45,
#   '其他正面情緒': 1.32,
#   '划算': 0.03,
#   '環境好': 0.31,
#   '食物很香': 0.38,
#   '食物精緻漂亮': 0.63,
#   '食物美味': 1.15},
#  'Double Yummy': {'份量大': 0.21,
#   '偏甜': 0.43,
#   '其他正面情緒': 0.29,
#   '划算': 0.11,
#   '小份量': 0.12,
#   '環境好': 0.86,
#   '重口味': 0.31,
#   '食物很香': 0.31,
#   '食物精緻漂亮': 0.79,
#   '食物美味': 0.93},
#  '水工坊早餐咖啡屋': {'份量大': 0.62,
#   '其他正面情緒': 0.35,
#   '划算': 0.32,
#   '小份量': 0.14,
#   '服務好': 0.14,
#   '環境好': 0.32,
#   '食物很香': 0.55,
#   '食物精緻漂亮': 0.32,
#   '食物美味': 0.38},
#  '庵六花 京都濃咖哩專賣': {'份量大': 0.18,
#   '偏辣': 0.56,
#   '其他正面情緒': 0.29,
#   '划算': 0.02,
#   '小份量': 0.09,
#   '服務好': -0.15,
#   '環境好': 0.33,
#   '重口味': 0.63,
#   '食物很香': 0.43,
#   '食物精緻漂亮': 0.92,
#   '食物美味': 1.16},
#  '佳里韓春館한춘관': {'份量大': 1.19,
#   '偏甜': 0.18,
#   '偏辣': 0.18,
#   '其他正面情緒': 0.35,
#   '划算': 0.43,
#   '口味清淡': 0.3,
#   '服務好': 0.21,
#   '環境好': 0.16,
#   '重口味': 0.38,
#   '食物很香': 0.46,
#   '食物精緻漂亮': 0.21,
#   '食物美味': 0.75},
#  'ORO(凱旋店)': {'份量大': 0.24,
#   '偏酸': 0.68,
#   '其他正面情緒': 0.26,
#   '划算': -0.19,
#   '小份量': 0.28,
#   '服務好': 0.14,
#   '環境好': 0.91,
#   '食物很香': 0.36,
#   '食物精緻漂亮': 0.28,
#   '食物美味': 0.41},
#  '艾芙迪髮型沙龍咖啡 Aphrodite Cafe': {'份量大': 0.38,
#   '其他正面情緒': 0.26,
#   '划算': -0.09,
#   '口味清淡': 0.42,
#   '小份量': 0.69,
#   '環境好': 0.33,
#   '重口味': 0.36,
#   '食物精緻漂亮': 0.37,
#   '食物美味': 0.33},
#  '5號樹屋': {'偏甜': 0.26,
#   '其他正面情緒': 0.86,
#   '划算': -0.13,
#   '口味清淡': 0.42,
#   '環境好': 0.05,
#   '重口味': 0.35,
#   '食物很香': 0.09,
#   '食物精緻漂亮': 0.19,
#   '食物美味': 0.23},
#  'Mr. Deer': {'偏甜': 0.52,
#   '偏酸': 0.68,
#   '其他正面情緒': 1.07,
#   '划算': 0.13,
#   '服務好': 0.14,
#   '環境好': 0.92,
#   '食物很香': 0.63,
#   '食物精緻漂亮': 0.79,
#   '食物美味': 1.45},
#  '新化老攤雞蛋糕': {'份量大': 0.1,
#   '偏甜': 0.43,
#   '其他正面情緒': 0.07,
#   '划算': 0.0,
#   '環境好': 0.23,
#   '重口味': 0.15,
#   '食物很香': 0.23,
#   '食物精緻漂亮': 0.12,
#   '食物美味': 0.25},
#  '多多巧思現烤蛋糕': {'偏甜': 0.2,
#   '其他正面情緒': 0.2,
#   '划算': 0.0,
#   '服務好': 0.08,
#   '環境好': 0.07,
#   '食物很香': 0.12,
#   '食物精緻漂亮': 0.27,
#   '食物美味': 0.44},
#  '哈根達斯 Häagen-Dazs(台南中山店)': {'份量大': 0.09,
#   '偏甜': 0.18,
#   '其他正面情緒': 0.16,
#   '划算': -0.07,
#   '環境好': 0.07,
#   '重口味': 0.13,
#   '食物精緻漂亮': 0.17,
#   '食物美味': 0.2},
#  '陶板屋和風創作料理(台南勝利店)': {'份量大': 0.27,
#   '偏甜': 0.58,
#   '其他正面情緒': 0.25,
#   '划算': 0.05,
#   '服務好': 0.3,
#   '環境好': 0.27,
#   '重口味': 0.13,
#   '食物很香': 0.47,
#   '食物精緻漂亮': 0.59,
#   '食物美味': 0.92},
#  '關子嶺茶壺雞': {'其他正面情緒': 0.23,
#   '划算': -0.04,
#   '環境好': 0.11,
#   '重口味': 0.11,
#   '食物很香': 0.05,
#   '食物精緻漂亮': 0.31,
#   '食物美味': 0.37},
#  '萬客樓餐館': {'份量大': 0.1,
#   '偏辣': 0.22,
#   '其他正面情緒': 0.04,
#   '划算': 0.05,
#   '環境好': 0.16,
#   '食物很香': 0.08,
#   '食物精緻漂亮': 0.12,
#   '食物美味': 0.56},
#  '狗啃玉米': {'份量大': 0.07,
#   '其他正面情緒': 0.1,
#   '划算': 0.0,
#   '口味清淡': 0.5,
#   '環境好': 0.36,
#   '重口味': 0.21,
#   '食物很香': 0.65,
#   '食物精緻漂亮': 0.47,
#   '食物美味': 0.43},
#  '王城珍饌牛肉麵': {'份量大': 0.42,
#   '其他正面情緒': 0.18,
#   '划算': -0.11,
#   '口味清淡': 0.35,
#   '小份量': 0.12,
#   '環境好': 0.2,
#   '重口味': 0.15,
#   '食物精緻漂亮': 0.32,
#   '食物美味': 0.34},
#  '1900 Café Focus in 生活文創(台南知事官邸)': {'偏酸': 0.56,
#   '其他正面情緒': 0.51,
#   '划算': 0.0,
#   '小份量': 0.36,
#   '環境好': 0.43,
#   '食物很香': 0.23,
#   '食物精緻漂亮': 0.28,
#   '食物美味': 0.47},
#  '9分10刻 西式新料理(中正店)': {'份量大': 0.1,
#   '偏甜': 0.45,
#   '偏酸': 0.56,
#   '其他正面情緒': 0.22,
#   '划算': 0.03,
#   '口味清淡': 0.35,
#   '環境好': 0.23,
#   '重口味': 0.15,
#   '食物很香': 0.08,
#   '食物精緻漂亮': 0.16,
#   '食物美味': 0.71},
#  '布老虎廚房': {'份量大': 0.36,
#   '偏甜': 0.18,
#   '其他正面情緒': 0.22,
#   '划算': 0.05,
#   '環境好': 0.37,
#   '食物很香': 0.06,
#   '食物精緻漂亮': 0.21,
#   '食物美味': 0.31},
#  '關廟鳳梨酥': {'份量大': 0.1,
#   '其他正面情緒': 0.22,
#   '划算': 0.0,
#   '服務好': 0.12,
#   '環境好': 0.0,
#   '食物精緻漂亮': 0.52,
#   '食物美味': 0.42},
#  '鴨桐伯薑母鴨': {'份量大': 0.22,
#   '偏辣': 0.1,
#   '其他正面情緒': 0.2,
#   '划算': 0.02,
#   '環境好': 0.03,
#   '重口味': 0.2,
#   '食物很香': 0.44,
#   '食物精緻漂亮': 0.17,
#   '食物美味': 0.22},
#  '高麗館韓國料理': {'份量大': 0.04,
#   '其他正面情緒': 0.02,
#   '划算': 0.04,
#   '環境好': 0.03,
#   '重口味': 0.16,
#   '食物很香': 0.05,
#   '食物美味': 0.19},
#  '呷霸白北浮水魚羹': {'偏甜': 0.37,
#   '其他正面情緒': 0.03,
#   '划算': 0.07,
#   '環境好': 0.04,
#   '食物精緻漂亮': 0.14,
#   '食物美味': 0.13},
#  '品田牧場(台南勝利店)': {'份量大': 0.33,
#   '偏甜': 1.35,
#   '偏酸': 0.44,
#   '其他正面情緒': 0.39,
#   '划算': 0.32,
#   '小份量': 0.18,
#   '服務好': 0.46,
#   '環境好': 0.33,
#   '重口味': 0.23,
#   '食物很香': 0.54,
#   '食物精緻漂亮': 0.31,
#   '食物美味': 1.09},
#  '喆發樂樂鍋': {'份量大': 0.84,
#   '偏甜': 0.18,
#   '偏辣': 0.18,
#   '其他正面情緒': 0.35,
#   '划算': 0.41,
#   '環境好': 0.51,
#   '重口味': 0.25,
#   '食物很香': 0.06,
#   '食物精緻漂亮': 0.14,
#   '食物美味': 0.69},
#  '湯婆婆拉麵': {'份量大': 0.44,
#   '其他正面情緒': 0.13,
#   '划算': 0.04,
#   '服務好': 0.08,
#   '環境好': 0.03,
#   '食物精緻漂亮': 0.06,
#   '食物美味': 0.33},
#  '溫室烘焙屋(市府店)': {'份量大': 0.1,
#   '偏甜': 0.65,
#   '偏酸': 0.56,
#   '其他正面情緒': 0.33,
#   '划算': 0.08,
#   '小份量': 0.12,
#   '環境好': 0.39,
#   '重口味': 0.29,
#   '食物很香': 0.31,
#   '食物精緻漂亮': 0.59,
#   '食物美味': 0.32},
#  'BELLINI Pasta Pasta 貝里尼(台南夢時代店)': {'份量大': 0.74,
#   '其他正面情緒': 0.48,
#   '划算': 0.33,
#   '口味清淡': 0.35,
#   '服務好': 0.12,
#   '環境好': 0.43,
#   '重口味': 0.45,
#   '食物很香': 0.38,
#   '食物精緻漂亮': 0.2,
#   '食物美味': 1.32},
#  '85度C咖啡蛋糕烘焙專賣店(台南北門店)': {'份量大': 0.13,
#   '偏甜': 0.26,
#   '其他正面情緒': 0.26,
#   '划算': 0.26,
#   '服務好': 0.14,
#   '環境好': 0.14,
#   '食物精緻漂亮': 0.23,
#   '食物美味': 0.17},
#  '查理理查': {'份量大': 0.04,
#   '偏酸': 0.4,
#   '其他正面情緒': 0.18,
#   '划算': 0.11,
#   '服務好': -0.07,
#   '環境好': 0.01,
#   '重口味': 0.16,
#   '食物精緻漂亮': 0.64,
#   '食物美味': 0.24},
#  'CT Life X 小日子': {'份量大': 0.1,
#   '其他正面情緒': 0.28,
#   '划算': 0.3,
#   '小份量': 0.64,
#   '環境好': 0.3,
#   '食物很香': 0.39,
#   '食物精緻漂亮': 0.72,
#   '食物美味': 0.45},
#  '小南碗粿': {'份量大': 0.2,
#   '偏辣': 0.16,
#   '其他正面情緒': 0.29,
#   '划算': 0.0,
#   '服務好': 0.12,
#   '環境好': 0.15,
#   '重口味': 0.32,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 0.41,
#   '食物美味': 0.6},
#  '御私藏鮮奶茶專賣店(安平店)': {'份量大': 0.54,
#   '偏甜': 0.75,
#   '偏辣': 0.58,
#   '其他正面情緒': 0.8,
#   '划算': 0.14,
#   '服務好': 0.1,
#   '環境好': 0.44,
#   '重口味': 0.26,
#   '食物很香': 0.94,
#   '食物精緻漂亮': 0.45,
#   '食物美味': 0.99},
#  '紙的部屋咖哩輕食': {'份量大': 0.36,
#   '偏甜': 0.37,
#   '其他正面情緒': 0.06,
#   '划算': 0.17,
#   '小份量': 0.21,
#   '服務好': 0.1,
#   '環境好': -0.07,
#   '食物很香': 0.13,
#   '食物精緻漂亮': 0.38,
#   '食物美味': 0.21},
#  'しゃぶしゃぶ温野菜日本涮涮鍋專門店Taiwan On-Yasai': {'份量大': 0.53,
#   '偏甜': 0.66,
#   '其他正面情緒': 0.87,
#   '划算': -0.03,
#   '口味清淡': 0.35,
#   '服務好': 0.47,
#   '環境好': 0.86,
#   '重口味': 0.75,
#   '食物很香': 1.24,
#   '食物精緻漂亮': 0.47,
#   '食物美味': 2.0},
#  '喜茶咖啡Season cafe': {'份量大': 0.38,
#   '其他正面情緒': 0.47,
#   '划算': 0.22,
#   '小份量': 0.14,
#   '服務好': 0.14,
#   '環境好': 0.51,
#   '食物精緻漂亮': 0.42,
#   '食物美味': 0.55},
#  'Tra di noi 塔蒂諾': {'偏甜': 0.2,
#   '其他正面情緒': 0.05,
#   '划算': 0.02,
#   '環境好': 0.05,
#   '食物很香': 1.25,
#   '食物精緻漂亮': 0.3,
#   '食物美味': 0.28},
#  '台南 秘氏咖啡': {'份量大': 0.04,
#   '偏甜': 0.08,
#   '其他正面情緒': 0.02,
#   '划算': 0.02,
#   '服務好': 0.07,
#   '環境好': 0.01,
#   '食物很香': 0.1,
#   '食物精緻漂亮': 0.16,
#   '食物美味': 0.16},
#  '勝利路西.B': {'其他正面情緒': 0.1,
#   '划算': 0.07,
#   '口味清淡': 0.17,
#   '服務好': 0.17,
#   '環境好': 0.05,
#   '食物很香': 0.12,
#   '食物精緻漂亮': 0.07,
#   '食物美味': 0.4},
#  '神田のLa Vie 風格誌': {'份量大': 0.33,
#   '偏甜': 0.51,
#   '偏酸': 1.32,
#   '其他正面情緒': 0.54,
#   '划算': 0.15,
#   '小份量': 0.09,
#   '服務好': 0.09,
#   '環境好': 0.3,
#   '食物精緻漂亮': 1.39,
#   '食物美味': 0.72},
#  '聖記軟骨飯專賣店': {'份量大': 0.38,
#   '偏甜': 0.26,
#   '其他正面情緒': 0.04,
#   '划算': 0.19,
#   '口味清淡': 0.42,
#   '環境好': 0.05,
#   '重口味': 0.18,
#   '食物很香': 0.18,
#   '食物精緻漂亮': 0.23,
#   '食物美味': 0.44},
#  '尊客平價牛排(中華店)': {'份量大': 0.87,
#   '偏甜': 0.26,
#   '其他正面情緒': 0.17,
#   '划算': 0.51,
#   '環境好': 0.73,
#   '重口味': 0.18,
#   '食物很香': 0.36,
#   '食物精緻漂亮': 0.09,
#   '食物美味': 0.8},
#  '慶中街綠豆湯': {'份量大': 0.3,
#   '偏甜': 0.31,
#   '其他正面情緒': 0.05,
#   '划算': -0.0,
#   '口味清淡': 0.25,
#   '服務好': 0.08,
#   '環境好': 0.22,
#   '重口味': 0.11,
#   '食物精緻漂亮': 0.14,
#   '食物美味': 0.37},
#  '韓金婆婆食品行(育賢店)': {'份量大': 0.13,
#   '偏甜': 1.54,
#   '偏辣': 0.26,
#   '其他正面情緒': 0.47,
#   '划算': -0.16,
#   '環境好': 0.05,
#   '重口味': 0.35,
#   '食物很香': 1.36,
#   '食物精緻漂亮': 0.37,
#   '食物美味': 1.02},
#  '比薩茶坊': {'份量大': 0.24,
#   '其他正面情緒': 0.34,
#   '划算': 0.17,
#   '服務好': 0.09,
#   '環境好': 0.03,
#   '食物很香': 0.36,
#   '食物精緻漂亮': 0.28,
#   '食物美味': 0.76},
#  '淙泉雪花冰': {'偏甜': 0.29,
#   '其他正面情緒': 0.13,
#   '划算': 0.02,
#   '口味清淡': 0.92,
#   '環境好': 0.39,
#   '食物很香': 0.61,
#   '食物精緻漂亮': 0.48,
#   '食物美味': 0.62},
#  '阿福羊肉': {'份量大': 0.24,
#   '其他正面情緒': 0.51,
#   '划算': 0.08,
#   '口味清淡': 0.55,
#   '服務好': 0.37,
#   '環境好': 0.06,
#   '重口味': 0.12,
#   '食物很香': 0.12,
#   '食物精緻漂亮': 0.21,
#   '食物美味': 0.53},
#  '夏帕焗烤專賣(台南夢時代店)': {'份量大': 0.62,
#   '偏酸': 0.68,
#   '其他正面情緒': 0.47,
#   '划算': 0.1,
#   '小份量': 0.28,
#   '環境好': 1.1,
#   '食物很香': 0.63,
#   '食物精緻漂亮': 1.02,
#   '食物美味': 1.16},
#  '咖啡平方隨行吧(崇德店)': {'份量大': 0.25,
#   '偏甜': 0.52,
#   '其他正面情緒': 0.9,
#   '划算': 0.55,
#   '口味清淡': 0.82,
#   '服務好': 0.28,
#   '環境好': 0.37,
#   '食物很香': 0.99,
#   '食物精緻漂亮': 0.14,
#   '食物美味': 0.83},
#  '小銅鍋咖啡館(新光小西門店)': {'偏甜': 0.2,
#   '其他正面情緒': 0.2,
#   '划算': -0.02,
#   '服務好': 0.08,
#   '環境好': 0.07,
#   '食物很香': 0.44,
#   '食物精緻漂亮': 0.33,
#   '食物美味': 0.33},
#  '東城麵家': {'份量大': 0.27,
#   '偏辣': 0.37,
#   '偏酸': 0.48,
#   '其他正面情緒': 0.25,
#   '划算': 0.07,
#   '口味清淡': 0.3,
#   '小份量': 0.1,
#   '服務好': 0.31,
#   '環境好': 0.55,
#   '重口味': 0.78,
#   '食物很香': 0.13,
#   '食物精緻漂亮': 0.24,
#   '食物美味': 0.42},
#  'OILILY CAFE': {'份量大': 0.31,
#   '其他正面情緒': 0.44,
#   '划算': 0.14,
#   '小份量': 0.12,
#   '環境好': 0.16,
#   '重口味': 0.15,
#   '食物很香': 0.15,
#   '食物精緻漂亮': 0.2,
#   '食物美味': 0.5},
#  '府城夯也(仁德總店)': {'份量大': 0.07,
#   '其他正面情緒': 0.27,
#   '划算': 0.03,
#   '服務好': 0.11,
#   '環境好': 0.05,
#   '食物很香': 0.75,
#   '食物精緻漂亮': 0.22,
#   '食物美味': 0.61},
#  '吉藏日本料理': {'份量大': 0.23,
#   '偏辣': 0.56,
#   '其他正面情緒': 0.41,
#   '划算': 0.41,
#   '口味清淡': 0.32,
#   '小份量': 0.09,
#   '服務好': 0.0,
#   '環境好': 0.13,
#   '重口味': 0.26,
#   '食物很香': 0.57,
#   '食物精緻漂亮': 0.78,
#   '食物美味': 0.72},
#  ...}

# %%
def like(wordict,word1,word2):
    publicwords=set(wordict[word1])&set(wordict[word2])
    if publicwords==set():
        return {word2:0}
    n=0
    for word in wordict[word1]:
        n+=wordict[word1][word]**2
    m=0
    for word in wordict[word2]:
        m+=wordict[word2][word]**2
    l=0
    for word in publicwords:
        l+=wordict[word1][word]*wordict[word2][word]

    if ((n**(1/2))*(m**(1/2)))==0:
        return {word2:0}
    sim=l/((n**(1/2))*(m**(1/2)))
    
    return {word2:sim}

# %%
def checksim(word1,wordict,N=5):
    simi={}
    from collections import Counter
    for word2 in wordict:
        simi.update(like(wordict,word1,word2))
    del simi[word1]
    simi=Counter(simi).most_common(N)
#     print(word1+' 相近詞')
    return dict(simi)

# %%
import pprint
dienVec={dien['name']:dien['featurescores'] for dien in bigtable if dien['style']=='甜點(合併飲品)'
         or dien['name'] in TainanStationDien500_5}
TainanStation=[{'一推':dien,'關聯推':list(checksim(dien,dienVec,N=5).keys())} for dien in TainanStationDien500_5]

# %%
print('台南火車站[異國>甜點]')
pprint.pprint(TainanStation)
# Out:
# 台南火車站[異國>甜點]
# [{'一推': 'TASTy 西堤牛排(民族店)',
#   '關聯推': ['綣綣屋 霜淇淋專賣', '阿川粉圓', '太陽牌冰品', '舒芙里法式烘培坊', '龍興冰品店']},
#  {'一推': '哞王 原味炭烤牛排',
#   '關聯推': ['貝伊拉手工鮮奶酪(永福門市)', '佳里御品紅豆', '冰鄉', '東東鮮蝦餅', '中一豆花']},
#  {'一推': '香格里拉台南遠東大飯店-遠東Cafe',
#   '關聯推': ['多多巧思現烤蛋糕', '香格里拉台南遠東大飯店-品香坊', '自己的房間', '莉莉水果店', '銀鋒冰果室']},
#  {'一推': '香格里拉台南遠東大飯店-醉月樓',
#   '關聯推': ['吉樂菓義式冰淇淋雪糕', '樹屋咖啡', 'Perfume Dance 跳舞香水(南紡門店)', '紅磚布丁', '起士公爵']},
#  {'一推': '香格里拉台南遠東大飯店-大廳茶軒',
#   '關聯推': ['ok bird 杯子蛋糕', '天使貝可 天然酵母手感烘焙', '台灣茶奶茶(無)', '葡吉麵包店', '香草鋪子(府中店)']},
#  {'一推': 'GO STAY dining room',
#   '關聯推': ['宇田家', '雄雄食社', '新營糖廠', '香格里拉台南遠東大飯店-遠東Cafe', '花見宇治抹茶甘味処']},
#  {'一推': 'DACOZ! 大口吃',
#   '關聯推': ['大億麗緻-風尚庭園咖啡下午茶',
#           '小南蕨 Le Petit Baron',
#           'Felicità 費尼希卡義式冰淇淋',
#           '冰ㄉ• かき氷',
#           'Perfume Dance 跳舞香水(南紡門店)']}]

# %%
import pprint

dienVec={dien['name']:dien['featurescores'] for dien in bigtable if dien['style']=='異國料理' or dien['style']=='鍋類'
         or dien['name'] in RedCutBuildDien500_5}
RedCutBuild=[{'一推':dien,'關聯推':list(checksim(dien,dienVec,N=5).keys())} for dien in RedCutBuildDien500_5]

# %%
print('赤崁樓[甜點飲料>主餐]')
pprint.pprint(RedCutBuild)
# Out:
# 赤崁樓[甜點飲料>主餐]
# [{'一推': '蘇格蕾法式甜點 Le Sucré Pâtisserie',
#   '關聯推': ["Alleycat's 手工窯烤披薩(南紡夢時代)",
#           '彭峇莊園阿根廷碳烤創意料理',
#           'Lazy Day CAFE',
#           '台南雲象泰式餐廳',
#           '逗點咖啡館']},
#  {'一推': '小象樹義式冰淇淋',
#   '關聯推': ['双生 Shuànsên Cafe',
#           '小星星義大利城堡(青年店)',
#           '麗瓷咖啡',
#           '麻豆驢子廚房民宿',
#           'IORO TEA HOUSE']},
#  {'一推': '花見宇治抹茶甘味処',
#   '關聯推': ['歐培拉(台南店)', '台糖長榮酒店', '漢來海港自助餐廳', 'A WEEK PANCAKE&COFFEE', '鯊嗑海鮮鍋物']},
#  {'一推': '吳萬春蜜餞(武廟店)', '關聯推': ['麻布廚房', '菓爾Pasta', 'Staykids', '小倆口', '月見溪創意餐廳']},
#  {'一推': '自己的房間',
#   '關聯推': ['大億麗緻酒店-共同市場歐亞自助餐廳',
#           'Picturesque 塗鴉空間書店',
#           'ici cafe',
#           '香格里拉台南遠東大飯店-醉月樓',
#           '義麵愛PASTA LOVE']},
#  {'一推': '禮物水果',
#   '關聯推': ['歐納牛排館', '綠橄欖義大利麵', '飛饗創意西式料理', 'Angry Burger  美式餐廳', '上海華都小吃']},
#  {'一推': '冰ㄉ• かき氷 no.2',
#   '關聯推': ['六百番', '毛房 蔥柚鍋', '聯盈發點心專門店', '九旺燒臘', '旺季麻辣鴛鴦火鍋']}]

# %%
import pprint
dienVec={dien['name']:dien['featurescores'] for dien in bigtable  if dien['style']=='飲品'
         or dien['name'] in GodRoadDien500_5}
GodRoad=[{'一推':dien,'關聯推':list(checksim(dien,dienVec,N=5).keys())} for dien in GodRoadDien500_5]

# %%
print('神農路海安路[小吃>飲品]')
pprint.pprint(GodRoad)
# Out:
# 神農路海安路[小吃>飲品]
# [{'一推': '老夫子牛肉麵(旗艦總店)',
#   '關聯推': ['老胡記', '好味乾拌麵', '許家芋粿', '御私藏鮮奶茶專賣店(安平店)', 'La Bottega coffee']},
#  {'一推': '好味乾拌麵',
#   '關聯推': ['老夫子牛肉麵(旗艦總店)', '老胡記', 'HIH CAFE', '醋頭家', 'Apt.slow 慢公寓']},
#  {'一推': '許家芋粿', '關聯推': ['江水號', '義豐阿川冬瓜茶', '懷舊小棧', '阿卿傳統飲品‧冰品', '義豐冬瓜茶']},
#  {'一推': '阿湯哥手工米麻糬',
#   '關聯推': ['台南艾咖啡', '義豐冬瓜茶(安平店)', '台南冰品', '幸の町 雪花冰專門店', 'YANA cafe 人拿咖啡吧']},
#  {'一推': '阿銘牛肉麵', '關聯推': ['歐風館', '丸作食茶', '棻園cafe', '咖啡平方隨行吧(東安店)', '東山老家咖啡']},
#  {'一推': '鯨吞燒 串燒酒場(海安總本店)',
#   '關聯推': ['卡加米亞咖啡', '小茶壺鴛鴦鮮奶茶', '波哥(台南誠品店)', '1982 Life House', '明卿蝦仁飯']},
#  {'一推': '明卿蝦仁飯', '關聯推': ['茶桶複合式餐飲', '茗香臺', '江水號', '樂茶棧', '137 Bookstore 咖啡館']}]
