# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
#找頁數
url="https://www.pixiv.net/search.php?s_mode=s_tag&word=%E9%87%8E%E7%94%9F%E3%81%AE%E4%BA%AC%E3%82%A2%E3%83%8B"
cookie="p_ab_id=7; p_ab_id_2=1; login_ever=yes; _ga=GA1.2.1030753389.1497925276; PHPSESSID=1147676_205a3b0106c0ca4d252ca119b14c8fba; module_orders_mypage=%5B%7B%22name%22%3A%22recommended_illusts%22%2C%22visible%22%3Atrue%7D%2C%7B%22name%22%3A%22everyone_new_illusts%22%2C%22visible%22%3Atrue%7D%2C%7B%22name%22%3A%22following_new_illusts%22%2C%22visible%22%3Atrue%7D%2C%7B%22name%22%3A%22mypixiv_new_illusts%22%2C%22visible%22%3Atrue%7D%2C%7B%22name%22%3A%22fanbox%22%2C%22visible%22%3Atrue%7D%2C%7B%22name%22%3A%22featured_tags%22%2C%22visible%22%3Atrue%7D%2C%7B%22name%22%3A%22contests%22%2C%22visible%22%3Atrue%7D%2C%7B%22name%22%3A%22sensei_courses%22%2C%22visible%22%3Atrue%7D%2C%7B%22name%22%3A%22spotlight%22%2C%22visible%22%3Atrue%7D%2C%7B%22name%22%3A%22booth_follow_items%22%2C%22visible%22%3Atrue%7D%5D; is_sensei_service_user=1; __utmt=1; user_language=zh_tw; __utma=235335808.1030753389.1497925276.1504772322.1505367023.28; __utmb=235335808.11.9.1505367098576; __utmc=235335808; __utmz=235335808.1502114180.25.5.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __utmv=235335808.|2=login%20ever=yes=1^3=plan=normal=1^5=gender=male=1^6=user_id=1147676=1^9=p_ab_id=7=1^10=p_ab_id_2=1=1^11=lang=zh_tw=1"
cookies={}
for i in cookie.split(";"):
    cookies[i.split("=")[0]]=i.split("=")[1]
res=requests.get(url,cookies=cookies)
import math
page=math.ceil(int(res.text.split('class="count-badge">')[1].split("件</span></div><div")[0])/20)
page
# Out:
# 26

# %%
for i in range(0,page):
    url='https://www.pixiv.net/search.php?word=%E9%87%8E%E7%94%9F%E3%81%AE%E4%BA%AC%E3%82%A2%E3%83%8B&order=date_d&p='+str(i)
    res=requests.get(url,cookies=cookies)

# %%
url='https://www.pixiv.net/search.php?word=%E9%87%8E%E7%94%9F%E3%81%AE%E4%BA%AC%E3%82%A2%E3%83%8B&order=date_d&p=1'
res=requests.get(url,cookies=cookies)

# %%
soup=bs(res.text,'lxml')
soup.select('div')
#js-mount-point-search-result-list > div > div:nth-child(1) > figure > div > a
# Out:
# [<div class="layout-wrapper"><h1 class="title header-logo"><div id="logoMap"><iframe allowtransparency="true" frameborder="0" height="50" marginheight="0" marginwidth="0" name="logo_side" scrolling="no" src="https://d.pixiv.org/show?zone_id=logo_side&amp;segments=noseg&amp;format=html&amp;pla_referer_page_name=pixiv_search&amp;K=280717a95c4&amp;ab_test_digits_first=7&amp;ab_test_digits_second=1&amp;num=59ba198c223" width="185"></iframe></div><a class="_icon sprites-logo" href="/">pixiv</a></h1><nav class="link-list"><ul><li class="link-item"><strong><a href="/premium.php?ref=header" style="color: #ff7e48;">Premium</a></strong></li><li class="link-item"><a class="header-help" href="/help.php">幫助</a></li><li class="link-item settings-menu"><a class="label header-settings" href="/setting_user.php">設置 ▾</a><ul class="items"><li><a class="item" href="/setting_user.php">用戶設置</a></li><li><a class="item" href="/setting_profile.php">設置個人資料</a></li><li><a class="item" href="/setting_info.php">
# ...

# %%
import pprint
pprint.pprint(soup)
# Out:
# <!DOCTYPE html>
# <!-- https://bugbounty.jp/program/0602f8c6f136dbbd92fbb909 --><html class="" lang="zh-tw" xmlns:wb="http://open.weibo.com/wb">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=970" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="pixiv" property="og:site_name"/>
# <meta content="140810032656374" property="fb:app_id"/>
# <meta content="4fd391fccdb49500" property="wb:webmaster"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="@pixiv" property="twitter:site"/>
# <meta content="「野生の京アニ」の人気イラストやマンガ・画像 | pixiv" property="twitter:title"/>
# <meta content="" property="twitter:image"/>
# <meta content="「野生の京アニ」に関する作品は517件投稿されています。" property="twitter:description"/>
# <meta content="https://source.pixiv.net/www/images/pixiv_logo.gif?2" property="twitter:image"/>
# <meta content="「野生の京アニ」の人気イラストやマンガ・画像 | pixiv" property="og:title"/>
# ...
