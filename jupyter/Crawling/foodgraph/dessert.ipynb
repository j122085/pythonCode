# %%
from bs4 import BeautifulSoup as bs
import requests
cookiestr='_gat=1; csrftoken=cVEgUGjnOu3DhMOPh5X3rUqmXxFcL3be; _ga=GA1.2.2111595002.1501148586; _gid=GA1.2.84699404.1501546628; _uetsid=_uetcc25b886; lbdat=%7B%22p%22%3A%22s%22%2C%22d%22%3A0%2C%22h%22%3A%227dd8300cadac511e530df69fb4bb919d%22%7D; search_history="[\"steak\"\054 \"dessert\"]"; sessionid=omtimfqsvpan4meaqrmromzcoc1gyanm; __ar_v4=MYZACBLRAJG3DFH3ROJLR3%3A20170726%3A8%7CQDZS7DMIYZF4JLPDDSIWUI%3A20170726%3A13%7CSNVTE2A4SZH6ZALVP4FKVA%3A20170726%3A13%7CFS6XYTV3UZEFZAUICSAC5S%3A20170726%3A5; lrpp=50'
cookies=cookiestr.split(";")
cookiedata={}
for cookie in cookies:
    cookiedata[cookie.split("=")[0]]=cookie.split("=")[1]

res = requests.get("http://www.fotosearch.com/photos-images/dessert.html",cookies=cookiedata)
pages=int(res.text.split('</span><span class="pageCount">')[1].split('</span></span><div class="next sp_paging btn btn-info" >')[0].replace(",",""))
res.close()

alllist=[]
# for page in range(1,pages+1):
for page in range(1,200):
    url='http://www.fotosearch.com/photos-images/dessert_%i.html'%page
#     print('http://www.fotosearch.com/photos-images/steak_%i.html'%page)
    res = requests.get(url,cookies=cookiedata)
    print(res.status_code)
    soup=bs(res.text,"lxml")
    res.close()
    pagelist=['http://www.fotosearch.com'+href["href"] for href in soup.select('div.imgresults > div > a')]
    alllist+=pagelist
    
alllist
listgraph=','.join(alllist)
with open("./dessertgraphlist.txt","w") as f:
    f.write(listgraph)
##leftcontainer > div.imgresults > div:nth-child(1) > a
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
import json
import math
import re
import time
import multiprocessing as mp
import concurrent.futures
import urllib.request
from bs4 import BeautifulSoup as bs
import requests
import csv
import os



def getGraphGo(url):
    if not os.path.exists('./dessert/'+url.replace("/","").split("com")[1]+'.jpg'):
        res=requests.get(url,cookies=cookiedata)

        res.close()
        soup=bs(res.text,'lxml')
        for i in soup.select("#qv1"):
            res2=requests.get(i['src'])
            with open('./dessert/'+url.replace("/","").split("com")[1]+'.jpg','wb') as f:
                f.write(res2.content)
            res2.close()          



if not os.path.exists('./dessert'):
    os.makedirs('dessert')
with open("./dessertgraphlist.txt") as f:
    a=csv.reader(f)
    urls=[url for url in a][0]
cookiestr='_gat=1; csrftoken=cVEgUGjnOu3DhMOPh5X3rUqmXxFcL3be; _ga=GA1.2.2111595002.1501148586; _gid=GA1.2.84699404.1501546628; _uetsid=_uetcc25b886; lbdat=%7B%22p%22%3A%22s%22%2C%22d%22%3A0%2C%22h%22%3A%227dd8300cadac511e530df69fb4bb919d%22%7D; search_history="[\"steak\"\054 \"dessert\"]"; sessionid=omtimfqsvpan4meaqrmromzcoc1gyanm; __ar_v4=MYZACBLRAJG3DFH3ROJLR3%3A20170726%3A8%7CQDZS7DMIYZF4JLPDDSIWUI%3A20170726%3A13%7CSNVTE2A4SZH6ZALVP4FKVA%3A20170726%3A13%7CFS6XYTV3UZEFZAUICSAC5S%3A20170726%3A5; lrpp=50'
cookies=cookiestr.split(";")
cookiedata={}
for cookie in cookies:
    cookiedata[cookie.split("=")[0]]=cookie.split("=")[1] 

dataList=[]
start = time.time()
with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
    graph = [executor.submit(getGraphGo, url) for url in urls]
    for future in concurrent.futures.as_completed(graph):
        try:
            data = future.result()
        except Exception as e:
            print(e)
            print("zzz")
            pass
        
end = time.time()  
print("-----------------")
print(end-start)
# Out:
# -----------------
# 3683.1680068969727

# %%
# import json
# import math
# import re
# import time
# import multiprocessing as mp
# import concurrent.futures
# import urllib.request
# from bs4 import BeautifulSoup as bs
# import requests
# import csv
# import io
# if not os.path.exists('./steak'):
#     os.makedirs('steak')


# with open("./steakgraphlist.txt") as f:
#     a=csv.reader(f)
#     urls=[url for url in a][0]
# cookiestr='__ar_v4=FS6XYTV3UZEFZAUICSAC5S%3A20170726%3A1%7CSNVTE2A4SZH6ZALVP4FKVA%3A20170726%3A2%7CQDZS7DMIYZF4JLPDDSIWUI%3A20170726%3A2%7CMYZACBLRAJG3DFH3ROJLR3%3A20170726%3A1; _gat=1; csrftoken=cVEgUGjnOu3DhMOPh5X3rUqmXxFcL3be; _ga=GA1.2.2111595002.1501148586; _gid=GA1.2.1236875034.1501148586; _uetsid=_uet91cbc8f7; lbdat=%7B%22p%22%3A%22s%22%2C%22d%22%3A0%2C%22h%22%3A%227dd8300cadac511e530df69fb4bb919d%22%7D; search_history="[\"steak\"]"; sessionid=omtimfqsvpan4meaqrmromzcoc1gyanm; lrpp=21'
# cookies=cookiestr.split(";")
# cookiedata={}
# for cookie in cookies:
#     cookiedata[cookie.split("=")[0]]=cookie.split("=")[1] 
# for url in urls:
#     if not os.path.exists('./steak/'+url.replace("/","").split("com")[1]+'.jpg'):
#         res=requests.get(url,cookies=cookiedata)

#         res.close()
#         soup=bs(res.text,'lxml')
#         for i in soup.select("#qv1"):
#             res2=requests.get(i['src'])
#             print(res2.status_code)
#             with open('./steak/'+url.replace("/","").split("com")[1]+'.jpg','wb') as f:
#                 f.write(res2.content)
#             res2.close()
    

    
##qv1
    
# with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
#     jobInfo = [executor.submit(getJobInfo, url) for url in dataLink
    
# dataList=[]
# start = time.time()
# with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
#     jobInfo = [executor.submit(<function that we should do>, <url>) for url in <urllist>]
#     for future in concurrent.futures.as_completed(jobInfo):
#         try:
#             data = future.result()
#             dataList.append(data)
#         except Exception as e:
#             print(e)
#             print("zzz")
#             pass
        
# end = time.time()  
# print("-----------------")
# print(end-start)
# Out:
# 200
# 200
# 200
# 200
# 200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-fafd93ec2acd> in <module>()
#      29         soup=bs(res.text,'lxml')
#      30         for i in soup.select("#qv1"):
# ---> 31             res2=requests.get(i['src'])
#      32             print(res2.status_code)
#      33             with open('./steak/'+url.replace("/","").split("com")[1]+'.jpg','wb') as f:
#
# D:\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# D:\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ...

# %%
# graph[0]
# Out:
# <Future at 0x8179da0 state=finished returned NoneType>

# %%
# def getGraphGo(url):
#     if not os.path.exists('./steak/'+url.replace("/","").split("com")[1]+'.jpg'):
#         res=requests.get(url,cookies=cookiedata)

#         res.close()
#         soup=bs(res.text,'lxml')
#         for i in soup.select("#qv1"):
#             res2=requests.get(i['src'])
#             with open('./steak/'+url.replace("/","").split("com")[1]+'.jpg','wb') as f:
#                 f.write(res2.content)
#             res2.close()
